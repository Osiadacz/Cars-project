# %% [markdown]
# ## Imports

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import urllib.parse
import time

# %%
# create dataframe (in the beginning it is empty)
df_cars = pd.DataFrame(columns=['New_used', 'Title', 'Mileage', 'Exterior_color', 'Interior_color', 'Drivetrain', 'Fuel_type', 'Transmission', 'Engine', 
                                'Comfort', 'Interior_design', 'Performance', 'Value_for_money', 'Exterior_styling', 'Reliability', 'Overall_score',
                                'Seller_score', 'Price', 'url'])

# Sequence of numbers - 1 to 475 (476 is not included)
for i in range(1,476):
    time.sleep(1)
    
    # variable for pages within website
    website = 'https://www.cars.com/shopping/results/?page='+str(i)+'&page_size=20&list_price_max=&makes[]=bmw&maximum_distance=all&maximum_distance_expanded=1&maximum_distance_expanded_from=all&models[]=&stock_type=new&zip='
    
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.121 Safari/537.36'}
    
    # request
    response = requests.get(website, headers=headers)
    
    # create soup object
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # result
    result = soup.find_all('div', {'phx-hook':'VehicleCard'})
    
    # we combine url part no. 1 with url part no. 2 in order to get the absolute url
    url_part_1 = 'https://www.cars.com'
    
    url_part_2 = []

    # Loop through the results
    for item in result:
        # Loop through links
        for link in item.find_all('a', {'class':'vehicle-card-link js-gallery-click-link'}):
            url_part_2.append(link.get('href'))
            
    url_joined = []

    for link_2 in url_part_2:
        url_joined.append(urllib.parse.urljoin(url_part_1, link_2))
        
    for link in url_joined:
        time.sleep(0.5)
        
        response = requests.get(link, headers=headers)
        
        # create soup object
        soup = BeautifulSoup(response.content, 'html.parser')
        
        # New_used
        try:
            new_used = soup.find('p', {'class':'new-used'}).get_text()
        except:
            new_used = 'n/a'
            
        # Title
        try:
            title = soup.find('h1', {'class':'listing-title'}).get_text()
        except:
            title = 'n/a'
            
        # Mileage
        try:
            mileage = soup.find('div', {'class':'listing-mileage'}).get_text()
        except:
            mileage = 'n/a'
            
        # Exterior_color
        try:
            ext_color = soup.findAll({'dd'})
            a = ext_color[0].get_text()
        except:
            a = 'n/a'
        
        # Interior_color
        try:
            int_color = soup.findAll({'dd'})
            b = int_color[1].get_text()
        except:
            b = 'n/a'
            
        # Drivetrain
        try:
            drivetrain = soup.findAll({'dd'})
            c = drivetrain[2].get_text()
        except:
            c = 'n/a'
        
        # Fuel_type
        try:
            fuel_type = soup.findAll({'dd'})
            d = fuel_type[4].get_text()
        except:
            d = 'n/a'
        
        # Transmission
        try:
            transmission = soup.findAll({'dd'})
            e = transmission[5].get_text()
        except:
            e = 'n/a'
        
        # Engine
        try:
            engine = soup.findAll({'dd'})
            f = engine[6].get_text()
        except:
            f = 'n/a'
        
        # Comfort
        try:
            comfort = soup.findAll('span', {'class':'sds-definition-list__value'})
            g = comfort[0].get_text()
        except:
            g = 'n/a'
        
        # Interior_design
        try:
            int_des = soup.findAll('span', {'class':'sds-definition-list__value'})
            h = int_des[1].get_text()
        except:
            h = 'n/a'
        
        # Performance
        try:
            performance = soup.findAll('span', {'class':'sds-definition-list__value'})
            i = performance[2].get_text()
        except:
            i = 'n/a'
        
        # Value_for_money
        try:
            vfm = soup.findAll('span', {'class':'sds-definition-list__value'})
            j = vfm[3].get_text()
        except:
            j = 'n/a'
        
        # Exterior_styling
        try:
            ext_sty = soup.findAll('span', {'class':'sds-definition-list__value'})
            k = ext_sty[4].get_text()
        except:
            k = 'n/a'
        
        # Reliability
        try:
            reliability = soup.findAll('span', {'class':'sds-definition-list__value'})
            l = reliability[5].get_text()
        except:
            l = 'n/a'
        
        # Overall_score
        try:
            os = soup.findAll('span', {'class':'sds-rating__count'})
            m = os[1].get_text()
        except:
            m = 'n/a'
        
        # Seller_score
        try:
            ss = soup.findAll('span', {'class':'sds-rating__count'})
            n = ss[0].get_text()
        except:
            n = 'n/a'
        
        # Price
        try:
            price = soup.find('span', {'class':'primary-price'}).get_text()
        except:
            price = 'n/a'
            
        # Pandas DataFrame
        df_cars = df_cars.append({'New_used': new_used, 'Title': title, 'Mileage': mileage, 'Exterior_color': a, 'Interior_color': b, 'Drivetrain': c, 'Fuel_type': d,
                                  'Transmission': e, 'Engine': f, 'Comfort': g, 'Interior_design': h, 'Performance': i, 'Value_for_money': j, 'Exterior_styling': k,
                                  'Reliability': l, 'Overall_score': m, 'Seller_score': n, 'Price': price, 'url': link}, ignore_index=True)

# %%
df_cars
# Out:
#      New_used                      Title  Mileage  \
# 0         New      2023 BMW X7 xDrive40i    0 mi.
# 1         New             2023 BMW 230 i   22 mi.
# 2         New   2022 BMW 540 540i xDrive    5 mi.
# 3         New               2023 BMW M5    16 mi.
# 4         New  2022 BMW ALPINA B7 xDrive   15 mi.
# ...       ...                        ...      ...
# 9488      New           2023 BMW M5 Base    9 mi.
# 9489      New      2023 BMW X3 sDrive30i
# 9490      New           2023 BMW X4 M40i
# 9491      New      2023 BMW X7 xDrive40i
# 9492      New      2023 BMW X5 xDrive40i   25 mi.
#
#                     Exterior_color  Interior_color          Drivetrain  \
# 0                    Alpine White          Coffee     All-wheel Drive
# 1          Mineral White Metallic           Beige    Rear-wheel Drive
# 2          Dark Graphite Metallic           Mocha     All-wheel Drive
# 3      Tanzanite Blue Ii Metallic    Aragon Brown     All-wheel Drive
# 4                    Alpine White           Black     All-wheel Drive
# ...                            ...             ...                 ...
# 9488      Black Sapphire Metallic               –                 AWD
# 9489                         Gray           Black                 RWD
# 9490                       Alpine          Cognac                 AWD
# 9491      Black Sapphire Metallic           Black     All-wheel Drive
# 9492                         Blue           Black     All-wheel Drive
#
#       Fuel_type       Transmission  \
# 0     Gasoline           Automatic
# 1     Gasoline   8-Speed Automatic
# 2       Hybrid           Automatic
# 3     Gasoline           Automatic
# 4     Gasoline   8-Speed Automatic
# ...         ...                ...
# 9488  Gasoline           Automatic
# 9489  Gasoline   8-Speed Automatic
# 9490  Gasoline   8-Speed Automatic
# 9491  Gasoline   8-Speed Automatic
# 9492  Gasoline   8-Speed Automatic
#
#                                             Engine Comfort Interior_design  \
# 0                       3.0L I6 24V GDI DOHC Turbo     5.0             5.0
# 1                       2.0L I4 16V GDI DOHC Turbo     n/a             n/a
# 2     Intercooled Turbo Gas/Electric I-6 3.0 L/183     n/a             n/a
# 3        Twin Turbo Premium Unleaded V-8 4.4 L/268     n/a             n/a
# 4                  4.4L V8 32V GDI DOHC Twin Turbo     n/a             n/a
# ...                                            ...     ...             ...
# 9488               4.4L V8 32V GDI DOHC Twin Turbo     n/a             n/a
# 9489                    2.0L I4 16V GDI DOHC Turbo     n/a             n/a
# 9490                    3.0L I6 24V GDI DOHC Turbo       —               —
# 9491                    3.0L I6 24V GDI DOHC Turbo     5.0             5.0
# 9492                    3.0L I6 24V GDI DOHC Turbo     n/a             n/a
#
#      Performance Value_for_money Exterior_styling Reliability Overall_score  \
# 0            5.0             4.0              5.0         5.0           4.9
# 1            n/a             n/a              n/a         n/a           n/a
# 2            n/a             n/a              n/a         n/a           n/a
# 3            n/a             n/a              n/a         n/a           n/a
# 4            n/a             n/a              n/a         n/a           n/a
# ...          ...             ...              ...         ...           ...
# 9488         n/a             n/a              n/a         n/a           n/a
# 9489         n/a             n/a              n/a         n/a           n/a
# 9490           —               —                —           —           n/a
# 9491         5.0             4.0              5.0         5.0           4.9
# 9492         n/a             n/a              n/a         n/a           5.0
#
#      Seller_score       Price  \
# 0             4.6     $83,195
# 1             3.7     $42,820
# 2             4.5     $73,385
# 3             4.5    $130,495
# 4             4.8    $151,345
# ...           ...         ...
# 9488          4.4  Not Priced
# 9489          4.6     $52,665
# 9490          4.6     $68,015
# 9491          4.6     $88,845
# 9492          5.0     $77,805
#
#                                                     url
# 0     https://www.cars.com/vehicledetail/eb664a9d-ec...
# 1     https://www.cars.com/vehicledetail/3741ed2b-64...
# 2     https://www.cars.com/vehicledetail/d90981ab-92...
# 3     https://www.cars.com/vehicledetail/6799c36c-2d...
# 4     https://www.cars.com/vehicledetail/d1f3533e-50...
# ...                                                 ...
# 9488  https://www.cars.com/vehicledetail/f8a18332-e0...
# 9489  https://www.cars.com/vehicledetail/820da616-98...
# 9490  https://www.cars.com/vehicledetail/81a4f504-62...
# 9491  https://www.cars.com/vehicledetail/aa798804-82...
# 9492  https://www.cars.com/vehicledetail/1eaa7792-9c...
#
# [9493 rows x 19 columns]

# %%
df = df_cars

# %% [markdown]
# ### Add a new column with the brand of the cars

# %%
df['Brand'] = 'BMW'

# %%
df.head()
# Out:
#   New_used                      Title  Mileage                Exterior_color  \
# 0      New      2023 BMW X7 xDrive40i    0 mi.                 Alpine White
# 1      New             2023 BMW 230 i   22 mi.       Mineral White Metallic
# 2      New   2022 BMW 540 540i xDrive    5 mi.       Dark Graphite Metallic
# 3      New               2023 BMW M5    16 mi.   Tanzanite Blue Ii Metallic
# 4      New  2022 BMW ALPINA B7 xDrive   15 mi.                 Alpine White
#
#    Interior_color          Drivetrain  Fuel_type       Transmission  \
# 0         Coffee     All-wheel Drive   Gasoline           Automatic
# 1          Beige    Rear-wheel Drive   Gasoline   8-Speed Automatic
# 2          Mocha     All-wheel Drive     Hybrid           Automatic
# 3   Aragon Brown     All-wheel Drive   Gasoline           Automatic
# 4          Black     All-wheel Drive   Gasoline   8-Speed Automatic
#
#                                          Engine Comfort Interior_design  \
# 0                    3.0L I6 24V GDI DOHC Turbo     5.0             5.0
# 1                    2.0L I4 16V GDI DOHC Turbo     n/a             n/a
# 2  Intercooled Turbo Gas/Electric I-6 3.0 L/183     n/a             n/a
# 3     Twin Turbo Premium Unleaded V-8 4.4 L/268     n/a             n/a
# 4               4.4L V8 32V GDI DOHC Twin Turbo     n/a             n/a
#
#   Performance Value_for_money Exterior_styling Reliability Overall_score  \
# 0         5.0             4.0              5.0         5.0           4.9
# 1         n/a             n/a              n/a         n/a           n/a
# 2         n/a             n/a              n/a         n/a           n/a
# 3         n/a             n/a              n/a         n/a           n/a
# 4         n/a             n/a              n/a         n/a           n/a
#
#   Seller_score     Price                                                url  \
# 0          4.6   $83,195  https://www.cars.com/vehicledetail/eb664a9d-ec...
# 1          3.7   $42,820  https://www.cars.com/vehicledetail/3741ed2b-64...
# 2          4.5   $73,385  https://www.cars.com/vehicledetail/d90981ab-92...
# 3          4.5  $130,495  https://www.cars.com/vehicledetail/6799c36c-2d...
# 4          4.8  $151,345  https://www.cars.com/vehicledetail/d1f3533e-50...
#
#   Brand
# 0   BMW
# 1   BMW
# 2   BMW
# 3   BMW
# 4   BMW

# %% [markdown]
# ### Store in Excel

# %%
df.to_excel(r'E:\Proyects\Python proyects\WEBSCRAPING\Project_CV_Cars\5-cars_new_BMW_5-10-2022.xlsx', index=False)
