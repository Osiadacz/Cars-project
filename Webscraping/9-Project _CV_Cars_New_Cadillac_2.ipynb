# %% [markdown]
# ## Imports

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import urllib.parse
import time

# %%
# create dataframe (in the beginning it is empty)
df_cars = pd.DataFrame(columns=['New_used', 'Title', 'Mileage', 'Exterior_color', 'Interior_color', 'Drivetrain', 'Fuel_type', 'Transmission', 'Engine', 
                                'Comfort', 'Interior_design', 'Performance', 'Value_for_money', 'Exterior_styling', 'Reliability', 'Overall_score',
                                'Seller_score', 'Price', 'url'])

# Sequence of numbers - 1 to 500 (501 is not included)
for i in range(1,501):
    time.sleep(1)
    
    # variable for pages within website
    website = 'https://www.cars.com/shopping/results/?page='+str(i)+'&page_size=20&list_price_max=&makes[]=cadillac&maximum_distance=all&models[]=&stock_type=new&zip='
    
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.121 Safari/537.36'}
    
    # request
    response = requests.get(website, headers=headers)
    
    # create soup object
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # result
    result = soup.find_all('div', {'phx-hook':'VehicleCard'})
    
    # we combine url part no. 1 with url part no. 2 in order to get the absolute url
    url_part_1 = 'https://www.cars.com'
    
    url_part_2 = []

    # Loop through the results
    for item in result:
        # Loop through links
        for link in item.find_all('a', {'class':'vehicle-card-link js-gallery-click-link'}):
            url_part_2.append(link.get('href'))
            
    url_joined = []

    for link_2 in url_part_2:
        url_joined.append(urllib.parse.urljoin(url_part_1, link_2))
        
    for link in url_joined:
        time.sleep(1)
        
        response = requests.get(link, headers=headers)
        
        # create soup object
        soup = BeautifulSoup(response.content, 'html.parser')
        
        # New_used
        try:
            new_used = soup.find('p', {'class':'new-used'}).get_text()
        except:
            new_used = 'n/a'
            
        # Title
        try:
            title = soup.find('h1', {'class':'listing-title'}).get_text()
        except:
            title = 'n/a'
            
        # Mileage
        try:
            mileage = soup.find('div', {'class':'listing-mileage'}).get_text()
        except:
            mileage = 'n/a'
            
        # Exterior_color
        try:
            ext_color = soup.findAll({'dd'})
            a = ext_color[0].get_text()
        except:
            a = 'n/a'
        
        # Interior_color
        try:
            int_color = soup.findAll({'dd'})
            b = int_color[1].get_text()
        except:
            b = 'n/a'
            
        # Drivetrain
        try:
            drivetrain = soup.findAll({'dd'})
            c = drivetrain[2].get_text()
        except:
            c = 'n/a'
        
        # Fuel_type
        try:
            fuel_type = soup.findAll({'dd'})
            d = fuel_type[4].get_text()
        except:
            d = 'n/a'
        
        # Transmission
        try:
            transmission = soup.findAll({'dd'})
            e = transmission[5].get_text()
        except:
            e = 'n/a'
        
        # Engine
        try:
            engine = soup.findAll({'dd'})
            f = engine[6].get_text()
        except:
            f = 'n/a'
        
        # Comfort
        try:
            comfort = soup.findAll('span', {'class':'sds-definition-list__value'})
            g = comfort[0].get_text()
        except:
            g = 'n/a'
        
        # Interior_design
        try:
            int_des = soup.findAll('span', {'class':'sds-definition-list__value'})
            h = int_des[1].get_text()
        except:
            h = 'n/a'
        
        # Performance
        try:
            performance = soup.findAll('span', {'class':'sds-definition-list__value'})
            i = performance[2].get_text()
        except:
            i = 'n/a'
        
        # Value_for_money
        try:
            vfm = soup.findAll('span', {'class':'sds-definition-list__value'})
            j = vfm[3].get_text()
        except:
            j = 'n/a'
        
        # Exterior_styling
        try:
            ext_sty = soup.findAll('span', {'class':'sds-definition-list__value'})
            k = ext_sty[4].get_text()
        except:
            k = 'n/a'
        
        # Reliability
        try:
            reliability = soup.findAll('span', {'class':'sds-definition-list__value'})
            l = reliability[5].get_text()
        except:
            l = 'n/a'
        
        # Overall_score
        try:
            os = soup.findAll('span', {'class':'sds-rating__count'})
            m = os[1].get_text()
        except:
            m = 'n/a'
        
        # Seller_score
        try:
            ss = soup.findAll('span', {'class':'sds-rating__count'})
            n = ss[0].get_text()
        except:
            n = 'n/a'
        
        # Price
        try:
            price = soup.find('span', {'class':'primary-price'}).get_text()
        except:
            price = 'n/a'
            
        # Pandas DataFrame
        df_cars = df_cars.append({'New_used': new_used, 'Title': title, 'Mileage': mileage, 'Exterior_color': a, 'Interior_color': b, 'Drivetrain': c, 'Fuel_type': d,
                                  'Transmission': e, 'Engine': f, 'Comfort': g, 'Interior_design': h, 'Performance': i, 'Value_for_money': j, 'Exterior_styling': k,
                                  'Reliability': l, 'Overall_score': m, 'Seller_score': n, 'Price': price, 'url': link}, ignore_index=True)

# %%
df_cars
# Out:
#      New_used                                      Title  Mileage  \
# 0         New     2022 Cadillac CT4-V V-Series Blackwing   20 mi.
# 1         New  2023 Cadillac Escalade ESV Sport Platinum    0 mi.
# 2         New  2023 Cadillac Escalade ESV Sport Platinum    0 mi.
# 3         New      2023 Cadillac Escalade Premium Luxury    0 mi.
# 4         New      2023 Cadillac Escalade Premium Luxury   10 mi.
# ...       ...                                        ...      ...
# 9924      New           2023 Cadillac XT4 Premium Luxury
# 9925      New           2023 Cadillac XT5 Premium Luxury   22 mi.
# 9926      New           2023 Cadillac XT5 Premium Luxury   23 mi.
# 9927      New      2022 Cadillac Escalade Sport Platinum    0 mi.
# 9928      New       2022 Cadillac CT5 Premium Luxury RWD    3 mi.
#
#                 Exterior_color    Interior_color          Drivetrain  \
# 0               Wave Metallic     Sky Cool Gray    Rear-wheel Drive
# 1       Dark Emerald Metallic         Jet Black    Four-wheel Drive
# 2       Crystal White Tricoat         Jet Black    Four-wheel Drive
# 3      Crystal White Tri-Coat         Jet Black                 4WD
# 4                 Black Raven             Black    Four-wheel Drive
# ...                        ...               ...                 ...
# 9924   Galactic Gray Metallic             Black     All-wheel Drive
# 9925   Stellar Black Metallic             Black     All-wheel Drive
# 9926          Wilder Metallic    Sedona Sauvage     All-wheel Drive
# 9927   Crystal White Tri-Coat       Dark Auburn    Four-wheel Drive
# 9928        Infrared Tintcoat       Maple Sugar    Rear-wheel Drive
#
#       Fuel_type                       Transmission  \
# 0     Gasoline                      6-Speed Manual
# 1     Gasoline                           Automatic
# 2     Gasoline                           Automatic
# 3     Gasoline                           Automatic
# 4       Diesel   10-Speed Automatic with Overdrive
# ...         ...                                ...
# 9924  Gasoline                   9-Speed Automatic
# 9925  Gasoline                   9-Speed Automatic
# 9926  Gasoline                   9-Speed Automatic
# 9927  Gasoline                           Automatic
# 9928  Gasoline                  10-Speed Automatic
#
#                                  Engine Comfort Interior_design Performance  \
# 0       3.6L V6 24V GDI DOHC Twin Turbo     n/a             n/a         n/a
# 1                       Gas V8 6.2L/375     n/a             n/a         n/a
# 2                       Gas V8 6.2L/375     n/a             n/a         n/a
# 3                   6.2L V8 16V GDI OHV     n/a             n/a         n/a
# 4     3.0L I6 24V DDI DOHC Turbo Diesel     n/a             n/a         n/a
# ...                                 ...     ...             ...         ...
# 9924         2.0L I4 16V GDI DOHC Turbo     5.0             5.0         5.0
# 9925               3.6L V6 24V GDI DOHC     n/a             n/a         n/a
# 9926         2.0L I4 16V GDI DOHC Turbo     n/a             n/a         n/a
# 9927                6.2L V8 16V GDI OHV     4.5             4.2         4.0
# 9928         2.0L I4 16V GDI DOHC Turbo     4.5             4.5         5.0
#
#      Value_for_money Exterior_styling Reliability Overall_score Seller_score  \
# 0                n/a              n/a         n/a           n/a          4.5
# 1                n/a              n/a         n/a           n/a          4.7
# 2                n/a              n/a         n/a           n/a          4.7
# 3                n/a              n/a         n/a           n/a          4.7
# 4                n/a              n/a         n/a           n/a          4.3
# ...              ...              ...         ...           ...          ...
# 9924             5.0              5.0         5.0           5.0          5.0
# 9925             n/a              n/a         n/a           n/a          4.8
# 9926             n/a              n/a         n/a           n/a          4.8
# 9927             4.0              4.2         4.5           4.2          4.4
# 9928             4.0              5.0         4.0           4.6          4.7
#
#            Price                                                url
# 0        $68,760  https://www.cars.com/vehicledetail/068a3d06-ab...
# 1       $122,040  https://www.cars.com/vehicledetail/585fda0c-a3...
# 2       $120,540  https://www.cars.com/vehicledetail/1166eeb9-4d...
# 3       $100,865  https://www.cars.com/vehicledetail/d69f7b95-53...
# 4        $94,885  https://www.cars.com/vehicledetail/ce51ed65-a0...
# ...          ...                                                ...
# 9924  Not Priced  https://www.cars.com/vehicledetail/f7a966b2-64...
# 9925  Not Priced  https://www.cars.com/vehicledetail/4bbd2498-c6...
# 9926  Not Priced  https://www.cars.com/vehicledetail/1ba5fc0c-5a...
# 9927  Not Priced  https://www.cars.com/vehicledetail/4d961065-34...
# 9928  Not Priced  https://www.cars.com/vehicledetail/180b0df4-8e...
#
# [9929 rows x 19 columns]

# %%
df = df_cars

# %% [markdown]
# ### Add a new column with the brand of the cars

# %%
df['Brand'] = 'Cadillac'

# %%
df.head()
# Out:
#   New_used                                      Title  Mileage  \
# 0      New     2022 Cadillac CT4-V V-Series Blackwing   20 mi.
# 1      New  2023 Cadillac Escalade ESV Sport Platinum    0 mi.
# 2      New  2023 Cadillac Escalade ESV Sport Platinum    0 mi.
# 3      New      2023 Cadillac Escalade Premium Luxury    0 mi.
# 4      New      2023 Cadillac Escalade Premium Luxury   10 mi.
#
#              Exterior_color   Interior_color          Drivetrain  Fuel_type  \
# 0            Wave Metallic    Sky Cool Gray    Rear-wheel Drive   Gasoline
# 1    Dark Emerald Metallic        Jet Black    Four-wheel Drive   Gasoline
# 2    Crystal White Tricoat        Jet Black    Four-wheel Drive   Gasoline
# 3   Crystal White Tri-Coat        Jet Black                 4WD   Gasoline
# 4              Black Raven            Black    Four-wheel Drive     Diesel
#
#                         Transmission                             Engine  \
# 0                     6-Speed Manual    3.6L V6 24V GDI DOHC Twin Turbo
# 1                          Automatic                    Gas V8 6.2L/375
# 2                          Automatic                    Gas V8 6.2L/375
# 3                          Automatic                6.2L V8 16V GDI OHV
# 4  10-Speed Automatic with Overdrive  3.0L I6 24V DDI DOHC Turbo Diesel
#
#   Comfort Interior_design Performance Value_for_money Exterior_styling  \
# 0     n/a             n/a         n/a             n/a              n/a
# 1     n/a             n/a         n/a             n/a              n/a
# 2     n/a             n/a         n/a             n/a              n/a
# 3     n/a             n/a         n/a             n/a              n/a
# 4     n/a             n/a         n/a             n/a              n/a
#
#   Reliability Overall_score Seller_score     Price  \
# 0         n/a           n/a          4.5   $68,760
# 1         n/a           n/a          4.7  $122,040
# 2         n/a           n/a          4.7  $120,540
# 3         n/a           n/a          4.7  $100,865
# 4         n/a           n/a          4.3   $94,885
#
#                                                  url     Brand
# 0  https://www.cars.com/vehicledetail/068a3d06-ab...  Cadillac
# 1  https://www.cars.com/vehicledetail/585fda0c-a3...  Cadillac
# 2  https://www.cars.com/vehicledetail/1166eeb9-4d...  Cadillac
# 3  https://www.cars.com/vehicledetail/d69f7b95-53...  Cadillac
# 4  https://www.cars.com/vehicledetail/ce51ed65-a0...  Cadillac

# %% [markdown]
# ### Store in Excel

# %%
df.to_excel(r'E:\Proyects\Python proyects\WEBSCRAPING\Project_CV_Cars\9-cars_new_Cadillac_9-10-2022.xlsx', index=False)
