# %% [markdown]
# ## Imports

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import urllib.parse
import time

# %%
# create dataframe (in the beginning it is empty)
df_cars = pd.DataFrame(columns=['New_used', 'Title', 'Mileage', 'Exterior_color', 'Interior_color', 'Drivetrain', 'Fuel_type', 'Transmission', 'Engine', 
                                'Comfort', 'Interior_design', 'Performance', 'Value_for_money', 'Exterior_styling', 'Reliability', 'Overall_score',
                                'Seller_score', 'Price', 'url'])

# Sequence of numbers - 1 to 500 (501 is not included)
for i in range(1,501):
    time.sleep(1)
    
    # variable for pages within website
    website = 'https://www.cars.com/shopping/results/?page='+str(i)+'&page_size=20&list_price_max=&makes[]=audi&maximum_distance=20&models[]=&stock_type=used&zip='
    
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.121 Safari/537.36'}
    
    # request
    response = requests.get(website, headers=headers)
    
    # create soup object
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # result
    result = soup.find_all('div', {'phx-hook':'VehicleCard'})
    
    # we combine url part no. 1 with url part no. 2 in order to get the absolute url
    url_part_1 = 'https://www.cars.com'
    
    url_part_2 = []

    # Loop through the results
    for item in result:
        # Loop through links
        for link in item.find_all('a', {'class':'vehicle-card-link js-gallery-click-link'}):
            url_part_2.append(link.get('href'))
            
    url_joined = []

    for link_2 in url_part_2:
        url_joined.append(urllib.parse.urljoin(url_part_1, link_2))
        
    for link in url_joined:
        time.sleep(0.5)
        
        response = requests.get(link, headers=headers)
        
        # create soup object
        soup = BeautifulSoup(response.content, 'html.parser')
        
        # New_used
        try:
            new_used = soup.find('p', {'class':'new-used'}).get_text()
        except:
            new_used = 'n/a'
            
        # Title
        try:
            title = soup.find('h1', {'class':'listing-title'}).get_text()
        except:
            title = 'n/a'
            
        # Mileage
        try:
            mileage = soup.find('div', {'class':'listing-mileage'}).get_text()
        except:
            mileage = 'n/a'
            
        # Exterior_color
        try:
            ext_color = soup.findAll({'dd'})
            a = ext_color[0].get_text()
        except:
            a = 'n/a'
        
        # Interior_color
        try:
            int_color = soup.findAll({'dd'})
            b = int_color[1].get_text()
        except:
            b = 'n/a'
            
        # Drivetrain
        try:
            drivetrain = soup.findAll({'dd'})
            c = drivetrain[2].get_text()
        except:
            c = 'n/a'
        
        # Fuel_type
        try:
            fuel_type = soup.findAll({'dd'})
            d = fuel_type[4].get_text()
        except:
            d = 'n/a'
        
        # Transmission
        try:
            transmission = soup.findAll({'dd'})
            e = transmission[5].get_text()
        except:
            e = 'n/a'
        
        # Engine
        try:
            engine = soup.findAll({'dd'})
            f = engine[6].get_text()
        except:
            f = 'n/a'
        
        # Comfort
        try:
            comfort = soup.findAll('span', {'class':'sds-definition-list__value'})
            g = comfort[0].get_text()
        except:
            g = 'n/a'
        
        # Interior_design
        try:
            int_des = soup.findAll('span', {'class':'sds-definition-list__value'})
            h = int_des[1].get_text()
        except:
            h = 'n/a'
        
        # Performance
        try:
            performance = soup.findAll('span', {'class':'sds-definition-list__value'})
            i = performance[2].get_text()
        except:
            i = 'n/a'
        
        # Value_for_money
        try:
            vfm = soup.findAll('span', {'class':'sds-definition-list__value'})
            j = vfm[3].get_text()
        except:
            j = 'n/a'
        
        # Exterior_styling
        try:
            ext_sty = soup.findAll('span', {'class':'sds-definition-list__value'})
            k = ext_sty[4].get_text()
        except:
            k = 'n/a'
        
        # Reliability
        try:
            reliability = soup.findAll('span', {'class':'sds-definition-list__value'})
            l = reliability[5].get_text()
        except:
            l = 'n/a'
        
        # Overall_score
        try:
            os = soup.findAll('span', {'class':'sds-rating__count'})
            m = os[1].get_text()
        except:
            m = 'n/a'
        
        # Seller_score
        try:
            ss = soup.findAll('span', {'class':'sds-rating__count'})
            n = ss[0].get_text()
        except:
            n = 'n/a'
        
        # Price
        try:
            price = soup.find('span', {'class':'primary-price'}).get_text()
        except:
            price = 'n/a'
            
        # Pandas DataFrame
        df_cars = df_cars.append({'New_used': new_used, 'Title': title, 'Mileage': mileage, 'Exterior_color': a, 'Interior_color': b, 'Drivetrain': c, 'Fuel_type': d,
                                  'Transmission': e, 'Engine': f, 'Comfort': g, 'Interior_design': h, 'Performance': i, 'Value_for_money': j, 'Exterior_styling': k,
                                  'Reliability': l, 'Overall_score': m, 'Seller_score': n, 'Price': price, 'url': link}, ignore_index=True)

# %%
df_cars
# Out:
#      New_used                                   Title       Mileage  \
# 0        Used                    2021 Audi TT RS 2.5T     3,680 mi.
# 1        Used               2020 Audi A5 2.0T Premium    24,694 mi.
# 2        Used          2015 Audi A6 3.0T Premium Plus    87,780 mi.
# 3        Used              2013 Audi S6 4.0T Prestige    44,607 mi.
# 4        Used  2012 Audi A7 3.0T Premium Plus quattro    54,178 mi.
# ...       ...                                     ...           ...
# 9955     Used          2019 Audi A4 2.0T Premium Plus    47,630 mi.
# 9956     Used          2015 Audi A5 2.0T Premium Plus   105,868 mi.
# 9957     Used                2021 Audi e-tron Premium    13,772 mi.
# 9958     Used                     2015 Audi A8 L 4.0T    71,583 mi.
# 9959     Used                2008 Audi A6 3.2 quattro   136,899 mi.
#
#                 Exterior_color         Interior_color         Drivetrain  \
# 0       Mythos Black Metallic    Black / Express Red    All-wheel Drive
# 1       Mythos Black Metallic                  Black    All-wheel Drive
# 2      Havanna Black Metallic                      –    All-wheel Drive
# 3                       Other                  Black    All-wheel Drive
# 4                        Gray                  Black    All-wheel Drive
# ...                        ...                    ...                ...
# 9955   Glacier White Metallic                  Black    All-wheel Drive
# 9956                     Gray                  Black    All-wheel Drive
# 9957    Typhoon Gray Metallic                  Black    All-wheel Drive
# 9958    Cuvee Silver Metallic           Velvet Beige    All-wheel Drive
# 9959         Night Blue Pearl                    Tan    All-wheel Drive
#
#               Fuel_type                       Transmission  \
# 0             Gasoline   7-Speed Automatic with Auto-Shift
# 1             Gasoline   7-Speed Automatic with Auto-Shift
# 2             Gasoline                   8-Speed Automatic
# 3             Gasoline                         7-SPEED A/T
# 4             Gasoline                   8-Speed Automatic
# ...                 ...                                ...
# 9955          Gasoline   7-Speed Automatic with Auto-Shift
# 9956     E85 Flex Fuel                   8-Speed Automatic
# 9957  1-Speed Automatic                           Electric
# 9958          Gasoline                   8-Speed Automatic
# 9959          Gasoline                   6-Speed Automatic
#
#                                         Engine Comfort Interior_design  \
# 0                   2.5L I5 20V PDI DOHC Turbo     4.0             5.0
# 1                   2.0L I4 16V GDI DOHC Turbo     5.0             5.0
# 2            3.0L V6 24V GDI DOHC Supercharged     4.7             4.8
# 3                            8 Cylinder Engine     4.5             4.9
# 4            3.0L V6 24V GDI DOHC Supercharged     4.7             4.7
# ...                                        ...     ...             ...
# 9955                2.0L I4 16V GDI DOHC Turbo     5.0             4.9
# 9956  2.0L I4 16V GDI DOHC Turbo Flexible Fuel     4.8             4.7
# 9957                        WA1AAAGE8MB030361      5.0             5.0
# 9958           4.0L V8 32V GDI DOHC Twin Turbo     5.0             4.9
# 9959                      3.1L V6 24V GDI DOHC     4.7             4.7
#
#      Performance Value_for_money Exterior_styling Reliability Overall_score  \
# 0            5.0             5.0              5.0         5.0           5.0
# 1            5.0             5.0              5.0         5.0           5.0
# 2            4.8             4.5              4.8         4.6           4.7
# 3            4.6             4.5              4.5         4.5           5.0
# 4            4.6             4.2              4.9         4.5           4.6
# ...          ...             ...              ...         ...           ...
# 9955         4.7             4.5              4.7         4.8           4.8
# 9956         4.7             4.6              4.9         4.9           4.7
# 9957         5.0             5.0              5.0         5.0           5.0
# 9958         4.8             4.7              4.8         4.7           4.8
# 9959         4.5             4.6              4.6         4.5           4.6
#
#      Seller_score    Price                                                url
# 0             4.5  $78,899  https://www.cars.com/vehicledetail/5464edc6-0c...
# 1             4.6  $41,880  https://www.cars.com/vehicledetail/15fab1d7-97...
# 2             4.6  $19,946  https://www.cars.com/vehicledetail/594940ad-65...
# 3             4.6  $31,200  https://www.cars.com/vehicledetail/a3ff24cf-96...
# 4             3.6  $24,850  https://www.cars.com/vehicledetail/b9392220-5f...
# ...           ...      ...                                                ...
# 9955          4.7  $31,991  https://www.cars.com/vehicledetail/aa4e9806-36...
# 9956          3.9  $20,995  https://www.cars.com/vehicledetail/e0b1dc22-c9...
# 9957          4.6  $64,992  https://www.cars.com/vehicledetail/375c05f1-ef...
# 9958          3.4  $29,988  https://www.cars.com/vehicledetail/904c19be-1b...
# 9959          3.9   $7,999  https://www.cars.com/vehicledetail/93bc5344-06...
#
# [9960 rows x 19 columns]

# %%
df = df_cars

# %% [markdown]
# ### Add a new column with the brand of the cars

# %%
df['Brand'] = 'Audi'

# %%
df.head()
# Out:
#   New_used                                   Title      Mileage  \
# 0     Used                    2021 Audi TT RS 2.5T    3,680 mi.
# 1     Used               2020 Audi A5 2.0T Premium   24,694 mi.
# 2     Used          2015 Audi A6 3.0T Premium Plus   87,780 mi.
# 3     Used              2013 Audi S6 4.0T Prestige   44,607 mi.
# 4     Used  2012 Audi A7 3.0T Premium Plus quattro   54,178 mi.
#
#              Exterior_color         Interior_color         Drivetrain  \
# 0    Mythos Black Metallic    Black / Express Red    All-wheel Drive
# 1    Mythos Black Metallic                  Black    All-wheel Drive
# 2   Havanna Black Metallic                      –    All-wheel Drive
# 3                    Other                  Black    All-wheel Drive
# 4                     Gray                  Black    All-wheel Drive
#
#    Fuel_type                       Transmission  \
# 0  Gasoline   7-Speed Automatic with Auto-Shift
# 1  Gasoline   7-Speed Automatic with Auto-Shift
# 2  Gasoline                   8-Speed Automatic
# 3  Gasoline                         7-SPEED A/T
# 4  Gasoline                   8-Speed Automatic
#
#                               Engine Comfort Interior_design Performance  \
# 0         2.5L I5 20V PDI DOHC Turbo     4.0             5.0         5.0
# 1         2.0L I4 16V GDI DOHC Turbo     5.0             5.0         5.0
# 2  3.0L V6 24V GDI DOHC Supercharged     4.7             4.8         4.8
# 3                  8 Cylinder Engine     4.5             4.9         4.6
# 4  3.0L V6 24V GDI DOHC Supercharged     4.7             4.7         4.6
#
#   Value_for_money Exterior_styling Reliability Overall_score Seller_score  \
# 0             5.0              5.0         5.0           5.0          4.5
# 1             5.0              5.0         5.0           5.0          4.6
# 2             4.5              4.8         4.6           4.7          4.6
# 3             4.5              4.5         4.5           5.0          4.6
# 4             4.2              4.9         4.5           4.6          3.6
#
#      Price                                                url Brand
# 0  $78,899  https://www.cars.com/vehicledetail/5464edc6-0c...  Audi
# 1  $41,880  https://www.cars.com/vehicledetail/15fab1d7-97...  Audi
# 2  $19,946  https://www.cars.com/vehicledetail/594940ad-65...  Audi
# 3  $31,200  https://www.cars.com/vehicledetail/a3ff24cf-96...  Audi
# 4  $24,850  https://www.cars.com/vehicledetail/b9392220-5f...  Audi

# %% [markdown]
# ### Store in Excel

# %%
df.to_excel(r'E:\Proyects\Python proyects\WEBSCRAPING\Project_CV_Cars\4-cars_used_Audi_5-10-2022.xlsx', index=False)
