# %% [markdown]
# ## Imports

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import urllib.parse
import time

# %%
# create dataframe (in the beginning it is empty)
df_cars = pd.DataFrame(columns=['New_used', 'Title', 'Mileage', 'Exterior_color', 'Interior_color', 'Drivetrain', 'Fuel_type', 'Transmission', 'Engine', 
                                'Comfort', 'Interior_design', 'Performance', 'Value_for_money', 'Exterior_styling', 'Reliability', 'Overall_score',
                                'Seller_score', 'Price', 'url'])

# Sequence of numbers - 1 to 127 (128 is not included)
for i in range(1,128):
    time.sleep(1)
    
    # variable for pages within website
    website = 'https://www.cars.com/shopping/results/?page='+str(i)+'&page_size=20&list_price_max=&makes[]=chrysler&maximum_distance=all&models[]=&stock_type=new&zip='
    
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.121 Safari/537.36'}
    
    # request
    response = requests.get(website, headers=headers)
    
    # create soup object
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # result
    result = soup.find_all('div', {'phx-hook':'VehicleCard'})
    
    # we combine url part no. 1 with url part no. 2 in order to get the absolute url
    url_part_1 = 'https://www.cars.com'
    
    url_part_2 = []

    # Loop through the results
    for item in result:
        # Loop through links
        for link in item.find_all('a', {'class':'vehicle-card-link js-gallery-click-link'}):
            url_part_2.append(link.get('href'))
            
    url_joined = []

    for link_2 in url_part_2:
        url_joined.append(urllib.parse.urljoin(url_part_1, link_2))
        
    for link in url_joined:
        time.sleep(1)
        
        response = requests.get(link, headers=headers)
        
        # create soup object
        soup = BeautifulSoup(response.content, 'html.parser')
        
        # New_used
        try:
            new_used = soup.find('p', {'class':'new-used'}).get_text()
        except:
            new_used = 'n/a'
            
        # Title
        try:
            title = soup.find('h1', {'class':'listing-title'}).get_text()
        except:
            title = 'n/a'
            
        # Mileage
        try:
            mileage = soup.find('div', {'class':'listing-mileage'}).get_text()
        except:
            mileage = 'n/a'
            
        # Exterior_color
        try:
            ext_color = soup.findAll({'dd'})
            a = ext_color[0].get_text()
        except:
            a = 'n/a'
        
        # Interior_color
        try:
            int_color = soup.findAll({'dd'})
            b = int_color[1].get_text()
        except:
            b = 'n/a'
            
        # Drivetrain
        try:
            drivetrain = soup.findAll({'dd'})
            c = drivetrain[2].get_text()
        except:
            c = 'n/a'
        
        # Fuel_type
        try:
            fuel_type = soup.findAll({'dd'})
            d = fuel_type[4].get_text()
        except:
            d = 'n/a'
        
        # Transmission
        try:
            transmission = soup.findAll({'dd'})
            e = transmission[5].get_text()
        except:
            e = 'n/a'
        
        # Engine
        try:
            engine = soup.findAll({'dd'})
            f = engine[6].get_text()
        except:
            f = 'n/a'
        
        # Comfort
        try:
            comfort = soup.findAll('span', {'class':'sds-definition-list__value'})
            g = comfort[0].get_text()
        except:
            g = 'n/a'
        
        # Interior_design
        try:
            int_des = soup.findAll('span', {'class':'sds-definition-list__value'})
            h = int_des[1].get_text()
        except:
            h = 'n/a'
        
        # Performance
        try:
            performance = soup.findAll('span', {'class':'sds-definition-list__value'})
            i = performance[2].get_text()
        except:
            i = 'n/a'
        
        # Value_for_money
        try:
            vfm = soup.findAll('span', {'class':'sds-definition-list__value'})
            j = vfm[3].get_text()
        except:
            j = 'n/a'
        
        # Exterior_styling
        try:
            ext_sty = soup.findAll('span', {'class':'sds-definition-list__value'})
            k = ext_sty[4].get_text()
        except:
            k = 'n/a'
        
        # Reliability
        try:
            reliability = soup.findAll('span', {'class':'sds-definition-list__value'})
            l = reliability[5].get_text()
        except:
            l = 'n/a'
        
        # Overall_score
        try:
            os = soup.findAll('span', {'class':'sds-rating__count'})
            m = os[1].get_text()
        except:
            m = 'n/a'
        
        # Seller_score
        try:
            ss = soup.findAll('span', {'class':'sds-rating__count'})
            n = ss[0].get_text()
        except:
            n = 'n/a'
        
        # Price
        try:
            price = soup.find('span', {'class':'primary-price'}).get_text()
        except:
            price = 'n/a'
            
        # Pandas DataFrame
        df_cars = df_cars.append({'New_used': new_used, 'Title': title, 'Mileage': mileage, 'Exterior_color': a, 'Interior_color': b, 'Drivetrain': c, 'Fuel_type': d,
                                  'Transmission': e, 'Engine': f, 'Comfort': g, 'Interior_design': h, 'Performance': i, 'Value_for_money': j, 'Exterior_styling': k,
                                  'Reliability': l, 'Overall_score': m, 'Seller_score': n, 'Price': price, 'url': link}, ignore_index=True)

# %%
df_cars
# Out:
#      New_used                                    Title  Mileage  \
# 0         New  2022 Chrysler Pacifica Hybrid Touring L
# 1         New                      2022 Chrysler 300 S   10 mi.
# 2         New              2022 Chrysler 300 Touring L    0 mi.
# 3         New                2022 Chrysler 300 Touring    8 mi.
# 4         New          2022 Chrysler Pacifica Pinnacle
# ...       ...                                      ...      ...
# 2501      New         2022 Chrysler Pacifica Touring-L    2 mi.
# 2502      New  2022 Chrysler Pacifica Hybrid Touring L   10 mi.
# 2503      New         2022 Chrysler Pacifica Touring-L
# 2504      New              2022 Chrysler 300 Touring L   30 mi.
# 2505      New                2022 Chrysler 300 Touring    0 mi.
#
#                            Exterior_color Interior_color           Drivetrain  \
# 0                 Ceramic Gray Clearcoat          Black    Front-wheel Drive
# 1                  Silver Mist Clearcoat          Black     Rear-wheel Drive
# 2                 Bright White Clearcoat          Black      All-wheel Drive
# 3                 Bright White Clearcoat          Black      All-wheel Drive
# 4      Brilliant Black Crystal Pearlcoat          Black    Front-wheel Drive
# ...                                   ...            ...                  ...
# 2501              Bright White Clearcoat          Black                  AWD
# 2502              Ceramic Gray Clearcoat          Black                  FWD
# 2503              Bright White Clearcoat          Black                  AWD
# 2504              Bright White Clearcoat          Black     Rear-wheel Drive
# 2505                Velvet Red Pearlcoat          Black     Rear-wheel Drive
#
#       Fuel_type       Transmission                          Engine Comfort  \
# 0       Hybrid       Automatic CVT    3.6L V6 24V MPFI DOHC Hybrid     n/a
# 1     Gasoline   8-Speed Automatic            5.7L V8 16V MPFI OHV     5.0
# 2     Gasoline   8-Speed Automatic           3.6L V6 24V MPFI DOHC     5.0
# 3     Gasoline   8-Speed Automatic              V6 Cylinder Engine     5.0
# 4     Gasoline   9-Speed Automatic           3.6L V6 24V MPFI DOHC     4.5
# ...         ...                ...                             ...     ...
# 2501  Gasoline           Automatic           3.6L V6 24V MPFI DOHC     4.5
# 2502    Hybrid       Automatic CVT    3.6L V6 24V MPFI DOHC Hybrid     n/a
# 2503  Gasoline   9-Speed Automatic           3.6L V6 24V MPFI DOHC     4.5
# 2504  Gasoline   8-Speed Automatic           3.6L V6 24V MPFI DOHC     5.0
# 2505  Gasoline           Automatic  Regular Unleaded V-6 3.6 L/220     5.0
#
#      Interior_design Performance Value_for_money Exterior_styling Reliability  \
# 0                n/a         n/a             n/a              n/a         n/a
# 1                5.0         5.0             5.0              5.0         5.0
# 2                5.0         5.0             5.0              5.0         5.0
# 3                5.0         5.0             5.0              5.0         5.0
# 4                4.0         4.0             3.5              3.5         4.5
# ...              ...         ...             ...              ...         ...
# 2501             4.0         4.0             3.5              3.5         4.5
# 2502             n/a         n/a             n/a              n/a         n/a
# 2503             4.0         4.0             3.5              3.5         4.5
# 2504             5.0         5.0             5.0              5.0         5.0
# 2505             5.0         5.0             5.0              5.0         5.0
#
#      Overall_score Seller_score       Price  \
# 0              n/a          4.5     $49,753
# 1              5.0          3.5     $49,225
# 2              5.0          5.0     $48,865
# 3              5.0          3.8     $44,991
# 4              4.0          4.7     $60,567
# ...            ...          ...         ...
# 2501           4.0          2.6  Not Priced
# 2502           5.0          5.0  Not Priced
# 2503           3.7          4.0     $45,128
# 2504           5.0          4.4  Not Priced
# 2505           4.8          4.9  Not Priced
#
#                                                     url
# 0     https://www.cars.com/vehicledetail/540b3cb5-c4...
# 1     https://www.cars.com/vehicledetail/51a11fb3-d1...
# 2     https://www.cars.com/vehicledetail/4c89ad70-d8...
# 3     https://www.cars.com/vehicledetail/36521677-84...
# 4     https://www.cars.com/vehicledetail/f22f4a36-4e...
# ...                                                 ...
# 2501  https://www.cars.com/vehicledetail/2969e325-28...
# 2502  https://www.cars.com/vehicledetail/5fddb644-22...
# 2503  https://www.cars.com/vehicledetail/a83f7eba-5f...
# 2504  https://www.cars.com/vehicledetail/69521e7b-ad...
# 2505  https://www.cars.com/vehicledetail/4683ab47-20...
#
# [2506 rows x 19 columns]

# %%
df = df_cars

# %% [markdown]
# ### Add a new column with the brand of the cars

# %%
df['Brand'] = 'Chrysler'

# %%
df.head()
# Out:
#   New_used                                    Title  Mileage  \
# 0      New  2022 Chrysler Pacifica Hybrid Touring L
# 1      New                      2022 Chrysler 300 S   10 mi.
# 2      New              2022 Chrysler 300 Touring L    0 mi.
# 3      New                2022 Chrysler 300 Touring    8 mi.
# 4      New          2022 Chrysler Pacifica Pinnacle
#
#                         Exterior_color Interior_color           Drivetrain  \
# 0              Ceramic Gray Clearcoat          Black    Front-wheel Drive
# 1               Silver Mist Clearcoat          Black     Rear-wheel Drive
# 2              Bright White Clearcoat          Black      All-wheel Drive
# 3              Bright White Clearcoat          Black      All-wheel Drive
# 4   Brilliant Black Crystal Pearlcoat          Black    Front-wheel Drive
#
#    Fuel_type       Transmission                        Engine Comfort  \
# 0    Hybrid       Automatic CVT  3.6L V6 24V MPFI DOHC Hybrid     n/a
# 1  Gasoline   8-Speed Automatic          5.7L V8 16V MPFI OHV     5.0
# 2  Gasoline   8-Speed Automatic         3.6L V6 24V MPFI DOHC     5.0
# 3  Gasoline   8-Speed Automatic            V6 Cylinder Engine     5.0
# 4  Gasoline   9-Speed Automatic         3.6L V6 24V MPFI DOHC     4.5
#
#   Interior_design Performance Value_for_money Exterior_styling Reliability  \
# 0             n/a         n/a             n/a              n/a         n/a
# 1             5.0         5.0             5.0              5.0         5.0
# 2             5.0         5.0             5.0              5.0         5.0
# 3             5.0         5.0             5.0              5.0         5.0
# 4             4.0         4.0             3.5              3.5         4.5
#
#   Overall_score Seller_score    Price  \
# 0           n/a          4.5  $49,753
# 1           5.0          3.5  $49,225
# 2           5.0          5.0  $48,865
# 3           5.0          3.8  $44,991
# 4           4.0          4.7  $60,567
#
#                                                  url     Brand
# 0  https://www.cars.com/vehicledetail/540b3cb5-c4...  Chrysler
# 1  https://www.cars.com/vehicledetail/51a11fb3-d1...  Chrysler
# 2  https://www.cars.com/vehicledetail/4c89ad70-d8...  Chrysler
# 3  https://www.cars.com/vehicledetail/36521677-84...  Chrysler
# 4  https://www.cars.com/vehicledetail/f22f4a36-4e...  Chrysler

# %% [markdown]
# ### Store in Excel

# %%
df.to_excel(r'E:\Proyects\Python proyects\WEBSCRAPING\Project_CV_Cars\13-cars_new_Chrysler_11-10-2022.xlsx', index=False)
