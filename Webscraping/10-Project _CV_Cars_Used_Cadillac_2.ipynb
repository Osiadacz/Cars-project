# %% [markdown]
# ## Imports

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import urllib.parse
import time

# %%
# create dataframe (in the beginning it is empty)
df_cars = pd.DataFrame(columns=['New_used', 'Title', 'Mileage', 'Exterior_color', 'Interior_color', 'Drivetrain', 'Fuel_type', 'Transmission', 'Engine', 
                                'Comfort', 'Interior_design', 'Performance', 'Value_for_money', 'Exterior_styling', 'Reliability', 'Overall_score',
                                'Seller_score', 'Price', 'url'])

# Sequence of numbers - 1 to 500 (501 is not included)
for i in range(1,501):
    time.sleep(1)
    
    # variable for pages within website
    website = 'https://www.cars.com/shopping/results/?page='+str(i)+'&page_size=20&list_price_max=&makes[]=cadillac&maximum_distance=all&models[]=&stock_type=used&zip='
    
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.121 Safari/537.36'}
    
    # request
    response = requests.get(website, headers=headers)
    
    # create soup object
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # result
    result = soup.find_all('div', {'phx-hook':'VehicleCard'})
    
    # we combine url part no. 1 with url part no. 2 in order to get the absolute url
    url_part_1 = 'https://www.cars.com'
    
    url_part_2 = []

    # Loop through the results
    for item in result:
        # Loop through links
        for link in item.find_all('a', {'class':'vehicle-card-link js-gallery-click-link'}):
            url_part_2.append(link.get('href'))
            
    url_joined = []

    for link_2 in url_part_2:
        url_joined.append(urllib.parse.urljoin(url_part_1, link_2))
        
    for link in url_joined:
        time.sleep(1)
        
        response = requests.get(link, headers=headers)
        
        # create soup object
        soup = BeautifulSoup(response.content, 'html.parser')
        
        # New_used
        try:
            new_used = soup.find('p', {'class':'new-used'}).get_text()
        except:
            new_used = 'n/a'
            
        # Title
        try:
            title = soup.find('h1', {'class':'listing-title'}).get_text()
        except:
            title = 'n/a'
            
        # Mileage
        try:
            mileage = soup.find('div', {'class':'listing-mileage'}).get_text()
        except:
            mileage = 'n/a'
            
        # Exterior_color
        try:
            ext_color = soup.findAll({'dd'})
            a = ext_color[0].get_text()
        except:
            a = 'n/a'
        
        # Interior_color
        try:
            int_color = soup.findAll({'dd'})
            b = int_color[1].get_text()
        except:
            b = 'n/a'
            
        # Drivetrain
        try:
            drivetrain = soup.findAll({'dd'})
            c = drivetrain[2].get_text()
        except:
            c = 'n/a'
        
        # Fuel_type
        try:
            fuel_type = soup.findAll({'dd'})
            d = fuel_type[4].get_text()
        except:
            d = 'n/a'
        
        # Transmission
        try:
            transmission = soup.findAll({'dd'})
            e = transmission[5].get_text()
        except:
            e = 'n/a'
        
        # Engine
        try:
            engine = soup.findAll({'dd'})
            f = engine[6].get_text()
        except:
            f = 'n/a'
        
        # Comfort
        try:
            comfort = soup.findAll('span', {'class':'sds-definition-list__value'})
            g = comfort[0].get_text()
        except:
            g = 'n/a'
        
        # Interior_design
        try:
            int_des = soup.findAll('span', {'class':'sds-definition-list__value'})
            h = int_des[1].get_text()
        except:
            h = 'n/a'
        
        # Performance
        try:
            performance = soup.findAll('span', {'class':'sds-definition-list__value'})
            i = performance[2].get_text()
        except:
            i = 'n/a'
        
        # Value_for_money
        try:
            vfm = soup.findAll('span', {'class':'sds-definition-list__value'})
            j = vfm[3].get_text()
        except:
            j = 'n/a'
        
        # Exterior_styling
        try:
            ext_sty = soup.findAll('span', {'class':'sds-definition-list__value'})
            k = ext_sty[4].get_text()
        except:
            k = 'n/a'
        
        # Reliability
        try:
            reliability = soup.findAll('span', {'class':'sds-definition-list__value'})
            l = reliability[5].get_text()
        except:
            l = 'n/a'
        
        # Overall_score
        try:
            os = soup.findAll('span', {'class':'sds-rating__count'})
            m = os[1].get_text()
        except:
            m = 'n/a'
        
        # Seller_score
        try:
            ss = soup.findAll('span', {'class':'sds-rating__count'})
            n = ss[0].get_text()
        except:
            n = 'n/a'
        
        # Price
        try:
            price = soup.find('span', {'class':'primary-price'}).get_text()
        except:
            price = 'n/a'
            
        # Pandas DataFrame
        df_cars = df_cars.append({'New_used': new_used, 'Title': title, 'Mileage': mileage, 'Exterior_color': a, 'Interior_color': b, 'Drivetrain': c, 'Fuel_type': d,
                                  'Transmission': e, 'Engine': f, 'Comfort': g, 'Interior_design': h, 'Performance': i, 'Value_for_money': j, 'Exterior_styling': k,
                                  'Reliability': l, 'Overall_score': m, 'Seller_score': n, 'Price': price, 'url': link}, ignore_index=True)

# %%
df_cars
# Out:
#      New_used                                     Title       Mileage  \
# 0        Used         2012 Cadillac Escalade ESV Luxury   126,937 mi.
# 1        Used       2018 Cadillac Escalade ESV Platinum    55,697 mi.
# 2        Used           2018 Cadillac CT6 3.6L Standard    25,786 mi.
# 3        Used  2016 Cadillac CT6 3.0L Twin Turbo Luxury    85,149 mi.
# 4        Used      2020 Cadillac CT5 Premium Luxury AWD    18,931 mi.
# ...       ...                                       ...           ...
# 9981     Used             2019 Cadillac Escalade Luxury    24,919 mi.
# 9982     Used             2021 Cadillac Escalade Luxury    21,722 mi.
# 9983     Used     2022 Cadillac Escalade Premium Luxury     3,721 mi.
# 9984     Used     2019 Cadillac Escalade Premium Luxury    26,714 mi.
# 9985     Used           2019 Cadillac Escalade Standard    53,118 mi.
#
#                  Exterior_color   Interior_color          Drivetrain  \
# 0                        Black    Ebony / Ebony     All-wheel Drive
# 1                  Black Raven        Jet Black    Four-wheel Drive
# 2         Bronze Dune Metallic    Light Neutral     All-wheel Drive
# 3                        Black                –     All-wheel Drive
# 4                  Black Raven        Jet Black     All-wheel Drive
# ...                         ...              ...                 ...
# 9981   Radiant Silver Metallic        Jet Black    Rear-wheel Drive
# 9982               Black Raven        Jet Black    Four-wheel Drive
# 9983    Crystal White Tri-Coat                –    Four-wheel Drive
# 9984               Black Raven       Kona Brown    Four-wheel Drive
# 9985           Shadow Metallic            Black    Rear-wheel Drive
#
#            Fuel_type        Transmission                              Engine  \
# 0     E85 Flex Fuel    6-Speed Automatic  6.2L V8 16V MPFI OHV Flexible Fuel
# 1          Gasoline   10-Speed Automatic                 6.2L V8 16V GDI OHV
# 2          Gasoline    8-Speed Automatic                3.6L V6 24V GDI DOHC
# 3          Gasoline    8-Speed Automatic     3.0L V6 24V GDI DOHC Twin Turbo
# 4          Gasoline   10-Speed Automatic          2.0L I4 16V GDI DOHC Turbo
# ...              ...                 ...                                 ...
# 9981       Gasoline   10-Speed Automatic                 6.2L V8 16V GDI OHV
# 9982       Gasoline   10-Speed Automatic                 6.2L V8 16V GDI OHV
# 9983       Gasoline   10-Speed Automatic                 6.2L V8 16V GDI OHV
# 9984       Gasoline   10-Speed Automatic                 6.2L V8 16V GDI OHV
# 9985       Gasoline   10-Speed Automatic                 6.2L V8 16V GDI OHV
#
#      Comfort Interior_design Performance Value_for_money Exterior_styling  \
# 0        5.0             4.9         4.9             4.5              4.9
# 1        5.0             5.0         5.0             4.9              5.0
# 2        4.9             4.8         4.8             4.9              5.0
# 3        4.9             4.9         4.8             4.4              5.0
# 4        4.4             4.3         4.4             4.2              4.4
# ...      ...             ...         ...             ...              ...
# 9981     4.9             4.8         4.9             4.4              4.7
# 9982     3.3             3.9         2.6             2.1              3.7
# 9983     4.5             4.2         4.0             4.0              4.2
# 9984     4.9             4.8         4.9             4.4              4.7
# 9985     4.9             4.8         4.9             4.4              4.7
#
#      Reliability Overall_score Seller_score     Price  \
# 0            5.0           4.9          3.7   $16,999
# 1            4.9           5.0          4.3   $59,220
# 2            4.9           5.0          5.0   $40,918
# 3            4.6           5.0          5.0   $28,900
# 4            4.6           4.4          4.8   $43,000
# ...          ...           ...          ...       ...
# 9981         4.9           4.8          4.7   $54,900
# 9982         2.0           5.0          5.0   $89,999
# 9983         4.5           4.2          4.5  $105,790
# 9984         4.9           4.8          4.5   $62,500
# 9985         4.9           4.8          3.5   $53,500
#
#                                                     url
# 0     https://www.cars.com/vehicledetail/9c4a9fe2-ab...
# 1     https://www.cars.com/vehicledetail/a037180a-f3...
# 2     https://www.cars.com/vehicledetail/f7de5365-0f...
# 3     https://www.cars.com/vehicledetail/9fe84968-40...
# 4     https://www.cars.com/vehicledetail/34f08646-d7...
# ...                                                 ...
# 9981  https://www.cars.com/vehicledetail/a96f7716-40...
# 9982  https://www.cars.com/vehicledetail/7e83ddee-8f...
# 9983  https://www.cars.com/vehicledetail/ca4fb4da-0c...
# 9984  https://www.cars.com/vehicledetail/18754fe7-fd...
# 9985  https://www.cars.com/vehicledetail/1c566864-77...
#
# [9986 rows x 19 columns]

# %%
df = df_cars

# %% [markdown]
# ### Add a new column with the brand of the cars

# %%
df['Brand'] = 'Cadillac'

# %%
df.head()
# Out:
#   New_used                                     Title       Mileage  \
# 0     Used         2012 Cadillac Escalade ESV Luxury   126,937 mi.
# 1     Used       2018 Cadillac Escalade ESV Platinum    55,697 mi.
# 2     Used           2018 Cadillac CT6 3.6L Standard    25,786 mi.
# 3     Used  2016 Cadillac CT6 3.0L Twin Turbo Luxury    85,149 mi.
# 4     Used      2020 Cadillac CT5 Premium Luxury AWD    18,931 mi.
#
#            Exterior_color   Interior_color          Drivetrain  \
# 0                  Black    Ebony / Ebony     All-wheel Drive
# 1            Black Raven        Jet Black    Four-wheel Drive
# 2   Bronze Dune Metallic    Light Neutral     All-wheel Drive
# 3                  Black                –     All-wheel Drive
# 4            Black Raven        Jet Black     All-wheel Drive
#
#         Fuel_type        Transmission                              Engine  \
# 0  E85 Flex Fuel    6-Speed Automatic  6.2L V8 16V MPFI OHV Flexible Fuel
# 1       Gasoline   10-Speed Automatic                 6.2L V8 16V GDI OHV
# 2       Gasoline    8-Speed Automatic                3.6L V6 24V GDI DOHC
# 3       Gasoline    8-Speed Automatic     3.0L V6 24V GDI DOHC Twin Turbo
# 4       Gasoline   10-Speed Automatic          2.0L I4 16V GDI DOHC Turbo
#
#   Comfort Interior_design Performance Value_for_money Exterior_styling  \
# 0     5.0             4.9         4.9             4.5              4.9
# 1     5.0             5.0         5.0             4.9              5.0
# 2     4.9             4.8         4.8             4.9              5.0
# 3     4.9             4.9         4.8             4.4              5.0
# 4     4.4             4.3         4.4             4.2              4.4
#
#   Reliability Overall_score Seller_score    Price  \
# 0         5.0           4.9          3.7  $16,999
# 1         4.9           5.0          4.3  $59,220
# 2         4.9           5.0          5.0  $40,918
# 3         4.6           5.0          5.0  $28,900
# 4         4.6           4.4          4.8  $43,000
#
#                                                  url     Brand
# 0  https://www.cars.com/vehicledetail/9c4a9fe2-ab...  Cadillac
# 1  https://www.cars.com/vehicledetail/a037180a-f3...  Cadillac
# 2  https://www.cars.com/vehicledetail/f7de5365-0f...  Cadillac
# 3  https://www.cars.com/vehicledetail/9fe84968-40...  Cadillac
# 4  https://www.cars.com/vehicledetail/34f08646-d7...  Cadillac

# %% [markdown]
# ### Store in Excel

# %%
df.to_excel(r'E:\Proyects\Python proyects\WEBSCRAPING\Project_CV_Cars\10-cars_used_Cadillac_9-10-2022.xlsx', index=False)
