# %% [markdown]
# ## Imports

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import urllib.parse
import time

# %%
# create dataframe (in the beginning it is empty)
df_cars = pd.DataFrame(columns=['New_used', 'Title', 'Mileage', 'Exterior_color', 'Interior_color', 'Drivetrain', 'Fuel_type', 'Transmission', 'Engine', 
                                'Comfort', 'Interior_design', 'Performance', 'Value_for_money', 'Exterior_styling', 'Reliability', 'Overall_score',
                                'Seller_score', 'Price', 'url'])

# Sequence of numbers - 1 to 500 (501 is not included)
for i in range(1,501):
    time.sleep(1)
    
    # variable for pages within website
    website = 'https://www.cars.com/shopping/results/?page='+str(i)+'&page_size=20&list_price_max=&makes[]=acura&maximum_distance=20&models[]=&stock_type=used&zip='
    
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.121 Safari/537.36'}
    
    # request
    response = requests.get(website, headers=headers)
    
    # create soup object
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # result
    result = soup.find_all('div', {'phx-hook':'VehicleCard'})
    
    # we combine url part no. 1 with url part no. 2 in order to get the absolute url
    url_part_1 = 'https://www.cars.com'
    
    url_part_2 = []

    # Loop through the results
    for item in result:
        # Loop through links
        for link in item.find_all('a', {'class':'vehicle-card-link js-gallery-click-link'}):
            url_part_2.append(link.get('href'))
            
    url_joined = []

    for link_2 in url_part_2:
        url_joined.append(urllib.parse.urljoin(url_part_1, link_2))
        
    for link in url_joined:
        time.sleep(0.5)
        
        response = requests.get(link, headers=headers)
        
        # create soup object
        soup = BeautifulSoup(response.content, 'html.parser')
        
        # New_used
        try:
            new_used = soup.find('p', {'class':'new-used'}).get_text()
        except:
            new_used = 'n/a'
            
        # Title
        try:
            title = soup.find('h1', {'class':'listing-title'}).get_text()
        except:
            title = 'n/a'
            
        # Mileage
        try:
            mileage = soup.find('div', {'class':'listing-mileage'}).get_text()
        except:
            mileage = 'n/a'
            
        # Exterior_color
        try:
            ext_color = soup.findAll({'dd'})
            a = ext_color[0].get_text()
        except:
            a = 'n/a'
        
        # Interior_color
        try:
            int_color = soup.findAll({'dd'})
            b = int_color[1].get_text()
        except:
            b = 'n/a'
            
        # Drivetrain
        try:
            drivetrain = soup.findAll({'dd'})
            c = drivetrain[2].get_text()
        except:
            c = 'n/a'
        
        # Fuel_type
        try:
            fuel_type = soup.findAll({'dd'})
            d = fuel_type[4].get_text()
        except:
            d = 'n/a'
        
        # Transmission
        try:
            transmission = soup.findAll({'dd'})
            e = transmission[5].get_text()
        except:
            e = 'n/a'
        
        # Engine
        try:
            engine = soup.findAll({'dd'})
            f = engine[6].get_text()
        except:
            f = 'n/a'
        
        # Comfort
        try:
            comfort = soup.findAll('span', {'class':'sds-definition-list__value'})
            g = comfort[0].get_text()
        except:
            g = 'n/a'
        
        # Interior_design
        try:
            int_des = soup.findAll('span', {'class':'sds-definition-list__value'})
            h = int_des[1].get_text()
        except:
            h = 'n/a'
        
        # Performance
        try:
            performance = soup.findAll('span', {'class':'sds-definition-list__value'})
            i = performance[2].get_text()
        except:
            i = 'n/a'
        
        # Value_for_money
        try:
            vfm = soup.findAll('span', {'class':'sds-definition-list__value'})
            j = vfm[3].get_text()
        except:
            j = 'n/a'
        
        # Exterior_styling
        try:
            ext_sty = soup.findAll('span', {'class':'sds-definition-list__value'})
            k = ext_sty[4].get_text()
        except:
            k = 'n/a'
        
        # Reliability
        try:
            reliability = soup.findAll('span', {'class':'sds-definition-list__value'})
            l = reliability[5].get_text()
        except:
            l = 'n/a'
        
        # Overall_score
        try:
            os = soup.findAll('span', {'class':'sds-rating__count'})
            m = os[1].get_text()
        except:
            m = 'n/a'
        
        # Seller_score
        try:
            ss = soup.findAll('span', {'class':'sds-rating__count'})
            n = ss[0].get_text()
        except:
            n = 'n/a'
        
        # Price
        try:
            price = soup.find('span', {'class':'primary-price'}).get_text()
        except:
            price = 'n/a'
            
        # Pandas DataFrame
        df_cars = df_cars.append({'New_used': new_used, 'Title': title, 'Mileage': mileage, 'Exterior_color': a, 'Interior_color': b, 'Drivetrain': c, 'Fuel_type': d,
                                  'Transmission': e, 'Engine': f, 'Comfort': g, 'Interior_design': h, 'Performance': i, 'Value_for_money': j, 'Exterior_styling': k,
                                  'Reliability': l, 'Overall_score': m, 'Seller_score': n, 'Price': price, 'url': link}, ignore_index=True)

# %%
df_cars
# Out:
#              New_used                                     Title       Mileage  \
# 0                Used                     2021 Acura RDX A-Spec    21,074 mi.
# 1                Used         2022 Acura RDX Technology Package     8,755 mi.
# 2                Used                    2022 Acura MDX Advance     6,070 mi.
# 3                Used  2020 Acura ILX Premium & A-SPEC Packages    21,038 mi.
# 4     Acura Certified                       2016 Acura ILX 2.4L    33,570 mi.
# ...               ...                                       ...           ...
# 9969             Used               2013 Acura MDX 3.7L Advance   125,687 mi.
# 9970             Used                           1992 Acura NSX    118,795 mi.
# 9971             Used     2020 Acura MDX 3.5L w/Advance Package    52,001 mi.
# 9972             Used     2016 Acura MDX 3.5L w/Advance Package   116,918 mi.
# 9973             Used                   2012 Acura TL Tech Auto   119,000 mi.
#
#                   Exterior_color Interior_color           Drivetrain  \
# 0         Modern Steel Metallic              –      All-wheel Drive
# 1               Performance Red      Parchment      All-wheel Drive
# 2                         Black          Ebony      All-wheel Drive
# 3                          Blue            Red    Front-wheel Drive
# 4           Crystal Black Pearl      Graystone    Front-wheel Drive
# ...                          ...            ...                  ...
# 9969                      White      Parchment      All-wheel Drive
# 9970                        Red          Black     Rear-wheel Drive
# 9971                      Black          Ebony      All-wheel Drive
# 9972   Graphite Luster Metallic          Ebony      All-wheel Drive
# 9973                      White          Black      All-wheel Drive
#
#       Fuel_type                       Transmission  \
# 0     Gasoline                  10-Speed Automatic
# 1     Gasoline                  10-Speed Automatic
# 2     Gasoline                  10-Speed Automatic
# 3     Gasoline   8-Speed Automatic with Auto-Shift
# 4     Gasoline   8-Speed Automatic with Auto-Shift
# ...         ...                                ...
# 9969  Gasoline                   6-Speed Automatic
# 9970  Gasoline                      5-Speed Manual
# 9971  Gasoline                   9-Speed Automatic
# 9972  Gasoline                   9-Speed Automatic
# 9973  Gasoline                           Automatic
#
#                                         Engine Comfort Interior_design  \
# 0                   2.0L I4 16V GDI DOHC Turbo     4.9             4.9
# 1                   2.0L I4 16V GDI DOHC Turbo     5.0             5.0
# 2                         3.5L V6 24V GDI SOHC     4.9             4.8
# 3                         2.4L I4 16V GDI DOHC     4.5             4.6
# 4                         2.4L I4 16V GDI DOHC     4.4             4.2
# ...                                        ...     ...             ...
# 9969                     3.7L V6 24V MPFI SOHC     4.7             4.6
# 9970                     3.0L V6 24V SPFI DOHC     4.8             4.8
# 9971                      3.5L V6 24V GDI SOHC     4.9             4.9
# 9972                      3.5L V6 24V GDI SOHC     4.7             4.5
# 9973  3.7L SOHC PGM-FI 24-valve VTEC V6 engine     4.7             4.7
#
#      Performance Value_for_money Exterior_styling Reliability Overall_score  \
# 0            4.7             4.6              4.9         4.8           4.8
# 1            5.0             5.0              5.0         5.0           4.0
# 2            4.9             4.9              4.9         4.9           4.9
# 3            4.5             4.4              4.7         4.4           4.5
# 4            4.3             4.4              4.5         4.7           4.4
# ...          ...             ...              ...         ...           ...
# 9969         4.7             4.4              4.7         4.7           4.6
# 9970         4.1             4.6              5.0         5.0           4.8
# 9971         4.9             4.8              4.8         4.9           4.9
# 9972         4.5             4.5              4.5         4.6           5.0
# 9973         4.7             4.7              4.7         4.8           4.7
#
#      Seller_score    Price                                                url
# 0             4.5  $42,603  https://www.cars.com/vehicledetail/4495c7bf-39...
# 1             5.0  $46,770  https://www.cars.com/vehicledetail/6ab41ab5-49...
# 2             4.8  $60,500  https://www.cars.com/vehicledetail/2f7a83b5-54...
# 3             4.9  $29,925  https://www.cars.com/vehicledetail/51a57ef1-f2...
# 4             4.1  $22,988  https://www.cars.com/vehicledetail/65e72941-9c...
# ...           ...      ...                                                ...
# 9969          3.4  $17,890  https://www.cars.com/vehicledetail/1043a4a5-f1...
# 9970          4.6  $51,989  https://www.cars.com/vehicledetail/920e7d9f-c4...
# 9971          4.4  $43,715  https://www.cars.com/vehicledetail/e9369d7c-7b...
# 9972          5.0  $23,988  https://www.cars.com/vehicledetail/53b1d64b-7a...
# 9973          3.6  $15,998  https://www.cars.com/vehicledetail/cb928945-13...
#
# [9974 rows x 19 columns]

# %%
df = df_cars

# %% [markdown]
# ### Add a new column with the brand of the cars

# %%
df['Brand'] = 'Acura'

# %%
df.head()
# Out:
#           New_used                                     Title      Mileage  \
# 0             Used                     2021 Acura RDX A-Spec   21,074 mi.
# 1             Used         2022 Acura RDX Technology Package    8,755 mi.
# 2             Used                    2022 Acura MDX Advance    6,070 mi.
# 3             Used  2020 Acura ILX Premium & A-SPEC Packages   21,038 mi.
# 4  Acura Certified                       2016 Acura ILX 2.4L   33,570 mi.
#
#             Exterior_color Interior_color           Drivetrain  Fuel_type  \
# 0   Modern Steel Metallic              –      All-wheel Drive   Gasoline
# 1         Performance Red      Parchment      All-wheel Drive   Gasoline
# 2                   Black          Ebony      All-wheel Drive   Gasoline
# 3                    Blue            Red    Front-wheel Drive   Gasoline
# 4     Crystal Black Pearl      Graystone    Front-wheel Drive   Gasoline
#
#                         Transmission                      Engine Comfort  \
# 0                 10-Speed Automatic  2.0L I4 16V GDI DOHC Turbo     4.9
# 1                 10-Speed Automatic  2.0L I4 16V GDI DOHC Turbo     5.0
# 2                 10-Speed Automatic        3.5L V6 24V GDI SOHC     4.9
# 3  8-Speed Automatic with Auto-Shift        2.4L I4 16V GDI DOHC     4.5
# 4  8-Speed Automatic with Auto-Shift        2.4L I4 16V GDI DOHC     4.4
#
#   Interior_design Performance Value_for_money Exterior_styling Reliability  \
# 0             4.9         4.7             4.6              4.9         4.8
# 1             5.0         5.0             5.0              5.0         5.0
# 2             4.8         4.9             4.9              4.9         4.9
# 3             4.6         4.5             4.4              4.7         4.4
# 4             4.2         4.3             4.4              4.5         4.7
#
#   Overall_score Seller_score    Price  \
# 0           4.8          4.5  $42,603
# 1           4.0          5.0  $46,770
# 2           4.9          4.8  $60,500
# 3           4.5          4.9  $29,925
# 4           4.4          4.1  $22,988
#
#                                                  url  Brand
# 0  https://www.cars.com/vehicledetail/4495c7bf-39...  Acura
# 1  https://www.cars.com/vehicledetail/6ab41ab5-49...  Acura
# 2  https://www.cars.com/vehicledetail/2f7a83b5-54...  Acura
# 3  https://www.cars.com/vehicledetail/51a57ef1-f2...  Acura
# 4  https://www.cars.com/vehicledetail/65e72941-9c...  Acura

# %% [markdown]
# ### Store in Excel

# %%
df.to_excel(r'E:\Proyects\Python proyects\WEBSCRAPING\Project_CV_Cars\2-cars_used_Acura_4-10-2022.xlsx', index=False)
