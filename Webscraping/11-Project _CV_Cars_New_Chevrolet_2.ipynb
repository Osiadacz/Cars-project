# %% [markdown]
# ## Imports

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import urllib.parse
import time

# %%
# create dataframe (in the beginning it is empty)
df_cars = pd.DataFrame(columns=['New_used', 'Title', 'Mileage', 'Exterior_color', 'Interior_color', 'Drivetrain', 'Fuel_type', 'Transmission', 'Engine', 
                                'Comfort', 'Interior_design', 'Performance', 'Value_for_money', 'Exterior_styling', 'Reliability', 'Overall_score',
                                'Seller_score', 'Price', 'url'])

# Sequence of numbers - 1 to 500 (501 is not included)
for i in range(1,501):
    time.sleep(1)
    
    # variable for pages within website
    website = 'https://www.cars.com/shopping/results/?page='+str(i)+'&page_size=20&list_price_max=&makes[]=chevrolet&maximum_distance=all&models[]=&stock_type=new&zip='
    
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.121 Safari/537.36'}
    
    # request
    response = requests.get(website, headers=headers)
    
    # create soup object
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # result
    result = soup.find_all('div', {'phx-hook':'VehicleCard'})
    
    # we combine url part no. 1 with url part no. 2 in order to get the absolute url
    url_part_1 = 'https://www.cars.com'
    
    url_part_2 = []

    # Loop through the results
    for item in result:
        # Loop through links
        for link in item.find_all('a', {'class':'vehicle-card-link js-gallery-click-link'}):
            url_part_2.append(link.get('href'))
            
    url_joined = []

    for link_2 in url_part_2:
        url_joined.append(urllib.parse.urljoin(url_part_1, link_2))
        
    for link in url_joined:
        time.sleep(1)
        
        response = requests.get(link, headers=headers)
        
        # create soup object
        soup = BeautifulSoup(response.content, 'html.parser')
        
        # New_used
        try:
            new_used = soup.find('p', {'class':'new-used'}).get_text()
        except:
            new_used = 'n/a'
            
        # Title
        try:
            title = soup.find('h1', {'class':'listing-title'}).get_text()
        except:
            title = 'n/a'
            
        # Mileage
        try:
            mileage = soup.find('div', {'class':'listing-mileage'}).get_text()
        except:
            mileage = 'n/a'
            
        # Exterior_color
        try:
            ext_color = soup.findAll({'dd'})
            a = ext_color[0].get_text()
        except:
            a = 'n/a'
        
        # Interior_color
        try:
            int_color = soup.findAll({'dd'})
            b = int_color[1].get_text()
        except:
            b = 'n/a'
            
        # Drivetrain
        try:
            drivetrain = soup.findAll({'dd'})
            c = drivetrain[2].get_text()
        except:
            c = 'n/a'
        
        # Fuel_type
        try:
            fuel_type = soup.findAll({'dd'})
            d = fuel_type[4].get_text()
        except:
            d = 'n/a'
        
        # Transmission
        try:
            transmission = soup.findAll({'dd'})
            e = transmission[5].get_text()
        except:
            e = 'n/a'
        
        # Engine
        try:
            engine = soup.findAll({'dd'})
            f = engine[6].get_text()
        except:
            f = 'n/a'
        
        # Comfort
        try:
            comfort = soup.findAll('span', {'class':'sds-definition-list__value'})
            g = comfort[0].get_text()
        except:
            g = 'n/a'
        
        # Interior_design
        try:
            int_des = soup.findAll('span', {'class':'sds-definition-list__value'})
            h = int_des[1].get_text()
        except:
            h = 'n/a'
        
        # Performance
        try:
            performance = soup.findAll('span', {'class':'sds-definition-list__value'})
            i = performance[2].get_text()
        except:
            i = 'n/a'
        
        # Value_for_money
        try:
            vfm = soup.findAll('span', {'class':'sds-definition-list__value'})
            j = vfm[3].get_text()
        except:
            j = 'n/a'
        
        # Exterior_styling
        try:
            ext_sty = soup.findAll('span', {'class':'sds-definition-list__value'})
            k = ext_sty[4].get_text()
        except:
            k = 'n/a'
        
        # Reliability
        try:
            reliability = soup.findAll('span', {'class':'sds-definition-list__value'})
            l = reliability[5].get_text()
        except:
            l = 'n/a'
        
        # Overall_score
        try:
            os = soup.findAll('span', {'class':'sds-rating__count'})
            m = os[1].get_text()
        except:
            m = 'n/a'
        
        # Seller_score
        try:
            ss = soup.findAll('span', {'class':'sds-rating__count'})
            n = ss[0].get_text()
        except:
            n = 'n/a'
        
        # Price
        try:
            price = soup.find('span', {'class':'primary-price'}).get_text()
        except:
            price = 'n/a'
            
        # Pandas DataFrame
        df_cars = df_cars.append({'New_used': new_used, 'Title': title, 'Mileage': mileage, 'Exterior_color': a, 'Interior_color': b, 'Drivetrain': c, 'Fuel_type': d,
                                  'Transmission': e, 'Engine': f, 'Comfort': g, 'Interior_design': h, 'Performance': i, 'Value_for_money': j, 'Exterior_styling': k,
                                  'Reliability': l, 'Overall_score': m, 'Seller_score': n, 'Price': price, 'url': link}, ignore_index=True)

# %%
df_cars
# Out:
#      New_used                                            Title   Mileage  \
# 0         New                        2023 Chevrolet Camaro 2LT     5 mi.
# 1         New                          2023 Chevrolet Tahoe LT    15 mi.
# 2         New                     2023 Chevrolet Tahoe Premier
# 3         New                      2022 Chevrolet Suburban Z71     0 mi.
# 4         New  2022 Chevrolet Silverado 1500 Custom Trail Boss   105 mi.
# ...       ...                                              ...       ...
# 9990      New                    2023 Chevrolet Trailblazer RS    10 mi.
# 9991      New                       2022 Chevrolet Suburban LT    10 mi.
# 9992      New                        2022 Chevrolet Blazer 3LT     7 mi.
# 9993      New                          2023 Chevrolet Tahoe LT    10 mi.
# 9994      New       2023 Chevrolet Silverado 1500 High Country     0 mi.
#
#                   Exterior_color Interior_color           Drivetrain  \
# 0                         Black      Jet Black     Rear-wheel Drive
# 1                  Summit White          Black     Four-wheel Drive
# 2        Midnight Blue Metallic      Jet Black     Four-wheel Drive
# 3                         Black      Jet Black     Four-wheel Drive
# 4           Silver Ice Metallic          Black     Four-wheel Drive
# ...                          ...            ...                  ...
# 9990              Fountain Blue      Jet Black    Front-wheel Drive
# 9991   Iridescent Pearl Tricoat         Gideon                  4WD
# 9992                       Gray      Jet Black    Front-wheel Drive
# 9993   Iridescent Pearl Tricoat      Jet Black     Four-wheel Drive
# 9994   Iridescent Pearl Tricoat      Jet Black                  4WD
#
#       Fuel_type                       Transmission  \
# 0     Gasoline                  10-Speed Automatic
# 1     Gasoline   10-Speed Automatic with Overdrive
# 2       Diesel   10-Speed Automatic with Overdrive
# 3     Gasoline                           Automatic
# 4     Gasoline                  10-Speed Automatic
# ...         ...                                ...
# 9990  Gasoline                       Automatic CVT
# 9991  Gasoline   10-Speed Automatic with Overdrive
# 9992  Gasoline                   9-Speed Automatic
# 9993  Gasoline                           Automatic
# 9994  Gasoline                           Automatic
#
#                                  Engine Comfort Interior_design Performance  \
# 0                      3.6L V6 GDI DOHC     n/a             n/a         n/a
# 1                   5.3L V8 16V GDI OHV     n/a             n/a         n/a
# 2     3.0L I6 24V DDI DOHC Turbo Diesel     n/a             n/a         n/a
# 3                   5.3L V8 16V GDI OHV     5.0             5.0         5.0
# 4                   5.3L V8 16V GDI OHV     5.0             5.0         5.0
# ...                                 ...     ...             ...         ...
# 9990         1.3L I3 12V GDI DOHC Turbo     n/a             n/a         n/a
# 9991                5.3L V8 16V GDI OHV     5.0             5.0         5.0
# 9992               3.6L V6 24V GDI DOHC     4.8             4.8         5.0
# 9993                5.3L V8 16V GDI OHV     n/a             n/a         n/a
# 9994                6.2L V8 16V GDI OHV     n/a             n/a         n/a
#
#      Value_for_money Exterior_styling Reliability Overall_score Seller_score  \
# 0                n/a              n/a         n/a           n/a          4.8
# 1                n/a              n/a         n/a           n/a          4.7
# 2                n/a              n/a         n/a           n/a          4.7
# 3                5.0              5.0         5.0           5.0          4.6
# 4                5.0              5.0         5.0           5.0          5.0
# ...              ...              ...         ...           ...          ...
# 9990             n/a              n/a         n/a           n/a          4.5
# 9991             5.0              5.0         5.0           5.0          4.7
# 9992             4.3              5.0         5.0           4.8          4.5
# 9993             n/a              n/a         n/a           n/a          4.0
# 9994             n/a              n/a         n/a           n/a          4.6
#
#         Price                                                url
# 0     $34,987  https://www.cars.com/vehicledetail/6830ce1c-72...
# 1     $65,985  https://www.cars.com/vehicledetail/e21809c8-19...
# 2     $76,595  https://www.cars.com/vehicledetail/cc7316c9-33...
# 3     $70,290  https://www.cars.com/vehicledetail/0b2a4da6-03...
# 4     $53,540  https://www.cars.com/vehicledetail/4aa827a5-c1...
# ...       ...                                                ...
# 9990  $31,510  https://www.cars.com/vehicledetail/10ec4239-c2...
# 9991  $72,135  https://www.cars.com/vehicledetail/d8402a40-a9...
# 9992  $41,645  https://www.cars.com/vehicledetail/c73507b6-11...
# 9993  $71,880  https://www.cars.com/vehicledetail/766b773b-6e...
# 9994  $75,390  https://www.cars.com/vehicledetail/107fcb2a-31...
#
# [9995 rows x 19 columns]

# %%
df = df_cars

# %% [markdown]
# ### Add a new column with the brand of the cars

# %%
df['Brand'] = 'Chevrolet'

# %%
df.head()
# Out:
#   New_used                                            Title   Mileage  \
# 0      New                        2023 Chevrolet Camaro 2LT     5 mi.
# 1      New                          2023 Chevrolet Tahoe LT    15 mi.
# 2      New                     2023 Chevrolet Tahoe Premier
# 3      New                      2022 Chevrolet Suburban Z71     0 mi.
# 4      New  2022 Chevrolet Silverado 1500 Custom Trail Boss   105 mi.
#
#              Exterior_color Interior_color          Drivetrain  Fuel_type  \
# 0                    Black      Jet Black    Rear-wheel Drive   Gasoline
# 1             Summit White          Black    Four-wheel Drive   Gasoline
# 2   Midnight Blue Metallic      Jet Black    Four-wheel Drive     Diesel
# 3                    Black      Jet Black    Four-wheel Drive   Gasoline
# 4      Silver Ice Metallic          Black    Four-wheel Drive   Gasoline
#
#                         Transmission                             Engine  \
# 0                 10-Speed Automatic                   3.6L V6 GDI DOHC
# 1  10-Speed Automatic with Overdrive                5.3L V8 16V GDI OHV
# 2  10-Speed Automatic with Overdrive  3.0L I6 24V DDI DOHC Turbo Diesel
# 3                          Automatic                5.3L V8 16V GDI OHV
# 4                 10-Speed Automatic                5.3L V8 16V GDI OHV
#
#   Comfort Interior_design Performance Value_for_money Exterior_styling  \
# 0     n/a             n/a         n/a             n/a              n/a
# 1     n/a             n/a         n/a             n/a              n/a
# 2     n/a             n/a         n/a             n/a              n/a
# 3     5.0             5.0         5.0             5.0              5.0
# 4     5.0             5.0         5.0             5.0              5.0
#
#   Reliability Overall_score Seller_score    Price  \
# 0         n/a           n/a          4.8  $34,987
# 1         n/a           n/a          4.7  $65,985
# 2         n/a           n/a          4.7  $76,595
# 3         5.0           5.0          4.6  $70,290
# 4         5.0           5.0          5.0  $53,540
#
#                                                  url      Brand
# 0  https://www.cars.com/vehicledetail/6830ce1c-72...  Chevrolet
# 1  https://www.cars.com/vehicledetail/e21809c8-19...  Chevrolet
# 2  https://www.cars.com/vehicledetail/cc7316c9-33...  Chevrolet
# 3  https://www.cars.com/vehicledetail/0b2a4da6-03...  Chevrolet
# 4  https://www.cars.com/vehicledetail/4aa827a5-c1...  Chevrolet

# %% [markdown]
# ### Store in Excel

# %%
df.to_excel(r'E:\Proyects\Python proyects\WEBSCRAPING\Project_CV_Cars\11-cars_used_Chevrolet_10-10-2022.xlsx', index=False)
