# %% [markdown]
# ## Imports

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import urllib.parse
import time

# %%
# create dataframe (in the beginning it is empty)
df_cars = pd.DataFrame(columns=['New_used', 'Title', 'Mileage', 'Exterior_color', 'Interior_color', 'Drivetrain', 'Fuel_type', 'Transmission', 'Engine', 
                                'Comfort', 'Interior_design', 'Performance', 'Value_for_money', 'Exterior_styling', 'Reliability', 'Overall_score',
                                'Seller_score', 'Price', 'url'])

# Sequence of numbers - 1 to 500 (501 is not included)
for i in range(1,501):
    time.sleep(1)
    
    # variable for pages within website
    website = 'https://www.cars.com/shopping/results/?page='+str(i)+'&page_size=20&list_price_max=&makes[]=buick&maximum_distance=all&models[]=&stock_type=used&zip='
    
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.121 Safari/537.36'}
    
    # request
    response = requests.get(website, headers=headers)
    
    # create soup object
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # result
    result = soup.find_all('div', {'phx-hook':'VehicleCard'})
    
    # we combine url part no. 1 with url part no. 2 in order to get the absolute url
    url_part_1 = 'https://www.cars.com'
    
    url_part_2 = []

    # Loop through the results
    for item in result:
        # Loop through links
        for link in item.find_all('a', {'class':'vehicle-card-link js-gallery-click-link'}):
            url_part_2.append(link.get('href'))
            
    url_joined = []

    for link_2 in url_part_2:
        url_joined.append(urllib.parse.urljoin(url_part_1, link_2))
        
    for link in url_joined:
        time.sleep(1)
        
        response = requests.get(link, headers=headers)
        
        # create soup object
        soup = BeautifulSoup(response.content, 'html.parser')
        
        # New_used
        try:
            new_used = soup.find('p', {'class':'new-used'}).get_text()
        except:
            new_used = 'n/a'
            
        # Title
        try:
            title = soup.find('h1', {'class':'listing-title'}).get_text()
        except:
            title = 'n/a'
            
        # Mileage
        try:
            mileage = soup.find('div', {'class':'listing-mileage'}).get_text()
        except:
            mileage = 'n/a'
            
        # Exterior_color
        try:
            ext_color = soup.findAll({'dd'})
            a = ext_color[0].get_text()
        except:
            a = 'n/a'
        
        # Interior_color
        try:
            int_color = soup.findAll({'dd'})
            b = int_color[1].get_text()
        except:
            b = 'n/a'
            
        # Drivetrain
        try:
            drivetrain = soup.findAll({'dd'})
            c = drivetrain[2].get_text()
        except:
            c = 'n/a'
        
        # Fuel_type
        try:
            fuel_type = soup.findAll({'dd'})
            d = fuel_type[4].get_text()
        except:
            d = 'n/a'
        
        # Transmission
        try:
            transmission = soup.findAll({'dd'})
            e = transmission[5].get_text()
        except:
            e = 'n/a'
        
        # Engine
        try:
            engine = soup.findAll({'dd'})
            f = engine[6].get_text()
        except:
            f = 'n/a'
        
        # Comfort
        try:
            comfort = soup.findAll('span', {'class':'sds-definition-list__value'})
            g = comfort[0].get_text()
        except:
            g = 'n/a'
        
        # Interior_design
        try:
            int_des = soup.findAll('span', {'class':'sds-definition-list__value'})
            h = int_des[1].get_text()
        except:
            h = 'n/a'
        
        # Performance
        try:
            performance = soup.findAll('span', {'class':'sds-definition-list__value'})
            i = performance[2].get_text()
        except:
            i = 'n/a'
        
        # Value_for_money
        try:
            vfm = soup.findAll('span', {'class':'sds-definition-list__value'})
            j = vfm[3].get_text()
        except:
            j = 'n/a'
        
        # Exterior_styling
        try:
            ext_sty = soup.findAll('span', {'class':'sds-definition-list__value'})
            k = ext_sty[4].get_text()
        except:
            k = 'n/a'
        
        # Reliability
        try:
            reliability = soup.findAll('span', {'class':'sds-definition-list__value'})
            l = reliability[5].get_text()
        except:
            l = 'n/a'
        
        # Overall_score
        try:
            os = soup.findAll('span', {'class':'sds-rating__count'})
            m = os[1].get_text()
        except:
            m = 'n/a'
        
        # Seller_score
        try:
            ss = soup.findAll('span', {'class':'sds-rating__count'})
            n = ss[0].get_text()
        except:
            n = 'n/a'
        
        # Price
        try:
            price = soup.find('span', {'class':'primary-price'}).get_text()
        except:
            price = 'n/a'
            
        # Pandas DataFrame
        df_cars = df_cars.append({'New_used': new_used, 'Title': title, 'Mileage': mileage, 'Exterior_color': a, 'Interior_color': b, 'Drivetrain': c, 'Fuel_type': d,
                                  'Transmission': e, 'Engine': f, 'Comfort': g, 'Interior_design': h, 'Performance': i, 'Value_for_money': j, 'Exterior_styling': k,
                                  'Reliability': l, 'Overall_score': m, 'Seller_score': n, 'Price': price, 'url': link}, ignore_index=True)

# %%
df_cars
# Out:
#              New_used                             Title       Mileage  \
# 0                Used        2016 Buick Enclave Leather    35,810 mi.
# 1                Used  2019 Buick Regal TourX Preferred    39,141 mi.
# 2                Used    2018 Buick Regal TourX Essence    59,182 mi.
# 3     Buick Certified         2022 Buick Enclave Avenir     2,896 mi.
# 4                Used       2017 Buick LaCrosse Premium   118,892 mi.
# ...               ...                               ...           ...
# 9944             Used       2018 Buick Encore Preferred    69,744 mi.
# 9945  Buick Certified         2019 Buick Encore Essence    12,364 mi.
# 9946  Buick Certified       2019 Buick Encore Preferred    29,161 mi.
# 9947             Used       2017 Buick Encore Preferred   110,510 mi.
# 9948             Used   2019 Buick Encore Sport Touring     4,368 mi.
#
#                   Exterior_color Interior_color           Drivetrain  \
# 0                        Silver          Black    Front-wheel Drive
# 1                     Sport Red          Ebony      All-wheel Drive
# 2                         Black          Black      All-wheel Drive
# 3                         White          Ebony    Front-wheel Drive
# 4          Crimson Red Tintcoat          Ebony      All-wheel Drive
# ...                          ...            ...                  ...
# 9944        Coppertino Metallic          Ebony    Front-wheel Drive
# 9945                       Deep          Shale      All-wheel Drive
# 9946   Winterberry Red Metallic          Ebony      All-wheel Drive
# 9947       White Frost Tri-Coat          Ebony    Front-wheel Drive
# 9948   Winterberry Red Metallic          Ebony    Front-wheel Drive
#
#       Fuel_type       Transmission                       Engine Comfort  \
# 0     Gasoline   6-Speed Automatic         3.6L V6 24V GDI DOHC     4.7
# 1     Gasoline   8-Speed Automatic   2.0L I4 16V GDI DOHC Turbo     4.6
# 2     Gasoline   8-Speed Automatic   2.0L I4 16V GDI DOHC Turbo     4.7
# 3     Gasoline           Automatic         3.6L V6 24V GDI DOHC     5.0
# 4     Gasoline   8-Speed Automatic         3.6L V6 24V GDI DOHC     4.9
# ...         ...                ...                          ...     ...
# 9944  Gasoline   6-Speed Automatic  1.4L I4 16V MPFI DOHC Turbo     4.8
# 9945  Gasoline   6-Speed Automatic   1.4L I4 16V GDI DOHC Turbo     4.7
# 9946  Gasoline   6-Speed Automatic  1.4L I4 16V MPFI DOHC Turbo     4.7
# 9947  Gasoline   6-Speed Automatic  1.4L I4 16V MPFI DOHC Turbo     4.6
# 9948  Gasoline   6-Speed Automatic  1.4L I4 16V MPFI DOHC Turbo     4.7
#
#      Interior_design Performance Value_for_money Exterior_styling Reliability  \
# 0                4.6         4.5             4.3              4.6         4.6
# 1                4.3         4.4             4.6              4.6         5.0
# 2                4.3         4.4             4.6              4.9         4.7
# 3                5.0         5.0             5.0              5.0         5.0
# 4                4.8         4.8             4.8              4.8         4.7
# ...              ...         ...             ...              ...         ...
# 9944             4.8         4.7             4.7              4.8         4.8
# 9945             4.6         4.6             4.6              4.8         4.7
# 9946             4.6         4.6             4.6              4.8         4.7
# 9947             4.6         4.5             4.6              4.8         4.7
# 9948             4.6         4.6             4.6              4.8         4.7
#
#      Overall_score Seller_score    Price  \
# 0              4.5          2.5  $25,998
# 1              4.6          4.6  $25,999
# 2              4.6          4.1  $24,900
# 3              5.0          3.9  $59,500
# 4              4.8          4.6  $19,995
# ...            ...          ...      ...
# 9944           4.8          4.8  $18,996
# 9945           4.7          4.6  $25,997
# 9946           4.7          4.7  $23,983
# 9947           4.6          4.6  $14,999
# 9948           5.0          5.0  $23,739
#
#                                                     url
# 0     https://www.cars.com/vehicledetail/85bf2830-90...
# 1     https://www.cars.com/vehicledetail/29761bf2-32...
# 2     https://www.cars.com/vehicledetail/15c5c384-b4...
# 3     https://www.cars.com/vehicledetail/4e9342c8-75...
# 4     https://www.cars.com/vehicledetail/b174ae49-d0...
# ...                                                 ...
# 9944  https://www.cars.com/vehicledetail/96cb71b2-89...
# 9945  https://www.cars.com/vehicledetail/5c0c3987-8b...
# 9946  https://www.cars.com/vehicledetail/b4f0e7da-9f...
# 9947  https://www.cars.com/vehicledetail/5d0243c6-75...
# 9948  https://www.cars.com/vehicledetail/9ac25faf-e0...
#
# [9949 rows x 19 columns]

# %%
df = df_cars

# %% [markdown]
# ### Add a new column with the brand of the cars

# %%
df['Brand'] = 'Buick'

# %%
df.head()
# Out:
#           New_used                             Title       Mileage  \
# 0             Used        2016 Buick Enclave Leather    35,810 mi.
# 1             Used  2019 Buick Regal TourX Preferred    39,141 mi.
# 2             Used    2018 Buick Regal TourX Essence    59,182 mi.
# 3  Buick Certified         2022 Buick Enclave Avenir     2,896 mi.
# 4             Used       2017 Buick LaCrosse Premium   118,892 mi.
#
#            Exterior_color Interior_color           Drivetrain  Fuel_type  \
# 0                 Silver          Black    Front-wheel Drive   Gasoline
# 1              Sport Red          Ebony      All-wheel Drive   Gasoline
# 2                  Black          Black      All-wheel Drive   Gasoline
# 3                  White          Ebony    Front-wheel Drive   Gasoline
# 4   Crimson Red Tintcoat          Ebony      All-wheel Drive   Gasoline
#
#         Transmission                      Engine Comfort Interior_design  \
# 0  6-Speed Automatic        3.6L V6 24V GDI DOHC     4.7             4.6
# 1  8-Speed Automatic  2.0L I4 16V GDI DOHC Turbo     4.6             4.3
# 2  8-Speed Automatic  2.0L I4 16V GDI DOHC Turbo     4.7             4.3
# 3          Automatic        3.6L V6 24V GDI DOHC     5.0             5.0
# 4  8-Speed Automatic        3.6L V6 24V GDI DOHC     4.9             4.8
#
#   Performance Value_for_money Exterior_styling Reliability Overall_score  \
# 0         4.5             4.3              4.6         4.6           4.5
# 1         4.4             4.6              4.6         5.0           4.6
# 2         4.4             4.6              4.9         4.7           4.6
# 3         5.0             5.0              5.0         5.0           5.0
# 4         4.8             4.8              4.8         4.7           4.8
#
#   Seller_score    Price                                                url  \
# 0          2.5  $25,998  https://www.cars.com/vehicledetail/85bf2830-90...
# 1          4.6  $25,999  https://www.cars.com/vehicledetail/29761bf2-32...
# 2          4.1  $24,900  https://www.cars.com/vehicledetail/15c5c384-b4...
# 3          3.9  $59,500  https://www.cars.com/vehicledetail/4e9342c8-75...
# 4          4.6  $19,995  https://www.cars.com/vehicledetail/b174ae49-d0...
#
#    Brand
# 0  Buick
# 1  Buick
# 2  Buick
# 3  Buick
# 4  Buick

# %% [markdown]
# ### Store in Excel

# %%
df.to_excel(r'E:\Proyects\Python proyects\WEBSCRAPING\Project_CV_Cars\8-cars_used_Buick_7-10-2022.xlsx', index=False)
