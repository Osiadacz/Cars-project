# %% [markdown]
# ## Imports

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import time
import urllib.parse

# %% [markdown]
# ### HTTP Request

# %% [markdown]
# #### store website in variable

# %%
website = 'https://www.cars.com/shopping/results/?page=1&page_size=20&list_price_max=&makes[]=chrysler&maximum_distance=all&models[]=&stock_type=used&zip='

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.121 Safari/537.36'}

# %% [markdown]
# #### Get Request

# %%
response = requests.get(website, headers=headers)

# %% [markdown]
# #### Status Code

# %%
response.status_code
# Out:
# 200

# %% [markdown]
# ### Soup Object

# %%
soup = BeautifulSoup(response.content, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html class="ep-theme-cars" lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <title data-suffix=" | Cars.com">Used Chrysler for Sale | Cars.com</title>
# <meta content="Shop Chrysler vehicles for sale at Cars.com. Research, compare, and save listings, or contact sellers directly from 10,000+ Chrysler models nationwide." name="description"/>
# <meta content="noindex, nofollow" name="robots"/>
# <meta content="Cars.com" property="og:site_name"/>
# <meta content="website" property="og:type"/>
# <meta content="Used Chrysler for Sale | Cars.com" property="og:title"/>
# <meta content="https://www.cars.com/shopping/results" property="og:url"/>
# <meta content="Shop Chrysler vehicles for sale at Cars.com. Research, compare, and save listings, or contact sellers directly from 10,000+ Chrysler models nationwide." property="og:description"/>
# <meta content="https://graphics.cars.com/images/core/logo.png" property="og:image"/>
# <meta content="290349283473" property="fb:app_id"/>
# <meta content="app-id=353263352" name="apple-itunes-app"/>
# <meta content="@carsdotcom" name="twitter:site"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="Used Chrysler for Sale | Cars.com" name="twitter:title"/>
# <meta content="Shop Chrysler vehicles for sale at Cars.com. Research, compare, and save listings, or contact sellers directly from 10,000+ Chrysler models nationwide." name="twitter:description"/>
# <meta content="https://graphics.cars.com/images/core/logo.png" name="twitter:image"/>
# <script type="application/ld+json">{"@context":"http://www.schema.org","@type":"WebSite","name":"Cars.com","url":"https://www.cars.com/"}</script>
# <style>
# a,abbr,acronym,address,applet,article,aside,audio,b,big,blockquote,body,button,canvas,caption,center,cite,code,dd,del,details,dfn,div,dl,dt,em,embed,fieldset,figcaption,figure,footer,form,h1,h2,h3,h4,h5,h6,header,hgroup,html,i,iframe,img,ins,kbd,label,legend,li,main,mark,menu,nav,object,ol,output,p,pre,q,ruby,s,samp,section,small,span,strike,strong,sub,summary,sup,table,tbody,td,tfoot,th,thead,time,tr,tt,u,ul,var,video{border:0;font-weight:400;margin:0;padding:0;vertical-align:baseline}article,aside,details,figcaption,figure,footer,header,hgroup,main,menu,nav,section{display:block}body{line-height:1}ol,ul{list-style:none}blockquote,q{quotes:none}blockquote:after,blockquote:before,q:after,q:before{content:"";content:none}table{border-collapse:collapse;border-spacing:0}.sds-checkbox,.sds-radio{display:inline;position:relative}.sds-checkbox:after,.sds-radio:after{content:"\a";white-space:pre}.sds-checkbox+.sds-checkbox,.sds-checkbox+.sds-radio,.sds-radio+.sds-checkbox,.sds-radio+.sds-radio{margin-top:16px}.sds-checkbox .sds-input,.sds-radio .sds-input{height:20px;left:0;opacity:0;position:absolute;top:0;width:20px}.sds-checkbox .sds-input+.sds-label,.sds-checkbox .sds-input+.sds-legend,.sds-radio .sds-input+.sds-label,.sds-radio .sds-input+.sds-legend{-webkit-user-select:none;-moz-user-select:none;user-select:none}.sds-checkbox .sds-input+.sds-label:before,.sds-checkbox .sds-input+.sds-legend:before,.sds-radio .sds-input+.sds-label:before,.sds-radio .sds-input+.sds-legend:before{border:1px solid #bdbdbd;content:"";height:20px;left:0;position:absolute;top:-.1em;width:20px}.sds-checkbox .sds-input:disabled+.sds-label,.sds-checkbox .sds-input:disabled+.sds-legend,.sds-radio .sds-input:disabled+.sds-label,.sds-radio .sds-input:disabled+.sds-legend{cursor:not-allowed;opacity:.4}.sds-checkbox .sds-input.error+.sds-label:before,.sds-checkbox .sds-input.error+.sds-legend:before,.sds-radio .sds-input.error+.sds-label:before,.sds-radio .sds-input.error+.sds-legend:before{border-color:#c10}.sds-checkbox .sds-input:focus+.sds-label:before,.sds-checkbox .sds-input:focus+.sds-legend:before,.sds-radio .sds-input:focus+.sds-label:before,.sds-radio .sds-input:focus+.sds-legend:before{box-shadow:0 0 0 2px #00bfde}.sds-checkbox .sds-input+.sds-label:after,.sds-checkbox .sds-input+.sds-legend:after,.sds-radio .sds-input+.sds-label:after,.sds-radio .sds-input+.sds-legend:after{border:3px solid #000;border-left:0;border-top:0;content:"";height:12px;left:7px;opacity:0;position:absolute;top:1px;transform:rotate(45deg);width:7px}.sds-inverse .sds-checkbox .sds-input+.sds-label:after,.sds-inverse .sds-checkbox .sds-input+.sds-legend:after,.sds-inverse .sds-radio .sds-input+.sds-label:after,.sds-inverse .sds-radio .sds-input+.sds-legend:after{border-color:#fff}.sds-checkbox .sds-input:checked+.sds-label:after,.sds-checkbox .sds-input:checked+.sds-legend:after,.sds-radio .sds-input:checked+.sds-label:after,.sds-radio .sds-input:checked+.sds-legend:after{opacity:1}.sds-checkbox .sds-label,.sds-checkbox .sds-legend,.sds-radio .sds-label,.sds-radio .sds-legend{cursor:pointer;margin:0;padding:0 0 0 32px;position:relative}.sds-checkbox .error~.sds-label,.sds-checkbox .error~.sds-legend,.sds-radio .error~.sds-label,.sds-radio .error~.sds-legend{color:#c10}.sds-checkbox:focus,.sds-radio:focus{outline:2px solid Highlight}@media(-webkit-min-device-pixel-ratio:0){.sds-checkbox:focus,.sds-radio:focus{outline-color:-webkit-focus-ring-color;outline-style:auto}}.sds-template-3-col,.sds-template-filters,.sds-template-sidebar,.sds-template-sidebar-tight{max-width:1170px}@media (min-width:768px){.sds-template-3-col,.sds-template-filters,.sds-template-sidebar,.sds-template-sidebar-tight{margin:0 auto}}@media (min-width:980px){.sds-template-3-col,.sds-template-filters,.sds-template-sidebar,.sds-template-sidebar-tight{display:grid}}html{box-sizing:border-box;height:100%;width:100%}*,:after,:before{-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale;box-sizing: ...
#
#       </style>
# <style>
# .accordion-group{border-bottom:1px solid #e6e6e6}.accordion-header{align-items:center;display:flex;height:48px;justify-content:space-between;min-height:48px}.accordion-header .accordion-section-title{font-size:16px;width:100%}.accordion-header[aria-expanded=true] .accordion-section-icon{transform:rotate(180deg)}.accordion-panel[aria-hidden=true]{display:none}.accordion-panel[aria-hidden=false]{display:flex;flex-direction:column;padding:0 0 16px}.active-filter-tags{margin:0 16px 16px;position:relative}@media (min-width:768px){.active-filter-tags{margin-right:0}}.active-filter-tags .flex-container{display:flex;flex-direction:row;justify-content:space-between}.active-filter-tags .flex-container .show-more-less{align-content:flex-end;display:flex;flex-direction:row;justify-content:flex-start;margin-top:16px}.active-filter-tags .flex-container .show-more-less .sds-text-field__icon{stroke:#b0c!important;margin-left:5px;margin-top:5px}.active-filter-tags .flex-container .show-more-less span{color:#b0c;cursor:pointer}.active-filter-tags .flex-container .clear-all-filter-tags{margin-right:16px;margin-top:16px}.active-filter-tags .flex-container .clear-all-filter-tags span{color:#b0c;cursor:pointer}.active-filter-tags .active-filter-checkbox{display:none}.active-filter-tags .mobile-filtering-by{margin-bottom:16px}@media (min-width:768px){.active-filter-tags .mobile-filtering-by{display:none}}.branded-canvas{border:1px solid #e6e6e6;box-shadow:inset 0 -1px 0 0 #e6e6e6;height:520px;margin-bottom:24px;position:relative;width:100%}@media (min-width:768px){.branded-canvas{height:343px}}@media (min-width:980px){.branded-canvas{height:343px}}.branded-canvas .branded-canvas-main-container{display:flex;flex-direction:column;height:272px;overflow:hidden;position:relative;width:100%}@media (min-width:768px){.branded-canvas .branded-canvas-main-container{flex-direction:row;height:265px;justify-content:space-between}}.branded-canvas .branded-canvas-main-container .branded-canvas-from{color:#fff;font-size:11px;font-style:italic;left:10px;position:absolute;top:32px;z-index:1}.branded-canvas .branded-canvas-main-container .branded-canvas-logo{height:55px;position:absolute;right:12px;top:10px;width:55px;z-index:1}.branded-canvas .branded-canvas-main-container .branded-canvas-car-container{flex:0 0 45%;height:175px;position:relative;text-align:center;z-index:1}@media (min-width:768px){.branded-canvas .branded-canvas-main-container .branded-canvas-car-container{flex:0 0 50%}}.branded-canvas .branded-canvas-main-container .branded-canvas-car-container img{max-width:280px;padding-top:52px;position:inherit}@media (min-width:768px){.branded-canvas .branded-canvas-main-container .branded-canvas-car-container img{left:11%;max-width:80%;padding-top:0;position:absolute;top:30%}}.branded-canvas .branded-canvas-main-container .branded-canvas-button-container-desktop{display:none}@media (min-width:768px){.branded-canvas .branded-canvas-main-container .branded-canvas-button-container-desktop{display:flex;justify-content:flex-end}}.branded-canvas .branded-canvas-main-container .branded-canvas-button-container-desktop .sds-button--secondary-dense .sds-text-field__icon_1{stroke:#532380}.branded-canvas .branded-canvas-main-container .branded-canvas-button-container-desktop .sds-button--secondary-dense:hover .sds-text-field__icon_1{stroke:#fff;transition:stroke .25s ease}.branded-canvas .branded-canvas-main-container .branded-canvas-button-container-desktop .button-1{flex:1 1 50%;margin:16px 8px 16px 0;padding:8px;z-index:3}.branded-canvas .branded-canvas-main-container .branded-canvas-button-container-desktop .button-1 .sds-text-field__icon{stroke:#532380;margin-left:4px}.branded-canvas .branded-canvas-main-container .branded-canvas-button-container-desktop .button-2{flex:1 1 50%;margin:16px 16px 16px 0;padding:8px;z-index:3}.branded-canvas .branded-canvas-main-container .branded-canvas-button-container-desktop .button-2 .sds-text-field__icon{stroke:#fff;margin-left:4px} ...
#
#           </style>
# <script defer="" src="/cf2f739ebb78c97a8bb9/js/app.js?vsn=d"></script>
# <script id="datadog-config" type="application/json">
#     {
#         "clientToken": "pubd9e029f457b6d51b3d399c5b5c8fa7a4",
#         "applicationId": "c7070c7e-6068-4c84-828a-0e3b134e372d",
#         "site": "datadoghq.com",
#         "service": "cars_web",
#         "sampleRate": 2,
#         "trackInteractions": true,
#         "trackFrustrations": true
#
#     }
# </script>
# <script id="datadog-global-context" type="application/json">
# {"env":"production","trip_id":""}
# </script>
# <meta content="ECMqYgcIAVwXAGFudzMvUWUuHAwoXisFaoR3LYvevA5Z6ZeeUJMCq5Z4" name="csrf-token"/>
# <script>bazadebezolkohpepadr="300431831"</script><script defer="" src="https://www.cars.com/akam/13/11e83a5d" type="text/javascript"></script></head>
# <div hidden="">
# <span id="new-tab-link">Opens website in a new tab</span>
# </div>
# <body>
# <div class="global-header-container">
# <cars-global-header>
# <header class="global-header">
# <section class="container">
# <a class="header-logo" data-activity-rule-type="page-over-page" data-component="header-click" data-linkname="header-home" href="/"><img alt="Cars.com" class="header-logo header-logo__img" src="/images/logo_cars-46214ae902ff93ba8fa2e40fb73dfa02.png?vsn=d"/></a>
# <nav class="">
# <ul class="header-links">
# <li class="header-link"><a class="link-active" data-activity-rule-type="page-over-page" data-component="header-click" data-component-index="1" data-linkname="header-buy" data-nav-link="" href="/shopping/">Cars for Sale</a></li>
# <li class="header-link"><a data-activity-rule-type="page-over-page" data-component="header-click" data-component-index="2" data-linkname="header-research" data-nav-link="" href="/research/">Research &amp; Reviews</a></li>
# <li class="header-link"><a data-activity-rule-type="page-over-page" data-component="header-click" data-component-index="3" data-linkname="header-news" data-nav-link="" href="/news/">News &amp; Videos</a></li>
# <li class="header-link"><a data-activity-rule-type="page-over-page" data-component="header-click" data-component-index="4" data-linkname="header-sell-your-car" data-nav-link="" href="/sell/">Sell Your Car</a></li>
# <li class="header-link"><a data-activity-rule-type="page-over-page" data-component="header-click" data-component-index="5" data-linkname="header-service" data-nav-link="" href="/auto-repair/">Service &amp; Repair</a></li>
# </ul>
# <button aria-haspopup="true" aria-label="navigation menu" class="nav-user-menu-button" data-activity-rule-type="custom" data-linkname="header-menu">
# <ep-svg class="menu-icon" library="cars" name="hamburger"></ep-svg>
# <span class="nav-user-name">
# Menu
#             </span>
# <span class="menu-text">Menu</span>
# </button>
# <div id="google-one-tap">
# <div data-client_id="67273791563-90cd8jqav0pgefmmb4l5732bguvbjapi.apps.googleusercontent.com" data-login_uri="/signin/google_callback/" data-moment_callback="trackGoogleOneTap" data-redirect_path="/shopping/results/?redirect_event%5Bsocial_platform%5D=google" id="g_id_onload">
# </div>
# </div>
# </nav>
# <ep-modal class="nav-modal">
# <div class="sds-heading--2" id="menu-heading">
# <span class="nav-user-name">
# Menu
#               </span>
# <span class="menu-text">Menu</span>
# </div>
# <ul class="menu-links">
# <li class="header-link"><a class="link-active" data-activity-rule-type="page-over-page" data-component="header-click" data-component-index="1" data-linkname="header-buy" data-nav-link="" href="/shopping/">Cars for Sale</a></li>
# <li class="header-link"><a data-activity-rule-type="page-over-page" data-component="header-click" data-component-index="2" data-linkname="header-research" data-nav-link="" href="/research/">Research &amp; Reviews</a></li>
# <li class="header-link"><a data-activity-rule-type="page-over-page" data-component="header-click" data-component-index="3" data-linkname="header-news" data-nav-link="" href="/news/">News &amp; Videos</a></li>
# <li class="header-link"><a data-activity-rule-type="page-over-page" data-component="header-click" data-component-index="4" data-linkname="header-sell-your-car" data-nav-link="" href="/sell/">Sell Your Car</a></li>
# <li class="header-link"><a data-activity-rule-type="page-over-page" data-component="header-click" data-component-index="5" data-linkname="header-service" data-nav-link="" href="/auto-repair/">Service &amp; Repair</a></li>
# </ul>
# <ul class="profile-links">
# <li class="profile-link"><a data-activity-rule-type="page-over-page" data-component="header-click" data-component-index="1" data-linkname="header-saved-cars" data-profile-link="" href="/profile/saved-cars/"><ep-svg library="cars" name="heart-empty"></ep-svg>
# Saved Cars</a></li>
# <li class="profile-link"><a data-activity-rule-type="page-over-page" data-component="header-click" data-component-index="2" data-linkname="header-saved-searches" data-profile-link="" href="/profile/saved-searches/"><ep-svg library="cars" name="search"></ep-svg>
# Saved Searches</a></li>
# <li class="profile-link"><a data-activity-rule-type="page-over-page" data-component="header-click" data-component-index="3" data-linkname="header-your-garage" data-profile-link="" href="/profile/your-garage/"><ep-svg library="cars" name="tag"></ep-svg>
# Your Garage</a></li>
# </ul>
# <div class="sign-in-up-out">
# <a class="header-signin sds-button--secondary-dense" content="Sign in" data-activity-rule-type="page-over-page" data-component="sign-in-start" data-linkname="header-sign-in" href="/signin/?redirect_path=%2Fshopping%2Fresults%2F%3Flist_price_max%3D%26makes%255B%255D%3Dchrysler%26maximum_distance%3Dall%26models%255B%255D%3D%26page%3D1%26page_size%3D20%26stock_type%3Dused%26zip%3D">Sign in</a>
# <a class="header-signup sds-button--dense" content="Create an account" data-activity-rule-type="page-over-page" data-component="sign-up-start" data-linkname="header-sign-up" href="/signup/?redirect_path=%2Fshopping%2Fresults%2F%3Flist_price_max%3D%26makes%255B%255D%3Dchrysler%26maximum_distance%3Dall%26models%255B%255D%3D%26page%3D1%26page_size%3D20%26stock_type%3Dused%26zip%3D">Create an account</a>
# </div>
# </ep-modal>
# </section>
# </header>
# <template>
# <cars-auth-modal csrftoken="ECMqYgcIAVwXAGFudzMvUWUuHAwoXisFaoR3LYvevA5Z6ZeeUJMCq5Z4" forgotpasswordpath="/forgot_password/" open="" redirectpath="/shopping/results/?page=1&amp;page_size=20&amp;list_price_max=&amp;makes%5B%5D=chrysler&amp;maximum_distance=all&amp;models%5B%5D=&amp;stock_type=used&amp;zip=" type="sign_up">
# <div slot="disclaimer">
# <div class="sds-disclaimer">
# By signing up, you agree to our
# <a data-activity-rule-type="custom" data-component="privacy-statement" data-linkname="privacy-statement" href="/about/privacy/" target="_blank">Privacy Statement</a>
# and
# <a data-activity-rule-type="custom" data-component="terms-of-service" data-linkname="tos" href="/about/terms/" target="_blank">Terms of Service</a>.
# </div>
# </div>
# <div class="social-slot" slot="social">
# <ul class="sds-list social-link-list">
# <li class="social-link">
# <a class="sds-button facebook-button" data-activity-rule-type="custom" data-component="continue-with-social" data-linkname="signin-social-facebook" href="/signin/fb_go/?redirect_path=%2Fshopping%2Fresults%2F%3Flist_price_max%3D%26makes%255B%255D%3Dchrysler%26maximum_distance%3Dall%26models%255B%255D%3D%26page%3D1%26page_size%3D20%26redirect_event%255Bsocial_platform%255D%3Dfacebook%26stock_type%3Dused%26zip%3D">
# <svg class="facebook-svg-icon" height="1365.12" viewbox="0 0 14222 14222" width="1365.12" xmlns="http://www.w3.org/2000/svg">
# <circle cx="7111" cy="7112" fill="#fff" r="7111"></circle>
# <path d="M9879 9168l315-2056H8222V5778c0-562 275-1111 1159-1111h897V2917s-814-139-1592-139c-1624 0-2686 984-2686 2767v1567H4194v2056h1806v4969c362 57 733 86 1111 86s749-30 1111-86V9168z" fill="#1977f3"></path>
# </svg>
#   Sign in with Facebook
# </a>
# </li>
# <li class="social-link">
# <a class="sds-button google-button" data-activity-rule-type="custom" data-component="continue-with-social" data-linkname="signin-social-google" href="/signin/google_go/?redirect_path=%2Fshopping%2Fresults%2F%3Flist_price_max%3D%26makes%255B%255D%3Dchrysler%26maximum_distance%3Dall%26models%255B%255D%3D%26page%3D1%26page_size%3D20%26redirect_event%255Bsocial_platform%255D%3Dgoogle%26stock_type%3Dused%26zip%3D">
# <svg fill="none" height="32" viewbox="0 0 32 32" width="32" xmlns="http://www.w3.org/2000/svg">
# <path clip-rule="evenodd" d="M28.48 16.2955C28.48 15.3736 28.3973 14.4873 28.2436 13.6364H16V18.665H22.9964C22.695 20.29 21.7791 21.6668 20.4023 22.5886V25.8505H24.6036C27.0618 23.5873 28.48 20.2545 28.48 16.2955Z" fill="#4285F4" fill-rule="evenodd"></path>
# <path clip-rule="evenodd" d="M16 29C19.51 29 22.4527 27.8359 24.6036 25.8505L20.4023 22.5886C19.2382 23.3686 17.7491 23.8295 16 23.8295C12.6141 23.8295 9.74819 21.5427 8.72592 18.47H4.38274V21.8382C6.52183 26.0868 10.9182 29 16 29Z" fill="#34A853" fill-rule="evenodd"></path>
# <path clip-rule="evenodd" d="M8.72591 18.47C8.46591 17.69 8.31818 16.8568 8.31818 16C8.31818 15.1432 8.46591 14.31 8.72591 13.53V10.1618H4.38273C3.50227 11.9168 3 13.9023 3 16C3 18.0977 3.50227 20.0832 4.38273 21.8382L8.72591 18.47Z" fill="#FBBC05" fill-rule="evenodd"></path>
# <path clip-rule="evenodd" d="M16 8.17045C17.9086 8.17045 19.6223 8.82636 20.9696 10.1145L24.6982 6.38591C22.4468 4.28818 19.5041 3 16 3C10.9182 3 6.52183 5.91318 4.38274 10.1618L8.72592 13.53C9.74819 10.4573 12.6141 8.17045 16 8.17045Z" fill="#EA4335" fill-rule="evenodd"></path>
# </svg>
#   Sign in with Google
# </a>
# </li>
# <li class="social-link">
# <a class="sds-button apple-button" data-activity-rule-type="custom" data-component="continue-with-social" data-linkname="signin-social-apple" href="/signin/apple_go/?redirect_path=%2Fshopping%2Fresults%2F%3Flist_price_max%3D%26makes%255B%255D%3Dchrysler%26maximum_distance%3Dall%26models%255B%255D%3D%26page%3D1%26page_size%3D20%26redirect_event%255Bsocial_platform%255D%3Dapple%26stock_type%3Dused%26zip%3D">
# <svg height="44px" version="1.1" viewbox="0 0 31 44" width="28px" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <title>Apple logo</title>
# <g fill="none" fill-rule="evenodd" stroke="none" stroke-width="1">
# <path d="M15.7099491,14.8846154 C16.5675461,14.8846154 17.642562,14.3048315 18.28274,13.5317864 C18.8625238,12.8312142 19.2852829,11.852829 19.2852829,10.8744437 C19.2852829,10.7415766 19.2732041,10.6087095 19.2490464,10.5 C18.2948188,10.5362365 17.1473299,11.140178 16.4588366,11.9494596 C15.9152893,12.56548 15.4200572,13.5317864 15.4200572,14.5222505 C15.4200572,14.6671964 15.4442149,14.8121424 15.4562937,14.8604577 C15.5166879,14.8725366 15.6133185,14.8846154 15.7099491,14.8846154 Z M12.6902416,29.5 C13.8618881,29.5 14.3812778,28.714876 15.8428163,28.714876 C17.3285124,28.714876 17.6546408,29.4758423 18.9591545,29.4758423 C20.2395105,29.4758423 21.0971074,28.292117 21.9063891,27.1325493 C22.8123013,25.8038779 23.1867451,24.4993643 23.2109027,24.4389701 C23.1263509,24.4148125 20.6743484,23.4122695 20.6743484,20.5979021 C20.6743484,18.1579784 22.6069612,17.0588048 22.7156707,16.974253 C21.4353147,15.1382708 19.490623,15.0899555 18.9591545,15.0899555 C17.5217737,15.0899555 16.3501271,15.9596313 15.6133185,15.9596313 C14.8161157,15.9596313 13.7652575,15.1382708 12.521138,15.1382708 C10.1536872,15.1382708 7.75,17.0950413 7.75,20.7911634 C7.75,23.0861411 8.64383344,25.513986 9.74300699,27.0842339 C10.6851558,28.4129053 11.5065162,29.5 12.6902416,29.5 Z" fill="#FFFFFF" fill-rule="nonzero" id=""></path>
# </g>
# </svg>
#   Sign in with Apple
# </a>
# </li>
# </ul>
# </div>
# <div class="sds-field" slot="emailField">
# <div class="sds-input-container">
# <input autocomplete="email" class="sds-text-field" id="auth-modal-email" maxlength="255" placeholder=" " required="" type="email"/>
# <label class="sds-label" for="auth-modal-email">Email</label>
# </div>
# <span class="sds-helper-text"></span>
# </div>
# <div class="sds-field" slot="newAccountEmailField">
# <div class="sds-input-container disabled">
# <input autocomplete="email" class="sds-text-field" disabled="" id="auth-modal-email2" maxlength="255" placeholder=" " type="email"/>
# <label class="sds-label" for="auth-modal-email2">Email</label>
# </div>
# <span class="sds-helper-text"></span>
# </div>
# <div class="sds-field" slot="currentPasswordField">
# <div class="sds-input-container">
# <input autocomplete="current-password" class="sds-text-field" id="auth-modal-current-password" maxlength="255" minlength="8" placeholder=" " required="" type="password"/>
# <label class="sds-label" for="auth-modal-current-password">Password</label>
# </div>
# <span class="sds-helper-text">Enter a minimum of 8 characters.</span>
# </div>
# <div class="sds-field" slot="newPasswordField">
# <div class="sds-input-container">
# <input autocomplete="new-password" class="sds-text-field" id="auth-modal-new-password" maxlength="255" minlength="8" placeholder=" " required="" type="password"/>
# <label class="sds-label" for="auth-modal-new-password">Password</label>
# </div>
# <span class="sds-helper-text">Enter a minimum of 8 characters.</span>
# </div>
# <div class="sds-field" slot="firstNameField">
# <div class="sds-input-container">
# <input autocomplete="given-name" class="sds-text-field" id="auth-modal-first-name" maxlength="255" placeholder=" " required="" type="text"/>
# <label class="sds-label" for="auth-modal-first-name">First name</label>
# </div>
# <span class="sds-helper-text"></span>
# </div>
# <div class="sds-field" slot="lastNameField">
# <div class="sds-input-container">
# <input autocomplete="family-name" class="sds-text-field" id="auth-modal-last-name" maxlength="255" placeholder=" " required="" type="text"/>
# <label class="sds-label" for="auth-modal-last-name">Last name</label>
# </div>
# <span class="sds-helper-text"></span>
# </div>
# </cars-auth-modal>
# </template>
# </cars-global-header>
# </div>
# <section class="sds-page-container" role="main">
# <div data-qa="notifications-are-here"></div>
# <div data-phx-main="true" data-phx-session="SFMyNTY.....a01OiJLGSanpfJy0mFVN31sKYKtWXEINDjesbmMNk3o" data-phx-static="SFMyNTY.g2gDaAJhBXQAAAADZAAKYXNzaWduX25ld2wAAAACZAANaXNfc2VhcmNoX2JvdGQADGN1cnJlbnRfdXNlcmpkAAVmbGFzaHQAAAAAZAACaWRtAAAAFHBoeC1GeUJ0cWlkbHNPZ0ZJbzhobgYAcUNOAIQBYgABUYA.UIRZpFOrKGG0hD0t9teMfw4d_7i535xREBn5pO5Qc7A" id="phx-FyBtqidlsOgFIo8h">
# <link as="image" href="https://platform.cstatic-images.com/large/in/v2/424036a4-b8db-5cad-9e10-5ae5808b295f/11081e8a-49c6-4742-9435-bc836892ef2c/uuCgIy0IIHijIqtTdGhkC5bFA-k.jpg" rel="preload"/>
# <div aria-modal="true" class="sds-modal aria-modal sds-modal-one lead-form-container" id="srp-lead-form-modal" phx-hook="LeadForm" phx-target="#srp-lead-form-modal">
# <div class="lead-modal sds-modal__content" phx-click="close" phx-target="#srp-lead-form-modal" phx-value-close="false">
# <div class="lead-modal sds-modal__content-head">
# <div class="sds-icon--target btn-close" phx-click="reset" phx-target="#srp-lead-form-modal" role="button">
# <span class="sds-icon">
# <svg height="16" width="16"><use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#close"></use></svg>
# </span>
# </div>
# </div>
# <div class="lead-modal sds-modal__content-body">
# <div class="dealer-section lead-form-top-anchor" id="dealer-section--">
# <header>
# <h2 class="sds-heading--3 lead-form-heading">Contact seller</h2>
# </header>
# </div>
# <div class="lead-form" id="lead-form-container-">
# <form action="#" data-index="" data-reset-activity-limit-for="email-lead-error--inline" id="fields-srp-lead-form-modal" method="post" phx-change="change" phx-hook="EmailLeadForm" phx-submit="save_lead" phx-target="#srp-lead-form-modal"><input name="_csrf_token" type="hidden" value="ECMqYgcIAVwXAGFudzMvUWUuHAwoXisFaoR3LYvevA5Z6ZeeUJMCq5Z4"/>
# <section data-activity-limit="1" data-activity-rule-type="custom" data-conversion-type="email-lead-error--inline" data-errorname="email-lead-error--inline" data-index="">
# <div>
# <div class="sds-field-group">
# <div class="customer-form">
# <div class="first-name">
# <div class="sds-input-container">
# <input class="sds-text-field" data-fs="exclude" id="first_name-modal-" name="lead[first_name]" phx-debounce="blur" placeholder=" " type="text"/>
# <label class="sds-label" for="first_name-modal-">First name</label>
# </div>
# </div>
# <div class="last-name">
# <div class="sds-input-container">
# <input class="sds-text-field" data-fs="exclude" id="last_name-modal-" name="lead[last_name]" phx-debounce="blur" placeholder=" " type="text"/>
# <label class="sds-label" for="last_name-modal-">Last name</label>
# </div>
# </div>
# <div class="email">
# <div class="sds-input-container">
# <input class="sds-text-field" data-emailtype="transact" data-fs="exclude" id="email-modal-" name="lead[email]" phx-debounce="blur" phx-hook="EmailInput" placeholder=" " type="text"/>
# <label class="sds-label" for="email-modal-">Email</label>
# </div>
# </div>
# <div class="phone">
# <div class="sds-input-container">
# <input class="sds-text-field" data-fs="exclude" id="phone-modal-" name="lead[phone]" phx-debounce="blur" phx-hook="PhoneNumber" placeholder=" " type="tel"/>
# <label class="sds-label" for="phone-modal-">Phone (optional)</label>
# </div>
# </div>
# <input id="subject-modal-" name="lead[subject]" type="hidden" value="Ask a question"/>
# <div class="comments">
# <div class="sds-input-container sds-input-container--textarea">
# <textarea class="sds-text-field comment-box" data-fs="exclude" id="comments-modal-" name="lead[comments]" phx-debounce="blur" placeholder=" ">
# </textarea>
# <label class="sds-label" for="comments-modal-">Comments</label>
# </div>
# </div>
# </div>
# <div class="sds-field trade-in hidden">
# <div class="sds-field trade-in-checkbox">
# <div class="sds-checkbox trade-in" phx-click="show_trade_in" phx-target="#srp-lead-form-modal">
# <input class="sds-input" id="trade-in-checkbox-srp-lead-form-modal" type="checkbox"/>
# <label class="sds-label" for="trade-in-checkbox-srp-lead-form-modal">I have a trade in</label>
# </div>
# </div>
# <div class="sds-field-group trade-in-form hidden">
# <div class="make">
# <div class="sds-input-container sds-input-container--dropdown">
# <select class="sds-text-field" id="fields-srp-lead-form-modal_make_select-modal-" name="lead[trade_in][make]"><optgroup label=""><option selected="" value="">Choose a make</option><option value="ac">AC</option><option value="acura">Acura</option><option value="alfa_romeo">Alfa Romeo</option><option value="american_motors">American Motors</option><option value="am_general">Am General</option><option value="aston_martin">Aston Martin</option><option value="auburn">Auburn</option><option value="audi">Audi</option><option value="austin">Austin</option><option value="austin_healey">Austin-Healey</option><option value="avanti_motors">Avanti Motors</option><option value="bentley">Bentley</option><option value="bmw">BMW</option><option value="bricklin">Bricklin</option><option value="bugatti">Bugatti</option><option value="buick">Buick</option><option value="cadillac">Cadillac</option><option value="checker">Checker</option><option value="chevrolet">Chevrolet</option><option value="chrysler">Chrysler</option><option value="citroen">Citroen</option><option value="daewoo">Daewoo</option><option value="daihatsu">Daihatsu</option><option value="datsun">Datsun</option><option value="delahaye">Delahaye</option><option value="delorean">Delorean</option><option value="desoto">Desoto</option><option value="detomaso">DeTomaso</option><option value="dodge">Dodge</option><option value="eagle">Eagle</option><option value="edsel">Edsel</option><option value="essex">Essex</option><option value="ferrari">Ferrari</option><option value="fiat">FIAT</option><option value="fisker">Fisker</option><option value="ford">Ford</option><option value="franklin">Franklin</option><option value="genesis">Genesis</option><option value="geo">Geo</option><option value="gmc">GMC</option><option value="honda">Honda</option><option value="hudson">Hudson</option><option value="hummer">Hummer</option><option value="hupmobile">Hupmobile</option><option value="hyundai">Hyundai</option><option value="infiniti">INFINITI</option><option value="international">International</option><option value="isuzu">Isuzu</option><option value="jaguar">Jaguar</option><option value="jeep">Jeep</option><option value="jensen">Jensen</option><option value="kaiser">Kaiser</option><option value="karma">Karma</option><option value="kia">Kia</option><option value="koenigsegg">Koenigsegg</option><option value="lamborghini">Lamborghini</option><option value="lancia">Lancia</option><option value="land_rover">Land Rover</option><option value="lasalle">LaSalle</option><option value="lexus">Lexus</option><option value="lincoln">Lincoln</option><option value="lotus">Lotus</option><option value="lucid">Lucid</option><option value="maserati">Maserati</option><option value="maybach">Maybach</option><option value="mazda">Mazda</option><option value="mclaren">McLaren</option><option value="mercedes_benz">Mercedes-Benz</option><option value="mercury">Mercury</option><option value="merkur">Merkur</option><option value="mg">MG</option><option value="mini">MINI</option><option value="mitsubishi">Mitsubishi</option><option value="morgan">Morgan</option><option value="morris">Morris</option><option value="nash">Nash</option><option value="nissan">Nissan</option><option value="oldsmobile">Oldsmobile</option><option value="opel">Opel</option><option value="packard">Packard</option><option value="pagani">Pagani</option><option value="panoz">Panoz</option><option value="peugeot">Peugeot</option><option value="plymouth">Plymouth</option><option value="polestar">Polestar</option><option value="pontiac">Pontiac</option><option value="porsche">Porsche</option><option value="qvale">Qvale</option><option value="ram">RAM</option><option value="renault">Renault</option><option value="rivian">Rivian</option><option value="rolls_royce">Rolls-Royce</option><option value="rover">Rover</option><option value="saab">Saab</option><option value="saleen">Saleen</option><option value="saturn">Saturn</option><option value="scion">Scion</optio ...
# <label class="sds-label" for="make_select-modal-">Make</label>
# <svg class="sds-text-field__icon" height="16" width="16"><use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#chevron-down"></use></svg>
# </div>
# </div>
# <div class="model">
# <div class="sds-input-container sds-input-container--dropdown">
# <select class="sds-text-field" disabled="" id="fields-srp-lead-form-modal_model_select-modal-" name="lead[trade_in][model]"><optgroup label=""><option selected="" value="">Choose a model</option></optgroup></select>
# <label class="sds-label" for="model_select-modal-">Model</label>
# <svg class="sds-text-field__icon" height="16" width="16"><use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#chevron-down"></use></svg>
# </div>
# </div>
# <div class="year">
# <div class="sds-input-container sds-input-container--dropdown">
# <select class="sds-text-field" disabled="" id="fields-srp-lead-form-modal_year_select-modal-" name="lead[trade_in][year]"><optgroup label=""><option selected="" value="">Choose a year</option></optgroup></select>
# <label class="sds-label" for="year_select-modal-">Year</label>
# <svg class="sds-text-field__icon" height="16" width="16"><use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#chevron-down"></use></svg>
# </div>
# </div>
# <div class="color">
# <div class="sds-input-container">
# <input class="sds-text-field" disabled="" id="color-modal-" name="lead[trade_in][color]" phx-debounce="blur" placeholder=" " type="text" value=""/>
# <label class="sds-label" for="color-modal-">Exterior color</label>
# </div>
# </div>
# <div class="mileage">
# <div class="sds-input-container">
# <input class="sds-text-field" disabled="" id="mileage_string-modal-" name="lead[trade_in][mileage_string]" phx-debounce="blur" phx-hook="Mileage" placeholder=" " type="text" value=""/>
# <label class="sds-label" for="mileage_string-modal-">Mileage</label>
# </div>
# </div>
# <div class="vin">
# <div class="sds-input-container">
# <input class="sds-text-field" disabled="" id="vin-modal-" name="lead[trade_in][vin]" phx-debounce="blur" placeholder=" " type="text" value=""/>
# <label class="sds-label" for="vin-modal-">VIN (optional)</label>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="sds-field sds-form-module__button">
# <button class="sds-button--fluid" type="submit">Contact seller</button>
# </div>
# <small class="sds-disclaimer">
# <p>
#
# By clicking here, you authorize Cars.com and its sellers/partners to contact you by text/calls which may include marketing and be by autodialer. Calls may be prerecorded. You also agree to our Privacy Statement. Consent is not required to purchase goods/services.
#
#         </p>
# <p>
# We value your privacy.
# <a data-linkname="privacy-statement" href="/about/privacy/" target="_blank">Cars.com Privacy Statement</a>
# </p>
# </small>
# </div>
# </section>
# </form>
# </div>
# </div>
# </div>
# </div>
# <div data-override-payload="null" phx-hook="LeadSubmissionTracker" phx-target="#srp-lead-form-modal" phx_value_cid="srp-lead-form-modal"></div>
# <div phx-hook="LeadFormPositionAdjustments"></div>
# <div></div>
# <div class="sds-page-section listings-page" data-applied-filter-criteria="" data-liveview-pageview="true" data-props='{"selected_refinement":null}' data-search-instance-id="41547187-a2a8-4a67-93ed-0e92b9a20a89" data-search-type="general-inventory-search" data-site-activity='{"total_results":10000,"search_zip":"","search_features":"","search_cab_types":"","search_makes":"chrysler","search_results_on_page":21,"model_group":null,"multipleVehicles":true,"search_stock_sub":"","transmission":"","search_door_counts":"","filter_category_value":"","features":"","search_interior_colors":"","search_instance_id":"","sort_field":"searchRank1","result_page_number":1,"search_contactless_services":"","search_make_model_groups":"","search_model_groups":"","search_min_price":null,"web_page_type_from":"","search_models":"","resultsType":"not_modified","search_seller_types":"","search_trims":"","search_bodystyles":"","cat":"multi_cats","stock_type":"","result_page_count":500,"search_keyword":null,"search_only_with_photos":null,"trip_id":null,"canonical_mmt":"","search_transmissions":"","seller_type":"","searchCategory":"results","fuel_type":"","search_max_price":"","interiorColor":"","vehicleArray":[{"badges":["fair_deal","virtual_appt","price_drop_in_cents","home_delivery","cpo"],"bodystyle":"Passenger Van","canonical_mmt":"Chrysler:Pacifica:Limited","cat":"van_mini","certified_preowned":true,"cpo_indicator":true,"customer_id":"155869","exterior_color":"Brilliant Black Crystal Pearlcoat","fuel_type":"Gasoline","listing_id":"14903092-e749-4ce6-9eae-2c9e2052de9f","make":"Chrysler","mileage":"28186","model":"Pacifica","msrp":null,"nvi_program":false,"price":"43994","seller_type":"dealership","sponsored":true,"sponsored_type":"inventory_ad","stock_sub":"","stock_type":"Used","trim":"Limited","vin":"2C4RC1GG6LR261991","year":"2020"},{"badges":["price_drop_in_cents"],"bodystyle":"Convertible","canonical_mmt":"Chrysler:Crossfire:Limited","cat":"coupeconvertible_coupe","certified_preowned":false,"cpo_indicator":false,"customer_id":"103956","exterior_color":"Bright Silver Clearcoat Metallic","fuel_type":"Gasoline","listing_id":"3459b73c-ac04-4a5e-99d2-6c25ce718674","make":"Chrysler","mileage":"32903","model":"Crossfire","msrp":null,"nvi_program":false,"price":"17900","seller_type":"dealership","sponsored":false,"sponsored_type":"none","stock_sub":"","stock_type":"Used","trim":"Limited","vin":"1C3LN65L37X072465","year":"2007"},{"badges":["fair_deal"],"bodystyle":"Passenger Van","canonical_mmt":"Chrysler:Town &amp; Country:Touring-L","cat":"van_mini","certified_preowned":false,"cpo_indicator":false,"customer_id":"6520","exterior_color":"Black","fuel_type":"E85 Flex Fuel","listing_id":"63ad5a75-a26d-4aa7-a2c2-e0d2b9906abe","make":"Chrysler","mileage":"88101","model":"Town &amp; Country","msrp":null,"nvi_program":false,"price":"12980","seller_type":"dealership","sponsored":false,"sponsored_type":"none","stock_sub":"","stock_type":"Used","trim":"Touring-L","vin":"2A4RR8DG4BR703641","year":"2011"},{"badges":["good_deal","virtual_appt","price_drop_in_cents","home_delivery"],"bodystyle":"Passenger Van","canonical_mmt":"Chrysler:Pacifica:Pinnacle","cat":"van_mini","certified_preowned":false,"cpo_indicator":false,"customer_id":"5397264","exterior_color":"Brilliant Black Crystal Pearlcoat","fuel_type":"Gasoline","listing_id":"97d44189-dc09-4527-8522-81f76dca93f1","make":"Chrysler","mileage":"17063","model":"Pacifica","msrp":null,"nvi_program":false,"price":"48995","seller_type":"dealership","sponsored":false,"sponsored_type":"none","stock_sub":"","stock_type":"Used","trim":"Pinnacle","vin":"2C4RC3PG7MR574030","year":"2021"},{"badges":["fair_deal","virtual_appt","home_delivery"],"bodystyle":"Passenger Van","canonical_mmt":"Chrysler:Pacifica Hybrid:Limited","cat":"hybrid_suv","certified_preowned":false,"cpo_indicator":false,"customer_id":"6051199","exterior_color":"Brilliant Black Crystal Pearlcoat","fuel_type":"Hybrid","listing_id":"a82d2714-02dd-457f-81e7-e44cbf24e ...
# <script type="application/ld+json">{"@context":"http://schema.org","@type":"ItemList","itemListElement":[{"@type":"ListItem","name":"2007 Chrysler Crossfire Limited","position":1,"url":"https://www.cars.com/vehicledetail/3459b73c-ac04-4a5e-99d2-6c25ce718674//"},{"@type":"ListItem","name":"2011 Chrysler Town & Country Touring-L","position":2,"url":"https://www.cars.com/vehicledetail/63ad5a75-a26d-4aa7-a2c2-e0d2b9906abe//"},{"@type":"ListItem","name":"2021 Chrysler Pacifica Pinnacle","position":3,"url":"https://www.cars.com/vehicledetail/97d44189-dc09-4527-8522-81f76dca93f1//"},{"@type":"ListItem","name":"2019 Chrysler Pacifica Hybrid Limited","position":4,"url":"https://www.cars.com/vehicledetail/a82d2714-02dd-457f-81e7-e44cbf24e724//"},{"@type":"ListItem","name":"2021 Chrysler 300 S","position":5,"url":"https://www.cars.com/vehicledetail/adca4eac-ff7f-404d-9529-4c4cb4e73a13//"},{"@type":"ListItem","name":"2016 Chrysler 300 S","position":6,"url":"https://www.cars.com/vehicledetail/5088740e-7a8d-47d9-895d-ca9dbaaf86cc//"},{"@type":"ListItem","name":"2018 Chrysler Pacifica Hybrid Limited","position":7,"url":"https://www.cars.com/vehicledetail/43d206a9-e1c7-41ff-8264-b55f8ac40d40//"},{"@type":"ListItem","name":"2012 Chrysler 300 S","position":8,"url":"https://www.cars.com/vehicledetail/24080ed4-77c6-4f09-8f5c-2d1d9e3ef8aa//"},{"@type":"ListItem","name":"2019 Chrysler 300 S","position":9,"url":"https://www.cars.com/vehicledetail/b4f3eb90-cfef-4a1a-aa18-62dbd352e854//"},{"@type":"ListItem","name":"2016 Chrysler Town & Country Touring","position":10,"url":"https://www.cars.com/vehicledetail/fba8c76e-996f-4c88-b337-8500a448930f//"},{"@type":"ListItem","name":"2001 Chrysler Prowler Base (Discontinued)","position":11,"url":"https://www.cars.com/vehicledetail/92ac4157-6fd6-42f3-b0bb-f9330ccba06e//"},{"@type":"ListItem","name":"2011 Chrysler 300C Base","position":12,"url":"https://www.cars.com/vehicledetail/50808a1b-d667-4a77-a171-2349037f166f//"},{"@type":"ListItem","name":"2015 Chrysler 300 S","position":13,"url":"https://www.cars.com/vehicledetail/cbd44cc1-984d-470b-8f74-f1dc57221af1//"},{"@type":"ListItem","name":"2021 Chrysler Voyager LXI","position":14,"url":"https://www.cars.com/vehicledetail/7fb5776c-10ec-4845-ae10-9bd91c5ddb0e//"},{"@type":"ListItem","name":"2015 Chrysler Town & Country Touring-L","position":15,"url":"https://www.cars.com/vehicledetail/08d3a4fc-8776-4631-a486-c537aa9d1905//"},{"@type":"ListItem","name":"2017 Chrysler 300C Platinum","position":16,"url":"https://www.cars.com/vehicledetail/638e6c7b-9003-4a4e-a72d-566d94137630//"},{"@type":"ListItem","name":"2016 Chrysler Town & Country Touring","position":17,"url":"https://www.cars.com/vehicledetail/07befdca-aa91-4424-8522-1be1cec3cbba//"},{"@type":"ListItem","name":"2017 Chrysler 300 S","position":18,"url":"https://www.cars.com/vehicledetail/be590a97-9a5b-41ca-bf0c-3ab1d0e5b9db//"},{"@type":"ListItem","name":"2020 Chrysler Voyager LXI","position":19,"url":"https://www.cars.com/vehicledetail/29e783cd-ed7f-4466-98eb-90170086aede//"},{"@type":"ListItem","name":"2015 Chrysler Town & Country Touring","position":20,"url":"https://www.cars.com/vehicledetail/45342dda-fe30-4b27-8a5b-cd6d437ed183//"}],"itemListOrder":"https://schema.org/ItemListUnordered","numberOfItems":20}</script>
# <script type="application/ld+json">{"@context":"http://schema.org","@type":"Car","availability":"https://schema.org/InStock","brand":{"@type":"Organization","name":"Chrysler"},"color":"Bright Silver Clearcoat Metallic","description":"Used 2007 Chrysler Crossfire for sale for $17,900.","driveWheelConfiguration":"Rear-wheel Drive","image":{"@type":"ImageObject","contentUrl":"https://platform.cstatic-images.com/in/v2/ca079241-ac98-5f62-8fb0-740aa70792d9/e70e2929-1b6d-4e40-9c31-b5e227d77f2b/x3OV3vqsQKy5A0lBzp87MfJr26g.jpg"},"itemCondition":"https://schema.org/UsedCondition","mileageFromOdometer":"32903","name":"Used 2007 Chrysler Crossfire","sku":"072465","vehicleIdentificationNumber":"1C3LN65L37X072465","vehicleInteriorColor":"Dark Slate Gray / Medium Slate Gray","vehicleTransmission":"6-Speed Manual"}</script><script type="application/ld+json">{"@context":"http://schema.org","@type":"Car","availability":"https://schema.org/InStock","brand":{"@type":"Organization","name":"Chrysler"},"color":"Black","description":"Used 2011 Chrysler Town & Country for sale for $12,980.","driveWheelConfiguration":"Front-wheel Drive","image":{"@type":"ImageObject","contentUrl":"https://platform.cstatic-images.com/in/v2/261a4938-a642-59dc-a81a-c61ff663f364/f819b16a-c7ca-4eb6-a95f-0838bb7e32e9/aBv-h63w8CQgxsGnW1NW56OpXyM.jpg"},"itemCondition":"https://schema.org/UsedCondition","mileageFromOdometer":"88101","name":"Used 2011 Chrysler Town & Country","sku":"22215","vehicleIdentificationNumber":"2A4RR8DG4BR703641","vehicleInteriorColor":"Dark Frost Beige / Medium Frost Bei","vehicleTransmission":"Automatic"}</script><script type="application/ld+json">{"@context":"http://schema.org","@type":"Car","availability":"https://schema.org/InStock","brand":{"@type":"Organization","name":"Chrysler"},"color":"Brilliant Black Crystal Pearlcoat","description":"Used 2021 Chrysler Pacifica for sale for $48,995.","driveWheelConfiguration":"All-wheel Drive","image":{"@type":"ImageObject","contentUrl":"https://platform.cstatic-images.com/in/v2/4efb5ae6-41da-5086-9b2d-73f00448f2ef/daf8f3bf-5f89-407a-9eaa-d7b4448a375d/6qAkLqNvjts_xNoeA_7C13x41Ic.jpg"},"itemCondition":"https://schema.org/UsedCondition","mileageFromOdometer":"17063","name":"Used 2021 Chrysler Pacifica","sku":"P1442","vehicleIdentificationNumber":"2C4RC3PG7MR574030","vehicleInteriorColor":"Deep Mocha","vehicleTransmission":"9-Speed Automatic"}</script><script type="application/ld+json">{"@context":"http://schema.org","@type":"Car","availability":"https://schema.org/InStock","brand":{"@type":"Organization","name":"Chrysler"},"color":"Brilliant Black Crystal Pearlcoat","description":"Used 2019 Chrysler Pacifica Hybrid for sale for $47,500.","driveWheelConfiguration":"Front-wheel Drive","image":{"@type":"ImageObject","contentUrl":"https://platform.cstatic-images.com/in/v2/14213845-d728-42e3-aaf1-040c179a6cb5/cf086e86-7aca-40b8-a9c0-09071414806d/K_gzuYpcP7auTsSE50ifxjdC1Hk.jpg"},"itemCondition":"https://schema.org/UsedCondition","mileageFromOdometer":"24316","name":"Used 2019 Chrysler Pacifica Hybrid","sku":"KR529094P","vehicleIdentificationNumber":"2C4RC1N70KR529094","vehicleInteriorColor":"Black","vehicleTransmission":"Automatic CVT"}</script><script type="application/ld+json">{"@context":"http://schema.org","@type":"Car","availability":"https://schema.org/InStock","brand":{"@type":"Organization","name":"Chrysler"},"color":"Orange","description":"Used 2021 Chrysler 300 for sale for $45,300.","driveWheelConfiguration":"Rear-wheel Drive","image":{"@type":"ImageObject","contentUrl":"https://platform.cstatic-images.com/in/v2/613da932-f6cb-5e61-b304-ea83d03fe7ae/3ee7fbd6-d550-4167-9669-d26590f1f9ce/9ZkKFXxj2MfdE7qx_PfU1Ltbey4.jpg"},"itemCondition":"https://schema.org/UsedCondition","mileageFromOdometer":"17202","name":"Used 2021 Chrysler 300","sku":"MU17855","vehicleIdentificationNumber":"2C3CCABT2MH566961","vehicleInteriorColor":"Black","vehicleTransmission":"8-Speed Automatic"}</script><script type="application/ld+j ...
# <nav class="search-filter-bar">
# <button class="subscribe-with-save-status-indicator" data-activity-rule-type="custom" data-component="save-search-add" data-linkname="save-search-email-modal-open" id="search_filter_bar_save_search_button" phx-click="save_search" phx-target="#search_filter_bar_save_search_button">
# <ep-svg class="save-status-indicator unsaved" name="heart-empty">
# </ep-svg>
# <span>Save search</span>
# </button>
# <button phx-click="show_sort_overlay">
# Sort
#     </button>
# <button id="show-search-form-overlay" phx-click="show_search_form_overlay">
# Filter
#     </button>
# </nav>
# <section class="sds-page-section search-live" id="search-live-container">
# <div class="display-ad" data-ad-sizes="[[970, 90], [728, 90], [970, 250], [320, 50]]" data-ad-type="full-page-width" data-ad-unit-path="6427/shop/used.srp/top" data-appnexus-placement-id="17848546" data-hidden-on="" id="srp-top" phx-update="ignore">
# <div alt="Advertisement" id="phx-ignore-container-srp-top" phx-update="ignore"></div>
# </div>
# </section>
# <header class="sds-page-section__header">
# <nav aria-label="breadcrumb">
# <ul class="sds-breadcrumb sds-breadcrumb--mobile-custom">
# <li class="sds-breadcrumb__parent">
# <span class="sds-icon">
# <svg aria-describedby="description" aria-labelledby="title" fill="none" height="16" role="img" stroke="#000000" stroke-linecap="round" stroke-linejoin="round" stroke-width="2" viewbox="0 0 24 24" width="16" xmlns="http://www.w3.org/2000/svg">
# <title id="title">arrow-left</title>
# <desc id="description">An arrow pointing left.</desc>
# <path d="M19 12H6M12 5l-7 7 7 7"></path></svg>
# </span>
# <span><a data-component="breadcrumb" data-linkname="Home" href="/">Home</a></span>
# </li>
# <li aria-current="page">Cars for Sale</li>
# </ul>
# </nav>
# <script type="application/ld+json">
# ...
# <li><a aria-describedby="new-tab-link" aria-label="DealerRater, External link" class="sds-link--ext" data-activity-rule-type="custom" data-component="footer-partners" data-component-index="2" data-linkname="footer-dealerrater" href="https://www.dealerrater.com/" rel="noopener" target="_blank">DealerRater<svg class="sds-text-field__icon" height="16" width="16"><use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#arrow-up-right"></use></svg></a></li>
# <li><a aria-describedby="new-tab-link" aria-label="FUEL, External link" class="sds-link--ext" data-activity-rule-type="custom" data-component="footer-partners" data-component-index="3" data-linkname="footer-fuel" href="https://fuel.cars" rel="noopener" target="_blank">FUEL<svg class="sds-text-field__icon" height="16" width="16"><use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#arrow-up-right"></use></svg></a></li>
# <li><a aria-describedby="new-tab-link" aria-label="Auto.com, External link" class="sds-link--ext" data-activity-rule-type="custom" data-component="footer-partners" data-component-index="4" data-linkname="footer-autocom" href="https://www.auto.com/" rel="noopener" target="_blank">Auto.com<svg class="sds-text-field__icon" height="16" width="16"><use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#arrow-up-right"></use></svg></a></li>
# <li><a aria-describedby="new-tab-link" aria-label="NewCars.com, External link" class="sds-link--ext" data-activity-rule-type="custom" data-component="footer-partners" data-component-index="5" data-linkname="footer-newcarscom" href="https://www.newcars.com/" rel="noopener" target="_blank">NewCars.com<svg class="sds-text-field__icon" height="16" width="16"><use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#arrow-up-right"></use></svg></a></li>
# <li><a aria-describedby="new-tab-link" aria-label="Pickuptrucks.com, External link" class="sds-link--ext" data-activity-rule-type="custom" data-component="footer-partners" data-component-index="6" data-linkname="footer-pickuptruckscom" href="https://www.pickuptrucks.com/" rel="noopener" target="_blank">Pickuptrucks.com<svg class="sds-text-field__icon" height="16" width="16"><use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#arrow-up-right"></use></svg></a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="global-footer-group accordion-group">
# <div aria-controls="footer-section-4" aria-expanded="false" class="accordion-header" id="footer-header-4" role="button" tabindex="0">
# <span class="global-footer-heading accordion-section-title">Our Company</span>
# <svg class="accordion-section-icon" height="16" width="16"><use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#chevron-down"></use></svg>
# </div>
# <div aria-labelledby="footer-header-4" class="accordion-panel" hidden="" id="footer-section-4" role="region">
# <ul class="global-footer-list sds-list">
# <li><a data-activity-rule-type="page-over-page" data-component="footer-our-company" data-component-index="1" data-linkname="footer-about-cars" href="/about/">About Cars.com</a></li>
# <li><a data-activity-rule-type="page-over-page" data-component="footer-our-company" data-component-index="2" data-linkname="footer-contact-cars" href="/contact/">Contact Cars.com</a></li>
# <li><a aria-describedby="new-tab-link" aria-label="Investor Relations, External link" class="sds-link--ext" data-activity-rule-type="custom" data-component="footer-our-company" data-component-index="3" data-linkname="footer-investor-relations" href="https://investor.cars.com/overview/default.aspx" rel="noopener" target="_blank">Investor Relations<svg class="sds-text-field__icon" height="16" width="16"><use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#arrow-up-right"></use></svg></a></li>
# <li><a data-activity-rule-type="page-over-page" data-component="footer-our-company" data-component-index="4" data-linkname="footer-careers" href="/careers/">Careers</a></li>
# <li><a aria-describedby="new-tab-link" aria-label="Licensing &amp; Reprints, External link" class="sds-link--ext" data-activity-rule-type="custom" data-component="footer-our-company" data-component-index="5" data-linkname="footer-licensing-reprints" href="https://info.wrightsmedia.com/cars-licensing-reprints" rel="noopener" target="_blank">Licensing &amp; Reprints<svg class="sds-text-field__icon" height="16" width="16"><use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#arrow-up-right"></use></svg></a></li>
# <li><a data-activity-rule-type="page-over-page" data-component="footer-our-company" data-component-index="6" data-linkname="footer-site-map" href="/sitemap/">Site Map</a></li>
# <li><a data-activity-rule-type="custom" data-component="footer-our-company" data-component-index="7" data-linkname="footer-feedback" data-target="#qualtrics-modal" data-toggle="modal" href="#">Feedback</a></li>
# </ul>
# </div>
# </div>
# <div class="global-footer-group global-footer-apps-and-social">
# <div class="global-footer-social-header">
# <span class="global-footer-heading">Our Mobile App</span>
# </div>
# <div class="global-footer-mobile-apps">
# <a data-activity-rule-type="page-over-page" data-linkname="footer-mobile-apps" href="/mobile/">Download the App Today</a>
# <div class="global-footer-mobile-buttons">
# <a data-activity-rule-type="custom" data-linkname="footer-app-store" href="https://apps.apple.com/us/app/cars-com-new-used-cars/id353263352">
# <img alt="App Store download" class="app-store-button js-lazy-load" data-src="https://beta.cstatic-images.com/medium/in/v2/static/mobile-apps/app-store-badge-us-black-1.png"/>
# </a>
# <a data-activity-rule-type="custom" data-linkname="footer-google-play" href="https://play.google.com/store/apps/details?id=com.cars.android&amp;hl=en_US">
# <img alt="Google Play download" class="google-play-button js-lazy-load" data-src="https://beta.cstatic-images.com/medium/in/v2/static/mobile-apps/google-play-badge-us-1.png"/>
# </a>
# </div>
# </div>
# <div class="global-footer-social-header">
# <span class="global-footer-heading">Connect With Us</span>
# </div>
# <div class="global-footer-social-buttons">
# <ul class="global-footer-list sds-list">
# <li class="social-link"><a aria-describedby="new-tab-link" aria-label="Twitter, External link" class="sds-link--ext sds-button--icon sds-icon--contain twitter" data-activity-rule-type="custom" data-component="footer-social" data-component-index="1" data-linkname="footer-twitter" href="https://twitter.com/carsdotcom" rel="noopener" target="_blank"><svg height="16" width="16"><use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#twitter"></use></svg></a></li>
# <li class="social-link"><a aria-describedby="new-tab-link" aria-label="Facebook, External link" class="sds-link--ext sds-button--icon sds-icon--contain facebook" data-activity-rule-type="custom" data-component="footer-social" data-component-index="2" data-linkname="footer-facebook" href="https://www.facebook.com/CarsDotCom/" rel="noopener" target="_blank"><svg height="16" width="16"><use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#facebook"></use></svg></a></li>
# <li class="social-link"><a aria-describedby="new-tab-link" aria-label="Youtube, External link" class="sds-link--ext sds-button--icon sds-icon--contain youtube" data-activity-rule-type="custom" data-component="footer-social" data-component-index="3" data-linkname="footer-youtube" href="https://www.youtube.com/user/Carscom/" rel="noopener" target="_blank"><svg height="16" width="16"><use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#youtube"></use></svg></a></li>
# <li class="social-link"><a aria-describedby="new-tab-link" aria-label="Instagram, External link" class="sds-link--ext sds-button--icon sds-icon--contain instagram" data-activity-rule-type="custom" data-component="footer-social" data-component-index="4" data-linkname="footer-instagram" href="https://www.instagram.com/carsdotcom/" rel="noopener" target="_blank"><svg height="16" width="16"><use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#instagram"></use></svg></a></li>
# <li class="social-link"><a aria-describedby="new-tab-link" aria-label="Linkedin, External link" class="sds-link--ext sds-button--icon sds-icon--contain linkedin" data-activity-rule-type="custom" data-component="footer-social" data-component-index="5" data-linkname="footer-linkedin" href="https://www.linkedin.com/company/cars-com" rel="noopener" target="_blank"><svg height="16" width="16"><use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#linkedin"></use></svg></a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="global-copyright">
# <div class="sds-container">
# <ul class="sds-list">
# <li><a data-activity-rule-type="page-over-page" data-component="footer-legal" data-component-index="1" data-linkname="footer-tos" href="/about/terms/">Terms of Service</a></li>
# <li><a data-activity-rule-type="page-over-page" data-component="footer-legal" data-component-index="2" data-linkname="footer-privacy-statement" href="/about/privacy/">Privacy Statement</a></li>
# <li><a data-activity-rule-type="page-over-page" data-component="footer-legal" data-component-index="3" data-linkname="footer-personal-information" href="/about/ccpa-privacy-notice/">Do Not Sell My Personal Information</a></li>
# <li><a data-activity-rule-type="page-over-page" data-component="footer-legal" data-component-index="4" data-linkname="footer-accessibility" href="/about/accessibility/">Accessibility Statement</a></li>
# <li><a data-activity-rule-type="page-over-page" data-component="footer-legal" data-component-index="5" data-linkname="footer-ad-choices" href="/about/ad-choices/">Ad Choices</a></li>
# </ul>
# <div class="global-copyright-copy">©
# 2022 Cars.com. All rights reserved.</div>
# </div>
# </div>
# <div aria-modal="true" class="sds-modal sds-modal-one" id="qualtrics-modal">
# <div class="sds-modal__content">
# <div class="sds-modal__content-head sds-modal__content-head">
# <div class="sds-icon--target btn-close js-close" role="button">
# <span class="sds-icon">
# <svg height="16" width="16"><use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#close"></use></svg>
# </span>
# </div>
# </div>
# <iframe class="qualtrics-form" data-src="https://cars.qualtrics.com/jfe/form/SV_81Hx3Jkheo8zhmC " height="800px" width="600px"></iframe>
# </div>
# </div>
# </footer>
# <script src=""></script>
# <link data-href="/cf2f739ebb78c97a8bb9/css/common.css?vsn=d" media="print" rel="stylesheet">
# <link data-href="/cf2f739ebb78c97a8bb9/css/srp.css?vsn=d" media="print" rel="stylesheet"/>
# <link data-href="https://fonts.googleapis.com/css?family=Roboto" rel="stylesheet" type="text/css"/>
# <script>
#   window.CARS = window.CARS || {}
#   window.CARS["initialActivity"] = {"seller_id":null,"page_name":"shopping/search-results","utm_medium":null,"marketing_click_id":"","lat_long":"/","customer_id":"","url_base":"","trip_id":"","loginStatus":false,"page_channel":"shopping","designated_market_area_key":null,"local_zone":null,"aff_code":"national","cat":null,"year":"","page_detail":null,"market_name":null,"user_state":"anonymous","marketing_click_data":null,"utm_content":null,"utm_term":null,"url_referer":"","utm_source":null,"model":"","marketing_referral_source":"","utm_campaign":null,"platform_id":"cars_responsive","bodystyle":null,"useragent":"","make":"","page_key":"search-results","profileAccountType":null,"page_type":"shopping/search-results","zip_ip2geo":null,"facebook_event_id":"dHJpcF9pZD1mODkzNzhiOC1jMDM2LTRhMmUtYmJmZC02YmJkN2EzNTkwYzEmdHM9MTY2NjQ1MjQzOTY4Ng=="}
# </script>
# <script>
#   window.CARS = window.CARS || {}
#   window.CARS["initialAls"] = {"seller_id":null,"total_results":10000,"als_private_data":"QTEyOEdDTQ.8zG90pzVdKrQT2IDKjjKFjuh1-8GZ-ed-py9c65TlOncCoQVWcr8XIS3xvQ.VyKjScGlADNDZDR4.dAky7PGXqyH_vjU4doApjWxRR4_Qposs-mTFP1k04PlqGM31KiVeYZbsfThiPeLmJwPPij3P._G6BB-PQkWJHpfREXZOA7A","listing_id":"","utm_medium":null,"page_url":"https://www.cars.com/shopping/results/?page=1&amp;page_size=20&amp;list_price_max=&amp;makes[]=chrysler&amp;maximum_distance=all&amp;models[]=&amp;stock_type=used&amp;zip=","upsells":[],"marketing_click_id":"","model_year":"","longitude":null,"page_instance_id":"FyBtqiOH1TQ1BSICd6eC","lead_event_id":null,"search_instance_id":null,"customer_id":"","roxanne_visit_id":"","trim":"","device_os":null,"trip_id":"","web_page_type_from":"","results_per_page":20,"content_slug":"","x_forwarded_for":null,"external_uuids":null,"aff_code":"national","device_model":null,"timestamp_utc":1666452439999,"results_page_number":1,"app_version":null,"adobe_id":null,"stock_type":"","ga_client_id":null,"is_bot":true,"horizontal_position":"","msrp":"","referer_url":"","internet_connection":null,"roxanne_visitor_id":"","vertical_position":"","utm_content":null,"utm_term":null,"facebook_event_intent_id":"capi_viv_event","carrier":null,"utm_source":null,"device_id":null,"model":"","price":null,"bot_type":"Unknown Bot (B0B1CB20BEBCAE0F191F2D67CC6B7C5E):monitor:Behavior Anomaly;High-Velocity-BOT:100:aggressive","profile_user_id":null,"utm_campaign":null,"latitude":null,"platform_id":"cars_responsive","bodystyle":"","incentive_ids":"","useragent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.121 Safari/537.36","make":"","iframe_location":"","search_zipcode":"","device_type":"desktop","experiment_ids":[{"index":0,"name":"ab_test_2_srp_hp_prod"},{"analytics":{"payload":{"pe":"tnt","tnta":"188464:1:0|0,188464:1:0|2,188464:1:0|1"}},"index":1,"name":"ab_test_12_srp_vdp_prod","options":[{"responseTokens":{"activity.id":"188464","activity.name":"Prod | Cars Web | AB Test 12 | SRP, VDP | All Visitors","experience.id":"1","experience.name":"Experience B","geo.city":"ashburn","geo.country":"united states","geo.state":"virginia","offer.id":"0","profile.activeActivities":"188464","profile.daysSinceLastVisit":"0","profile.firstDateTime":"1666452439681","profile.fourGroups":"GroupC","profile.isFirstSession":"true","profile.isNewSession":"false","profile.tntId":"cbb2ba12-a4a6-4cef-b6fd-0a7510dde216","profile.twentyGroups":"Group8","profile.twoGroups":"GroupA","profile.visitNumber":"Place holder: requires new solution"},"sourceType":"target"}]},{"index":2,"name":"ab_test_14_srp_prod"}],"web_page_type_to":"shopping/search-results","results_page_count":500,"facebook_event_id":"dHJpcF9pZD1mODkzNzhiOC1jMDM2LTRhMmUtYmJmZC02YmJkN2EzNTkwYzEmdHM9MTY2NjQ1MjQzOTY4Ng==","cpo_indicator":false,"marketing_click_source":"","pdid":null,"finance_application_id":null}
# </script>
# <script async="" data-src="https://www.googletagservices.com/tag/js/gpt.js"></script>
# <script>
#   window.googletag = window.googletag || {cmd: []};
#   window.pbjs = window.pbjs || {que: []};
#   window.CARS = window.CARS || {};
#   window.CARS.disableAds = false;
#   window.CARS.disablePrebid = true;
#   window.CARS.isTest = false
# </script>
# <script async="" data-src="https://assets.adobedtm.com/306a737f2df1/a3d882c1ebd5/launch-3edaffcf6794.min.js" id="adobe-launch-script"></script>
# <script async="" data-src="https://d1n00d49gkbray.cloudfront.net/js/cars.js"></script>
# <script async="" data-src="https://accounts.google.com/gsi/client" defer=""></script>
# <script>
#   window.CARS["dispatcher"] = [];
#   window.CARS["dispatcher"].push({"CarsWeb": null})
#
#
# </script>
# <div data-id="188464:1:0|0,188464:1:0|2,188464:1:0|1" hidden="" id="tnta-options"></div>
# <script id="graphql-config" type="application/json">
#     {
#
#       "apiKey": "5rrmnWVl1MDzPcEnDvEp3Pu101IGXEGo",
#       "url": "https://graph.cars.com/graphql/api"
#     }
#   </script>
# <noscript><img src="https://www.cars.com/akam/13/pixel_11e83a5d?a=dD0wZDViYTE2ODAyZWFiYzZkMjI2YjI1NWNiMWI2MzcyYzllMzE0YmI4JmpzPW9mZg==" style="visibility: hidden; position: absolute; left: -999px; top: -999px;"/></noscript><script src="/nct3uuwFUO2NJSkdiA/7J9NthpDEbGO/BUYyEwh-WAY/FWtfDAZ/WRH0B" type="text/javascript"></script></link></body>
# </html>

# %% [markdown]
# ### Results

# %%
result = soup.find_all('div', {'phx-hook':'VehicleCard'})

# %%
len(result)
# Out:
# 21

# %% [markdown]
# ### Concatenate 2 URL Parts

# %%
# we combine url part no. 1 with url part no. 2 in order to get the absolute url
url_part_1 = 'https://www.cars.com'

# %% [markdown]
# #### Create List for URL Part 2

# %%
url_part_2 = []

# Loop through the results
for item in result:
    # Loop through links
    for link in item.find_all('a', {'class':'vehicle-card-link js-gallery-click-link'}):
        url_part_2.append(link.get('href'))

# %%
url_part_2
# Out:
# ['/vehicledetail/3459b73c-ac04-4a5e-99d2-6c25ce718674/',
#  '/vehicledetail/63ad5a75-a26d-4aa7-a2c2-e0d2b9906abe/',
#  '/vehicledetail/97d44189-dc09-4527-8522-81f76dca93f1/',
#  '/vehicledetail/a82d2714-02dd-457f-81e7-e44cbf24e724/',
#  '/vehicledetail/adca4eac-ff7f-404d-9529-4c4cb4e73a13/',
#  '/vehicledetail/5088740e-7a8d-47d9-895d-ca9dbaaf86cc/',
#  '/vehicledetail/43d206a9-e1c7-41ff-8264-b55f8ac40d40/',
#  '/vehicledetail/24080ed4-77c6-4f09-8f5c-2d1d9e3ef8aa/',
#  '/vehicledetail/b4f3eb90-cfef-4a1a-aa18-62dbd352e854/',
#  '/vehicledetail/fba8c76e-996f-4c88-b337-8500a448930f/',
#  '/vehicledetail/92ac4157-6fd6-42f3-b0bb-f9330ccba06e/',
#  '/vehicledetail/50808a1b-d667-4a77-a171-2349037f166f/',
#  '/vehicledetail/cbd44cc1-984d-470b-8f74-f1dc57221af1/',
#  '/vehicledetail/7fb5776c-10ec-4845-ae10-9bd91c5ddb0e/',
#  '/vehicledetail/08d3a4fc-8776-4631-a486-c537aa9d1905/',
#  '/vehicledetail/638e6c7b-9003-4a4e-a72d-566d94137630/',
#  '/vehicledetail/07befdca-aa91-4424-8522-1be1cec3cbba/',
#  '/vehicledetail/be590a97-9a5b-41ca-bf0c-3ab1d0e5b9db/',
#  '/vehicledetail/29e783cd-ed7f-4466-98eb-90170086aede/',
#  '/vehicledetail/45342dda-fe30-4b27-8a5b-cd6d437ed183/']

# %%
url_joined = []

for link_2 in url_part_2:
    url_joined.append(urllib.parse.urljoin(url_part_1, link_2))

# %%
url_joined
# Out:
# ['https://www.cars.com/vehicledetail/3459b73c-ac04-4a5e-99d2-6c25ce718674/',
#  'https://www.cars.com/vehicledetail/63ad5a75-a26d-4aa7-a2c2-e0d2b9906abe/',
#  'https://www.cars.com/vehicledetail/97d44189-dc09-4527-8522-81f76dca93f1/',
#  'https://www.cars.com/vehicledetail/a82d2714-02dd-457f-81e7-e44cbf24e724/',
#  'https://www.cars.com/vehicledetail/adca4eac-ff7f-404d-9529-4c4cb4e73a13/',
#  'https://www.cars.com/vehicledetail/5088740e-7a8d-47d9-895d-ca9dbaaf86cc/',
#  'https://www.cars.com/vehicledetail/43d206a9-e1c7-41ff-8264-b55f8ac40d40/',
#  'https://www.cars.com/vehicledetail/24080ed4-77c6-4f09-8f5c-2d1d9e3ef8aa/',
#  'https://www.cars.com/vehicledetail/b4f3eb90-cfef-4a1a-aa18-62dbd352e854/',
#  'https://www.cars.com/vehicledetail/fba8c76e-996f-4c88-b337-8500a448930f/',
#  'https://www.cars.com/vehicledetail/92ac4157-6fd6-42f3-b0bb-f9330ccba06e/',
#  'https://www.cars.com/vehicledetail/50808a1b-d667-4a77-a171-2349037f166f/',
#  'https://www.cars.com/vehicledetail/cbd44cc1-984d-470b-8f74-f1dc57221af1/',
#  'https://www.cars.com/vehicledetail/7fb5776c-10ec-4845-ae10-9bd91c5ddb0e/',
#  'https://www.cars.com/vehicledetail/08d3a4fc-8776-4631-a486-c537aa9d1905/',
#  'https://www.cars.com/vehicledetail/638e6c7b-9003-4a4e-a72d-566d94137630/',
#  'https://www.cars.com/vehicledetail/07befdca-aa91-4424-8522-1be1cec3cbba/',
#  'https://www.cars.com/vehicledetail/be590a97-9a5b-41ca-bf0c-3ab1d0e5b9db/',
#  'https://www.cars.com/vehicledetail/29e783cd-ed7f-4466-98eb-90170086aede/',
#  'https://www.cars.com/vehicledetail/45342dda-fe30-4b27-8a5b-cd6d437ed183/']

# %% [markdown]
# ### Get Data from First Link

# %%
len(url_joined)
# Out:
# 20

# %% [markdown]
# #### Store first link in variable

# %%
first_link = url_joined[0]

# %%
response = requests.get(first_link, headers=headers)

# %%
soup = BeautifulSoup(response.content, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html class="ep-theme-cars" lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <title>Used 2007 Chrysler Crossfire Limited For Sale $17,900 | Cars.com</title>
# <meta content="Used 2007 Chrysler Crossfire Limited for sale at Rayco Eurospec Motorcars in Kingston, PA for $17,900. View now on Cars.com" name="description"/>
# <meta content="noindex, nofollow" name="robots"/>
# <meta content="Cars.com" property="og:site_name"/>
# <meta content="website" property="og:type"/>
# <meta content="Used 2007 Chrysler Crossfire Limited For Sale $17,900 | Cars.com" property="og:title"/>
# <meta content="https://www.cars.com/vehicledetail/3459b73c-ac04-4a5e-99d2-6c25ce718674" property="og:url"/>
# <meta content="Used 2007 Chrysler Crossfire Limited for sale at Rayco Eurospec Motorcars in Kingston, PA for $17,900. View now on Cars.com" property="og:description"/>
# <meta content="https://platform.cstatic-images.com/in/v2/ca079241-ac98-5f62-8fb0-740aa70792d9/e70e2929-1b6d-4e40-9c31-b5e227d77f2b/x3OV3vqsQKy5A0lBzp87MfJr26g.jpg" property="og:image"/>
# <meta content="290349283473" property="fb:app_id"/>
# <meta content="app-id=353263352" name="apple-itunes-app"/>
# <meta content="@carsdotcom" name="twitter:site"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="Used 2007 Chrysler Crossfire Limited For Sale $17,900 | Cars.com" name="twitter:title"/>
# <meta content="Used 2007 Chrysler Crossfire Limited for sale at Rayco Eurospec Motorcars in Kingston, PA for $17,900. View now on Cars.com" name="twitter:description"/>
# <meta content="https://platform.cstatic-images.com/in/v2/ca079241-ac98-5f62-8fb0-740aa70792d9/e70e2929-1b6d-4e40-9c31-b5e227d77f2b/x3OV3vqsQKy5A0lBzp87MfJr26g.jpg" name="twitter:image"/>
# <script type="application/ld+json">{"@context":"http://www.schema.org","@type":"WebSite","name":"Cars.com","url":"https://www.cars.com/"}</script>
# <style>
# a,abbr,acronym,address,applet,article,aside,audio,b,big,blockquote,body,button,canvas,caption,center,cite,code,dd,del,details,dfn,div,dl,dt,em,embed,fieldset,figcaption,figure,footer,form,h1,h2,h3,h4,h5,h6,header,hgroup,html,i,iframe,img,ins,kbd,label,legend,li,main,mark,menu,nav,object,ol,output,p,pre,q,ruby,s,samp,section,small,span,strike,strong,sub,summary,sup,table,tbody,td,tfoot,th,thead,time,tr,tt,u,ul,var,video{border:0;font-weight:400;margin:0;padding:0;vertical-align:baseline}article,aside,details,figcaption,figure,footer,header,hgroup,main,menu,nav,section{display:block}body{line-height:1}ol,ul{list-style:none}blockquote,q{quotes:none}blockquote:after,blockquote:before,q:after,q:before{content:"";content:none}table{border-collapse:collapse;border-spacing:0}.sds-checkbox,.sds-radio{display:inline;position:relative}.sds-checkbox:after,.sds-radio:after{content:"\a";white-space:pre}.sds-checkbox+.sds-checkbox,.sds-checkbox+.sds-radio,.sds-radio+.sds-checkbox,.sds-radio+.sds-radio{margin-top:16px}.sds-checkbox .sds-input,.sds-radio .sds-input{height:20px;left:0;opacity:0;position:absolute;top:0;width:20px}.sds-checkbox .sds-input+.sds-label,.sds-checkbox .sds-input+.sds-legend,.sds-radio .sds-input+.sds-label,.sds-radio .sds-input+.sds-legend{-webkit-user-select:none;-moz-user-select:none;user-select:none}.sds-checkbox .sds-input+.sds-label:before,.sds-checkbox .sds-input+.sds-legend:before,.sds-radio .sds-input+.sds-label:before,.sds-radio .sds-input+.sds-legend:before{border:1px solid #bdbdbd;content:"";height:20px;left:0;position:absolute;top:-.1em;width:20px}.sds-checkbox .sds-input:disabled+.sds-label,.sds-checkbox .sds-input:disabled+.sds-legend,.sds-radio .sds-input:disabled+.sds-label,.sds-radio .sds-input:disabled+.sds-legend{cursor:not-allowed;opacity:.4}.sds-checkbox .sds-input.error+.sds-label:before,.sds-checkbox .sds-input.error+.sds-legend:before,.sds-radio .sds-input.error+.sds-label:before,.sds-radio .sds-input.error+.sds-legend:before{border-color:#c10}.sds-checkbox .sds-input:focus+.sds-label:before,.sds-checkbox .sds-input:focus+.sds-legend:before,.sds-radio .sds-input:focus+.sds-label:before,.sds-radio .sds-input:focus+.sds-legend:before{box-shadow:0 0 0 2px #00bfde}.sds-checkbox .sds-input+.sds-label:after,.sds-checkbox .sds-input+.sds-legend:after,.sds-radio .sds-input+.sds-label:after,.sds-radio .sds-input+.sds-legend:after{border:3px solid #000;border-left:0;border-top:0;content:"";height:12px;left:7px;opacity:0;position:absolute;top:1px;transform:rotate(45deg);width:7px}.sds-inverse .sds-checkbox .sds-input+.sds-label:after,.sds-inverse .sds-checkbox .sds-input+.sds-legend:after,.sds-inverse .sds-radio .sds-input+.sds-label:after,.sds-inverse .sds-radio .sds-input+.sds-legend:after{border-color:#fff}.sds-checkbox .sds-input:checked+.sds-label:after,.sds-checkbox .sds-input:checked+.sds-legend:after,.sds-radio .sds-input:checked+.sds-label:after,.sds-radio .sds-input:checked+.sds-legend:after{opacity:1}.sds-checkbox .sds-label,.sds-checkbox .sds-legend,.sds-radio .sds-label,.sds-radio .sds-legend{cursor:pointer;margin:0;padding:0 0 0 32px;position:relative}.sds-checkbox .error~.sds-label,.sds-checkbox .error~.sds-legend,.sds-radio .error~.sds-label,.sds-radio .error~.sds-legend{color:#c10}.sds-checkbox:focus,.sds-radio:focus{outline:2px solid Highlight}@media(-webkit-min-device-pixel-ratio:0){.sds-checkbox:focus,.sds-radio:focus{outline-color:-webkit-focus-ring-color;outline-style:auto}}.sds-template-3-col,.sds-template-filters,.sds-template-sidebar,.sds-template-sidebar-tight{max-width:1170px}@media (min-width:768px){.sds-template-3-col,.sds-template-filters,.sds-template-sidebar,.sds-template-sidebar-tight{margin:0 auto}}@media (min-width:980px){.sds-template-3-col,.sds-template-filters,.sds-template-sidebar,.sds-template-sidebar-tight{display:grid}}html{box-sizing:border-box;height:100%;width:100%}*,:after,:before{-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale;box-sizing: ...
#
#       </style>
# <style>
# .accordion-group{border-bottom:1px solid #e6e6e6}.accordion-header{align-items:center;display:flex;height:48px;justify-content:space-between;min-height:48px}.accordion-header .accordion-section-title{font-size:16px;width:100%}.accordion-header[aria-expanded=true] .accordion-section-icon{transform:rotate(180deg)}.accordion-panel[aria-hidden=true]{display:none}.accordion-panel[aria-hidden=false]{display:flex;flex-direction:column;padding:0 0 16px}.active-filter-tags{margin:0 16px 16px;position:relative}@media (min-width:768px){.active-filter-tags{margin-right:0}}.active-filter-tags .flex-container{display:flex;flex-direction:row;justify-content:space-between}.active-filter-tags .flex-container .show-more-less{align-content:flex-end;display:flex;flex-direction:row;justify-content:flex-start;margin-top:16px}.active-filter-tags .flex-container .show-more-less .sds-text-field__icon{stroke:#b0c!important;margin-left:5px;margin-top:5px}.active-filter-tags .flex-container .show-more-less span{color:#b0c;cursor:pointer}.active-filter-tags .flex-container .clear-all-filter-tags{margin-right:16px;margin-top:16px}.active-filter-tags .flex-container .clear-all-filter-tags span{color:#b0c;cursor:pointer}.active-filter-tags .active-filter-checkbox{display:none}.active-filter-tags .mobile-filtering-by{margin-bottom:16px}@media (min-width:768px){.active-filter-tags .mobile-filtering-by{display:none}}@-webkit-keyframes fadeInAnimation{0%{opacity:0}to{opacity:1}}@keyframes fadeInAnimation{0%{opacity:0}to{opacity:1}}@-webkit-keyframes fadeInZoomLeftAnimation{0%{left:100%;opacity:0}to{left:1%;opacity:1}}@keyframes fadeInZoomLeftAnimation{0%{left:100%;opacity:0}to{left:1%;opacity:1}}@-webkit-keyframes fadeInZoomLeftMobileAnimation{0%{left:100%;opacity:0}to{left:5%;opacity:1}}@keyframes fadeInZoomLeftMobileAnimation{0%{left:100%;opacity:0}to{left:5%;opacity:1}}.drive-in-ad-section{margin:0 auto;padding:0}.drive-in-ad{min-height:1px}.drive-in-ad .drive-in-absolute{-webkit-animation:fadeInAnimation .75s ease 0s 1 normal forwards;animation:fadeInAnimation .75s ease 0s 1 normal forwards;background:url(/images/drive_in_ad_background.png),linear-gradient(180deg,#fff,#e6e6e6);bottom:0;height:112px;left:0;opacity:0;padding:20px 0;position:fixed;width:100%;z-index:7000}@media (min-width:768px){.drive-in-ad .drive-in-absolute{height:130px;padding:0}}.drive-in-ad .drive-in-absolute .drive-in-top-border{background:#00bfde;background:linear-gradient(90deg,#00bfde 0,#00bfde 25%,#532380 0,#532380 50%,#b0c 0,#b0c 75%,#00bfde 0,#00bfde);display:block;height:10px;left:-10px;position:relative;top:-28%;transform:skew(45deg);width:calc(100% + 40px)}@media (min-width:768px){.drive-in-ad .drive-in-absolute .drive-in-top-border{top:0}}.drive-in-ad .drive-in-absolute:before{background-color:#212121;border-radius:0 0 2px 0;color:#fff;content:"Ad";font-size:10px;font-weight:700;left:0;line-height:1;padding:4px 8px 6px 6px;position:absolute;top:0;z-index:1}.drive-in-ad .drive-in-absolute .drive-in-content{align-items:center;color:#212121;display:flex;height:68px;margin:0 auto;max-width:1170px;padding-top:14px;position:relative}@media(min-width:800px){.drive-in-ad .drive-in-absolute .drive-in-content{height:125px}}.drive-in-ad .drive-in-absolute .drive-in-content .drive-in-car{display:block;flex:0 0 175px;height:100%}@media (min-width:768px){.drive-in-ad .drive-in-absolute .drive-in-content .drive-in-car{flex:0 0 200px}}@media (min-width:980px){.drive-in-ad .drive-in-absolute .drive-in-content .drive-in-car{flex:0 0 280px;margin-right:28px}}.drive-in-ad .drive-in-absolute .drive-in-content .drive-in-car img{-webkit-animation:fadeInZoomLeftMobileAnimation 1.75s ease 0s 1 normal forwards;animation:fadeInZoomLeftMobileAnimation 1.75s ease 0s 1 normal forwards;position:absolute;top:-18%;width:130px;z-index:7000}@media (min-width:768px){.drive-in-ad .drive-in-absolute .drive-in-content .drive-in-car img{top:18%;width:140px}}@media (min-width:980px){.drive-in-ad .drive-in-absolute .dr ...
#
#           </style>
# <script defer="" src="/cf2f739ebb78c97a8bb9/js/app.js?vsn=d"></script>
# <script id="datadog-config" type="application/json">
#     {
#         "clientToken": "pubd9e029f457b6d51b3d399c5b5c8fa7a4",
#         "applicationId": "c7070c7e-6068-4c84-828a-0e3b134e372d",
#         "site": "datadoghq.com",
#         "service": "cars_web",
#         "sampleRate": 1,
#         "trackInteractions": true,
#         "trackFrustrations": true
#
#     }
# </script>
# <script id="datadog-global-context" type="application/json">
# {"env":"production","trip_id":""}
# </script>
# <meta content="BVwvYkV-Bhw8Ci0aE0pjJSoBPwAGLR8P00h5176_pItryg3BsUHyWyEC" name="csrf-token"/>
# <script>bazadebezolkohpepadr="300431831"</script><script defer="" src="https://www.cars.com/akam/13/11e83a5d" type="text/javascript"></script></head>
# <div hidden="">
# <span id="new-tab-link">Opens website in a new tab</span>
# </div>
# <body>
# <div class="global-header-container">
# <cars-global-header>
# <header class="global-header">
# <section class="container">
# <a class="header-logo" data-activity-rule-type="page-over-page" data-component="header-click" data-linkname="header-home" href="/"><img alt="Cars.com" class="header-logo header-logo__img" src="/images/logo_cars-46214ae902ff93ba8fa2e40fb73dfa02.png?vsn=d"/></a>
# <nav class="">
# <ul class="header-links">
# <li class="header-link"><a data-activity-rule-type="page-over-page" data-component="header-click" data-component-index="1" data-linkname="header-buy" data-nav-link="" href="/shopping/">Cars for Sale</a></li>
# <li class="header-link"><a data-activity-rule-type="page-over-page" data-component="header-click" data-component-index="2" data-linkname="header-research" data-nav-link="" href="/research/">Research &amp; Reviews</a></li>
# <li class="header-link"><a data-activity-rule-type="page-over-page" data-component="header-click" data-component-index="3" data-linkname="header-news" data-nav-link="" href="/news/">News &amp; Videos</a></li>
# <li class="header-link"><a data-activity-rule-type="page-over-page" data-component="header-click" data-component-index="4" data-linkname="header-sell-your-car" data-nav-link="" href="/sell/">Sell Your Car</a></li>
# <li class="header-link"><a data-activity-rule-type="page-over-page" data-component="header-click" data-component-index="5" data-linkname="header-service" data-nav-link="" href="/auto-repair/">Service &amp; Repair</a></li>
# </ul>
# <button aria-haspopup="true" aria-label="navigation menu" class="nav-user-menu-button" data-activity-rule-type="custom" data-linkname="header-menu">
# <ep-svg class="menu-icon" library="cars" name="hamburger"></ep-svg>
# <span class="nav-user-name">
# Menu
#             </span>
# <span class="menu-text">Menu</span>
# </button>
# <div id="google-one-tap">
# <div data-client_id="67273791563-90cd8jqav0pgefmmb4l5732bguvbjapi.apps.googleusercontent.com" data-login_uri="/signin/google_callback/" data-moment_callback="trackGoogleOneTap" data-redirect_path="/vehicledetail/3459b73c-ac04-4a5e-99d2-6c25ce718674/?redirect_event%5Bsocial_platform%5D=google" id="g_id_onload">
# </div>
# </div>
# </nav>
# <ep-modal class="nav-modal">
# <div class="sds-heading--2" id="menu-heading">
# <span class="nav-user-name">
# Menu
#               </span>
# <span class="menu-text">Menu</span>
# </div>
# <ul class="menu-links">
# <li class="header-link"><a data-activity-rule-type="page-over-page" data-component="header-click" data-component-index="1" data-linkname="header-buy" data-nav-link="" href="/shopping/">Cars for Sale</a></li>
# <li class="header-link"><a data-activity-rule-type="page-over-page" data-component="header-click" data-component-index="2" data-linkname="header-research" data-nav-link="" href="/research/">Research &amp; Reviews</a></li>
# <li class="header-link"><a data-activity-rule-type="page-over-page" data-component="header-click" data-component-index="3" data-linkname="header-news" data-nav-link="" href="/news/">News &amp; Videos</a></li>
# <li class="header-link"><a data-activity-rule-type="page-over-page" data-component="header-click" data-component-index="4" data-linkname="header-sell-your-car" data-nav-link="" href="/sell/">Sell Your Car</a></li>
# <li class="header-link"><a data-activity-rule-type="page-over-page" data-component="header-click" data-component-index="5" data-linkname="header-service" data-nav-link="" href="/auto-repair/">Service &amp; Repair</a></li>
# </ul>
# <ul class="profile-links">
# <li class="profile-link"><a data-activity-rule-type="page-over-page" data-component="header-click" data-component-index="1" data-linkname="header-saved-cars" data-profile-link="" href="/profile/saved-cars/"><ep-svg library="cars" name="heart-empty"></ep-svg>
# Saved Cars</a></li>
# <li class="profile-link"><a data-activity-rule-type="page-over-page" data-component="header-click" data-component-index="2" data-linkname="header-saved-searches" data-profile-link="" href="/profile/saved-searches/"><ep-svg library="cars" name="search"></ep-svg>
# Saved Searches</a></li>
# <li class="profile-link"><a data-activity-rule-type="page-over-page" data-component="header-click" data-component-index="3" data-linkname="header-your-garage" data-profile-link="" href="/profile/your-garage/"><ep-svg library="cars" name="tag"></ep-svg>
# Your Garage</a></li>
# </ul>
# <div class="sign-in-up-out">
# <a class="header-signin sds-button--secondary-dense" content="Sign in" data-activity-rule-type="page-over-page" data-component="sign-in-start" data-linkname="header-sign-in" href="/signin/?redirect_path=%2Fvehicledetail%2F3459b73c-ac04-4a5e-99d2-6c25ce718674%2F">Sign in</a>
# <a class="header-signup sds-button--dense" content="Create an account" data-activity-rule-type="page-over-page" data-component="sign-up-start" data-linkname="header-sign-up" href="/signup/?redirect_path=%2Fvehicledetail%2F3459b73c-ac04-4a5e-99d2-6c25ce718674%2F">Create an account</a>
# </div>
# </ep-modal>
# </section>
# </header>
# <template>
# <cars-auth-modal csrftoken="BVwvYkV-Bhw8Ci0aE0pjJSoBPwAGLR8P00h5176_pItryg3BsUHyWyEC" forgotpasswordpath="/forgot_password/" open="" redirectpath="/vehicledetail/3459b73c-ac04-4a5e-99d2-6c25ce718674/" type="sign_up">
# <div slot="disclaimer">
# <div class="sds-disclaimer">
# By signing up, you agree to our
# <a data-activity-rule-type="custom" data-component="privacy-statement" data-linkname="privacy-statement" href="/about/privacy/" target="_blank">Privacy Statement</a>
# and
# <a data-activity-rule-type="custom" data-component="terms-of-service" data-linkname="tos" href="/about/terms/" target="_blank">Terms of Service</a>.
# </div>
# </div>
# <div class="social-slot" slot="social">
# <ul class="sds-list social-link-list">
# <li class="social-link">
# <a class="sds-button facebook-button" data-activity-rule-type="custom" data-component="continue-with-social" data-linkname="signin-social-facebook" href="/signin/fb_go/?redirect_path=%2Fvehicledetail%2F3459b73c-ac04-4a5e-99d2-6c25ce718674%2F%3Fredirect_event%255Bsocial_platform%255D%3Dfacebook">
# <svg class="facebook-svg-icon" height="1365.12" viewbox="0 0 14222 14222" width="1365.12" xmlns="http://www.w3.org/2000/svg">
# <circle cx="7111" cy="7112" fill="#fff" r="7111"></circle>
# <path d="M9879 9168l315-2056H8222V5778c0-562 275-1111 1159-1111h897V2917s-814-139-1592-139c-1624 0-2686 984-2686 2767v1567H4194v2056h1806v4969c362 57 733 86 1111 86s749-30 1111-86V9168z" fill="#1977f3"></path>
# </svg>
#   Sign in with Facebook
# </a>
# </li>
# <li class="social-link">
# <a class="sds-button google-button" data-activity-rule-type="custom" data-component="continue-with-social" data-linkname="signin-social-google" href="/signin/google_go/?redirect_path=%2Fvehicledetail%2F3459b73c-ac04-4a5e-99d2-6c25ce718674%2F%3Fredirect_event%255Bsocial_platform%255D%3Dgoogle">
# <svg fill="none" height="32" viewbox="0 0 32 32" width="32" xmlns="http://www.w3.org/2000/svg">
# <path clip-rule="evenodd" d="M28.48 16.2955C28.48 15.3736 28.3973 14.4873 28.2436 13.6364H16V18.665H22.9964C22.695 20.29 21.7791 21.6668 20.4023 22.5886V25.8505H24.6036C27.0618 23.5873 28.48 20.2545 28.48 16.2955Z" fill="#4285F4" fill-rule="evenodd"></path>
# <path clip-rule="evenodd" d="M16 29C19.51 29 22.4527 27.8359 24.6036 25.8505L20.4023 22.5886C19.2382 23.3686 17.7491 23.8295 16 23.8295C12.6141 23.8295 9.74819 21.5427 8.72592 18.47H4.38274V21.8382C6.52183 26.0868 10.9182 29 16 29Z" fill="#34A853" fill-rule="evenodd"></path>
# <path clip-rule="evenodd" d="M8.72591 18.47C8.46591 17.69 8.31818 16.8568 8.31818 16C8.31818 15.1432 8.46591 14.31 8.72591 13.53V10.1618H4.38273C3.50227 11.9168 3 13.9023 3 16C3 18.0977 3.50227 20.0832 4.38273 21.8382L8.72591 18.47Z" fill="#FBBC05" fill-rule="evenodd"></path>
# <path clip-rule="evenodd" d="M16 8.17045C17.9086 8.17045 19.6223 8.82636 20.9696 10.1145L24.6982 6.38591C22.4468 4.28818 19.5041 3 16 3C10.9182 3 6.52183 5.91318 4.38274 10.1618L8.72592 13.53C9.74819 10.4573 12.6141 8.17045 16 8.17045Z" fill="#EA4335" fill-rule="evenodd"></path>
# </svg>
#   Sign in with Google
# </a>
# </li>
# <li class="social-link">
# <a class="sds-button apple-button" data-activity-rule-type="custom" data-component="continue-with-social" data-linkname="signin-social-apple" href="/signin/apple_go/?redirect_path=%2Fvehicledetail%2F3459b73c-ac04-4a5e-99d2-6c25ce718674%2F%3Fredirect_event%255Bsocial_platform%255D%3Dapple">
# <svg height="44px" version="1.1" viewbox="0 0 31 44" width="28px" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <title>Apple logo</title>
# <g fill="none" fill-rule="evenodd" stroke="none" stroke-width="1">
# <path d="M15.7099491,14.8846154 C16.5675461,14.8846154 17.642562,14.3048315 18.28274,13.5317864 C18.8625238,12.8312142 19.2852829,11.852829 19.2852829,10.8744437 C19.2852829,10.7415766 19.2732041,10.6087095 19.2490464,10.5 C18.2948188,10.5362365 17.1473299,11.140178 16.4588366,11.9494596 C15.9152893,12.56548 15.4200572,13.5317864 15.4200572,14.5222505 C15.4200572,14.6671964 15.4442149,14.8121424 15.4562937,14.8604577 C15.5166879,14.8725366 15.6133185,14.8846154 15.7099491,14.8846154 Z M12.6902416,29.5 C13.8618881,29.5 14.3812778,28.714876 15.8428163,28.714876 C17.3285124,28.714876 17.6546408,29.4758423 18.9591545,29.4758423 C20.2395105,29.4758423 21.0971074,28.292117 21.9063891,27.1325493 C22.8123013,25.8038779 23.1867451,24.4993643 23.2109027,24.4389701 C23.1263509,24.4148125 20.6743484,23.4122695 20.6743484,20.5979021 C20.6743484,18.1579784 22.6069612,17.0588048 22.7156707,16.974253 C21.4353147,15.1382708 19.490623,15.0899555 18.9591545,15.0899555 C17.5217737,15.0899555 16.3501271,15.9596313 15.6133185,15.9596313 C14.8161157,15.9596313 13.7652575,15.1382708 12.521138,15.1382708 C10.1536872,15.1382708 7.75,17.0950413 7.75,20.7911634 C7.75,23.0861411 8.64383344,25.513986 9.74300699,27.0842339 C10.6851558,28.4129053 11.5065162,29.5 12.6902416,29.5 Z" fill="#FFFFFF" fill-rule="nonzero" id=""></path>
# </g>
# </svg>
#   Sign in with Apple
# </a>
# </li>
# </ul>
# </div>
# <div class="sds-field" slot="emailField">
# <div class="sds-input-container">
# <input autocomplete="email" class="sds-text-field" id="auth-modal-email" maxlength="255" placeholder=" " required="" type="email"/>
# <label class="sds-label" for="auth-modal-email">Email</label>
# </div>
# <span class="sds-helper-text"></span>
# </div>
# <div class="sds-field" slot="newAccountEmailField">
# <div class="sds-input-container disabled">
# <input autocomplete="email" class="sds-text-field" disabled="" id="auth-modal-email2" maxlength="255" placeholder=" " type="email"/>
# <label class="sds-label" for="auth-modal-email2">Email</label>
# </div>
# <span class="sds-helper-text"></span>
# </div>
# <div class="sds-field" slot="currentPasswordField">
# <div class="sds-input-container">
# <input autocomplete="current-password" class="sds-text-field" id="auth-modal-current-password" maxlength="255" minlength="8" placeholder=" " required="" type="password"/>
# <label class="sds-label" for="auth-modal-current-password">Password</label>
# </div>
# <span class="sds-helper-text">Enter a minimum of 8 characters.</span>
# </div>
# <div class="sds-field" slot="newPasswordField">
# <div class="sds-input-container">
# <input autocomplete="new-password" class="sds-text-field" id="auth-modal-new-password" maxlength="255" minlength="8" placeholder=" " required="" type="password"/>
# <label class="sds-label" for="auth-modal-new-password">Password</label>
# </div>
# <span class="sds-helper-text">Enter a minimum of 8 characters.</span>
# </div>
# <div class="sds-field" slot="firstNameField">
# <div class="sds-input-container">
# <input autocomplete="given-name" class="sds-text-field" id="auth-modal-first-name" maxlength="255" placeholder=" " required="" type="text"/>
# <label class="sds-label" for="auth-modal-first-name">First name</label>
# </div>
# <span class="sds-helper-text"></span>
# </div>
# <div class="sds-field" slot="lastNameField">
# <div class="sds-input-container">
# <input autocomplete="family-name" class="sds-text-field" id="auth-modal-last-name" maxlength="255" placeholder=" " required="" type="text"/>
# <label class="sds-label" for="auth-modal-last-name">Last name</label>
# </div>
# <span class="sds-helper-text"></span>
# </div>
# </cars-auth-modal>
# </template>
# </cars-global-header>
# </div>
# <section class="sds-page-container" role="main">
# <div data-qa="notifications-are-here"></div>
# <section class="sds-page-section--full vdp-sticky-bar invisible" id="vdp-sticky-bar">
# <div class="sticky-bar-wrapper">
# <div class="title-row">
# <div class="sticky-bar-title-price">
# <h1 class="sticky-header-listing-title">2007 Chrysler Crossfire Limited</h1>
# <div class="price-section price-section-vehicle-card">
# <span class="primary-price">$17,900</span>
# <span class="secondary-price price-drop">$1,000 price drop</span>
# </div>
# </div>
# </div>
# <div class="sticky-bar-buttons">
# <div class="save-heart-wrapper" data-phx-session="SFMyNTY.....uPr6nNg0zDFV2YUTKra50dwis6twMxexNF2cH5kZuak" data-phx-static="SFMyNTY.g2gDaAJhBXQAAAADZAAKYXNzaWduX25ld2pkAAVmbGFzaHQAAAAAZAACaWRtAAAAFHBoeC1GeUJ0dm9zeEtiaXlKYTBEbgYAqZhPAIQBYgABUYA.UE4C0Xq_wW47oBRRqaeXdncGiRmwjgHPdV3taK3HlKQ" id="phx-FyBtvosxKbiyJa0D">
# <div></div>
# <div>
# <button class="heart" data-activity-rule-type="custom" data-component="save-vehicle-add" data-hook-heart-id="sticky-bar-heart-vehicle-save-heart" data-index="" data-linkname="save-vehicle-sign-up" data-listing-id="3459b73c-ac04-4a5e-99d2-6c25ce718674" id="sticky-bar-heart-vehicle-save-heart" onclick="event.preventDefault()" phx-hook="RecordSaveListingAction" phx-target="2" phx-value-is_vdp="true" phx-value-listing_id="3459b73c-ac04-4a5e-99d2-6c25ce718674">
# <save-listing-wrapper>
# <ep-save reference-id="3459b73c-ac04-4a5e-99d2-6c25ce718674" variant="button"></ep-save>
# </save-listing-wrapper>
# </button>
# </div>
# </div>
# <div data-phx-session="SFMyNTY...._...-...-...-...-...-...-...-...-...-...-KmKqGUORkBEouFxn3--...-...-...-..._8AAAAAAAAGQAEHByaW1hcnlfbG9jYXRpb25kAAR0cnVlZAAFc3RhdGVtAAAAAlBBZAANc2VhcmNoX3JhbmtfM2QAA25pbGQAB2hvdF9jYXJkAAVmYWxzZWQACWdlb19wb2ludHQAAAAEZAAKX19zdHJ1Y3RfX2QAEEVsaXhpci5HZW8uUG9pbnRkAAtjb29yZGluYXRlc2gCRsBS-KmKqGUORkBEouFxn3-....EOI79zovBogOd1PlFNRDMT6pWfroR9EIp1_m36sVxIo" data-phx-static="SFMyNTY.g2gDaAJhBXQAAAADZAAKYXNzaWduX25ld2pkAAVmbGFzaHQAAAAAZAACaWRtAAAAFHBoeC1GeUJ0dm93NGtUZXlKVHdsbgYAvZhPAIQBYgABUYA.wCebgTyfZXZTg2VY32qpRBVs1HEnP5dMd8j3sgrW1ik" id="phx-FyBtvow4kTeyJTwl">
# <button class="sds-button--medium" data-activity-rule-type="custom" data-linkname="email-lead-form-vdp" id="modal-trigger" phx-click="open_modal" phx-target="#lead-form-sticky-nav" type="button">Check availability</button>
# <div aria-modal="true" class="sds-modal aria-modal sds-modal-one lead-form-container" id="lead-form-sticky-nav" phx-hook="LeadForm" phx-target="#lead-form-sticky-nav">
# <div class="lead-modal sds-modal__content" phx-click="close" phx-target="#lead-form-sticky-nav" phx-value-close="false">
# <div class="lead-modal sds-modal__content-head">
# <div class="sds-icon--target btn-close" phx-click="reset" phx-target="#lead-form-sticky-nav" role="button">
# <span class="sds-icon">
# <svg height="16" width="16"><use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#close"></use></svg>
# </span>
# </div>
# </div>
# <div class="lead-modal sds-modal__content-body">
# <div class="dealer-section lead-form-top-anchor" id="dealer-section-sticky-sticky">
# <header>
# <h2 class="sds-heading--3 lead-form-heading">Contact seller</h2>
# </header>
# <div class="vehicle-dealer">
# <section class="dealer-phone-section">
# </section>
# </div>
# </div>
# <div class="lead-form" id="lead-form-container-sticky">
# <form action="#" data-index="sticky" data-reset-activity-limit-for="email-lead-error-vdp-inline" id="fields-lead-form-sticky-nav" method="post" phx-change="change" phx-hook="EmailLeadForm" phx-submit="save_lead" phx-target="#lead-form-sticky-nav"><input name="_csrf_token" type="hidden" value="BVwvYkV-Bhw8Ci0aE0pjJSoBPwAGLR8P00h5176_pItryg3BsUHyWyEC"/>
# <section data-activity-limit="1" data-activity-rule-type="custom" data-conversion-type="email-lead-error-vdp-inline" data-errorname="email-lead-error-vdp-inline" data-index="sticky">
# <div>
# <div class="sds-field-group">
# <div class="customer-form">
# <div class="first-name">
# <div class="sds-input-container">
# <input class="sds-text-field" data-fs="exclude" id="first_name-modal-sticky" name="lead[first_name]" phx-debounce="blur" placeholder=" " type="text"/>
# <label class="sds-label" for="first_name-modal-sticky">First name</label>
# </div>
# </div>
# <div class="last-name">
# <div class="sds-input-container">
# <input class="sds-text-field" data-fs="exclude" id="last_name-modal-sticky" name="lead[last_name]" phx-debounce="blur" placeholder=" " type="text"/>
# <label class="sds-label" for="last_name-modal-sticky">Last name</label>
# </div>
# </div>
# <div class="email">
# <div class="sds-input-container">
# <input class="sds-text-field" data-emailtype="transact" data-fs="exclude" id="email-modal-sticky" name="lead[email]" phx-debounce="blur" phx-hook="EmailInput" placeholder=" " type="text"/>
# <label class="sds-label" for="email-modal-sticky">Email</label>
# </div>
# </div>
# <div class="phone">
# <div class="sds-input-container">
# <input class="sds-text-field" data-fs="exclude" id="phone-modal-sticky" name="lead[phone]" phx-debounce="blur" phx-hook="PhoneNumber" placeholder=" " type="tel"/>
# <label class="sds-label" for="phone-modal-sticky">Phone (optional)</label>
# </div>
# </div>
# <div class="subject">
# <div class="sds-input-container sds-input-container--dropdown">
# <select class="sds-text-field" id="subject-modal-sticky" name="lead[subject]"><option selected="" value="Check availability">Check availability</option><option value="Get a price quote">Get a price quote</option><option value="Schedule a test drive">Schedule a test drive</option><option value="Discuss financing">Discuss financing</option><option value="Ask a question">Ask a question</option></select>
# <label class="sds-label" for="subject-modal-sticky">Subject</label>
# <svg class="sds-text-field__icon" height="16" width="16"><use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#chevron-down"></use></svg>
# </div>
# </div>
# <div class="comments">
# <div class="sds-input-container sds-input-container--textarea">
# <textarea class="sds-text-field comment-box" data-fs="exclude" id="comments-modal-sticky" name="lead[comments]" phx-debounce="blur" placeholder=" ">
# I'd like to know if the Used 2007 Chrysler Crossfire Limited you have listed on Cars.com for $17,900 is still available.</textarea>
# <label class="sds-label" for="comments-modal-sticky">Comments</label>
# </div>
# </div>
# </div>
# <div class="sds-field trade-in">
# <div class="sds-field trade-in-checkbox">
# <div class="sds-checkbox trade-in" phx-click="show_trade_in" phx-target="#lead-form-sticky-nav">
# <input class="sds-input" id="trade-in-checkbox-lead-form-sticky-nav" type="checkbox"/>
# <label class="sds-label" for="trade-in-checkbox-lead-form-sticky-nav">I have a trade in</label>
# </div>
# </div>
# <div class="sds-field-group trade-in-form hidden">
# <div class="make">
# <div class="sds-input-container sds-input-container--dropdown">
# <select class="sds-text-field" id="fields-lead-form-sticky-nav_make_select-modal-sticky" name="lead[trade_in][make]"><optgroup label=""><option selected="" value="">Choose a make</option><option value="ac">AC</option><option value="acura">Acura</option><option value="alfa_romeo">Alfa Romeo</option><option value="american_motors">American Motors</option><option value="am_general">Am General</option><option value="aston_martin">Aston Martin</option><option value="auburn">Auburn</option><option value="audi">Audi</option><option value="austin">Austin</option><option value="austin_healey">Austin-Healey</option><option value="avanti_motors">Avanti Motors</option><option value="bentley">Bentley</option><option value="bmw">BMW</option><option value="bricklin">Bricklin</option><option value="bugatti">Bugatti</option><option value="buick">Buick</option><option value="cadillac">Cadillac</option><option value="checker">Checker</option><option value="chevrolet">Chevrolet</option><option value="chrysler">Chrysler</option><option value="citroen">Citroen</option><option value="daewoo">Daewoo</option><option value="daihatsu">Daihatsu</option><option value="datsun">Datsun</option><option value="delahaye">Delahaye</option><option value="delorean">Delorean</option><option value="desoto">Desoto</option><option value="detomaso">DeTomaso</option><option value="dodge">Dodge</option><option value="eagle">Eagle</option><option value="edsel">Edsel</option><option value="essex">Essex</option><option value="ferrari">Ferrari</option><option value="fiat">FIAT</option><option value="fisker">Fisker</option><option value="ford">Ford</option><option value="franklin">Franklin</option><option value="genesis">Genesis</option><option value="geo">Geo</option><option value="gmc">GMC</option><option value="honda">Honda</option><option value="hudson">Hudson</option><option value="hummer">Hummer</option><option value="hupmobile">Hupmobile</option><option value="hyundai">Hyundai</option><option value="infiniti">INFINITI</option><option value="international">International</option><option value="isuzu">Isuzu</option><option value="jaguar">Jaguar</option><option value="jeep">Jeep</option><option value="jensen">Jensen</option><option value="kaiser">Kaiser</option><option value="karma">Karma</option><option value="kia">Kia</option><option value="koenigsegg">Koenigsegg</option><option value="lamborghini">Lamborghini</option><option value="lancia">Lancia</option><option value="land_rover">Land Rover</option><option value="lasalle">LaSalle</option><option value="lexus">Lexus</option><option value="lincoln">Lincoln</option><option value="lotus">Lotus</option><option value="lucid">Lucid</option><option value="maserati">Maserati</option><option value="maybach">Maybach</option><option value="mazda">Mazda</option><option value="mclaren">McLaren</option><option value="mercedes_benz">Mercedes-Benz</option><option value="mercury">Mercury</option><option value="merkur">Merkur</option><option value="mg">MG</option><option value="mini">MINI</option><option value="mitsubishi">Mitsubishi</option><option value="morgan">Morgan</option><option value="morris">Morris</option><option value="nash">Nash</option><option value="nissan">Nissan</option><option value="oldsmobile">Oldsmobile</option><option value="opel">Opel</option><option value="packard">Packard</option><option value="pagani">Pagani</option><option value="panoz">Panoz</option><option value="peugeot">Peugeot</option><option value="plymouth">Plymouth</option><option value="polestar">Polestar</option><option value="pontiac">Pontiac</option><option value="porsche">Porsche</option><option value="qvale">Qvale</option><option value="ram">RAM</option><option value="renault">Renault</option><option value="rivian">Rivian</option><option value="rolls_royce">Rolls-Royce</option><option value="rover">Rover</option><option value="saab">Saab</option><option value="saleen">Saleen</option><option value="saturn">Saturn</option><option value="scion">Scion ...
# <label class="sds-label" for="make_select-modal-sticky">Make</label>
# <svg class="sds-text-field__icon" height="16" width="16"><use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#chevron-down"></use></svg>
# </div>
# </div>
# <div class="model">
# <div class="sds-input-container sds-input-container--dropdown">
# <select class="sds-text-field" disabled="" id="fields-lead-form-sticky-nav_model_select-modal-sticky" name="lead[trade_in][model]"><optgroup label=""><option selected="" value="">Choose a model</option></optgroup></select>
# <label class="sds-label" for="model_select-modal-sticky">Model</label>
# <svg class="sds-text-field__icon" height="16" width="16"><use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#chevron-down"></use></svg>
# </div>
# </div>
# <div class="year">
# <div class="sds-input-container sds-input-container--dropdown">
# <select class="sds-text-field" disabled="" id="fields-lead-form-sticky-nav_year_select-modal-sticky" name="lead[trade_in][year]"><optgroup label=""><option selected="" value="">Choose a year</option></optgroup></select>
# <label class="sds-label" for="year_select-modal-sticky">Year</label>
# <svg class="sds-text-field__icon" height="16" width="16"><use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#chevron-down"></use></svg>
# </div>
# </div>
# <div class="color">
# <div class="sds-input-container">
# <input class="sds-text-field" disabled="" id="color-modal-sticky" name="lead[trade_in][color]" phx-debounce="blur" placeholder=" " type="text" value=""/>
# <label class="sds-label" for="color-modal-sticky">Exterior color</label>
# </div>
# </div>
# <div class="mileage">
# <div class="sds-input-container">
# <input class="sds-text-field" disabled="" id="mileage_string-modal-sticky" name="lead[trade_in][mileage_string]" phx-debounce="blur" phx-hook="Mileage" placeholder=" " type="text" value=""/>
# <label class="sds-label" for="mileage_string-modal-sticky">Mileage</label>
# </div>
# </div>
# <div class="vin">
# <div class="sds-input-container">
# <input class="sds-text-field" disabled="" id="vin-modal-sticky" name="lead[trade_in][vin]" phx-debounce="blur" placeholder=" " type="text" value=""/>
# <label class="sds-label" for="vin-modal-sticky">VIN (optional)</label>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="sds-field sds-form-module__button">
# <button class="sds-button--fluid" type="submit">Check availability</button>
# </div>
# <small class="sds-disclaimer">
# <p>
#
# By clicking here, you authorize Cars.com and its sellers/partners to contact you by text/calls which may include marketing and be by autodialer. Calls may be prerecorded. You also agree to our Privacy Statement. Consent is not required to purchase goods/services.
#
#         </p>
# <p>
# We value your privacy.
# <a data-linkname="privacy-statement" href="/about/privacy/" target="_blank">Cars.com Privacy Statement</a>
# </p>
# </small>
# </div>
# </section>
# </form>
# </div>
# </div>
# </div>
# </div>
# <div data-override-payload="null" phx-hook="LeadSubmissionTracker" phx-target="#lead-form-sticky-nav" phx_value_cid="lead-form-sticky-nav"></div>
# <div phx-hook="LeadFormPositionAdjustments"></div>
# <div></div>
# </div>
# </div>
# </div>
# </section>
# <div data-phx-session="SFMyNTY.....7QiKgxvUC2312t2MAPerXegy4YMzxx8taEiXN0sTcM0" data-phx-static="SFMyNTY.g2gDaAJhBXQAAAADZAAKYXNzaWduX25ld2pkAAVmbGFzaHQAAAAAZAACaWRtAAAAFHBoeC1GeUJ0dm95VWxCR3lKZmFpbgYAwJhPAIQBYgABUYA.N6few8chBue8d2egHozE0JloQwA2uBsvhncLVd4d4lg" id="phx-FyBtvoyUlBGyJfai">
# <div class="hidden">
# <div class="sds-page-section__content">
# </div>
# </div>
# </div>
# <div data-phx-session="SFMyNTY..q7JRmbZLBd0Ve6M2-H4XeKBUWvbfYvUhoT56S_Gi6Cs" data-phx-static="SFMyNTY.g2gDaAJhBXQAAAADZAAKYXNzaWduX25ld2pkAAVmbGFzaHQAAAAAZAACaWRtAAAAFHBoeC1GeUJ0dm95WGZ0MnlKZmJDbgYAwZhPAIQBYgABUYA.gpFhHvVECUddLw6HaclLOF0_4_Wp3JmKPex4r07I67o" id="phx-FyBtvoyXft2yJfbC">
# <div id="print-listener" phx-hook="PrintListener"></div>
# </div>
# <script>
#   window.addEventListener("scroll", function(event) {
#     event.stopImmediatePropagation();
#   });
# </script>
# <section class="sds-page-section profile-banner">
# <div class="display-ad" data-ad-sizes="[[970, 90], [728, 90], [320, 50]]" data-ad-type="full-page-width" data-ad-unit-path="6427/shop/used.vdp/inline.10" data-appnexus-placement-id="17848547" data-hidden-on="" id="cars_banner_ad_6427/shop/used.vdp/inline.10" phx-update="ignore">
# <div alt="Advertisement" id="phx-ignore-container-cars_banner_ad_6427/shop/used.vdp/inline.10" phx-update="ignore"></div>
# </div>
# </section>
# <div>
# <section class="sds-page-section vdp-breadcrumb">
# <nav aria-label="breadcrumb">
# <ul class="sds-breadcrumb sds-breadcrumb--mobile-custom">
# <li><a data-component="breadcrumb" data-linkname="home" href="/">Home</a></li>
# <li class="sds-breadcrumb__parent">
# <span class="sds-icon">
# <svg aria-describedby="description" aria-labelledby="title" fill="none" height="16" role="img" stroke="#000000" stroke-linecap="round" stroke-linejoin="round" stroke-width="2" viewbox="0 0 24 24" width="16" xmlns="http://www.w3.org/2000/svg">
# <title id="title">arrow-left</title>
# <desc id="description">An arrow pointing left.</desc>
# <path d="M19 12H6M12 5l-7 7 7 7"></path></svg>
# </span>
# <span><a data-component="breadcrumb" data-linkname="shopping-mmystock" data-slugs="used;chrysler-crossfire-2007" href="/shopping/used/chrysler-crossfire-2007/">Shop other used 2007 Chrysler Crossfires</a></span>
# </li>
# <li aria-current="page">Used 2007 Chrysler Crossfire Limited</li>
# </ul>
# </nav>
# <script type="application/ld+json">
#   {"@context":"http://schema.org","@type":"BreadcrumbList","itemListElement":[{"@type":"ListItem","item":{"@id":"https://www.cars.com/","name":"Home"},"position":1},{"@type":"ListItem","item":{"@id":"https://www.cars.com/shopping/used/chrysler-crossfire-2007/","name":"Shop other used 2007 Chrysler Crossfires"},"position":2},{"@type":"ListItem","item":{"@id":"https://www.cars.com/vehicledetail/3459b73c-ac04-4a5e-99d2-6c25ce718674/","name":"Used 2007 Chrysler Crossfire Limited"},"position":3}]}
# </script>
# </section>
# </div>
# <div class="vdp-content-wrapper price-history-grid">
# <section class="listing-overview">
# <vdp-gallery label="2007 Bright Silver Clearcoat Metallic Chrysler Crossfire" media-count="25" video-url="https://vid.dmotorworks.com/vid5/?client=CARSCOM&amp;w=100%&amp;h=100%&amp;vid=E53F52DD67D56567E05337824D649F54">
# <div class="display-ad lightbox-ad lightbox-ad-desktop" slot="lightbox-ad">
# <div class="display-ad lightbox-ad lightbox-ad-desktop" data-ad-sizes="[[300, 600], [300, 250]]" data-ad-type="partial-page-width" data-ad-unit-path="6427/shop/used.vdp/photo" data-appnexus-placement-id="22499487" data-hidden-on='["mobile"]' id="desktop-gallery-lightbox-ad" phx-update="ignore">
# <div alt="Advertisement" id="phx-ignore-container-desktop-gallery-lightbox-ad" phx-update="ignore"></div>
# </div>
# </div>
# <iframe allow="fullscreen" allowfullscreen="" class="spin-frame" height="100%" src="" width="100%"></iframe>
# <gallery-controls allow-maximize="" arrow-click-intent-id="vdp-photo-gallery-click" context="vdp-gallery" maximize-click-intent-id="vdp-photo-gallery-click" media-count="25" tabindex="-1">
# </gallery-controls>
# <gallery-slides aria-label="Image carousel" context="vdp-gallery" maximize-click-intent-id="vdp-photo-gallery-click" slide-change-intent-id="vdp-photo-gallery-click">
# <div class="vdp-swipe-image-placeholder-before-loading"></div>
# <img alt="Photo of 2007 Bright Silver Clearcoat Metallic Chrysler Crossfire" class="swipe-main-image image-index-0" src="https://platform.cstatic-images.com/xlarge/in/v2/ca079241-ac98-5f62-8fb0-740aa70792d9/e70e2929-1b6d-4e40-9c31-b5e227d77f2b/x3OV3vqsQKy5A0lBzp87MfJr26g.jpg" tabindex="0"/>
# <img alt="Photo of 2007 Bright Silver Clearcoat Metallic Chrysler Crossfire" class="swipe-main-image image-index-1" data-src="https://platform.cstatic-images.com/xlarge/in/v2/ca079241-ac98-5f62-8fb0-740aa70792d9/e70e2929-1b6d-4e40-9c31-b5e227d77f2b/-CGEAPmP8QBO5T17FuLI-ERakxU.jpg" loading="lazy" src="/images/placeholder_10x10.png"/>
# <div class="show-for-mobile" data-modal-only="">
# <div class="display-ad lightbox-ad lightbox-ad-mobile" data-ad-sizes="[[300, 250]]" data-ad-type="partial-page-width" data-ad-unit-path="6427/shop/used.vdp/photo" data-appnexus-placement-id="22499487" data-hidden-on='["tablet", "desktop"]' id="mobile-gallery-lightbox-ad" phx-update="ignore">
# <div alt="Advertisement" id="phx-ignore-container-mobile-gallery-lightbox-ad" phx-update="ignore"></div>
# </div>
# </div>
# <img alt="Photo of 2007 Bright Silver Clearcoat Metallic Chrysler Crossfire" class="swipe-main-image image-index-2" data-src="https://platform.cstatic-images.com/xlarge/in/v2/ca079241-ac98-5f62-8fb0-740aa70792d9/e70e2929-1b6d-4e40-9c31-b5e227d77f2b/CgYXS6xiPPisN1zzlTglJGZXrhI.jpg" loading="lazy" src="/images/placeholder_10x10.png"/>
# <img alt="Photo of 2007 Bright Silver Clearcoat Metallic Chrysler Crossfire" class="swipe-main-image image-index-3" data-src="https://platform.cstatic-images.com/xlarge/in/v2/ca079241-ac98-5f62-8fb0-740aa70792d9/e70e2929-1b6d-4e40-9c31-b5e227d77f2b/axvgPPtIUQQzHzUjJ9-elhE9II8.jpg" loading="lazy" src="/images/placeholder_10x10.png"/>
# <img alt="Photo of 2007 Bright Silver Clearcoat Metallic Chrysler Crossfire" class="swipe-main-image image-index-4" data-src="https://platform.cstatic-images.com/xlarge/in/v2/ca079241-ac98-5f62-8fb0-740aa70792d9/e70e2929-1b6d-4e40-9c31-b5e227d77f2b/-K4_gQVlZRN0my01P4-ZCVvYA3g.jpg" loading="lazy" src="/images/placeholder_10x10.png"/>
# <img alt="Photo of 2007 Bright Silver Clearcoat Metallic Chrysler Crossfire" class="swipe-main-image image-index-5" data-src="https://platform.cstatic-images.com/xlarge/in/v2/ca079241-ac98-5f62-8fb0-740aa70792d9/e70e2929-1b6d-4e40-9c31-b5e227d77f2b/ZtRyIm_yRKETvxxkAvVvroqwAcA.jpg" loading="lazy" src="/images/placeholder_10x10.png"/>
# <img alt="Photo of 2007 Bright Silver Clearcoat Metallic Chrysler Crossfire" class="swipe-main-image image-index-6" data-src="https://platform.cstatic-images.com/xlarge/in/v2/ca079241-ac98-5f62-8fb0-740aa70792d9/e70e2929-1b6d-4e40-9c31-b5e227d77f2b/Olm3ze8D19-PSjBoaIDXkiGufa4.jpg" loading="lazy" src="/images/placeholder_10x10.png"/>
# <img alt="Photo of 2007 Bright Silver Clearcoat Metallic Chrysler Crossfire" class="swipe-main-image image-index-7" data-src="https://platform.cstatic-images.com/xlarge/in/v2/ca079241-ac98-5f62-8fb0-740aa70792d9/e70e2929-1b6d-4e40-9c31-b5e227d77f2b/p13Kjtro3j9s87quprrQjlbjqac.jpg" loading="lazy" src="/images/placeholder_10x10.png"/>
# <img alt="Photo of 2007 Bright Silver Clearcoat Metallic Chrysler Crossfire" class="swipe-main-image image-index-8" data-src="https://platform.cstatic-images.com/xlarge/in/v2/ca079241-ac98-5f62-8fb0-740aa70792d9/e70e2929-1b6d-4e40-9c31-b5e227d77f2b/ad6kouJLSr-JqDN4C5N0SFJIueM.jpg" loading="lazy" src="/images/placeholder_10x10.png"/>
# <img alt="Photo of 2007 Bright Silver Clearcoat Metallic Chrysler Crossfire" class="swipe-main-image image-index-9" data-src="https://platform.cstatic-images.com/xlarge/in/v2/ca079241-ac98-5f62-8fb0-740aa70792d9/e70e2929-1b6d-4e40-9c31-b5e227d77f2b/IH9b4ptdWNK_xN091EbE1Ai2HuA.jpg" loading="lazy" src="/images/placeholder_10x10.png"/>
# <img alt="Photo of 2007 Bright Silver Clearcoat Metallic Chrysler Crossfire" class="swipe-main-image image-index-10" data-src="https://platform.cstatic-images.com/xlarge/in/v2/ca079241-ac98-5f62-8fb0-740aa70792d9/e70e2929-1b6d-4e40-9c31-b5e227d77f2b/pj5iQTS5ybDUbwpHb3kGxTWL2A8.jpg" loading="lazy" src="/images/placeholder_10x10.png"/>
# <img alt="Photo of 2007 Bright Silver Clearcoat Metallic Chrysler Crossfire" class="swipe-main-image image-index-11" data-src="https://platform.cstatic-images.com/xlarge/in/v2/ca079241-ac98-5f62-8fb0-740aa70792d9/e70e2929-1b6d-4e40-9c31-b5e227d77f2b/86ijg2NLF-mTGSKsNKC11E4jCR8.jpg" loading="lazy" src="/images/placeholder_10x10.png"/>
# <img alt="Photo of 2007 Bright Silver Clearcoat Metallic Chrysler Crossfire" class="swipe-main-image image-index-12" data-src="https://platform.cstatic-images.com/xlarge/in/v2/ca079241-ac98-5f62-8fb0-740aa70792d9/e70e2929-1b6d-4e40-9c31-b5e227d77f2b/imGRBtn9Uy07MpzI33O-qwdOPyI.jpg" loading="lazy" src="/images/placeholder_10x10.png"/>
# <img alt="Photo of 2007 Bright Silver Clearcoat Metallic Chrysler Crossfire" class="swipe-main-image image-index-13" data-src="https://platform.cstatic-images.com/xlarge/in/v2/ca079241-ac98-5f62-8fb0-740aa70792d9/e70e2929-1b6d-4e40-9c31-b5e227d77f2b/qeDvn26IgV7ps5lo0iKCM5eeG14.jpg" loading="lazy" src="/images/placeholder_10x10.png"/>
# <img alt="Photo of 2007 Bright Silver Clearcoat Metallic Chrysler Crossfire" class="swipe-main-image image-index-14" data-src="https://platform.cstatic-images.com/xlarge/in/v2/ca079241-ac98-5f62-8fb0-740aa70792d9/e70e2929-1b6d-4e40-9c31-b5e227d77f2b/2SBEe90_qh5uz9Wfm17YV1B7Hdk.jpg" loading="lazy" src="/images/placeholder_10x10.png"/>
# <img alt="Photo of 2007 Bright Silver Clearcoat Metallic Chrysler Crossfire" class="swipe-main-image image-index-15" data-src="https://platform.cstatic-images.com/xlarge/in/v2/ca079241-ac98-5f62-8fb0-740aa70792d9/e70e2929-1b6d-4e40-9c31-b5e227d77f2b/hEp33UEHr_gzjww609a3kiio8HQ.jpg" loading="lazy" src="/images/placeholder_10x10.png"/>
# ...
# <li><a data-activity-rule-type="page-over-page" data-component="footer-our-company" data-component-index="4" data-linkname="footer-careers" href="/careers/">Careers</a></li>
# <li><a aria-describedby="new-tab-link" aria-label="Licensing &amp; Reprints, External link" class="sds-link--ext" data-activity-rule-type="custom" data-component="footer-our-company" data-component-index="5" data-linkname="footer-licensing-reprints" href="https://info.wrightsmedia.com/cars-licensing-reprints" rel="noopener" target="_blank">Licensing &amp; Reprints<svg class="sds-text-field__icon" height="16" width="16"><use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#arrow-up-right"></use></svg></a></li>
# <li><a data-activity-rule-type="page-over-page" data-component="footer-our-company" data-component-index="6" data-linkname="footer-site-map" href="/sitemap/">Site Map</a></li>
# <li><a data-activity-rule-type="custom" data-component="footer-our-company" data-component-index="7" data-linkname="footer-feedback" data-target="#qualtrics-modal" data-toggle="modal" href="#">Feedback</a></li>
# </ul>
# </div>
# </div>
# <div class="global-footer-group global-footer-apps-and-social">
# <div class="global-footer-social-header">
# <span class="global-footer-heading">Our Mobile App</span>
# </div>
# <div class="global-footer-mobile-apps">
# <a data-activity-rule-type="page-over-page" data-linkname="footer-mobile-apps" href="/mobile/">Download the App Today</a>
# <div class="global-footer-mobile-buttons">
# <a data-activity-rule-type="custom" data-linkname="footer-app-store" href="https://apps.apple.com/us/app/cars-com-new-used-cars/id353263352">
# <img alt="App Store download" class="app-store-button js-lazy-load" data-src="https://beta.cstatic-images.com/medium/in/v2/static/mobile-apps/app-store-badge-us-black-1.png"/>
# </a>
# <a data-activity-rule-type="custom" data-linkname="footer-google-play" href="https://play.google.com/store/apps/details?id=com.cars.android&amp;hl=en_US">
# <img alt="Google Play download" class="google-play-button js-lazy-load" data-src="https://beta.cstatic-images.com/medium/in/v2/static/mobile-apps/google-play-badge-us-1.png"/>
# </a>
# </div>
# </div>
# <div class="global-footer-social-header">
# <span class="global-footer-heading">Connect With Us</span>
# </div>
# <div class="global-footer-social-buttons">
# <ul class="global-footer-list sds-list">
# <li class="social-link"><a aria-describedby="new-tab-link" aria-label="Twitter, External link" class="sds-link--ext sds-button--icon sds-icon--contain twitter" data-activity-rule-type="custom" data-component="footer-social" data-component-index="1" data-linkname="footer-twitter" href="https://twitter.com/carsdotcom" rel="noopener" target="_blank"><svg height="16" width="16"><use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#twitter"></use></svg></a></li>
# <li class="social-link"><a aria-describedby="new-tab-link" aria-label="Facebook, External link" class="sds-link--ext sds-button--icon sds-icon--contain facebook" data-activity-rule-type="custom" data-component="footer-social" data-component-index="2" data-linkname="footer-facebook" href="https://www.facebook.com/CarsDotCom/" rel="noopener" target="_blank"><svg height="16" width="16"><use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#facebook"></use></svg></a></li>
# <li class="social-link"><a aria-describedby="new-tab-link" aria-label="Youtube, External link" class="sds-link--ext sds-button--icon sds-icon--contain youtube" data-activity-rule-type="custom" data-component="footer-social" data-component-index="3" data-linkname="footer-youtube" href="https://www.youtube.com/user/Carscom/" rel="noopener" target="_blank"><svg height="16" width="16"><use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#youtube"></use></svg></a></li>
# <li class="social-link"><a aria-describedby="new-tab-link" aria-label="Instagram, External link" class="sds-link--ext sds-button--icon sds-icon--contain instagram" data-activity-rule-type="custom" data-component="footer-social" data-component-index="4" data-linkname="footer-instagram" href="https://www.instagram.com/carsdotcom/" rel="noopener" target="_blank"><svg height="16" width="16"><use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#instagram"></use></svg></a></li>
# <li class="social-link"><a aria-describedby="new-tab-link" aria-label="Linkedin, External link" class="sds-link--ext sds-button--icon sds-icon--contain linkedin" data-activity-rule-type="custom" data-component="footer-social" data-component-index="5" data-linkname="footer-linkedin" href="https://www.linkedin.com/company/cars-com" rel="noopener" target="_blank"><svg height="16" width="16"><use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#linkedin"></use></svg></a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="global-copyright">
# <div class="sds-container">
# <ul class="sds-list">
# <li><a data-activity-rule-type="page-over-page" data-component="footer-legal" data-component-index="1" data-linkname="footer-tos" href="/about/terms/">Terms of Service</a></li>
# <li><a data-activity-rule-type="page-over-page" data-component="footer-legal" data-component-index="2" data-linkname="footer-privacy-statement" href="/about/privacy/">Privacy Statement</a></li>
# <li><a data-activity-rule-type="page-over-page" data-component="footer-legal" data-component-index="3" data-linkname="footer-personal-information" href="/about/ccpa-privacy-notice/">Do Not Sell My Personal Information</a></li>
# <li><a data-activity-rule-type="page-over-page" data-component="footer-legal" data-component-index="4" data-linkname="footer-accessibility" href="/about/accessibility/">Accessibility Statement</a></li>
# <li><a data-activity-rule-type="page-over-page" data-component="footer-legal" data-component-index="5" data-linkname="footer-ad-choices" href="/about/ad-choices/">Ad Choices</a></li>
# </ul>
# <div class="global-copyright-copy">©
# 2022 Cars.com. All rights reserved.</div>
# </div>
# </div>
# <div aria-modal="true" class="sds-modal sds-modal-one" id="qualtrics-modal">
# <div class="sds-modal__content">
# <div class="sds-modal__content-head sds-modal__content-head">
# <div class="sds-icon--target btn-close js-close" role="button">
# <span class="sds-icon">
# <svg height="16" width="16"><use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#close"></use></svg>
# </span>
# </div>
# </div>
# <iframe class="qualtrics-form" data-src="https://cars.qualtrics.com/jfe/form/SV_81Hx3Jkheo8zhmC " height="800px" width="600px"></iframe>
# </div>
# </div>
# </footer>
# <script src="https://prod.embed.conversations.dealerinspire.com/5b76-e888-110a5"></script>
# <link data-href="/cf2f739ebb78c97a8bb9/css/common.css?vsn=d" media="print" rel="stylesheet"/>
# <link data-href="/cf2f739ebb78c97a8bb9/css/shop.css?vsn=d" media="print" rel="stylesheet"/>
# <link data-href="https://fonts.googleapis.com/css?family=Roboto" rel="stylesheet" type="text/css"/>
# <script>
#   window.CARS = window.CARS || {}
#   window.CARS["initialActivity"] = {"photo_count":25,"market_name":null,"user_state":"anonymous","utm_campaign":null,"designated_market_area_key":null,"private_seller":"","lat_long":"/","trip_id":"","local_zone":null,"customer_id":"103956","trim":"Limited","stock_sub":"","page_key":"vehicle-details","msrp":null,"facebook_event_id":"dHJpcF9pZD1iN2ZkZGJkOC0wOWY3LTRiM2QtYTVlNy05NTUxMGQ3MzA5NzAmdHM9MTY2NjQ1MjUyNzIwNg==","price":"17900","loginStatus":false,"bodystyle":"Convertible","sponsored":false,"canonical_mmt":"Chrysler:Crossfire:Limited","year":"2007","utm_source":null,"utm_term":null,"platform_id":"cars_responsive","dealer_zip":"18704","fuel_type":"Gasoline","url_referer":"","dealer_dma":"","cpo_indicator":false,"vhr":{"accidents_or_damage":false,"one_owner_vehicle":false,"open_recall":false,"personal_use_only":false,"vhr_type":"carfax free"},"page_channel":"shopping","aff_code":"national","stock_type":"Used","vin":"1C3LN65L37X072465","marketing_click_data":null,"page_features":["ph"],"canonical_mmty":"Chrysler:Crossfire:Limited:2007","seller_type":"dealership","drivetrain":"Rear-wheel Drive","dealer_name":"Rayco Eurospec Motorcars","interior_color":"Dark Slate Gray / Medium Slate Gray","price_badge":null,"search_instance_id":"","page_detail":null,"model":"Crossfire","utm_medium":null,"cat":"coupeconvertible_coupe","partner_name":"","utm_content":null,"page_type":"shopping/vehicle-details","badges":["price_drop_in_cents"],"url_base":"","exterior_color":"Bright Silver Clearcoat Metallic","profileAccountType":null,"listing_id":"3459b73c-ac04-4a5e-99d2-6c25ce718674","seller_id":null,"marketing_referral_source":"","make":"Chrysler","zip_ip2geo":null,"page_name":"shopping/vehicle-details","mileage":"32903","useragent":"","vertical_position":"","marketing_click_id":""}
# </script>
# <script>
#   window.CARS = window.CARS || {}
#   window.CARS["initialAls"] = {"adobe_id":null,"results_per_page":null,"als_private_data":"QTEyOEdDTQ.6KM9dXoGt71yHZ78u-69CUSEN6ul4tY8pztd7toeyZ0NByBrplxXTMUsI-I.fqtE6bZKRLEJoA8S.-3S592m76lEZKArZFlGz4U_o-3VL_V8nqerkYB1FyIT1zhzbxEzzbjNVdNCwCBKsoGt5oRyn.5XC1foNjaLeOHN5YnlfbCA","web_page_type_from":"","utm_campaign":null,"bot_type":"Unknown Bot (B0B1CB20BEBCAE0F191F2D67CC6B7C5E):monitor:Behavior Anomaly;High-Velocity-BOT:100:aggressive","latitude":null,"trip_id":"","lead_event_id":null,"upsells":["conversations"],"web_page_type_to":"shopping/vehicle-details","internet_connection":null,"customer_id":"103956","roxanne_visit_id":"","pdid":null,"trim":"limited","ga_client_id":null,"msrp":null,"facebook_event_id":"dHJpcF9pZD1iN2ZkZGJkOC0wOWY3LTRiM2QtYTVlNy05NTUxMGQ3MzA5NzAmdHM9MTY2NjQ1MjUyNzIwNg==","price":17900,"model_year":"2007","bodystyle":"convertible","utm_source":null,"utm_term":null,"device_model":null,"marketing_click_source":"","platform_id":"cars_responsive","finance_application_id":null,"device_os":null,"carrier":null,"cpo_indicator":false,"iframe_location":"","app_version":null,"aff_code":"national","x_forwarded_for":null,"stock_type":"used","page_instance_id":"FyBtvoPp24ywsiUAtDul","profile_user_id":null,"results_page_number":null,"incentive_ids":"","referer_url":"","search_instance_id":null,"device_id":null,"model":"crossfire","timestamp_utc":1666452527258,"utm_medium":null,"external_uuids":null,"utm_content":null,"experiment_ids":[{"index":0,"name":"ab_test_2_srp_hp_prod"},{"index":1,"name":"ab_test_6_vdp_prod"},{"index":2,"name":"ab_test_11_vdp_prod"},{"analytics":{"payload":{"pe":"tnt","tnta":"188464:0:0|0,188464:0:0|2,188464:0:0|1"}},"index":3,"name":"ab_test_12_srp_vdp_prod","options":[{"responseTokens":{"activity.id":"188464","activity.name":"Prod | Cars Web | AB Test 12 | SRP, VDP | All Visitors","experience.id":"0","experience.name":"Control","geo.city":"ashburn","geo.country":"united states","geo.state":"virginia","offer.id":"0","profile.activeActivities":"188464","profile.daysSinceLastVisit":"0","profile.firstDateTime":"1666452527196","profile.fourGroups":"GroupB","profile.isFirstSession":"true","profile.isNewSession":"true","profile.tntId":"4bc20847-83b3-45a3-9a12-9ba6884f9998","profile.twentyGroups":"Group9","profile.twoGroups":"GroupA","profile.visitNumber":"Place holder: requires new solution"},"sourceType":"target"}]}],"listing_id":"3459b73c-ac04-4a5e-99d2-6c25ce718674","seller_id":null,"roxanne_visitor_id":"","results_page_count":null,"facebook_event_intent_id":"capi_viv_event","device_type":"desktop","make":"chrysler","longitude":null,"page_url":"https://www.cars.com/vehicledetail/3459b73c-ac04-4a5e-99d2-6c25ce718674/","content_slug":"","horizontal_position":"","total_results":null,"search_zipcode":null,"useragent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.121 Safari/537.36","is_bot":true,"vertical_position":"","marketing_click_id":""}
# </script>
# <script async="" data-src="https://www.googletagservices.com/tag/js/gpt.js"></script>
# <script>
#   window.googletag = window.googletag || {cmd: []};
#   window.pbjs = window.pbjs || {que: []};
#   window.CARS = window.CARS || {};
#   window.CARS.disableAds = false;
#   window.CARS.disablePrebid = true;
#   window.CARS.isTest = false
# </script>
# <script async="" data-src="https://assets.adobedtm.com/306a737f2df1/a3d882c1ebd5/launch-3edaffcf6794.min.js" id="adobe-launch-script"></script>
# <script async="" data-src="https://d1n00d49gkbray.cloudfront.net/js/cars.js"></script>
# <script async="" data-src="https://accounts.google.com/gsi/client" defer=""></script>
# <script>
#   window.CARS["dispatcher"] = [];
#   window.CARS["dispatcher"].push({"CarsWeb": null})
#
#   window.CARS["dispatcher"].push({"CarsWeb.ListingController": null})
# window.CARS["dispatcher"].push({"CarsWeb.ListingController.show": {"callSourceDniMetadata":{"analytics":{"affCode":"national","ipAddress":"186.104.251.122","platform":"cars_responsive","source":"ca079241-ac98-5f62-8fb0-740aa70792d9","sourcePage":"shopping/vehicle-details","sourceUrl":"https://www.cars.com/vehicledetail/3459b73c-ac04-4a5e-99d2-6c25ce718674/"},"dimensions":{"bodyStyle":["Convertible"],"certified":false,"cylCntId":["6"],"drCntId":["2"],"drvTrnId":["Rear-wheel Drive"],"extColor":["Bright Silver Clearcoat Metallic"],"fuelTypeId":["Gasoline"],"intColor":["Dark Slate Gray / Medium Slate Gray"],"listingId":"3459b73c-ac04-4a5e-99d2-6c25ce718674","make":["Chrysler"],"mileage":"32903","model":["Crossfire"],"normFeatureId":["Premium Sound System","Brake Assist","Leather Seats","Alloy Wheels","Stability Control"],"price":"17900","stockNumber":"072465","transTypeId":["6-Speed Manual"],"trim":["Limited"],"type":["Used"],"vin":"1C3LN65L37X072465","year":"2007"},"seller":{"id":"ca079241-ac98-5f62-8fb0-740aa70792d9","phoneNumber":"(570) 763-4500","zipcode":"18704"},"user":{"city":"Kingston","profileUserId":null,"state":"PA","tripId":""}},"chatWidgetMetadata":{"affId":"national","carsData":{"aff_code":"national","customer_id":103956,"data_version":"1","listing_id":"3459b73c-ac04-4a5e-99d2-6c25ce718674","make":"Chrysler","model":"Crossfire","page_instance_id":"FyBtvoPp24ywsiUAtDul","page_url":"https://www.cars.com/vehicledetail/3459b73c-ac04-4a5e-99d2-6c25ce718674/","pdid":null,"platform_id":"cars_responsive","price":17900,"search_instance_id":null,"stock_number":"072465","stock_type":"Used","trip_id":"","utm_campaign":null,"utm_medium":null,"utm_source":null,"vin":"1C3LN65L37X072465","web_page_type_from":"shopping/vehicle-details","year":2007}},"chatWidgetProvider":"dealer_inspire","remoteUserPreferencesFlagEnabled":true,"shopperFinancingConfig":{"credit_iq_destination_org_id":"55345020-a94f-bb8a-b888-031ba15fecaf","listing_id":"3459b73c-ac04-4a5e-99d2-6c25ce718674","model_year_id":"e5ef0243-f3b3-47a8-811c-2be62600af07","sdk_url":"https://checkout.creditiq.com/ciq-sdk.js","source_org_id":"87f675b7-c000-414b-87f8-45c5a1555e8c","token_bundle":null,"trim_id":"013fd6a6-7b59-48c4-b361-288924fea89e","trip_id":"","user":{},"vehicleInfo":{"isCertified":false,"make":"Chrysler","mileage":"32903","model":"Crossfire","salePrice":"17900","trim":"Limited","type":"used","vin":"1C3LN65L37X072465","year":"2007"}}}})
#
# </script>
# <div data-id="188464:0:0|0,188464:0:0|2,188464:0:0|1" hidden="" id="tnta-options"></div>
# <script id="graphql-config" type="application/json">
#     {
#
#       "apiKey": "5rrmnWVl1MDzPcEnDvEp3Pu101IGXEGo",
#       "url": "https://graph.cars.com/graphql/api"
#     }
#   </script>
# <noscript><img src="https://www.cars.com/akam/13/pixel_11e83a5d?a=dD0wZDViYTE2ODAyZWFiYzZkMjI2YjI1NWNiMWI2MzcyYzllMzE0YmI4JmpzPW9mZg==" style="visibility: hidden; position: absolute; left: -999px; top: -999px;"/></noscript><script src="/nct3uuwFUO2NJSkdiA/7J9NthpDEbGO/BUYyEwh-WAY/FWtfDAZ/WRH0B" type="text/javascript"></script></body>
# </html>

# %% [markdown]
# ### New_used

# %%
try:
    new_used = soup.find('p', {'class':'new-used'}).get_text()
except:
    new_used = 'n/a'
new_used
# Out:
# 'Used'

# %% [markdown]
# ### Title

# %%
try:
    title = soup.find('h1', {'class':'listing-title'}).get_text()
except:
    title = 'n/a'
title
# Out:
# '2007 Chrysler Crossfire Limited'

# %% [markdown]
# ### Mileage

# %%
try:
    mileage = soup.find('div', {'class':'listing-mileage'}).get_text()
except:
    mileage = 'n/a'
mileage
# Out:
# ' 32,903 mi.'

# %% [markdown]
# ### Price

# %%
try:
    price = soup.find('span', {'class':'primary-price'}).get_text()
except:
    price = 'n/a'
price
# Out:
# '$17,900'

# %% [markdown]
# ### Exterior_color

# %%
try:
    ext_color = soup.findAll({'dd'})
except:
    ext_color = 'n/a'
a = ext_color[0].get_text()
a
# Out:
# ' Bright Silver Clearcoat Metallic '

# %% [markdown]
# ### Interior_color

# %%
try:
    int_color = soup.findAll({'dd'})
except:
    int_color = 'n/a'
b = int_color[1].get_text()
b
# Out:
# ' Dark Slate Gray / Medium Slate Gray '

# %% [markdown]
# ### Drivetrain

# %%
try:
    drivetrain = soup.findAll({'dd'})
except:
    drivetrain = 'n/a'
c = drivetrain[2].get_text()
c
# Out:
# ' Rear-wheel Drive '

# %% [markdown]
# ### Fuel_type

# %%
try:
    fuel_type = soup.findAll({'dd'})
except:
    fuel_type = 'n/a'
d = fuel_type[4].get_text()
d
# Out:
# 'Gasoline '

# %% [markdown]
# ### Transmission

# %%
try:
    transmission = soup.findAll({'dd'})
except:
    transmission = 'n/a'
e = transmission[5].get_text()
e
# Out:
# '6-Speed Manual'

# %% [markdown]
# ### Engine

# %%
try:
    engine = soup.findAll({'dd'})
except:
    engine = 'n/a'
f = engine[6].get_text()
f
# Out:
# '3.2L V6 18V MPFI SOHC'

# %% [markdown]
# ### Comfort

# %%
try:
    comfort = soup.findAll('span', {'class':'sds-definition-list__value'})
except:
    comfort = 'n/a'
g = comfort[0].get_text()
g
# Out:
# '4.1'

# %% [markdown]
# ### Interior_design

# %%
try:
    int_des = soup.findAll('span', {'class':'sds-definition-list__value'})
except:
    int_des = 'n/a'
h = int_des[1].get_text()
h
# Out:
# '4.5'

# %% [markdown]
# ### Performance

# %%
try:
    performance = soup.findAll('span', {'class':'sds-definition-list__value'})
except:
    performance = 'n/a'
i = performance[2].get_text()
i
# Out:
# '4.7'

# %% [markdown]
# ### Value_for_money

# %%
try:
    vfm = soup.findAll('span', {'class':'sds-definition-list__value'})
except:
    vfm = 'n/a'
j = vfm[3].get_text()
j
# Out:
# '5.0'

# %% [markdown]
# ### Exterior_styling

# %%
try:
    ext_sty = soup.findAll('span', {'class':'sds-definition-list__value'})
except:
    ext_sty = 'n/a'
k = ext_sty[4].get_text()
k
# Out:
# '4.9'

# %% [markdown]
# ### Reliability

# %%
try:
    reliability = soup.findAll('span', {'class':'sds-definition-list__value'})
except:
    reliability = 'n/a'
l = reliability[5].get_text()
l
# Out:
# '4.9'

# %% [markdown]
# ### Overall_score

# %%
try:
    os = soup.findAll('span', {'class':'sds-rating__count'})
except:
    os = 'n/a'
m = os[1].get_text()
m
# Out:
# '4.9'

# %% [markdown]
# ### Seller_score

# %%
try:
    ss = soup.findAll('span', {'class':'sds-rating__count'})
except:
    ss = 'n/a'
n = ss[0].get_text()
n
# Out:
# '4.7'

# %% [markdown]
# ### URL

# %%
try:
    url = first_link
except:
    url = 'n/a'
url
# Out:
# 'https://www.cars.com/vehicledetail/3459b73c-ac04-4a5e-99d2-6c25ce718674/'
