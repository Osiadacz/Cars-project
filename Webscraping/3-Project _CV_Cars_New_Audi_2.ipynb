# %% [markdown]
# ## Imports

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import urllib.parse
import time

# %%
# create dataframe (in the beginning it is empty)
df_cars = pd.DataFrame(columns=['New_used', 'Title', 'Mileage', 'Exterior_color', 'Interior_color', 'Drivetrain', 'Fuel_type', 'Transmission', 'Engine', 
                                'Comfort', 'Interior_design', 'Performance', 'Value_for_money', 'Exterior_styling', 'Reliability', 'Overall_score',
                                'Seller_score', 'Price', 'url'])

# Sequence of numbers - 1 to 500 (501 is not included)
for i in range(1,501):
    time.sleep(1)
    
    # variable for pages within website
    website = 'https://www.cars.com/shopping/results/?page='+str(i)+'&page_size=20&list_price_max=&makes[]=audi&maximum_distance=20&models[]=&stock_type=new&zip='
    
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.121 Safari/537.36'}
    
    # request
    response = requests.get(website, headers=headers)
    
    # create soup object
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # result
    result = soup.find_all('div', {'phx-hook':'VehicleCard'})
    
    # we combine url part no. 1 with url part no. 2 in order to get the absolute url
    url_part_1 = 'https://www.cars.com'
    
    url_part_2 = []

    # Loop through the results
    for item in result:
        # Loop through links
        for link in item.find_all('a', {'class':'vehicle-card-link js-gallery-click-link'}):
            url_part_2.append(link.get('href'))
            
    url_joined = []

    for link_2 in url_part_2:
        url_joined.append(urllib.parse.urljoin(url_part_1, link_2))
        
    for link in url_joined:
        time.sleep(0.5)
        
        response = requests.get(link, headers=headers)
        
        # create soup object
        soup = BeautifulSoup(response.content, 'html.parser')
        
        # New_used
        try:
            new_used = soup.find('p', {'class':'new-used'}).get_text()
        except:
            new_used = 'n/a'
            
        # Title
        try:
            title = soup.find('h1', {'class':'listing-title'}).get_text()
        except:
            title = 'n/a'
            
        # Mileage
        try:
            mileage = soup.find('div', {'class':'listing-mileage'}).get_text()
        except:
            mileage = 'n/a'
            
        # Exterior_color
        try:
            ext_color = soup.findAll({'dd'})
            a = ext_color[0].get_text()
        except:
            a = 'n/a'
        
        # Interior_color
        try:
            int_color = soup.findAll({'dd'})
            b = int_color[1].get_text()
        except:
            b = 'n/a'
            
        # Drivetrain
        try:
            drivetrain = soup.findAll({'dd'})
            c = drivetrain[2].get_text()
        except:
            c = 'n/a'
        
        # Fuel_type
        try:
            fuel_type = soup.findAll({'dd'})
            d = fuel_type[4].get_text()
        except:
            d = 'n/a'
        
        # Transmission
        try:
            transmission = soup.findAll({'dd'})
            e = transmission[5].get_text()
        except:
            e = 'n/a'
        
        # Engine
        try:
            engine = soup.findAll({'dd'})
            f = engine[6].get_text()
        except:
            f = 'n/a'
        
        # Comfort
        try:
            comfort = soup.findAll('span', {'class':'sds-definition-list__value'})
            g = comfort[0].get_text()
        except:
            g = 'n/a'
        
        # Interior_design
        try:
            int_des = soup.findAll('span', {'class':'sds-definition-list__value'})
            h = int_des[1].get_text()
        except:
            h = 'n/a'
        
        # Performance
        try:
            performance = soup.findAll('span', {'class':'sds-definition-list__value'})
            i = performance[2].get_text()
        except:
            i = 'n/a'
        
        # Value_for_money
        try:
            vfm = soup.findAll('span', {'class':'sds-definition-list__value'})
            j = vfm[3].get_text()
        except:
            j = 'n/a'
        
        # Exterior_styling
        try:
            ext_sty = soup.findAll('span', {'class':'sds-definition-list__value'})
            k = ext_sty[4].get_text()
        except:
            k = 'n/a'
        
        # Reliability
        try:
            reliability = soup.findAll('span', {'class':'sds-definition-list__value'})
            l = reliability[5].get_text()
        except:
            l = 'n/a'
        
        # Overall_score
        try:
            os = soup.findAll('span', {'class':'sds-rating__count'})
            m = os[1].get_text()
        except:
            m = 'n/a'
        
        # Seller_score
        try:
            ss = soup.findAll('span', {'class':'sds-rating__count'})
            n = ss[0].get_text()
        except:
            n = 'n/a'
        
        # Price
        try:
            price = soup.find('span', {'class':'primary-price'}).get_text()
        except:
            price = 'n/a'
            
        # Pandas DataFrame
        df_cars = df_cars.append({'New_used': new_used, 'Title': title, 'Mileage': mileage, 'Exterior_color': a, 'Interior_color': b, 'Drivetrain': c, 'Fuel_type': d,
                                  'Transmission': e, 'Engine': f, 'Comfort': g, 'Interior_design': h, 'Performance': i, 'Value_for_money': j, 'Exterior_styling': k,
                                  'Reliability': l, 'Overall_score': m, 'Seller_score': n, 'Price': price, 'url': link}, ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# D:\Anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     174             conn = connection.create_connection(
# --> 175                 (self._dns_host, self.port), self.timeout, **extra_kw
#     176             )
#
# D:\Anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      95     if err is not None:
# ---> 96         raise err
#      97
#
# D:\Anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      85                 sock.bind(source_address)
# ---> 86             sock.connect(sa)
#      87             return sock
#
# TimeoutError: [WinError 10060] Se produjo un error durante el intento de conexión ya que la parte conectada no respondió adecuadamente tras un periodo de tiempo, o bien se produjo un error en la conexión establecida ya que el host conectado no ha podido responder
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# D:\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     705                 headers=headers,
# --> 706                 chunked=chunked,
#     707             )
#
# D:\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     381         try:
# --> 382             self._validate_conn(conn)
#     383         except (SocketTimeout, BaseSSLError) as e:
#
# D:\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#    1009         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1010             conn.connect()
#    1011
#
# D:\Anaconda3\lib\site-packages\urllib3\connection.py in connect(self)
#     357         # Add certificate verification
# --> 358         conn = self._new_conn()
#     359         hostname = self.host
#
# D:\Anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     186             raise NewConnectionError(
# --> 187                 self, "Failed to establish a new connection: %s" % e
#     188             )
#
# NewConnectionError: <urllib3.connection.HTTPSConnection object at 0x0000023515D77CC8>: Failed to establish a new connection: [WinError 10060] Se produjo un error durante el intento de conexión ya que la parte conectada no respondió adecuadamente tras un periodo de tiempo, o bien se produjo un error en la conexión establecida ya que el host conectado no ha podido responder
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# D:\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#
# D:\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     755             retries = retries.increment(
# --> 756                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     757             )
#
# D:\Anaconda3\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     573         if new_retry.is_exhausted():
# --> 574             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     575
#
# MaxRetryError: HTTPSConnectionPool(host='www.cars.com', port=443): Max retries exceeded with url: /vehicledetail/5a535e20-5dce-4df5-965b-0f4e29833110/ (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000023515D77CC8>: Failed to establish a new connection: [WinError 10060] Se produjo un error durante el intento de conexión ya que la parte conectada no respondió adecuadamente tras un periodo de tiempo, o bien se produjo un error en la conexión establecida ya que el host conectado no ha podido responder'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1940/3097479917.py in <module>
#      41         time.sleep(0.5)
#      42
# ---> 43         response = requests.get(link, headers=headers)
#      44
#      45         # create soup object
#
# D:\Anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73     """
#      74
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# D:\Anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# D:\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# D:\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# D:\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     514                 raise SSLError(e, request=request)
#     515
# --> 516             raise ConnectionError(e, request=request)
#     517
#     518         except ClosedPoolError as e:
#
# ConnectionError: HTTPSConnectionPool(host='www.cars.com', port=443): Max retries exceeded with url: /vehicledetail/5a535e20-5dce-4df5-965b-0f4e29833110/ (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000023515D77CC8>: Failed to establish a new connection: [WinError 10060] Se produjo un error durante el intento de conexión ya que la parte conectada no respondió adecuadamente tras un periodo de tiempo, o bien se produjo un error en la conexión establecida ya que el host conectado no ha podido responder'))

# %%
df_cars
# Out:
#      New_used                           Title  Mileage  \
# 0         New         2022 Audi Q7 45 Premium    7 mi.
# 1         New         2022 Audi Q7 55 Premium   10 mi.
# 2         New         2022 Audi Q7 55 Premium   10 mi.
# 3         New         2022 Audi Q7 55 Premium    5 mi.
# 4         New         2023 Audi Q7 55 Premium    7 mi.
# ...       ...                             ...      ...
# 6336      New      2023 Audi SQ5 3.0T Premium   14 mi.
# 6337      New  2022 Audi A5 2.0T Premium Plus    0 mi.
# 6338      New         2023 Audi A6 55 Premium    7 mi.
# 6339      New             2023 Audi RS 3 2.5T    0 mi.
# 6340      New      2022 Audi SQ5 3.0T Premium   18 mi.
#
#                    Exterior_color Interior_color         Drivetrain  \
# 0          Mythos Black Metallic          Black                AWD
# 1          Navarra Blue Metallic          Black                AWD
# 2                  Carrara White          Black    All-wheel Drive
# 3          Navarra Blue Metallic          Black    All-wheel Drive
# 4          Navarra Blue Metallic          Black    All-wheel Drive
# ...                           ...            ...                ...
# 6336       Mythos Black Metallic          Black    All-wheel Drive
# 6337                  Ibis White          Black    All-wheel Drive
# 6338       Chronos Gray Metallic          Black                AWD
# 6339      Kyalami Green Metallic          Black    All-wheel Drive
# 6340   Daytona Gray Pearl Effect          Black    All-wheel Drive
#
#       Fuel_type                       Transmission  \
# 0     Gasoline                           Automatic
# 1     Gasoline                           Automatic
# 2     Gasoline                           Automatic
# 3     Gasoline                           Automatic
# 4     Gasoline                           Automatic
# ...         ...                                ...
# 6336  Gasoline                           Automatic
# 6337  Gasoline   7-Speed Automatic with Auto-Shift
# 6338  Gasoline                           Automatic
# 6339  Gasoline                           Automatic
# 6340  Gasoline                           Automatic
#
#                           Engine Comfort Interior_design Performance  \
# 0     2.0L I4 16V GDI DOHC Turbo     5.0             5.0         5.0
# 1     3.0L V6 24V GDI DOHC Turbo     5.0             5.0         5.0
# 2     3.0L V6 24V GDI DOHC Turbo     5.0             5.0         5.0
# 3     3.0L V6 24V GDI DOHC Turbo     5.0             5.0         5.0
# 4     3.0L V6 24V GDI DOHC Turbo     n/a             n/a         n/a
# ...                          ...     ...             ...         ...
# 6336  3.0L V6 24V GDI DOHC Turbo     n/a             n/a         n/a
# 6337  2.0L I4 16V GDI DOHC Turbo     n/a             n/a         n/a
# 6338  3.0L V6 24V GDI DOHC Turbo     n/a             n/a         n/a
# 6339                    Gasoline     n/a             n/a         n/a
# 6340  3.0L V6 24V GDI DOHC Turbo     n/a             n/a         n/a
#
#      Value_for_money Exterior_styling Reliability Overall_score Seller_score  \
# 0                5.0              5.0         5.0           5.0          4.7
# 1                5.0              5.0         5.0           5.0          4.7
# 2                5.0              5.0         5.0           5.0          4.7
# 3                5.0              5.0         5.0           5.0          4.6
# 4                n/a              n/a         n/a           n/a          4.7
# ...              ...              ...         ...           ...          ...
# 6336             n/a              n/a         n/a           n/a          4.8
# 6337             n/a              n/a         n/a           5.0          5.0
# 6338             n/a              n/a         n/a           n/a          4.7
# 6339             n/a              n/a         n/a           4.4          4.7
# 6340             n/a              n/a         n/a           n/a          4.9
#
#         Price                                                url
# 0     $62,540  https://www.cars.com/vehicledetail/c1bfd477-b3...
# 1     $68,240  https://www.cars.com/vehicledetail/93de7bb7-5f...
# 2     $65,685  https://www.cars.com/vehicledetail/66035be2-78...
# 3     $67,765  https://www.cars.com/vehicledetail/817e7322-24...
# 4     $68,405  https://www.cars.com/vehicledetail/1c009213-91...
# ...       ...                                                ...
# 6336  $72,055  https://www.cars.com/vehicledetail/ddabd8b4-a7...
# 6337  $53,040  https://www.cars.com/vehicledetail/6c7c2b7a-7f...
# 6338  $64,590  https://www.cars.com/vehicledetail/66dea813-b2...
# 6339  $65,925  https://www.cars.com/vehicledetail/c5b76b8e-23...
# 6340  $63,635  https://www.cars.com/vehicledetail/c441cf72-79...
#
# [6341 rows x 19 columns]

# %%
df = df_cars

# %% [markdown]
# ### Add a new column with the brand of the cars

# %%
df['Brand'] = 'Audi'

# %%
df.head()
# Out:
#   New_used                    Title  Mileage           Exterior_color  \
# 0      New  2022 Audi Q7 45 Premium    7 mi.   Mythos Black Metallic
# 1      New  2022 Audi Q7 55 Premium   10 mi.   Navarra Blue Metallic
# 2      New  2022 Audi Q7 55 Premium   10 mi.           Carrara White
# 3      New  2022 Audi Q7 55 Premium    5 mi.   Navarra Blue Metallic
# 4      New  2023 Audi Q7 55 Premium    7 mi.   Navarra Blue Metallic
#
#   Interior_color         Drivetrain  Fuel_type Transmission  \
# 0         Black                AWD   Gasoline     Automatic
# 1         Black                AWD   Gasoline     Automatic
# 2         Black    All-wheel Drive   Gasoline     Automatic
# 3         Black    All-wheel Drive   Gasoline     Automatic
# 4         Black    All-wheel Drive   Gasoline     Automatic
#
#                        Engine Comfort Interior_design Performance  \
# 0  2.0L I4 16V GDI DOHC Turbo     5.0             5.0         5.0
# 1  3.0L V6 24V GDI DOHC Turbo     5.0             5.0         5.0
# 2  3.0L V6 24V GDI DOHC Turbo     5.0             5.0         5.0
# 3  3.0L V6 24V GDI DOHC Turbo     5.0             5.0         5.0
# 4  3.0L V6 24V GDI DOHC Turbo     n/a             n/a         n/a
#
#   Value_for_money Exterior_styling Reliability Overall_score Seller_score  \
# 0             5.0              5.0         5.0           5.0          4.7
# 1             5.0              5.0         5.0           5.0          4.7
# 2             5.0              5.0         5.0           5.0          4.7
# 3             5.0              5.0         5.0           5.0          4.6
# 4             n/a              n/a         n/a           n/a          4.7
#
#      Price                                                url Brand
# 0  $62,540  https://www.cars.com/vehicledetail/c1bfd477-b3...  Audi
# 1  $68,240  https://www.cars.com/vehicledetail/93de7bb7-5f...  Audi
# 2  $65,685  https://www.cars.com/vehicledetail/66035be2-78...  Audi
# 3  $67,765  https://www.cars.com/vehicledetail/817e7322-24...  Audi
# 4  $68,405  https://www.cars.com/vehicledetail/1c009213-91...  Audi

# %% [markdown]
# ### Store in Excel

# %%
df.to_excel(r'E:\Proyects\Python proyects\WEBSCRAPING\Project_CV_Cars\3-cars_new_Audi_4-10-2022.xlsx', index=False)
