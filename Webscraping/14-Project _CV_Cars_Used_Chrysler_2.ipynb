# %% [markdown]
# ## Imports

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import urllib.parse
import time

# %%
# create dataframe (in the beginning it is empty)
df_cars = pd.DataFrame(columns=['New_used', 'Title', 'Mileage', 'Exterior_color', 'Interior_color', 'Drivetrain', 'Fuel_type', 'Transmission', 'Engine', 
                                'Comfort', 'Interior_design', 'Performance', 'Value_for_money', 'Exterior_styling', 'Reliability', 'Overall_score',
                                'Seller_score', 'Price', 'url'])

# Sequence of numbers - 1 to 500 (501 is not included)
for i in range(1,501):
    time.sleep(1)
    
    # variable for pages within website
    website = 'https://www.cars.com/shopping/results/?page='+str(i)+'&page_size=20&list_price_max=&makes[]=chrysler&maximum_distance=all&models[]=&stock_type=used&zip='
    
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.121 Safari/537.36'}
    
    # request
    response = requests.get(website, headers=headers)
    
    # create soup object
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # result
    result = soup.find_all('div', {'phx-hook':'VehicleCard'})
    
    # we combine url part no. 1 with url part no. 2 in order to get the absolute url
    url_part_1 = 'https://www.cars.com'
    
    url_part_2 = []

    # Loop through the results
    for item in result:
        # Loop through links
        for link in item.find_all('a', {'class':'vehicle-card-link js-gallery-click-link'}):
            url_part_2.append(link.get('href'))
            
    url_joined = []

    for link_2 in url_part_2:
        url_joined.append(urllib.parse.urljoin(url_part_1, link_2))
        
    for link in url_joined:
        time.sleep(1)
        
        response = requests.get(link, headers=headers)
        
        # create soup object
        soup = BeautifulSoup(response.content, 'html.parser')
        
        # New_used
        try:
            new_used = soup.find('p', {'class':'new-used'}).get_text()
        except:
            new_used = 'n/a'
            
        # Title
        try:
            title = soup.find('h1', {'class':'listing-title'}).get_text()
        except:
            title = 'n/a'
            
        # Mileage
        try:
            mileage = soup.find('div', {'class':'listing-mileage'}).get_text()
        except:
            mileage = 'n/a'
            
        # Exterior_color
        try:
            ext_color = soup.findAll({'dd'})
            a = ext_color[0].get_text()
        except:
            a = 'n/a'
        
        # Interior_color
        try:
            int_color = soup.findAll({'dd'})
            b = int_color[1].get_text()
        except:
            b = 'n/a'
            
        # Drivetrain
        try:
            drivetrain = soup.findAll({'dd'})
            c = drivetrain[2].get_text()
        except:
            c = 'n/a'
        
        # Fuel_type
        try:
            fuel_type = soup.findAll({'dd'})
            d = fuel_type[4].get_text()
        except:
            d = 'n/a'
        
        # Transmission
        try:
            transmission = soup.findAll({'dd'})
            e = transmission[5].get_text()
        except:
            e = 'n/a'
        
        # Engine
        try:
            engine = soup.findAll({'dd'})
            f = engine[6].get_text()
        except:
            f = 'n/a'
        
        # Comfort
        try:
            comfort = soup.findAll('span', {'class':'sds-definition-list__value'})
            g = comfort[0].get_text()
        except:
            g = 'n/a'
        
        # Interior_design
        try:
            int_des = soup.findAll('span', {'class':'sds-definition-list__value'})
            h = int_des[1].get_text()
        except:
            h = 'n/a'
        
        # Performance
        try:
            performance = soup.findAll('span', {'class':'sds-definition-list__value'})
            i = performance[2].get_text()
        except:
            i = 'n/a'
        
        # Value_for_money
        try:
            vfm = soup.findAll('span', {'class':'sds-definition-list__value'})
            j = vfm[3].get_text()
        except:
            j = 'n/a'
        
        # Exterior_styling
        try:
            ext_sty = soup.findAll('span', {'class':'sds-definition-list__value'})
            k = ext_sty[4].get_text()
        except:
            k = 'n/a'
        
        # Reliability
        try:
            reliability = soup.findAll('span', {'class':'sds-definition-list__value'})
            l = reliability[5].get_text()
        except:
            l = 'n/a'
        
        # Overall_score
        try:
            os = soup.findAll('span', {'class':'sds-rating__count'})
            m = os[1].get_text()
        except:
            m = 'n/a'
        
        # Seller_score
        try:
            ss = soup.findAll('span', {'class':'sds-rating__count'})
            n = ss[0].get_text()
        except:
            n = 'n/a'
        
        # Price
        try:
            price = soup.find('span', {'class':'primary-price'}).get_text()
        except:
            price = 'n/a'
            
        # Pandas DataFrame
        df_cars = df_cars.append({'New_used': new_used, 'Title': title, 'Mileage': mileage, 'Exterior_color': a, 'Interior_color': b, 'Drivetrain': c, 'Fuel_type': d,
                                  'Transmission': e, 'Engine': f, 'Comfort': g, 'Interior_design': h, 'Performance': i, 'Value_for_money': j, 'Exterior_styling': k,
                                  'Reliability': l, 'Overall_score': m, 'Seller_score': n, 'Price': price, 'url': link}, ignore_index=True)

# %%
df_cars
# Out:
#      New_used                                  Title       Mileage  \
# 0        Used                    2016 Chrysler 300 S    57,516 mi.
# 1        Used                    2016 Chrysler 200 S    10,070 mi.
# 2        Used                    2021 Chrysler 300 S    17,453 mi.
# 3        Used                    2020 Chrysler 300 S    42,825 mi.
# 4        Used  2017 Chrysler Pacifica Touring-L Plus    70,889 mi.
# ...       ...                                    ...           ...
# 9928     Used         2017 Chrysler Pacifica Touring    66,483 mi.
# 9929     Used              2020 Chrysler Voyager LXI    71,705 mi.
# 9930     Used                    2021 Chrysler 300 S    44,935 mi.
# 9931     Used              2012 Chrysler 300 Limited   166,192 mi.
# 9932     Used       2019 Chrysler Pacifica Touring-L    45,422 mi.
#
#                             Exterior_color Interior_color  \
# 0                                    Blue              –
# 1      Granite Crystal Clearcoat Metallic          Black
# 2                             Gloss Black          Black
# 3                                  Maroon          Black
# 4                    Velvet Red Pearlcoat          Black
# ...                                    ...            ...
# 9928                                 Gold          Black
# 9929               Bright White Clearcoat         Cognac
# 9930                                White              –
# 9931                                Black          Black
# 9932    Brilliant Black Crystal Pearlcoat          Black
#
#                Drivetrain       Fuel_type       Transmission  \
# 0        All-wheel Drive        Gasoline   8-Speed Automatic
# 1        All-wheel Drive   E85 Flex Fuel   9-Speed Automatic
# 2       Rear-wheel Drive        Gasoline   8-Speed Automatic
# 3        All-wheel Drive        Gasoline   8-Speed Automatic
# 4      Front-wheel Drive        Gasoline   9-Speed Automatic
# ...                   ...             ...                ...
# 9928   Front-wheel Drive        Gasoline   9-Speed Automatic
# 9929   Front-wheel Drive        Gasoline   9-Speed Automatic
# 9930    Rear-wheel Drive        Gasoline   8-Speed Automatic
# 9931    Rear-wheel Drive   E85 Flex Fuel   8-Speed Automatic
# 9932   Front-wheel Drive        Gasoline   9-Speed Automatic
#
#                                    Engine Comfort Interior_design Performance  \
# 0                   3.6L V6 24V MPFI DOHC     4.7             4.7         4.7
# 1     3.6L V6 24V MPFI DOHC Flexible Fuel     4.5             4.5         4.3
# 2                   3.6L V6 24V MPFI DOHC     5.0             5.0         5.0
# 3                   3.6L V6 24V MPFI DOHC     4.7             4.8         4.8
# 4                   3.6L V6 24V MPFI DOHC     4.8             4.7         4.6
# ...                                   ...     ...             ...         ...
# 9928                3.6L V6 24V MPFI DOHC     4.8             4.7         4.6
# 9929                3.6L V6 24V MPFI DOHC     5.0             4.5         5.0
# 9930                3.6L V6 24V MPFI DOHC     5.0             5.0         5.0
# 9931  3.6L V6 24V MPFI DOHC Flexible Fuel     4.9             4.8         4.7
# 9932                3.6L V6 24V MPFI DOHC     4.9             4.8         4.7
#
#      Value_for_money Exterior_styling Reliability Overall_score Seller_score  \
# 0                4.6              4.7         4.6           2.1          4.7
# 1                4.2              4.7         4.4           5.0          5.0
# 2                5.0              5.0         5.0           5.0          5.0
# 3                4.8              4.8         4.9           4.8          4.8
# 4                4.4              4.8         4.5           1.6          4.6
# ...              ...              ...         ...           ...          ...
# 9928             4.4              4.8         4.5           1.6          4.6
# 9929             5.0              5.0         5.0           5.0          5.0
# 9930             5.0              5.0         5.0           5.0          5.0
# 9931             4.7              4.9         4.7           4.8          3.5
# 9932             4.6              4.8         4.6           5.0          5.0
#
#         Price                                                url
# 0     $26,995  https://www.cars.com/vehicledetail/278e26a6-77...
# 1     $24,475  https://www.cars.com/vehicledetail/63a818c4-b2...
# 2     $34,000  https://www.cars.com/vehicledetail/3e225570-91...
# 3     $27,900  https://www.cars.com/vehicledetail/2fc7a7c3-f5...
# 4     $25,250  https://www.cars.com/vehicledetail/093b5ce0-d2...
# ...       ...                                                ...
# 9928  $21,900  https://www.cars.com/vehicledetail/70074847-95...
# 9929  $21,377  https://www.cars.com/vehicledetail/156dfdb5-41...
# 9930  $35,995  https://www.cars.com/vehicledetail/db0aa509-73...
# 9931   $9,695  https://www.cars.com/vehicledetail/65ab58b8-7c...
# 9932  $29,995  https://www.cars.com/vehicledetail/7a2fbd7e-db...
#
# [9933 rows x 19 columns]

# %%
df = df_cars

# %% [markdown]
# ### Add a new column with the brand of the cars

# %%
df['Brand'] = 'Chrysler'

# %%
df.head()
# Out:
#   New_used                                  Title      Mileage  \
# 0     Used                    2016 Chrysler 300 S   57,516 mi.
# 1     Used                    2016 Chrysler 200 S   10,070 mi.
# 2     Used                    2021 Chrysler 300 S   17,453 mi.
# 3     Used                    2020 Chrysler 300 S   42,825 mi.
# 4     Used  2017 Chrysler Pacifica Touring-L Plus   70,889 mi.
#
#                          Exterior_color Interior_color           Drivetrain  \
# 0                                 Blue              –      All-wheel Drive
# 1   Granite Crystal Clearcoat Metallic          Black      All-wheel Drive
# 2                          Gloss Black          Black     Rear-wheel Drive
# 3                               Maroon          Black      All-wheel Drive
# 4                 Velvet Red Pearlcoat          Black    Front-wheel Drive
#
#         Fuel_type       Transmission                               Engine  \
# 0       Gasoline   8-Speed Automatic                3.6L V6 24V MPFI DOHC
# 1  E85 Flex Fuel   9-Speed Automatic  3.6L V6 24V MPFI DOHC Flexible Fuel
# 2       Gasoline   8-Speed Automatic                3.6L V6 24V MPFI DOHC
# 3       Gasoline   8-Speed Automatic                3.6L V6 24V MPFI DOHC
# 4       Gasoline   9-Speed Automatic                3.6L V6 24V MPFI DOHC
#
#   Comfort Interior_design Performance Value_for_money Exterior_styling  \
# 0     4.7             4.7         4.7             4.6              4.7
# 1     4.5             4.5         4.3             4.2              4.7
# 2     5.0             5.0         5.0             5.0              5.0
# 3     4.7             4.8         4.8             4.8              4.8
# 4     4.8             4.7         4.6             4.4              4.8
#
#   Reliability Overall_score Seller_score    Price  \
# 0         4.6           2.1          4.7  $26,995
# 1         4.4           5.0          5.0  $24,475
# 2         5.0           5.0          5.0  $34,000
# 3         4.9           4.8          4.8  $27,900
# 4         4.5           1.6          4.6  $25,250
#
#                                                  url     Brand
# 0  https://www.cars.com/vehicledetail/278e26a6-77...  Chrysler
# 1  https://www.cars.com/vehicledetail/63a818c4-b2...  Chrysler
# 2  https://www.cars.com/vehicledetail/3e225570-91...  Chrysler
# 3  https://www.cars.com/vehicledetail/2fc7a7c3-f5...  Chrysler
# 4  https://www.cars.com/vehicledetail/093b5ce0-d2...  Chrysler

# %% [markdown]
# ### Store in Excel

# %%
df.to_excel(r'E:\Proyects\Python proyects\WEBSCRAPING\Project_CV_Cars\14-cars_used_Chrysler_22-10-2022.xlsx', index=False)
