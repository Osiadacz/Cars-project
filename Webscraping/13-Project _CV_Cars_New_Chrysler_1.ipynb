# %% [markdown]
# ## Imports

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import time
import urllib.parse

# %% [markdown]
# ### HTTP Request

# %% [markdown]
# #### store website in variable

# %%
website = 'https://www.cars.com/shopping/results/?page=1&page_size=20&list_price_max=&makes[]=chrysler&maximum_distance=all&models[]=&stock_type=new&zip='

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.121 Safari/537.36'}

# %% [markdown]
# #### Get Request

# %%
response = requests.get(website, headers=headers)

# %% [markdown]
# #### Status Code

# %%
response.status_code
# Out:
# 200

# %% [markdown]
# ### Soup Object

# %%
soup = BeautifulSoup(response.content, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html class="ep-theme-cars" lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <title data-suffix=" | Cars.com">New Chrysler for Sale | Cars.com</title>
# <meta content="Shop Chrysler vehicles for sale at Cars.com. Research, compare, and save listings, or contact sellers directly from 2,535 Chrysler models nationwide." name="description"/>
# <meta content="noindex, nofollow" name="robots"/>
# <meta content="Cars.com" property="og:site_name"/>
# <meta content="website" property="og:type"/>
# <meta content="New Chrysler for Sale | Cars.com" property="og:title"/>
# <meta content="https://www.cars.com/shopping/results" property="og:url"/>
# <meta content="Shop Chrysler vehicles for sale at Cars.com. Research, compare, and save listings, or contact sellers directly from 2,535 Chrysler models nationwide." property="og:description"/>
# <meta content="https://graphics.cars.com/images/core/logo.png" property="og:image"/>
# <meta content="290349283473" property="fb:app_id"/>
# <meta content="app-id=353263352" name="apple-itunes-app"/>
# <meta content="@carsdotcom" name="twitter:site"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="New Chrysler for Sale | Cars.com" name="twitter:title"/>
# <meta content="Shop Chrysler vehicles for sale at Cars.com. Research, compare, and save listings, or contact sellers directly from 2,535 Chrysler models nationwide." name="twitter:description"/>
# <meta content="https://graphics.cars.com/images/core/logo.png" name="twitter:image"/>
# <script type="application/ld+json">{"@context":"http://www.schema.org","@type":"WebSite","name":"Cars.com","url":"https://www.cars.com/"}</script>
# <style>
# a,abbr,acronym,address,applet,article,aside,audio,b,big,blockquote,body,button,canvas,caption,center,cite,code,dd,del,details,dfn,div,dl,dt,em,embed,fieldset,figcaption,figure,footer,form,h1,h2,h3,h4,h5,h6,header,hgroup,html,i,iframe,img,ins,kbd,label,legend,li,main,mark,menu,nav,object,ol,output,p,pre,q,ruby,s,samp,section,small,span,strike,strong,sub,summary,sup,table,tbody,td,tfoot,th,thead,time,tr,tt,u,ul,var,video{border:0;font-weight:400;margin:0;padding:0;vertical-align:baseline}article,aside,details,figcaption,figure,footer,header,hgroup,main,menu,nav,section{display:block}body{line-height:1}ol,ul{list-style:none}blockquote,q{quotes:none}blockquote:after,blockquote:before,q:after,q:before{content:"";content:none}table{border-collapse:collapse;border-spacing:0}.sds-checkbox,.sds-radio{display:inline;position:relative}.sds-checkbox:after,.sds-radio:after{content:"\a";white-space:pre}.sds-checkbox+.sds-checkbox,.sds-checkbox+.sds-radio,.sds-radio+.sds-checkbox,.sds-radio+.sds-radio{margin-top:16px}.sds-checkbox .sds-input,.sds-radio .sds-input{height:20px;left:0;opacity:0;position:absolute;top:0;width:20px}.sds-checkbox .sds-input+.sds-label,.sds-checkbox .sds-input+.sds-legend,.sds-radio .sds-input+.sds-label,.sds-radio .sds-input+.sds-legend{-webkit-user-select:none;-moz-user-select:none;user-select:none}.sds-checkbox .sds-input+.sds-label:before,.sds-checkbox .sds-input+.sds-legend:before,.sds-radio .sds-input+.sds-label:before,.sds-radio .sds-input+.sds-legend:before{border:1px solid #bdbdbd;content:"";height:20px;left:0;position:absolute;top:-.1em;width:20px}.sds-checkbox .sds-input:disabled+.sds-label,.sds-checkbox .sds-input:disabled+.sds-legend,.sds-radio .sds-input:disabled+.sds-label,.sds-radio .sds-input:disabled+.sds-legend{cursor:not-allowed;opacity:.4}.sds-checkbox .sds-input.error+.sds-label:before,.sds-checkbox .sds-input.error+.sds-legend:before,.sds-radio .sds-input.error+.sds-label:before,.sds-radio .sds-input.error+.sds-legend:before{border-color:#c10}.sds-checkbox .sds-input:focus+.sds-label:before,.sds-checkbox .sds-input:focus+.sds-legend:before,.sds-radio .sds-input:focus+.sds-label:before,.sds-radio .sds-input:focus+.sds-legend:before{box-shadow:0 0 0 2px #00bfde}.sds-checkbox .sds-input+.sds-label:after,.sds-checkbox .sds-input+.sds-legend:after,.sds-radio .sds-input+.sds-label:after,.sds-radio .sds-input+.sds-legend:after{border:3px solid #000;border-left:0;border-top:0;content:"";height:12px;left:7px;opacity:0;position:absolute;top:1px;transform:rotate(45deg);width:7px}.sds-inverse .sds-checkbox .sds-input+.sds-label:after,.sds-inverse .sds-checkbox .sds-input+.sds-legend:after,.sds-inverse .sds-radio .sds-input+.sds-label:after,.sds-inverse .sds-radio .sds-input+.sds-legend:after{border-color:#fff}.sds-checkbox .sds-input:checked+.sds-label:after,.sds-checkbox .sds-input:checked+.sds-legend:after,.sds-radio .sds-input:checked+.sds-label:after,.sds-radio .sds-input:checked+.sds-legend:after{opacity:1}.sds-checkbox .sds-label,.sds-checkbox .sds-legend,.sds-radio .sds-label,.sds-radio .sds-legend{cursor:pointer;margin:0;padding:0 0 0 32px;position:relative}.sds-checkbox .error~.sds-label,.sds-checkbox .error~.sds-legend,.sds-radio .error~.sds-label,.sds-radio .error~.sds-legend{color:#c10}.sds-checkbox:focus,.sds-radio:focus{outline:2px solid Highlight}@media(-webkit-min-device-pixel-ratio:0){.sds-checkbox:focus,.sds-radio:focus{outline-color:-webkit-focus-ring-color;outline-style:auto}}.sds-template-3-col,.sds-template-filters,.sds-template-sidebar,.sds-template-sidebar-tight{max-width:1170px}@media (min-width:768px){.sds-template-3-col,.sds-template-filters,.sds-template-sidebar,.sds-template-sidebar-tight{margin:0 auto}}@media (min-width:980px){.sds-template-3-col,.sds-template-filters,.sds-template-sidebar,.sds-template-sidebar-tight{display:grid}}html{box-sizing:border-box;height:100%;width:100%}*,:after,:before{-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale;box-sizing: ...
#
#       </style>
# <style>
# .accordion-group{border-bottom:1px solid #e6e6e6}.accordion-header{align-items:center;display:flex;height:48px;justify-content:space-between;min-height:48px}.accordion-header .accordion-section-title{font-size:16px;width:100%}.accordion-header[aria-expanded=true] .accordion-section-icon{transform:rotate(180deg)}.accordion-panel[aria-hidden=true]{display:none}.accordion-panel[aria-hidden=false]{display:flex;flex-direction:column;padding:0 0 16px}.active-filter-tags{margin:0 16px 16px;position:relative}@media (min-width:768px){.active-filter-tags{margin-right:0}}.active-filter-tags .flex-container{display:flex;flex-direction:row;justify-content:space-between}.active-filter-tags .flex-container .show-more-less{align-content:flex-end;display:flex;flex-direction:row;justify-content:flex-start;margin-top:16px}.active-filter-tags .flex-container .show-more-less .sds-text-field__icon{stroke:#b0c!important;margin-left:5px;margin-top:5px}.active-filter-tags .flex-container .show-more-less span{color:#b0c;cursor:pointer}.active-filter-tags .flex-container .clear-all-filter-tags{margin-right:16px;margin-top:16px}.active-filter-tags .flex-container .clear-all-filter-tags span{color:#b0c;cursor:pointer}.active-filter-tags .active-filter-checkbox{display:none}.active-filter-tags .mobile-filtering-by{margin-bottom:16px}@media (min-width:768px){.active-filter-tags .mobile-filtering-by{display:none}}.branded-canvas{border:1px solid #e6e6e6;box-shadow:inset 0 -1px 0 0 #e6e6e6;height:520px;margin-bottom:24px;position:relative;width:100%}@media (min-width:768px){.branded-canvas{height:343px}}@media (min-width:980px){.branded-canvas{height:343px}}.branded-canvas .branded-canvas-main-container{display:flex;flex-direction:column;height:272px;overflow:hidden;position:relative;width:100%}@media (min-width:768px){.branded-canvas .branded-canvas-main-container{flex-direction:row;height:265px;justify-content:space-between}}.branded-canvas .branded-canvas-main-container .branded-canvas-from{color:#fff;font-size:11px;font-style:italic;left:10px;position:absolute;top:32px;z-index:1}.branded-canvas .branded-canvas-main-container .branded-canvas-logo{height:55px;position:absolute;right:12px;top:10px;width:55px;z-index:1}.branded-canvas .branded-canvas-main-container .branded-canvas-car-container{flex:0 0 45%;height:175px;position:relative;text-align:center;z-index:1}@media (min-width:768px){.branded-canvas .branded-canvas-main-container .branded-canvas-car-container{flex:0 0 50%}}.branded-canvas .branded-canvas-main-container .branded-canvas-car-container img{max-width:280px;padding-top:52px;position:inherit}@media (min-width:768px){.branded-canvas .branded-canvas-main-container .branded-canvas-car-container img{left:11%;max-width:80%;padding-top:0;position:absolute;top:30%}}.branded-canvas .branded-canvas-main-container .branded-canvas-button-container-desktop{display:none}@media (min-width:768px){.branded-canvas .branded-canvas-main-container .branded-canvas-button-container-desktop{display:flex;justify-content:flex-end}}.branded-canvas .branded-canvas-main-container .branded-canvas-button-container-desktop .sds-button--secondary-dense .sds-text-field__icon_1{stroke:#532380}.branded-canvas .branded-canvas-main-container .branded-canvas-button-container-desktop .sds-button--secondary-dense:hover .sds-text-field__icon_1{stroke:#fff;transition:stroke .25s ease}.branded-canvas .branded-canvas-main-container .branded-canvas-button-container-desktop .button-1{flex:1 1 50%;margin:16px 8px 16px 0;padding:8px;z-index:3}.branded-canvas .branded-canvas-main-container .branded-canvas-button-container-desktop .button-1 .sds-text-field__icon{stroke:#532380;margin-left:4px}.branded-canvas .branded-canvas-main-container .branded-canvas-button-container-desktop .button-2{flex:1 1 50%;margin:16px 16px 16px 0;padding:8px;z-index:3}.branded-canvas .branded-canvas-main-container .branded-canvas-button-container-desktop .button-2 .sds-text-field__icon{stroke:#fff;margin-left:4px} ...
#
#           </style>
# <script defer="" src="/348126e679f08e6d6721/js/app.js?vsn=d"></script>
# <script id="datadog-config" type="application/json">
#     {
#         "clientToken": "pubd9e029f457b6d51b3d399c5b5c8fa7a4",
#         "applicationId": "c7070c7e-6068-4c84-828a-0e3b134e372d",
#         "site": "datadoghq.com",
#         "service": "cars_web",
#         "sampleRate": 2,
#         "trackInteractions": true,
#         "trackFrustrations": true
#
#     }
# </script>
# <script id="datadog-global-context" type="application/json">
# {"env":"production","trip_id":""}
# </script>
# <meta content="AmMvZhgIOzZpFV0KKghZGw0wVA9AZjZyP5J3ACTl_J5PAE-h_T1h9_rB" name="csrf-token"/>
# <script>bazadebezolkohpepadr="919080078"</script><script defer="" src="https://www.cars.com/akam/13/36c80cba" type="text/javascript"></script></head>
# <div hidden="">
# <span id="new-tab-link">Opens website in a new tab</span>
# </div>
# <body>
# <div class="global-header-container">
# <cars-global-header>
# <header class="global-header">
# <section class="container">
# <a class="header-logo" data-activity-rule-type="page-over-page" data-component="header-click" data-linkname="header-home" href="/"><img alt="Cars.com" class="header-logo header-logo__img" src="/images/logo_cars-46214ae902ff93ba8fa2e40fb73dfa02.png?vsn=d"/></a>
# <nav class="">
# <ul class="header-links">
# <li class="header-link"><a class="link-active" data-activity-rule-type="page-over-page" data-component="header-click" data-component-index="1" data-linkname="header-buy" data-nav-link="" href="/shopping/">Cars for Sale</a></li>
# <li class="header-link"><a data-activity-rule-type="page-over-page" data-component="header-click" data-component-index="2" data-linkname="header-research" data-nav-link="" href="/research/">Research &amp; Reviews</a></li>
# <li class="header-link"><a data-activity-rule-type="page-over-page" data-component="header-click" data-component-index="3" data-linkname="header-news" data-nav-link="" href="/news/">News &amp; Videos</a></li>
# <li class="header-link"><a data-activity-rule-type="page-over-page" data-component="header-click" data-component-index="4" data-linkname="header-sell-your-car" data-nav-link="" href="/sell/">Sell Your Car</a></li>
# <li class="header-link"><a data-activity-rule-type="page-over-page" data-component="header-click" data-component-index="5" data-linkname="header-service" data-nav-link="" href="/auto-repair/">Service &amp; Repair</a></li>
# </ul>
# <button aria-haspopup="true" aria-label="navigation menu" class="nav-user-menu-button" data-activity-rule-type="custom" data-linkname="header-menu">
# <ep-svg class="menu-icon" library="cars" name="hamburger"></ep-svg>
# <span class="nav-user-name">
# Menu
#             </span>
# <span class="menu-text">Menu</span>
# </button>
# <div id="google-one-tap">
# <div data-client_id="67273791563-90cd8jqav0pgefmmb4l5732bguvbjapi.apps.googleusercontent.com" data-login_uri="/signin/google_callback/" data-moment_callback="trackGoogleOneTap" data-redirect_path="/shopping/results/?redirect_event%5Bsocial_platform%5D=google" id="g_id_onload">
# </div>
# </div>
# </nav>
# <ep-modal class="nav-modal">
# <div class="sds-heading--2" id="menu-heading">
# <span class="nav-user-name">
# Menu
#               </span>
# <span class="menu-text">Menu</span>
# </div>
# <ul class="menu-links">
# <li class="header-link"><a class="link-active" data-activity-rule-type="page-over-page" data-component="header-click" data-component-index="1" data-linkname="header-buy" data-nav-link="" href="/shopping/">Cars for Sale</a></li>
# <li class="header-link"><a data-activity-rule-type="page-over-page" data-component="header-click" data-component-index="2" data-linkname="header-research" data-nav-link="" href="/research/">Research &amp; Reviews</a></li>
# <li class="header-link"><a data-activity-rule-type="page-over-page" data-component="header-click" data-component-index="3" data-linkname="header-news" data-nav-link="" href="/news/">News &amp; Videos</a></li>
# <li class="header-link"><a data-activity-rule-type="page-over-page" data-component="header-click" data-component-index="4" data-linkname="header-sell-your-car" data-nav-link="" href="/sell/">Sell Your Car</a></li>
# <li class="header-link"><a data-activity-rule-type="page-over-page" data-component="header-click" data-component-index="5" data-linkname="header-service" data-nav-link="" href="/auto-repair/">Service &amp; Repair</a></li>
# </ul>
# <ul class="profile-links">
# <li class="profile-link"><a data-activity-rule-type="page-over-page" data-component="header-click" data-component-index="1" data-linkname="header-saved-cars" data-profile-link="" href="/profile/saved-cars/"><ep-svg library="cars" name="heart-empty"></ep-svg>
# Saved Cars</a></li>
# <li class="profile-link"><a data-activity-rule-type="page-over-page" data-component="header-click" data-component-index="2" data-linkname="header-saved-searches" data-profile-link="" href="/profile/saved-searches/"><ep-svg library="cars" name="search"></ep-svg>
# Saved Searches</a></li>
# <li class="profile-link"><a data-activity-rule-type="page-over-page" data-component="header-click" data-component-index="3" data-linkname="header-your-garage" data-profile-link="" href="/profile/your-garage/"><ep-svg library="cars" name="tag"></ep-svg>
# Your Garage</a></li>
# </ul>
# <div class="sign-in-up-out">
# <a class="header-signin sds-button--secondary-dense" content="Sign in" data-activity-rule-type="page-over-page" data-component="sign-in-start" data-linkname="header-sign-in" href="/signin/?redirect_path=%2Fshopping%2Fresults%2F%3Flist_price_max%3D%26makes%255B%255D%3Dchrysler%26maximum_distance%3Dall%26models%255B%255D%3D%26page%3D1%26page_size%3D20%26stock_type%3Dnew%26zip%3D">Sign in</a>
# <a class="header-signup sds-button--dense" content="Create an account" data-activity-rule-type="page-over-page" data-component="sign-up-start" data-linkname="header-sign-up" href="/signup/?redirect_path=%2Fshopping%2Fresults%2F%3Flist_price_max%3D%26makes%255B%255D%3Dchrysler%26maximum_distance%3Dall%26models%255B%255D%3D%26page%3D1%26page_size%3D20%26stock_type%3Dnew%26zip%3D">Create an account</a>
# </div>
# </ep-modal>
# </section>
# </header>
# </cars-global-header>
# </div>
# <section class="sds-page-container" role="main">
# <div data-qa="notifications-are-here"></div>
# <div data-phx-main="true" data-phx-session="SFMyNTY...._6qcmDAWIAAVGA.ZsKhrSqXq0QmsXDi13PYRw-rxcs0Ak_cfV3UQzG0IDo" data-phx-static="SFMyNTY.g2gDaAJhBXQAAAADZAAKYXNzaWduX25ld2wAAAACZAANaXNfc2VhcmNoX2JvdGQADGN1cnJlbnRfdXNlcmpkAAVmbGFzaHQAAAAAZAACaWRtAAAAFHBoeC1GeDByNWVHSjY0WmFYYklCbgYA7_qpyYMBYgABUYA.deRx5vFqkFTHe3RWCoFOBGXVGUALVgoFd_uG3kT8qRY" id="phx-Fx0r5eGJ64ZaXbIB">
# <link as="image" href="https://platform.cstatic-images.com/large/in/v2/color_matched_stock_photos/f4137412-01e3-4fea-8634-48ef3d8d54c4/df8a8cfc-7cae-4181-9a57-8c505071b941.jpg" rel="preload"/>
# <div aria-modal="true" class="sds-modal aria-modal sds-modal-one lead-form-container" id="srp-lead-form-modal" phx-hook="LeadForm" phx-target="#srp-lead-form-modal">
# <div class="lead-modal sds-modal__content" phx-click="close" phx-target="#srp-lead-form-modal" phx-value-close="false">
# <div class="lead-modal sds-modal__content-head">
# <div class="sds-icon--target btn-close" phx-click="reset" phx-target="#srp-lead-form-modal" role="button">
# <span class="sds-icon">
# <svg height="16" width="16"><use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#close"></use></svg>
# </span>
# </div>
# </div>
# <div class="lead-modal sds-modal__content-body">
# <div class="dealer-section lead-form-top-anchor" id="dealer-section--">
# <header>
# <h2 class="sds-heading--3 lead-form-heading">Contact seller</h2>
# </header>
# </div>
# <div class="lead-form" id="lead-form-container-">
# <form action="#" data-index="" data-reset-activity-limit-for="email-lead-error--inline" id="fields-srp-lead-form-modal" method="post" phx-change="change" phx-hook="EmailLeadForm" phx-submit="save_lead" phx-target="#srp-lead-form-modal"><input name="_csrf_token" type="hidden" value="AmMvZhgIOzZpFV0KKghZGw0wVA9AZjZyP5J3ACTl_J5PAE-h_T1h9_rB"/>
# <section data-activity-limit="1" data-activity-rule-type="custom" data-conversion-type="email-lead-error--inline" data-errorname="email-lead-error--inline" data-index="">
# <div>
# <div class="sds-field-group">
# <div class="customer-form">
# <div class="first-name">
# <div class="sds-input-container">
# <input class="sds-text-field" data-fs="exclude" id="first_name-modal-" name="lead[first_name]" phx-debounce="blur" placeholder=" " type="text"/>
# <label class="sds-label" for="first_name-modal-">First name</label>
# </div>
# </div>
# <div class="last-name">
# <div class="sds-input-container">
# <input class="sds-text-field" data-fs="exclude" id="last_name-modal-" name="lead[last_name]" phx-debounce="blur" placeholder=" " type="text"/>
# <label class="sds-label" for="last_name-modal-">Last name</label>
# </div>
# </div>
# <div class="email">
# <div class="sds-input-container">
# <input class="sds-text-field" data-emailtype="transact" data-fs="exclude" id="email-modal-" name="lead[email]" phx-debounce="blur" phx-hook="EmailInput" placeholder=" " type="text"/>
# <label class="sds-label" for="email-modal-">Email</label>
# </div>
# </div>
# <div class="phone">
# <div class="sds-input-container">
# <input class="sds-text-field" data-fs="exclude" id="phone-modal-" name="lead[phone]" phx-debounce="blur" phx-hook="PhoneNumber" placeholder=" " type="tel"/>
# <label class="sds-label" for="phone-modal-">Phone (optional)</label>
# </div>
# </div>
# <input id="subject-modal-" name="lead[subject]" type="hidden" value="Ask a question"/>
# <div class="comments">
# <div class="sds-input-container sds-input-container--textarea">
# <textarea class="sds-text-field comment-box" data-fs="exclude" id="comments-modal-" name="lead[comments]" phx-debounce="blur" placeholder=" ">
# </textarea>
# <label class="sds-label" for="comments-modal-">Comments</label>
# </div>
# </div>
# </div>
# <div class="sds-field trade-in hidden">
# <div class="sds-field trade-in-checkbox">
# <div class="sds-checkbox trade-in" phx-click="show_trade_in" phx-target="#srp-lead-form-modal">
# <input class="sds-input" id="trade-in-checkbox-srp-lead-form-modal" type="checkbox"/>
# <label class="sds-label" for="trade-in-checkbox-srp-lead-form-modal">I have a trade in</label>
# </div>
# </div>
# <div class="sds-field-group trade-in-form hidden">
# <div class="make">
# <div class="sds-input-container sds-input-container--dropdown">
# <select class="sds-text-field" id="fields-srp-lead-form-modal_make_select-modal-" name="lead[trade_in][make]"><optgroup label=""><option selected="" value="">Choose a make</option><option value="ac">AC</option><option value="acura">Acura</option><option value="alfa_romeo">Alfa Romeo</option><option value="american_motors">American Motors</option><option value="am_general">Am General</option><option value="aston_martin">Aston Martin</option><option value="auburn">Auburn</option><option value="audi">Audi</option><option value="austin">Austin</option><option value="austin_healey">Austin-Healey</option><option value="avanti_motors">Avanti Motors</option><option value="bentley">Bentley</option><option value="bmw">BMW</option><option value="bricklin">Bricklin</option><option value="bugatti">Bugatti</option><option value="buick">Buick</option><option value="cadillac">Cadillac</option><option value="checker">Checker</option><option value="chevrolet">Chevrolet</option><option value="chrysler">Chrysler</option><option value="citroen">Citroen</option><option value="daewoo">Daewoo</option><option value="daihatsu">Daihatsu</option><option value="datsun">Datsun</option><option value="delahaye">Delahaye</option><option value="delorean">Delorean</option><option value="desoto">Desoto</option><option value="detomaso">DeTomaso</option><option value="dodge">Dodge</option><option value="eagle">Eagle</option><option value="edsel">Edsel</option><option value="essex">Essex</option><option value="ferrari">Ferrari</option><option value="fiat">FIAT</option><option value="fisker">Fisker</option><option value="ford">Ford</option><option value="franklin">Franklin</option><option value="genesis">Genesis</option><option value="geo">Geo</option><option value="gmc">GMC</option><option value="honda">Honda</option><option value="hudson">Hudson</option><option value="hummer">Hummer</option><option value="hupmobile">Hupmobile</option><option value="hyundai">Hyundai</option><option value="infiniti">INFINITI</option><option value="international">International</option><option value="isuzu">Isuzu</option><option value="jaguar">Jaguar</option><option value="jeep">Jeep</option><option value="jensen">Jensen</option><option value="kaiser">Kaiser</option><option value="karma">Karma</option><option value="kia">Kia</option><option value="koenigsegg">Koenigsegg</option><option value="lamborghini">Lamborghini</option><option value="lancia">Lancia</option><option value="land_rover">Land Rover</option><option value="lasalle">LaSalle</option><option value="lexus">Lexus</option><option value="lincoln">Lincoln</option><option value="lotus">Lotus</option><option value="lucid">Lucid</option><option value="maserati">Maserati</option><option value="maybach">Maybach</option><option value="mazda">Mazda</option><option value="mclaren">McLaren</option><option value="mercedes_benz">Mercedes-Benz</option><option value="mercury">Mercury</option><option value="merkur">Merkur</option><option value="mg">MG</option><option value="mini">MINI</option><option value="mitsubishi">Mitsubishi</option><option value="morgan">Morgan</option><option value="morris">Morris</option><option value="nash">Nash</option><option value="nissan">Nissan</option><option value="oldsmobile">Oldsmobile</option><option value="opel">Opel</option><option value="packard">Packard</option><option value="pagani">Pagani</option><option value="panoz">Panoz</option><option value="peugeot">Peugeot</option><option value="plymouth">Plymouth</option><option value="polestar">Polestar</option><option value="pontiac">Pontiac</option><option value="porsche">Porsche</option><option value="qvale">Qvale</option><option value="ram">RAM</option><option value="renault">Renault</option><option value="rivian">Rivian</option><option value="rolls_royce">Rolls-Royce</option><option value="rover">Rover</option><option value="saab">Saab</option><option value="saleen">Saleen</option><option value="saturn">Saturn</option><option value="scion">Scion</optio ...
# <label class="sds-label" for="make_select-modal-">Make</label>
# <svg class="sds-text-field__icon" height="16" width="16"><use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#chevron-down"></use></svg>
# </div>
# </div>
# <div class="model">
# <div class="sds-input-container sds-input-container--dropdown">
# <select class="sds-text-field" disabled="" id="fields-srp-lead-form-modal_model_select-modal-" name="lead[trade_in][model]"><optgroup label=""><option selected="" value="">Choose a model</option></optgroup></select>
# <label class="sds-label" for="model_select-modal-">Model</label>
# <svg class="sds-text-field__icon" height="16" width="16"><use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#chevron-down"></use></svg>
# </div>
# </div>
# <div class="year">
# <div class="sds-input-container sds-input-container--dropdown">
# <select class="sds-text-field" disabled="" id="fields-srp-lead-form-modal_year_select-modal-" name="lead[trade_in][year]"><optgroup label=""><option selected="" value="">Choose a year</option></optgroup></select>
# <label class="sds-label" for="year_select-modal-">Year</label>
# <svg class="sds-text-field__icon" height="16" width="16"><use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#chevron-down"></use></svg>
# </div>
# </div>
# <div class="color">
# <div class="sds-input-container">
# <input class="sds-text-field" disabled="" id="color-modal-" name="lead[trade_in][color]" phx-debounce="blur" placeholder=" " type="text" value=""/>
# <label class="sds-label" for="color-modal-">Exterior color</label>
# </div>
# </div>
# <div class="mileage">
# <div class="sds-input-container">
# <input class="sds-text-field" disabled="" id="mileage_string-modal-" name="lead[trade_in][mileage_string]" phx-debounce="blur" phx-hook="Mileage" placeholder=" " type="text" value=""/>
# <label class="sds-label" for="mileage_string-modal-">Mileage</label>
# </div>
# </div>
# <div class="vin">
# <div class="sds-input-container">
# <input class="sds-text-field" disabled="" id="vin-modal-" name="lead[trade_in][vin]" phx-debounce="blur" placeholder=" " type="text" value=""/>
# <label class="sds-label" for="vin-modal-">VIN (optional)</label>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="sds-field sds-form-module__button">
# <button class="sds-button--fluid" type="submit">Contact seller</button>
# </div>
# <small class="sds-disclaimer">
# <p>
#
# By clicking here, you authorize Cars.com and its sellers/partners to contact you by text/calls which may include marketing and be by autodialer. Calls may be prerecorded. You also agree to our Privacy Statement. Consent is not required to purchase goods/services.
#
#         </p>
# <p>
# We value your privacy.
# <a data-linkname="privacy-statement" href="/about/privacy/" target="_blank">Cars.com Privacy Statement</a>
# </p>
# </small>
# </div>
# </section>
# </form>
# </div>
# </div>
# </div>
# </div>
# <div data-override-payload="null" phx-hook="LeadSubmissionTracker" phx-target="#srp-lead-form-modal" phx_value_cid="srp-lead-form-modal"></div>
# <div phx-hook="LeadFormPositionAdjustments"></div>
# <div></div>
# <div class="sds-page-section listings-page" data-applied-filter-criteria="" data-liveview-pageview="true" data-props='{"selected_refinement":null}' data-search-instance-id="62a254d3-5e7b-49df-b233-501e8cd1f115" data-search-type="general-inventory-search" data-site-activity='{"search_seller_types":"","stock_sub":"","search_models":"","search_keyword":null,"search_stock_type":"new","search_instance_id":"","model_group":null,"search_max_year":"","model":"","search_zip":"","search_contactless_services":"","search_stock_type_standard":"new","search_make_model_trims":[{"make":"chrysler"}],"dealerSearchType":"multiple_dealers","search_min_year":"","listing_ids":["3251a93f-60c0-4bef-aa02-485e7793811e","540b3cb5-c4f0-4fa1-9c3e-272d1d9c4869","51a11fb3-d15b-4914-a5dc-69aa67aa534e","6562b17a-7c89-4ee1-acc7-574106f56ea2","f22f4a36-4ea5-4f1c-9e34-98e00cd22959","4c89ad70-d8c1-46e4-87c9-5475466bd4dd","36521677-8470-427e-bfe1-41ab44c81553","691e4d6b-b4f1-440e-ac9c-bc256fc31c91","65c9902f-bd10-4c49-aeb9-5a32a0a05aa1","8b228e71-4bc1-4743-ba31-3dc2c9d165a8","5392b978-a22a-48b7-8e52-711105c54a66","b73c4005-bada-4502-a6f6-d35190b17cc5","35ba5a1d-c381-4c09-8554-7e8bc6aa3c3d","ad7b4d70-9770-4dd2-819a-1f97bfe9ad74","e26eace6-35a9-4bb5-8ff4-554a68ace6e9","27662b28-bff1-43cb-acce-3bb6229f3ad7","a4e33362-5538-4d09-b35b-da8ad5d31bad","4794a1c4-f3e2-4009-a879-6e080d49937a","460995af-7c5d-46c1-baff-8da3998fc41d","91ebe580-6ac5-43bd-a86d-2a6095d5eeba","12dc7aa6-641a-455b-8964-3c87cd537028"],"interiorColor":"","search_results_on_page":21,"search_stock_sub":"","result_page_number":1,"search_interior_colors":"","features":"","multipleVehicles":true,"search_features":"","search_only_with_photos":null,"cpo_indicator":false,"bodystyle":"","total_results":2535,"sort_order":"desc","search_mileage_max":null,"vehicleArray":[{"badges":[],"bodystyle":"Passenger Van","canonical_mmt":"Chrysler:Pacifica:Touring-L","cat":"van_mini","certified_preowned":false,"cpo_indicator":false,"customer_id":"17522","exterior_color":"Gray","fuel_type":"Gasoline","listing_id":"3251a93f-60c0-4bef-aa02-485e7793811e","make":"Chrysler","mileage":"9","model":"Pacifica","msrp":null,"nvi_program":false,"price":"45323","seller_type":"dealership","sponsored":true,"sponsored_type":"inventory_ad","stock_sub":"","stock_type":"New","trim":"Touring-L","vin":"2C4RC3BG0NR200397","year":"2022"},{"badges":["virtual_appt","price_drop_in_cents","home_delivery"],"bodystyle":"Passenger Van","canonical_mmt":"Chrysler:Pacifica Hybrid:Touring L","cat":"hybrid_suv","certified_preowned":false,"cpo_indicator":false,"customer_id":"151464","exterior_color":"Ceramic Gray Clearcoat","fuel_type":"Hybrid","listing_id":"540b3cb5-c4f0-4fa1-9c3e-272d1d9c4869","make":"Chrysler","mileage":null,"model":"Pacifica Hybrid","msrp":"50503","nvi_program":false,"price":"49753","seller_type":"dealership","sponsored":false,"sponsored_type":"none","stock_sub":"","stock_type":"New","trim":"Touring L","vin":"2C4RC1L79NR206928","year":"2022"},{"badges":["virtual_appt","home_delivery"],"bodystyle":"Sedan","canonical_mmt":"Chrysler:300:S","cat":"sedan_fullsize","certified_preowned":false,"cpo_indicator":false,"customer_id":"197567","exterior_color":"Silver Mist Clearcoat","fuel_type":"Gasoline","listing_id":"51a11fb3-d15b-4914-a5dc-69aa67aa534e","make":"Chrysler","mileage":"10","model":"300","msrp":null,"nvi_program":false,"price":"49225","seller_type":"dealership","sponsored":false,"sponsored_type":"none","stock_sub":"","stock_type":"New","trim":"S","vin":"2C3CCABT4NH206446","year":"2022"},{"badges":["virtual_appt","home_delivery"],"bodystyle":"Passenger Van","canonical_mmt":"Chrysler:Pacifica Hybrid:Touring L","cat":"hybrid_suv","certified_preowned":false,"cpo_indicator":false,"customer_id":"23018","exterior_color":"Bright White Clearcoat","fuel_type":"Hybrid","listing_id":"6562b17a-7c89-4ee1-acc7-574106f56ea2","make":"Chrysler","mileage":"10","model":"Pacifica Hybrid","msrp":null,"nvi_program":false,"price":"56976","seller_type":"dealership ...
# <script type="application/ld+json">{"@context":"http://schema.org","@type":"ItemList","itemListElement":[{"@type":"ListItem","name":"2022 Chrysler Pacifica Hybrid Touring L","position":1,"url":"https://www.cars.com/vehicledetail/540b3cb5-c4f0-4fa1-9c3e-272d1d9c4869//"},{"@type":"ListItem","name":"2022 Chrysler 300 S","position":2,"url":"https://www.cars.com/vehicledetail/51a11fb3-d15b-4914-a5dc-69aa67aa534e//"},{"@type":"ListItem","name":"2022 Chrysler Pacifica Hybrid Touring L","position":3,"url":"https://www.cars.com/vehicledetail/6562b17a-7c89-4ee1-acc7-574106f56ea2//"},{"@type":"ListItem","name":"2022 Chrysler Pacifica Pinnacle","position":4,"url":"https://www.cars.com/vehicledetail/f22f4a36-4ea5-4f1c-9e34-98e00cd22959//"},{"@type":"ListItem","name":"2022 Chrysler 300 Touring L","position":5,"url":"https://www.cars.com/vehicledetail/4c89ad70-d8c1-46e4-87c9-5475466bd4dd//"},{"@type":"ListItem","name":"2022 Chrysler 300 Touring","position":6,"url":"https://www.cars.com/vehicledetail/36521677-8470-427e-bfe1-41ab44c81553//"},{"@type":"ListItem","name":"2022 Chrysler Pacifica Hybrid Touring L","position":7,"url":"https://www.cars.com/vehicledetail/691e4d6b-b4f1-440e-ac9c-bc256fc31c91//"},{"@type":"ListItem","name":"2022 Chrysler Pacifica Hybrid Touring L","position":8,"url":"https://www.cars.com/vehicledetail/65c9902f-bd10-4c49-aeb9-5a32a0a05aa1//"},{"@type":"ListItem","name":"2022 Chrysler 300 S","position":9,"url":"https://www.cars.com/vehicledetail/8b228e71-4bc1-4743-ba31-3dc2c9d165a8//"},{"@type":"ListItem","name":"2022 Chrysler 300 Touring L","position":10,"url":"https://www.cars.com/vehicledetail/5392b978-a22a-48b7-8e52-711105c54a66//"},{"@type":"ListItem","name":"2022 Chrysler Pacifica Pinnacle","position":11,"url":"https://www.cars.com/vehicledetail/b73c4005-bada-4502-a6f6-d35190b17cc5//"},{"@type":"ListItem","name":"2022 Chrysler 300 S","position":12,"url":"https://www.cars.com/vehicledetail/35ba5a1d-c381-4c09-8554-7e8bc6aa3c3d//"},{"@type":"ListItem","name":"2022 Chrysler Pacifica Hybrid Pinnacle","position":13,"url":"https://www.cars.com/vehicledetail/ad7b4d70-9770-4dd2-819a-1f97bfe9ad74//"},{"@type":"ListItem","name":"2022 Chrysler Pacifica Pinnacle","position":14,"url":"https://www.cars.com/vehicledetail/e26eace6-35a9-4bb5-8ff4-554a68ace6e9//"},{"@type":"ListItem","name":"2022 Chrysler Pacifica Limited","position":15,"url":"https://www.cars.com/vehicledetail/27662b28-bff1-43cb-acce-3bb6229f3ad7//"},{"@type":"ListItem","name":"2022 Chrysler Pacifica Touring-L","position":16,"url":"https://www.cars.com/vehicledetail/a4e33362-5538-4d09-b35b-da8ad5d31bad//"},{"@type":"ListItem","name":"2022 Chrysler 300 Touring L","position":17,"url":"https://www.cars.com/vehicledetail/4794a1c4-f3e2-4009-a879-6e080d49937a//"},{"@type":"ListItem","name":"2022 Chrysler 300 S","position":18,"url":"https://www.cars.com/vehicledetail/460995af-7c5d-46c1-baff-8da3998fc41d//"},{"@type":"ListItem","name":"2022 Chrysler 300 Touring L","position":19,"url":"https://www.cars.com/vehicledetail/91ebe580-6ac5-43bd-a86d-2a6095d5eeba//"},{"@type":"ListItem","name":"2022 Chrysler Pacifica Pinnacle","position":20,"url":"https://www.cars.com/vehicledetail/12dc7aa6-641a-455b-8964-3c87cd537028//"}],"itemListOrder":"https://schema.org/ItemListUnordered","numberOfItems":20}</script>
# <script type="application/ld+json">{"@context":"http://schema.org","@type":"Car","availability":"https://schema.org/InStock","brand":{"@type":"Organization","name":"Chrysler"},"color":"Ceramic Gray Clearcoat","description":"New 2022 Chrysler Pacifica Hybrid for sale for $49,753.","driveWheelConfiguration":"Front-wheel Drive","image":{"@type":"ImageObject","contentUrl":"https://platform.cstatic-images.com/in/v2/187bb31f-e7d6-5818-9925-645dc4d0f8c1/cca371d2-5ff9-4623-a1d7-ba8a32b442f1/OctXu_Lb9Hb44nkUnnnf4egCcPU.jpg"},"itemCondition":"https://schema.org/NewCondition","name":"New 2022 Chrysler Pacifica Hybrid","sku":"22817","vehicleIdentificationNumber":"2C4RC1L79NR206928","vehicleInteriorColor":"Black","vehicleTransmission":"Automatic CVT"}</script><script type="application/ld+json">{"@context":"http://schema.org","@type":"Car","availability":"https://schema.org/InStock","brand":{"@type":"Organization","name":"Chrysler"},"color":"Silver Mist Clearcoat","description":"New 2022 Chrysler 300 for sale for $49,225.","driveWheelConfiguration":"Rear-wheel Drive","image":{"@type":"ImageObject","contentUrl":"https://platform.cstatic-images.com/in/v2/93af79c3-8a3c-584c-92e7-96bfdf152dbd/5f0b25c1-8784-46b9-b359-7ef2be900b00/Y42VYR2q4dxSafAFI-5fDALU4Nk.jpg"},"itemCondition":"https://schema.org/NewCondition","mileageFromOdometer":"10","name":"New 2022 Chrysler 300","sku":"C39919","vehicleIdentificationNumber":"2C3CCABT4NH206446","vehicleInteriorColor":"Black","vehicleTransmission":"8-Speed Automatic"}</script><script type="application/ld+json">{"@context":"http://schema.org","@type":"Car","availability":"https://schema.org/InStock","brand":{"@type":"Organization","name":"Chrysler"},"color":"Bright White Clearcoat","description":"New 2022 Chrysler Pacifica Hybrid for sale for $56,976.","driveWheelConfiguration":"Front-wheel Drive","image":{"@type":"ImageObject","contentUrl":"https://platform.cstatic-images.com/in/v2/df93f755-8706-5bee-be1c-c3f090941ee9/81dd3daa-50bd-4e47-a155-3048131a821b/5_WVn6J8xaue6OXOuodhNwYSioA.jpg"},"itemCondition":"https://schema.org/NewCondition","mileageFromOdometer":"10","name":"New 2022 Chrysler Pacifica Hybrid","sku":"NR212453","vehicleIdentificationNumber":"2C4RC1L77NR212453","vehicleTransmission":"Automatic CVT"}</script><script type="application/ld+json">{"@context":"http://schema.org","@type":"Car","availability":"https://schema.org/InStock","brand":{"@type":"Organization","name":"Chrysler"},"color":"Brilliant Black Crystal Pearlcoat","description":"New 2022 Chrysler Pacifica for sale for $60,567.","driveWheelConfiguration":"Front-wheel Drive","image":{"@type":"ImageObject","contentUrl":"https://platform.cstatic-images.com/in/v2/591daf08-4628-5266-a5fd-cdb9e70b357c/944ccaec-601f-46f0-9669-640eb5c68ca4/pLYA4zrbwiIxZH-WRcOj-DLOZuE.jpg"},"itemCondition":"https://schema.org/NewCondition","name":"New 2022 Chrysler Pacifica","sku":"221336","vehicleIdentificationNumber":"2C4RC1PG3NR160426","vehicleInteriorColor":"Black","vehicleTransmission":"9-Speed Automatic"}</script><script type="application/ld+json">{"@context":"http://schema.org","@type":"Car","availability":"https://schema.org/InStock","brand":{"@type":"Organization","name":"Chrysler"},"color":"Bright White Clearcoat","description":"New 2022 Chrysler 300 for sale for $48,865.","driveWheelConfiguration":"All-wheel Drive","image":{"@type":"ImageObject","contentUrl":"https://platform.cstatic-images.com/in/v2/003db9fd-8de7-53b0-bc05-26bb49311444/95c706b3-dc91-4a78-9f9e-952d858f2595/NZlJ23kENhcfNr__NbFJaJ3-zOY.jpg"},"itemCondition":"https://schema.org/NewCondition","mileageFromOdometer":"0","name":"New 2022 Chrysler 300","sku":"22231","vehicleIdentificationNumber":"2C3CCASG7NH205567","vehicleInteriorColor":"Black","vehicleTransmission":"8-Speed Automatic"}</script><script type="application/ld+json">{"@context":"http://schema.org","@type":"Car","availability":"https://schema.org/InStock","brand":{"@type":"Organization","name":"Chrysler"},"color":"Bright White Clearc ...
# <nav class="search-filter-bar">
# <button class="subscribe-with-save-status-indicator" data-activity-rule-type="custom" data-component="save-search-add" data-linkname="save-search-email-modal-open" id="search_filter_bar_save_search_button" phx-click="save_search" phx-target="#search_filter_bar_save_search_button">
# <ep-svg class="save-status-indicator unsaved" name="heart-empty">
# </ep-svg>
# <span>Save search</span>
# </button>
# <button phx-click="show_sort_overlay">
# Sort
#     </button>
# <button id="show-search-form-overlay" phx-click="show_search_form_overlay">
# Filter
#     </button>
# </nav>
# <section class="sds-page-section search-live" id="search-live-container">
# <div class="display-ad" data-ad-sizes="[[970, 90], [728, 90], [970, 250], [320, 50]]" data-ad-type="full-page-width" data-ad-unit-path="6427/shop/new.srp/top" data-appnexus-placement-id="17848526" data-hidden-on="" id="srp-top" phx-update="ignore">
# <div alt="Advertisement" id="phx-ignore-container-srp-top" phx-update="ignore"></div>
# </div>
# </section>
# <header class="sds-page-section__header">
# <nav aria-label="breadcrumb">
# <ul class="sds-breadcrumb sds-breadcrumb--mobile-custom">
# <li class="sds-breadcrumb__parent">
# <span class="sds-icon">
# <svg aria-describedby="description" aria-labelledby="title" fill="none" height="16" role="img" stroke="#000000" stroke-linecap="round" stroke-linejoin="round" stroke-width="2" viewbox="0 0 24 24" width="16" xmlns="http://www.w3.org/2000/svg">
# <title id="title">arrow-left</title>
# <desc id="description">An arrow pointing left.</desc>
# <path d="M19 12H6M12 5l-7 7 7 7"></path></svg>
# </span>
# <span><a data-component="breadcrumb" data-linkname="Home" href="/">Home</a></span>
# </li>
# <li aria-current="page">Cars for Sale</li>
# </ul>
# </nav>
# <script type="application/ld+json">
#   {"@context":"http://schema.org","@type":"BreadcrumbList","itemListElement":[{"@type":"ListItem","item":{"@id":"https://www.cars.com/","name":"Home"},"position":1},{"@type":"ListItem","item":{"@id":"https://www.cars.com/shopping/","name":"Cars for Sale"},"position":2}]}
# </script>
# <div class="heading-container">
# <h1 class="sds-heading--1 sds-page-section__title">New Chrysler for sale</h1>
# <form action="#" class="sort-form" id="desktop_sort" method="post" phx-auto-recover="ignore" phx-change="sort_form_change">
# <div class="sds-input-container sds-input-container--dropdown">
# <select class="sds-text-field" data-activitykey="sort-dropdown" data-component="sort-apply" id="sort-dropdown" name="sort" phx-page-loading=""><option selected="" value="best_match_desc">Best match</option><option value="list_price">Lowest price</option><option value="list_price_desc">Highest price</option><option value="distance">Nearest location</option><option value="year_desc">Newest year</option><option value="year">Oldest year</option><option value="listed_at_desc">Newest listed</option><option value="listed_at">Oldest listed</option></select>
# <label class="sds-label" for="sort-dropdown">Sort by</label>
# <svg class="sds-text-field__icon" height="16" width="16"><use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#chevron-down"></use></svg>
# </div>
# </form>
# </div>
# <div class="entries-and-location-container">
# <span class="total-entries">
# 2,535 matches
#       </span>
# </div>
# </header>
# <div class="sds-page-section__content">
# <div class="vehicle-cards" data-tracking-orientation="vertical" id="vehicle-cards-container" phx-update="replace">
# <div class="save-search-banner">
# <div class="header medium-header">
# <ep-svg library="cars-duotone" name="bell"></ep-svg>
# <div class="message">
# <strong>Never miss a car!</strong>
# <p class="sub-text">Get email alerts on this search.</p>
# </div>
# </div>
# <div class="subscribe-form-section">
# <form action="#" class="subscribe-form" method="post" phx-submit="submit_subscribe" phx-target="#banner_save_search_button"><input name="_csrf_token" type="hidden" value="AmMvZhgIOzZpFV0KKghZGw0wVA9AZjZyP5J3ACTl_J5PAE-h_T1h9_rB"/>
# <div class="sds-field email">
# <div class="sds-input-container">
# <input class="sds-text-field" id="user_email" name="user[email]" placeholder=" " type="text"/>
# <label class="sds-label" for="user_email">Email</label>
# </div>
# </div>
# <button class="sds-button--secondary sds-button--large" data-click-intent-id="srp-banner-search-alert-subscribe" id="banner_save_search_button" type="submit">Subscribe</button>
# </form>
# <div class="sds-disclaimer">
# By subscribing, you agree to our
# <a data-activity-rule-type="custom" data-component="privacy-statement" data-linkname="privacy-statement" href="/about/privacy/" target="_blank">Privacy Statement</a>
# and
# <a data-activity-rule-type="custom" data-component="terms-of-service" data-linkname="tos" href="/about/terms/" target="_blank">Terms of Service</a>.
# </div>
# <ep-modal id="subscribe-search-modal-desktop" label="Save this search" phx-hook="SavedSearchSubscription">
# <p>
#     We'll send you new listings and price drops based on your search criteria.
#   </p>
# <form action="#" method="post" phx-submit="submit_subscribe_modal" phx-target="#banner_save_search_button"><input name="_csrf_token" type="hidden" value="AmMvZhgIOzZpFV0KKghZGw0wVA9AZjZyP5J3ACTl_J5PAE-h_T1h9_rB"/>
# <div>
# <div class="sds-input-container subscriber-email">
# <input class="sds-text-field" id="user_email" name="user[email]" placeholder=" " type="text"/>
# <label class="sds-label" for="user_email">Email</label>
# </div>
# </div>
# <button class="sds-button--fluid" type="submit">Save search</button>
# <div class="sds-disclaimer">
# By subscribing, you agree to our
# <a data-activity-rule-type="custom" data-component="privacy-statement" data-linkname="privacy-statement" href="/about/privacy/" target="_blank">Privacy Statement</a>
# and
# <a data-activity-rule-type="custom" data-component="terms-of-service" data-linkname="tos" href="/about/terms/" target="_blank">Terms of Service</a>.
# </div>
# </form>
# </ep-modal>
# </div>
# </div>
# <div class="mobile-save-search-banner">
# <div class="header">
# <ep-svg library="cars-duotone" name="bell"></ep-svg>
# <div class="message">
# <p class="mobile-message">
# <strong>
# Never miss a car!
#                 </strong>
# </p>
# <button class="sds-button--link" data-activity-rule-type="custom" data-click-intent-id="srp-mobile-banner-search-alert-modal-open" data-component="save-search-add" data-linkname="search-alert-modal-open" id="mobile_banner_save_search_button" phx-click="open_subscribe_modal" phx-target="#mobile_banner_save_search_button">
#   Get email alerts on this search.
# </button>
# <ep-modal id="subscribe-search-modal-mobile" label="Save this search" phx-hook="SavedSearchSubscription">
# <p>
#     We'll send you new listings and price drops based on your search criteria.
#   </p>
# <form action="#" method="post" phx-submit="submit_subscribe_modal" phx-target="#mobile_banner_save_search_button"><input name="_csrf_token" type="hidden" value="AmMvZhgIOzZpFV0KKghZGw0wVA9AZjZyP5J3ACTl_J5PAE-h_T1h9_rB"/>
# <div>
# <div class="sds-input-container subscriber-email">
# <input class="sds-text-field" id="user_email" name="user[email]" placeholder=" " type="text"/>
# <label class="sds-label" for="user_email">Email</label>
# </div>
# </div>
# <button class="sds-button--fluid" type="submit">Save search</button>
# <div class="sds-disclaimer">
# By subscribing, you agree to our
# <a data-activity-rule-type="custom" data-component="privacy-statement" data-linkname="privacy-statement" href="/about/privacy/" target="_blank">Privacy Statement</a>
# and
# <a data-activity-rule-type="custom" data-component="terms-of-service" data-linkname="tos" href="/about/terms/" target="_blank">Terms of Service</a>.
# </div>
# </form>
# </ep-modal>
# </div>
# </div>
# </div>
# <div class="vehicle-card inventory-ad" data-inventory-ad="true" data-koddi-click-tracking-url="https://cars.koddi.io/event-collection/beacon?action=click&amp;trackingData={trackingData}&amp;rank={rank}&amp;clientName=Cars&amp;beaconIssued=2022-10-12T00:48:23Z" data-koddi-impression-tracking-url="https://cars.koddi.io/event-collection/beacon?action=impression&amp;trackingData={trackingData}&amp;rank={rank}&amp;ts={ts}&amp;clientName=Cars&amp;beaconIssued=2022-10-12T00:48:23Z" data-koddi-listing-id="3251a93f-60c0-4bef-aa02-485e7793811e" data-koddi-tracking-data="..." data-koddi-tracking-guid="8787b0b0-2fd7-4df5-a68d-cf5ff9256276" data-koddi-user-guid="" data-listing-id="3251a93f-60c0-4bef-aa02-485e7793811e" data-tracking-id="1" data-tracking-type="srp-vehicle-card" id="vehicle-card-3251a93f-60c0-4bef-aa02-485e7793811e-sponsored" phx-hook="VehicleCard" phx-target="6">
# <a class="vehicle-card-visited-tracking-link" href="/vehicledetail/3251a93f-60c0-4bef-aa02-485e7793811e/" rel="nofollow" tabindex="-1"></a>
# <div class="inventory-ad-main vehicle-card-main">
# <div class="vehicle-card-photos">
# <a class="image-gallery-link" data-activity-rule-type="page-over-page" data-linkname="inventory-ad-photo" data-override-payload='{"sponsored_type":"inventory_ad","vertical_position":1,"web_page_type_from":"inventory-ad-photo"}' href="/vehicledetail/3251a93f-60c0-4bef-aa02-485e7793811e/" rel="nofollow"></a>
# <cars-filmstrip totalcount="1">
# <div class="gallery-wrap">
# <div aria-label="Photo 1 of 1 of 2022 Chrysler Pacifica Touring-L" class="image-wrap" data-index="0">
# <img alt="Photo 1 of 1 of 2022 Chrysler Pacifica Touring-L" class="vehicle-image" loading="lazy" src="https://platform.cstatic-images.com/large/in/v2/color_matched_stock_photos/f4137412-01e3-4fea-8634-48ef3d8d54c4/df8a8cfc-7cae-4181-9a57-8c505071b941.jpg"/>
# </div>
# </div>
# </cars-filmstrip>
# </div>
# ...
# <span class="global-footer-heading accordion-section-title">Explore Our Brand</span>
# <svg class="accordion-section-icon" height="16" width="16"><use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#chevron-down"></use></svg>
# </div>
# <div aria-labelledby="footer-header-3" class="accordion-panel" hidden="" id="footer-section-3" role="region">
# <ul class="global-footer-list sds-list">
# <li><a aria-describedby="new-tab-link" aria-label="Dealer Inspire, External link" class="sds-link--ext" data-activity-rule-type="custom" data-component="footer-partners" data-component-index="1" data-linkname="footer-dealer-inspire" href="https://www.dealerinspire.com/" rel="noopener" target="_blank">Dealer Inspire<svg class="sds-text-field__icon" height="16" width="16"><use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#arrow-up-right"></use></svg></a></li>
# <li><a aria-describedby="new-tab-link" aria-label="DealerRater, External link" class="sds-link--ext" data-activity-rule-type="custom" data-component="footer-partners" data-component-index="2" data-linkname="footer-dealerrater" href="https://www.dealerrater.com/" rel="noopener" target="_blank">DealerRater<svg class="sds-text-field__icon" height="16" width="16"><use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#arrow-up-right"></use></svg></a></li>
# <li><a aria-describedby="new-tab-link" aria-label="FUEL, External link" class="sds-link--ext" data-activity-rule-type="custom" data-component="footer-partners" data-component-index="3" data-linkname="footer-fuel" href="https://fuel.cars" rel="noopener" target="_blank">FUEL<svg class="sds-text-field__icon" height="16" width="16"><use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#arrow-up-right"></use></svg></a></li>
# <li><a aria-describedby="new-tab-link" aria-label="Auto.com, External link" class="sds-link--ext" data-activity-rule-type="custom" data-component="footer-partners" data-component-index="4" data-linkname="footer-autocom" href="https://www.auto.com/" rel="noopener" target="_blank">Auto.com<svg class="sds-text-field__icon" height="16" width="16"><use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#arrow-up-right"></use></svg></a></li>
# <li><a aria-describedby="new-tab-link" aria-label="NewCars.com, External link" class="sds-link--ext" data-activity-rule-type="custom" data-component="footer-partners" data-component-index="5" data-linkname="footer-newcarscom" href="https://www.newcars.com/" rel="noopener" target="_blank">NewCars.com<svg class="sds-text-field__icon" height="16" width="16"><use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#arrow-up-right"></use></svg></a></li>
# <li><a aria-describedby="new-tab-link" aria-label="Pickuptrucks.com, External link" class="sds-link--ext" data-activity-rule-type="custom" data-component="footer-partners" data-component-index="6" data-linkname="footer-pickuptruckscom" href="https://www.pickuptrucks.com/" rel="noopener" target="_blank">Pickuptrucks.com<svg class="sds-text-field__icon" height="16" width="16"><use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#arrow-up-right"></use></svg></a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="global-footer-group accordion-group">
# <div aria-controls="footer-section-4" aria-expanded="false" class="accordion-header" id="footer-header-4" role="button" tabindex="0">
# <span class="global-footer-heading accordion-section-title">Our Company</span>
# <svg class="accordion-section-icon" height="16" width="16"><use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#chevron-down"></use></svg>
# </div>
# <div aria-labelledby="footer-header-4" class="accordion-panel" hidden="" id="footer-section-4" role="region">
# <ul class="global-footer-list sds-list">
# <li><a data-activity-rule-type="page-over-page" data-component="footer-our-company" data-component-index="1" data-linkname="footer-about-cars" href="/about/">About Cars.com</a></li>
# <li><a data-activity-rule-type="page-over-page" data-component="footer-our-company" data-component-index="2" data-linkname="footer-contact-cars" href="/contact/">Contact Cars.com</a></li>
# <li><a aria-describedby="new-tab-link" aria-label="Investor Relations, External link" class="sds-link--ext" data-activity-rule-type="custom" data-component="footer-our-company" data-component-index="3" data-linkname="footer-investor-relations" href="https://investor.cars.com/overview/default.aspx" rel="noopener" target="_blank">Investor Relations<svg class="sds-text-field__icon" height="16" width="16"><use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#arrow-up-right"></use></svg></a></li>
# <li><a data-activity-rule-type="page-over-page" data-component="footer-our-company" data-component-index="4" data-linkname="footer-careers" href="/careers/">Careers</a></li>
# <li><a aria-describedby="new-tab-link" aria-label="Licensing &amp; Reprints, External link" class="sds-link--ext" data-activity-rule-type="custom" data-component="footer-our-company" data-component-index="5" data-linkname="footer-licensing-reprints" href="https://info.wrightsmedia.com/cars-licensing-reprints" rel="noopener" target="_blank">Licensing &amp; Reprints<svg class="sds-text-field__icon" height="16" width="16"><use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#arrow-up-right"></use></svg></a></li>
# <li><a data-activity-rule-type="page-over-page" data-component="footer-our-company" data-component-index="6" data-linkname="footer-site-map" href="/sitemap/">Site Map</a></li>
# <li><a data-activity-rule-type="custom" data-component="footer-our-company" data-component-index="7" data-linkname="footer-feedback" data-target="#qualtrics-modal" data-toggle="modal" href="#">Feedback</a></li>
# </ul>
# </div>
# </div>
# <div class="global-footer-group global-footer-apps-and-social">
# <div class="global-footer-social-header">
# <span class="global-footer-heading">Our Mobile App</span>
# </div>
# <div class="global-footer-mobile-apps">
# <a data-activity-rule-type="page-over-page" data-linkname="footer-mobile-apps" href="/mobile/">Download the App Today</a>
# <div class="global-footer-mobile-buttons">
# <a data-activity-rule-type="custom" data-linkname="footer-app-store" href="https://apps.apple.com/us/app/cars-com-new-used-cars/id353263352">
# <img alt="App Store download" class="app-store-button js-lazy-load" data-src="https://beta.cstatic-images.com/medium/in/v2/static/mobile-apps/app-store-badge-us-black-1.png"/>
# </a>
# <a data-activity-rule-type="custom" data-linkname="footer-google-play" href="https://play.google.com/store/apps/details?id=com.cars.android&amp;hl=en_US">
# <img alt="Google Play download" class="google-play-button js-lazy-load" data-src="https://beta.cstatic-images.com/medium/in/v2/static/mobile-apps/google-play-badge-us-1.png"/>
# </a>
# </div>
# </div>
# <div class="global-footer-social-header">
# <span class="global-footer-heading">Connect With Us</span>
# </div>
# <div class="global-footer-social-buttons">
# <ul class="global-footer-list sds-list">
# <li class="social-link"><a aria-describedby="new-tab-link" aria-label="Twitter, External link" class="sds-link--ext sds-button--icon sds-icon--contain twitter" data-activity-rule-type="custom" data-component="footer-social" data-component-index="1" data-linkname="footer-twitter" href="https://twitter.com/carsdotcom" rel="noopener" target="_blank"><svg height="16" width="16"><use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#twitter"></use></svg></a></li>
# <li class="social-link"><a aria-describedby="new-tab-link" aria-label="Facebook, External link" class="sds-link--ext sds-button--icon sds-icon--contain facebook" data-activity-rule-type="custom" data-component="footer-social" data-component-index="2" data-linkname="footer-facebook" href="https://www.facebook.com/CarsDotCom/" rel="noopener" target="_blank"><svg height="16" width="16"><use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#facebook"></use></svg></a></li>
# <li class="social-link"><a aria-describedby="new-tab-link" aria-label="Youtube, External link" class="sds-link--ext sds-button--icon sds-icon--contain youtube" data-activity-rule-type="custom" data-component="footer-social" data-component-index="3" data-linkname="footer-youtube" href="https://www.youtube.com/user/Carscom/" rel="noopener" target="_blank"><svg height="16" width="16"><use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#youtube"></use></svg></a></li>
# <li class="social-link"><a aria-describedby="new-tab-link" aria-label="Instagram, External link" class="sds-link--ext sds-button--icon sds-icon--contain instagram" data-activity-rule-type="custom" data-component="footer-social" data-component-index="4" data-linkname="footer-instagram" href="https://www.instagram.com/carsdotcom/" rel="noopener" target="_blank"><svg height="16" width="16"><use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#instagram"></use></svg></a></li>
# <li class="social-link"><a aria-describedby="new-tab-link" aria-label="Linkedin, External link" class="sds-link--ext sds-button--icon sds-icon--contain linkedin" data-activity-rule-type="custom" data-component="footer-social" data-component-index="5" data-linkname="footer-linkedin" href="https://www.linkedin.com/company/cars-com" rel="noopener" target="_blank"><svg height="16" width="16"><use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#linkedin"></use></svg></a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="global-copyright">
# <div class="sds-container">
# <ul class="sds-list">
# <li><a data-activity-rule-type="page-over-page" data-component="footer-legal" data-component-index="1" data-linkname="footer-tos" href="/about/terms/">Terms of Service</a></li>
# <li><a data-activity-rule-type="page-over-page" data-component="footer-legal" data-component-index="2" data-linkname="footer-privacy-statement" href="/about/privacy/">Privacy Statement</a></li>
# <li><a data-activity-rule-type="page-over-page" data-component="footer-legal" data-component-index="3" data-linkname="footer-personal-information" href="/about/ccpa-privacy-notice/">Do Not Sell My Personal Information</a></li>
# <li><a data-activity-rule-type="page-over-page" data-component="footer-legal" data-component-index="4" data-linkname="footer-accessibility" href="/about/accessibility/">Accessibility Statement</a></li>
# <li><a data-activity-rule-type="page-over-page" data-component="footer-legal" data-component-index="5" data-linkname="footer-ad-choices" href="/about/ad-choices/">Ad Choices</a></li>
# </ul>
# <div class="global-copyright-copy">©
# 2022 Cars.com. All rights reserved.</div>
# </div>
# </div>
# <div aria-modal="true" class="sds-modal sds-modal-one" id="qualtrics-modal">
# <div class="sds-modal__content">
# <div class="sds-modal__content-head sds-modal__content-head">
# <div class="sds-icon--target btn-close js-close" role="button">
# <span class="sds-icon">
# <svg height="16" width="16"><use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#close"></use></svg>
# </span>
# </div>
# </div>
# <iframe class="qualtrics-form" data-src="https://cars.qualtrics.com/jfe/form/SV_81Hx3Jkheo8zhmC " height="800px" width="600px"></iframe>
# </div>
# </div>
# </footer>
# <script src=""></script>
# <link data-href="/348126e679f08e6d6721/css/common.css?vsn=d" media="print" rel="stylesheet">
# <link data-href="/348126e679f08e6d6721/css/srp.css?vsn=d" media="print" rel="stylesheet"/>
# <link data-href="https://fonts.googleapis.com/css?family=Roboto" rel="stylesheet" type="text/css"/>
# <script>
#   window.CARS = window.CARS || {}
#   window.CARS["initialActivity"] = {"seller_id":null,"page_key":"search-results","page_detail":null,"aff_code":"national","zip_ip2geo":null,"model":"","page_channel":"shopping","utm_source":null,"page_type":"shopping/search-results","utm_content":null,"user_state":"anonymous","url_referer":"","utm_medium":null,"useragent":"","year":"","marketing_click_id":"","loginStatus":false,"customer_id":"","url_base":"","local_zone":null,"lat_long":"/","marketing_click_data":null,"designated_market_area_key":null,"profileAccountType":null,"facebook_event_id":"dHJpcF9pZD1mNmRjMjhkMC05ZDZlLTQzYjEtYTM2Yi03M2ZiOGYxZDA0N2YmdHM9MTY2NTUzNTcwMzUxMQ==","marketing_referral_source":"","utm_term":null,"platform_id":"cars_responsive","page_name":"shopping/search-results","cat":null,"utm_campaign":null,"market_name":null,"make":"","trip_id":""}
# </script>
# <script>
#   window.CARS = window.CARS || {}
#   window.CARS["initialAls"] = {"timestamp_utc":1665535703861,"vertical_position":"","device_id":null,"seller_id":null,"als_private_data":"QTEyOEdDTQ.K54kZGlc0hPoGn6TFHhWNBUUrDuxGue7T535YNofjT4d10xo3ap9AknAM2s.7cbqbDKJIqt6Q0DG.aV0QtQ2hgXAOYmeREDMLA1Zl147aKDILvvH9K-wlKay0iWJxnIFd51OLYA5wvAFJxqsVg8w.WfW4DJ5azurCiu1QsYVmMA","referer_url":"","aff_code":"national","search_instance_id":null,"results_page_count":127,"model":"","utm_source":null,"search_zipcode":"","device_type":"desktop","utm_content":null,"trim":"","ga_client_id":null,"app_version":null,"msrp":"","page_url":"https://www.cars.com/shopping/results/?page=1&amp;page_size=20&amp;list_price_max=&amp;makes[]=chrysler&amp;maximum_distance=all&amp;models[]=&amp;stock_type=new&amp;zip=","is_bot":true,"device_model":null,"latitude":null,"longitude":null,"cpo_indicator":false,"utm_medium":null,"bodystyle":"","facebook_event_intent_id":"capi_viv_event","roxanne_visit_id":"","total_results":2535,"lead_event_id":null,"results_page_number":1,"x_forwarded_for":null,"useragent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.121 Safari/537.36","marketing_click_source":"","iframe_location":"","finance_application_id":null,"incentive_ids":"","price":null,"web_page_type_to":"shopping/search-results","upsells":[],"bot_type":"Unknown Bot (B0B1CB20BEBCAE0F191F2D67CC6B7C5E):monitor:Behavior Anomaly;High-Velocity-BOT:100:aggressive","device_os":null,"marketing_click_id":"","pdid":null,"page_instance_id":"Fx0r5d0at-08Wl0Ax7Hh","carrier":null,"customer_id":"","results_per_page":20,"internet_connection":null,"facebook_event_id":"dHJpcF9pZD1mNmRjMjhkMC05ZDZlLTQzYjEtYTM2Yi03M2ZiOGYxZDA0N2YmdHM9MTY2NTUzNTcwMzUxMQ==","experiment_ids":[{"index":0,"name":"ab_test_2_srp_hp_prod"},{"index":1,"name":"ab_test_14_srp_prod"}],"utm_term":null,"listing_id":"","adobe_id":null,"platform_id":"cars_responsive","model_year":"","roxanne_visitor_id":"","stock_type":"","profile_user_id":null,"web_page_type_from":"","external_uuids":null,"utm_campaign":null,"horizontal_position":"","make":"","trip_id":""}
# </script>
# <script async="" data-src="https://www.googletagservices.com/tag/js/gpt.js"></script>
# <script>
#   window.googletag = window.googletag || {cmd: []};
#   window.pbjs = window.pbjs || {que: []};
#   window.CARS = window.CARS || {};
#   window.CARS.disableAds = false;
#   window.CARS.disablePrebid = true;
#   window.CARS.isTest = false
# </script>
# <script async="" data-src="https://assets.adobedtm.com/306a737f2df1/a3d882c1ebd5/launch-3edaffcf6794.min.js" id="adobe-launch-script"></script>
# <script async="" data-src="https://d1n00d49gkbray.cloudfront.net/js/cars.js"></script>
# <script async="" data-src="https://accounts.google.com/gsi/client" defer=""></script>
# <script>
#   window.CARS["dispatcher"] = [];
#   window.CARS["dispatcher"].push({"CarsWeb": null})
#
#
# </script>
# <script id="graphql-config" type="application/json">
#     {
#
#       "apiKey": "5rrmnWVl1MDzPcEnDvEp3Pu101IGXEGo",
#       "url": "https://graph.cars.com/graphql/api"
#     }
#   </script>
# <noscript><img src="https://www.cars.com/akam/13/pixel_36c80cba?a=dD1hNTVlZWY3ODc2Y2MxYzZiODMxNDM0YWEyNWY1ODUxNDBmYTc0YzMzJmpzPW9mZg==" style="visibility: hidden; position: absolute; left: -999px; top: -999px;"/></noscript><script src="/eYlhd0z4z2AUvNOMnLRi/9zuEfzmVz9Yf/FEF2AQ/KSE-ZR/9LYi8B" type="text/javascript"></script></link></body>
# </html>

# %% [markdown]
# ### Results

# %%
result = soup.find_all('div', {'phx-hook':'VehicleCard'})

# %%
len(result)
# Out:
# 21

# %% [markdown]
# ### Concatenate 2 URL Parts

# %%
# we combine url part no. 1 with url part no. 2 in order to get the absolute url
url_part_1 = 'https://www.cars.com'

# %% [markdown]
# #### Create List for URL Part 2

# %%
url_part_2 = []

# Loop through the results
for item in result:
    # Loop through links
    for link in item.find_all('a', {'class':'vehicle-card-link js-gallery-click-link'}):
        url_part_2.append(link.get('href'))

# %%
url_part_2
# Out:
# ['/vehicledetail/540b3cb5-c4f0-4fa1-9c3e-272d1d9c4869/',
#  '/vehicledetail/51a11fb3-d15b-4914-a5dc-69aa67aa534e/',
#  '/vehicledetail/6562b17a-7c89-4ee1-acc7-574106f56ea2/',
#  '/vehicledetail/f22f4a36-4ea5-4f1c-9e34-98e00cd22959/',
#  '/vehicledetail/4c89ad70-d8c1-46e4-87c9-5475466bd4dd/',
#  '/vehicledetail/36521677-8470-427e-bfe1-41ab44c81553/',
#  '/vehicledetail/691e4d6b-b4f1-440e-ac9c-bc256fc31c91/',
#  '/vehicledetail/65c9902f-bd10-4c49-aeb9-5a32a0a05aa1/',
#  '/vehicledetail/8b228e71-4bc1-4743-ba31-3dc2c9d165a8/',
#  '/vehicledetail/5392b978-a22a-48b7-8e52-711105c54a66/',
#  '/vehicledetail/b73c4005-bada-4502-a6f6-d35190b17cc5/',
#  '/vehicledetail/35ba5a1d-c381-4c09-8554-7e8bc6aa3c3d/',
#  '/vehicledetail/ad7b4d70-9770-4dd2-819a-1f97bfe9ad74/',
#  '/vehicledetail/e26eace6-35a9-4bb5-8ff4-554a68ace6e9/',
#  '/vehicledetail/27662b28-bff1-43cb-acce-3bb6229f3ad7/',
#  '/vehicledetail/a4e33362-5538-4d09-b35b-da8ad5d31bad/',
#  '/vehicledetail/4794a1c4-f3e2-4009-a879-6e080d49937a/',
#  '/vehicledetail/460995af-7c5d-46c1-baff-8da3998fc41d/',
#  '/vehicledetail/91ebe580-6ac5-43bd-a86d-2a6095d5eeba/',
#  '/vehicledetail/12dc7aa6-641a-455b-8964-3c87cd537028/']

# %%
url_joined = []

for link_2 in url_part_2:
    url_joined.append(urllib.parse.urljoin(url_part_1, link_2))

# %%
url_joined
# Out:
# ['https://www.cars.com/vehicledetail/540b3cb5-c4f0-4fa1-9c3e-272d1d9c4869/',
#  'https://www.cars.com/vehicledetail/51a11fb3-d15b-4914-a5dc-69aa67aa534e/',
#  'https://www.cars.com/vehicledetail/6562b17a-7c89-4ee1-acc7-574106f56ea2/',
#  'https://www.cars.com/vehicledetail/f22f4a36-4ea5-4f1c-9e34-98e00cd22959/',
#  'https://www.cars.com/vehicledetail/4c89ad70-d8c1-46e4-87c9-5475466bd4dd/',
#  'https://www.cars.com/vehicledetail/36521677-8470-427e-bfe1-41ab44c81553/',
#  'https://www.cars.com/vehicledetail/691e4d6b-b4f1-440e-ac9c-bc256fc31c91/',
#  'https://www.cars.com/vehicledetail/65c9902f-bd10-4c49-aeb9-5a32a0a05aa1/',
#  'https://www.cars.com/vehicledetail/8b228e71-4bc1-4743-ba31-3dc2c9d165a8/',
#  'https://www.cars.com/vehicledetail/5392b978-a22a-48b7-8e52-711105c54a66/',
#  'https://www.cars.com/vehicledetail/b73c4005-bada-4502-a6f6-d35190b17cc5/',
#  'https://www.cars.com/vehicledetail/35ba5a1d-c381-4c09-8554-7e8bc6aa3c3d/',
#  'https://www.cars.com/vehicledetail/ad7b4d70-9770-4dd2-819a-1f97bfe9ad74/',
#  'https://www.cars.com/vehicledetail/e26eace6-35a9-4bb5-8ff4-554a68ace6e9/',
#  'https://www.cars.com/vehicledetail/27662b28-bff1-43cb-acce-3bb6229f3ad7/',
#  'https://www.cars.com/vehicledetail/a4e33362-5538-4d09-b35b-da8ad5d31bad/',
#  'https://www.cars.com/vehicledetail/4794a1c4-f3e2-4009-a879-6e080d49937a/',
#  'https://www.cars.com/vehicledetail/460995af-7c5d-46c1-baff-8da3998fc41d/',
#  'https://www.cars.com/vehicledetail/91ebe580-6ac5-43bd-a86d-2a6095d5eeba/',
#  'https://www.cars.com/vehicledetail/12dc7aa6-641a-455b-8964-3c87cd537028/']

# %% [markdown]
# ### Get Data from First Link

# %%
len(url_joined)
# Out:
# 20

# %% [markdown]
# #### Store first link in variable

# %%
first_link = url_joined[0]

# %%
response = requests.get(first_link, headers=headers)

# %%
soup = BeautifulSoup(response.content, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html class="ep-theme-cars" lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <title>New 2022 Chrysler Pacifica Hybrid Touring L For Sale $49,753 | Cars.com</title>
# <meta content="New 2022 Chrysler Pacifica Hybrid Touring L for sale at Whitten Brothers of Richmond in Richmond, VA for $49,753. View now on Cars.com" name="description"/>
# <meta content="noindex, nofollow" name="robots"/>
# <meta content="Cars.com" property="og:site_name"/>
# <meta content="website" property="og:type"/>
# <meta content="New 2022 Chrysler Pacifica Hybrid Touring L For Sale $49,753 | Cars.com" property="og:title"/>
# <meta content="https://www.cars.com/vehicledetail/540b3cb5-c4f0-4fa1-9c3e-272d1d9c4869" property="og:url"/>
# <meta content="New 2022 Chrysler Pacifica Hybrid Touring L for sale at Whitten Brothers of Richmond in Richmond, VA for $49,753. View now on Cars.com" property="og:description"/>
# <meta content="https://platform.cstatic-images.com/in/v2/187bb31f-e7d6-5818-9925-645dc4d0f8c1/cca371d2-5ff9-4623-a1d7-ba8a32b442f1/OctXu_Lb9Hb44nkUnnnf4egCcPU.jpg" property="og:image"/>
# <meta content="290349283473" property="fb:app_id"/>
# <meta content="app-id=353263352" name="apple-itunes-app"/>
# <meta content="@carsdotcom" name="twitter:site"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="New 2022 Chrysler Pacifica Hybrid Touring L For Sale $49,753 | Cars.com" name="twitter:title"/>
# <meta content="New 2022 Chrysler Pacifica Hybrid Touring L for sale at Whitten Brothers of Richmond in Richmond, VA for $49,753. View now on Cars.com" name="twitter:description"/>
# <meta content="https://platform.cstatic-images.com/in/v2/187bb31f-e7d6-5818-9925-645dc4d0f8c1/cca371d2-5ff9-4623-a1d7-ba8a32b442f1/OctXu_Lb9Hb44nkUnnnf4egCcPU.jpg" name="twitter:image"/>
# <script type="application/ld+json">{"@context":"http://www.schema.org","@type":"WebSite","name":"Cars.com","url":"https://www.cars.com/"}</script>
# <style>
# a,abbr,acronym,address,applet,article,aside,audio,b,big,blockquote,body,button,canvas,caption,center,cite,code,dd,del,details,dfn,div,dl,dt,em,embed,fieldset,figcaption,figure,footer,form,h1,h2,h3,h4,h5,h6,header,hgroup,html,i,iframe,img,ins,kbd,label,legend,li,main,mark,menu,nav,object,ol,output,p,pre,q,ruby,s,samp,section,small,span,strike,strong,sub,summary,sup,table,tbody,td,tfoot,th,thead,time,tr,tt,u,ul,var,video{border:0;font-weight:400;margin:0;padding:0;vertical-align:baseline}article,aside,details,figcaption,figure,footer,header,hgroup,main,menu,nav,section{display:block}body{line-height:1}ol,ul{list-style:none}blockquote,q{quotes:none}blockquote:after,blockquote:before,q:after,q:before{content:"";content:none}table{border-collapse:collapse;border-spacing:0}.sds-checkbox,.sds-radio{display:inline;position:relative}.sds-checkbox:after,.sds-radio:after{content:"\a";white-space:pre}.sds-checkbox+.sds-checkbox,.sds-checkbox+.sds-radio,.sds-radio+.sds-checkbox,.sds-radio+.sds-radio{margin-top:16px}.sds-checkbox .sds-input,.sds-radio .sds-input{height:20px;left:0;opacity:0;position:absolute;top:0;width:20px}.sds-checkbox .sds-input+.sds-label,.sds-checkbox .sds-input+.sds-legend,.sds-radio .sds-input+.sds-label,.sds-radio .sds-input+.sds-legend{-webkit-user-select:none;-moz-user-select:none;user-select:none}.sds-checkbox .sds-input+.sds-label:before,.sds-checkbox .sds-input+.sds-legend:before,.sds-radio .sds-input+.sds-label:before,.sds-radio .sds-input+.sds-legend:before{border:1px solid #bdbdbd;content:"";height:20px;left:0;position:absolute;top:-.1em;width:20px}.sds-checkbox .sds-input:disabled+.sds-label,.sds-checkbox .sds-input:disabled+.sds-legend,.sds-radio .sds-input:disabled+.sds-label,.sds-radio .sds-input:disabled+.sds-legend{cursor:not-allowed;opacity:.4}.sds-checkbox .sds-input.error+.sds-label:before,.sds-checkbox .sds-input.error+.sds-legend:before,.sds-radio .sds-input.error+.sds-label:before,.sds-radio .sds-input.error+.sds-legend:before{border-color:#c10}.sds-checkbox .sds-input:focus+.sds-label:before,.sds-checkbox .sds-input:focus+.sds-legend:before,.sds-radio .sds-input:focus+.sds-label:before,.sds-radio .sds-input:focus+.sds-legend:before{box-shadow:0 0 0 2px #00bfde}.sds-checkbox .sds-input+.sds-label:after,.sds-checkbox .sds-input+.sds-legend:after,.sds-radio .sds-input+.sds-label:after,.sds-radio .sds-input+.sds-legend:after{border:3px solid #000;border-left:0;border-top:0;content:"";height:12px;left:7px;opacity:0;position:absolute;top:1px;transform:rotate(45deg);width:7px}.sds-inverse .sds-checkbox .sds-input+.sds-label:after,.sds-inverse .sds-checkbox .sds-input+.sds-legend:after,.sds-inverse .sds-radio .sds-input+.sds-label:after,.sds-inverse .sds-radio .sds-input+.sds-legend:after{border-color:#fff}.sds-checkbox .sds-input:checked+.sds-label:after,.sds-checkbox .sds-input:checked+.sds-legend:after,.sds-radio .sds-input:checked+.sds-label:after,.sds-radio .sds-input:checked+.sds-legend:after{opacity:1}.sds-checkbox .sds-label,.sds-checkbox .sds-legend,.sds-radio .sds-label,.sds-radio .sds-legend{cursor:pointer;margin:0;padding:0 0 0 32px;position:relative}.sds-checkbox .error~.sds-label,.sds-checkbox .error~.sds-legend,.sds-radio .error~.sds-label,.sds-radio .error~.sds-legend{color:#c10}.sds-checkbox:focus,.sds-radio:focus{outline:2px solid Highlight}@media(-webkit-min-device-pixel-ratio:0){.sds-checkbox:focus,.sds-radio:focus{outline-color:-webkit-focus-ring-color;outline-style:auto}}.sds-template-3-col,.sds-template-filters,.sds-template-sidebar,.sds-template-sidebar-tight{max-width:1170px}@media (min-width:768px){.sds-template-3-col,.sds-template-filters,.sds-template-sidebar,.sds-template-sidebar-tight{margin:0 auto}}@media (min-width:980px){.sds-template-3-col,.sds-template-filters,.sds-template-sidebar,.sds-template-sidebar-tight{display:grid}}html{box-sizing:border-box;height:100%;width:100%}*,:after,:before{-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale;box-sizing: ...
#
#       </style>
# <style>
# .accordion-group{border-bottom:1px solid #e6e6e6}.accordion-header{align-items:center;display:flex;height:48px;justify-content:space-between;min-height:48px}.accordion-header .accordion-section-title{font-size:16px;width:100%}.accordion-header[aria-expanded=true] .accordion-section-icon{transform:rotate(180deg)}.accordion-panel[aria-hidden=true]{display:none}.accordion-panel[aria-hidden=false]{display:flex;flex-direction:column;padding:0 0 16px}.active-filter-tags{margin:0 16px 16px;position:relative}@media (min-width:768px){.active-filter-tags{margin-right:0}}.active-filter-tags .flex-container{display:flex;flex-direction:row;justify-content:space-between}.active-filter-tags .flex-container .show-more-less{align-content:flex-end;display:flex;flex-direction:row;justify-content:flex-start;margin-top:16px}.active-filter-tags .flex-container .show-more-less .sds-text-field__icon{stroke:#b0c!important;margin-left:5px;margin-top:5px}.active-filter-tags .flex-container .show-more-less span{color:#b0c;cursor:pointer}.active-filter-tags .flex-container .clear-all-filter-tags{margin-right:16px;margin-top:16px}.active-filter-tags .flex-container .clear-all-filter-tags span{color:#b0c;cursor:pointer}.active-filter-tags .active-filter-checkbox{display:none}.active-filter-tags .mobile-filtering-by{margin-bottom:16px}@media (min-width:768px){.active-filter-tags .mobile-filtering-by{display:none}}@-webkit-keyframes fadeInAnimation{0%{opacity:0}to{opacity:1}}@keyframes fadeInAnimation{0%{opacity:0}to{opacity:1}}@-webkit-keyframes fadeInZoomLeftAnimation{0%{left:100%;opacity:0}to{left:1%;opacity:1}}@keyframes fadeInZoomLeftAnimation{0%{left:100%;opacity:0}to{left:1%;opacity:1}}@-webkit-keyframes fadeInZoomLeftMobileAnimation{0%{left:100%;opacity:0}to{left:5%;opacity:1}}@keyframes fadeInZoomLeftMobileAnimation{0%{left:100%;opacity:0}to{left:5%;opacity:1}}.drive-in-ad-section{margin:0 auto;padding:0}.drive-in-ad{min-height:1px}.drive-in-ad .drive-in-absolute{-webkit-animation:fadeInAnimation .75s ease 0s 1 normal forwards;animation:fadeInAnimation .75s ease 0s 1 normal forwards;background:url(/images/drive_in_ad_background.png),linear-gradient(180deg,#fff,#e6e6e6);bottom:0;height:112px;left:0;opacity:0;padding:20px 0;position:fixed;width:100%;z-index:7000}@media (min-width:768px){.drive-in-ad .drive-in-absolute{height:130px;padding:0}}.drive-in-ad .drive-in-absolute .drive-in-top-border{background:#00bfde;background:linear-gradient(90deg,#00bfde 0,#00bfde 25%,#532380 0,#532380 50%,#b0c 0,#b0c 75%,#00bfde 0,#00bfde);display:block;height:10px;left:-10px;position:relative;top:-28%;transform:skew(45deg);width:calc(100% + 40px)}@media (min-width:768px){.drive-in-ad .drive-in-absolute .drive-in-top-border{top:0}}.drive-in-ad .drive-in-absolute:before{background-color:#212121;border-radius:0 0 2px 0;color:#fff;content:"Ad";font-size:10px;font-weight:700;left:0;line-height:1;padding:4px 8px 6px 6px;position:absolute;top:0;z-index:1}.drive-in-ad .drive-in-absolute .drive-in-content{align-items:center;color:#212121;display:flex;height:68px;margin:0 auto;max-width:1170px;padding-top:14px;position:relative}@media(min-width:800px){.drive-in-ad .drive-in-absolute .drive-in-content{height:125px}}.drive-in-ad .drive-in-absolute .drive-in-content .drive-in-car{display:block;flex:0 0 175px;height:100%}@media (min-width:768px){.drive-in-ad .drive-in-absolute .drive-in-content .drive-in-car{flex:0 0 200px}}@media (min-width:980px){.drive-in-ad .drive-in-absolute .drive-in-content .drive-in-car{flex:0 0 280px;margin-right:28px}}.drive-in-ad .drive-in-absolute .drive-in-content .drive-in-car img{-webkit-animation:fadeInZoomLeftMobileAnimation 1.75s ease 0s 1 normal forwards;animation:fadeInZoomLeftMobileAnimation 1.75s ease 0s 1 normal forwards;position:absolute;top:-18%;width:130px;z-index:7000}@media (min-width:768px){.drive-in-ad .drive-in-absolute .drive-in-content .drive-in-car img{top:18%;width:140px}}@media (min-width:980px){.drive-in-ad .drive-in-absolute .dr ...
#
#           </style>
# <script defer="" src="/348126e679f08e6d6721/js/app.js?vsn=d"></script>
# <script id="datadog-config" type="application/json">
#     {
#         "clientToken": "pubd9e029f457b6d51b3d399c5b5c8fa7a4",
#         "applicationId": "c7070c7e-6068-4c84-828a-0e3b134e372d",
#         "site": "datadoghq.com",
#         "service": "cars_web",
#         "sampleRate": 1,
#         "trackInteractions": true,
#         "trackFrustrations": true
#
#     }
# </script>
# <script id="datadog-global-context" type="application/json">
# {"env":"production","trip_id":""}
# </script>
# <meta content="NggXJQ8fLBBaChUfYnUsRzwXCRssA0UZaRgKW-FQ8rp-0MHqMFMw_r2_" name="csrf-token"/>
# <script>bazadebezolkohpepadr="919080078"</script><script defer="" src="https://www.cars.com/akam/13/36c80cba" type="text/javascript"></script></head>
# <div hidden="">
# <span id="new-tab-link">Opens website in a new tab</span>
# </div>
# <body>
# <div class="global-header-container">
# <cars-global-header>
# <header class="global-header">
# <section class="container">
# <a class="header-logo" data-activity-rule-type="page-over-page" data-component="header-click" data-linkname="header-home" href="/"><img alt="Cars.com" class="header-logo header-logo__img" src="/images/logo_cars-46214ae902ff93ba8fa2e40fb73dfa02.png?vsn=d"/></a>
# <nav class="">
# <ul class="header-links">
# <li class="header-link"><a data-activity-rule-type="page-over-page" data-component="header-click" data-component-index="1" data-linkname="header-buy" data-nav-link="" href="/shopping/">Cars for Sale</a></li>
# <li class="header-link"><a data-activity-rule-type="page-over-page" data-component="header-click" data-component-index="2" data-linkname="header-research" data-nav-link="" href="/research/">Research &amp; Reviews</a></li>
# <li class="header-link"><a data-activity-rule-type="page-over-page" data-component="header-click" data-component-index="3" data-linkname="header-news" data-nav-link="" href="/news/">News &amp; Videos</a></li>
# <li class="header-link"><a data-activity-rule-type="page-over-page" data-component="header-click" data-component-index="4" data-linkname="header-sell-your-car" data-nav-link="" href="/sell/">Sell Your Car</a></li>
# <li class="header-link"><a data-activity-rule-type="page-over-page" data-component="header-click" data-component-index="5" data-linkname="header-service" data-nav-link="" href="/auto-repair/">Service &amp; Repair</a></li>
# </ul>
# <button aria-haspopup="true" aria-label="navigation menu" class="nav-user-menu-button" data-activity-rule-type="custom" data-linkname="header-menu">
# <ep-svg class="menu-icon" library="cars" name="hamburger"></ep-svg>
# <span class="nav-user-name">
# Menu
#             </span>
# <span class="menu-text">Menu</span>
# </button>
# <div id="google-one-tap">
# <div data-client_id="67273791563-90cd8jqav0pgefmmb4l5732bguvbjapi.apps.googleusercontent.com" data-login_uri="/signin/google_callback/" data-moment_callback="trackGoogleOneTap" data-redirect_path="/vehicledetail/540b3cb5-c4f0-4fa1-9c3e-272d1d9c4869/?redirect_event%5Bsocial_platform%5D=google" id="g_id_onload">
# </div>
# </div>
# </nav>
# <ep-modal class="nav-modal">
# <div class="sds-heading--2" id="menu-heading">
# <span class="nav-user-name">
# Menu
#               </span>
# <span class="menu-text">Menu</span>
# </div>
# <ul class="menu-links">
# <li class="header-link"><a data-activity-rule-type="page-over-page" data-component="header-click" data-component-index="1" data-linkname="header-buy" data-nav-link="" href="/shopping/">Cars for Sale</a></li>
# <li class="header-link"><a data-activity-rule-type="page-over-page" data-component="header-click" data-component-index="2" data-linkname="header-research" data-nav-link="" href="/research/">Research &amp; Reviews</a></li>
# <li class="header-link"><a data-activity-rule-type="page-over-page" data-component="header-click" data-component-index="3" data-linkname="header-news" data-nav-link="" href="/news/">News &amp; Videos</a></li>
# <li class="header-link"><a data-activity-rule-type="page-over-page" data-component="header-click" data-component-index="4" data-linkname="header-sell-your-car" data-nav-link="" href="/sell/">Sell Your Car</a></li>
# <li class="header-link"><a data-activity-rule-type="page-over-page" data-component="header-click" data-component-index="5" data-linkname="header-service" data-nav-link="" href="/auto-repair/">Service &amp; Repair</a></li>
# </ul>
# <ul class="profile-links">
# <li class="profile-link"><a data-activity-rule-type="page-over-page" data-component="header-click" data-component-index="1" data-linkname="header-saved-cars" data-profile-link="" href="/profile/saved-cars/"><ep-svg library="cars" name="heart-empty"></ep-svg>
# Saved Cars</a></li>
# <li class="profile-link"><a data-activity-rule-type="page-over-page" data-component="header-click" data-component-index="2" data-linkname="header-saved-searches" data-profile-link="" href="/profile/saved-searches/"><ep-svg library="cars" name="search"></ep-svg>
# Saved Searches</a></li>
# <li class="profile-link"><a data-activity-rule-type="page-over-page" data-component="header-click" data-component-index="3" data-linkname="header-your-garage" data-profile-link="" href="/profile/your-garage/"><ep-svg library="cars" name="tag"></ep-svg>
# Your Garage</a></li>
# </ul>
# <div class="sign-in-up-out">
# <a class="header-signin sds-button--secondary-dense" content="Sign in" data-activity-rule-type="page-over-page" data-component="sign-in-start" data-linkname="header-sign-in" href="/signin/?redirect_path=%2Fvehicledetail%2F540b3cb5-c4f0-4fa1-9c3e-272d1d9c4869%2F">Sign in</a>
# <a class="header-signup sds-button--dense" content="Create an account" data-activity-rule-type="page-over-page" data-component="sign-up-start" data-linkname="header-sign-up" href="/signup/?redirect_path=%2Fvehicledetail%2F540b3cb5-c4f0-4fa1-9c3e-272d1d9c4869%2F">Create an account</a>
# </div>
# </ep-modal>
# </section>
# </header>
# </cars-global-header>
# <section class="sds-page-section sds-page-section--full open-text-search mobile-search">
# <div class="open-text-search-container">
# <div class="open-text-search-mobile-close-button hidden" tabindex="0">
# <svg class="close-icon" height="40px" width="40px"><use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#close"></use></svg>
# </div>
# <div class="sds-input-container open-text-search-input">
# <div class="sds-text-field open-text-search-input-field">
# <div class="open-text-search-field-mmy open-text-search-field-mmy-mobile">
# <div class="open-text-search-field-container">
# <div class="svg-wrapper-mmy">
# <svg class="svg-icon" height="16" width="16"><use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#search"></use></svg>
# </div>
# <div class="open-text-search-field-input-container">
# <input autocomplete="off" class="sds-text-field input-mmy" id="ae_label2" name="q" tabindex="0" type="text" value=""/>
# </div>
# </div>
# <div class="open-text-search-dropdown mmy-suggestions-drop-down hidden">
# <ul class="mmy-suggestions"></ul>
# </div>
# </div>
# </div>
# <div class="reset-icon-container reset-icon-mmy hidden" tabindex="0">
# <svg height="16" width="16"><use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#close-circle"></use></svg>
# </div>
# </div>
# <div>
# </div></div></section>
# </div>
# <section class="sds-page-container" role="main">
# <div data-qa="notifications-are-here"></div>
# <section class="sds-page-section--full vdp-sticky-bar invisible" id="vdp-sticky-bar">
# <div class="sticky-bar-wrapper">
# <div class="title-row">
# <div class="sticky-bar-title-price">
# <h1 class="sticky-header-listing-title">2022 Chrysler Pacifica Hybrid Touring L</h1>
# <div class="price-section price-section-vehicle-card">
# <span class="primary-price">$49,753</span>
# <span class="secondary-price price-drop">$750 price drop</span>
# </div>
# </div>
# </div>
# <div class="sticky-bar-buttons">
# <div class="save-heart-wrapper" data-phx-session="SFMyNTY.....Z40Z3GaWQMNtjPFzhvKzX8-TfGnx1OoHH0qSSAW4P9A" data-phx-static="SFMyNTY.g2gDaAJhBXQAAAADZAAKYXNzaWduX25ld2pkAAVmbGFzaHQAAAAAZAACaWRtAAAAFHBoeC1GeDByN1FqNDJOOFA3RlJCbgYA7nGqyYMBYgABUYA.KcII0lx9x6XS5DdpjKmnLzQZuWcEADBkpLRMs_hrSWg" id="phx-Fx0r7Qj42N8P7FRB">
# <div></div>
# <div>
# <button class="heart" data-activity-rule-type="custom" data-component="save-vehicle-add" data-hook-heart-id="sticky-bar-heart-vehicle-save-heart" data-index="" data-linkname="save-vehicle-sign-up" data-listing-id="540b3cb5-c4f0-4fa1-9c3e-272d1d9c4869" id="sticky-bar-heart-vehicle-save-heart" onclick="event.preventDefault()" phx-hook="RecordSaveListingAction" phx-target="2" phx-value-is_vdp="true" phx-value-listing_id="540b3cb5-c4f0-4fa1-9c3e-272d1d9c4869">
# <save-listing-wrapper>
# <ep-save reference-id="540b3cb5-c4f0-4fa1-9c3e-272d1d9c4869" variant="button"></ep-save>
# </save-listing-wrapper>
# </button>
# </div>
# </div>
# <div data-phx-session="SFMyNTY....__..._..._...-..._...-...-...-...-...-..._..._..._..._..._..._..._..._...___...__..._..._..._..._..._..._..._ZAAEdHJ1ZXQAAAAEZAAKX19zdHJ1Y3RfX2QAKkVsaXhpci5FbmdpbmUuSW5jZW50aXZlcy5QYXlsb2FkLlN0YWNrSXRlbWQADnN0YWNrX2dyb3VwX2lkYgAA3OJkAAhzdGFja19pZGIAACF__..._..._...___..._ZAAEdHJ1ZXQAAAAEZAAKX19zdHJ1Y3RfX2QAKkVsaXhpci5FbmdpbmUuSW5jZW50aXZlcy5QYXlsb2FkLlN0YWNrSXRlbWQADnN0YWNrX2dyb3VwX2lkYgAA-_ZAAEdHJ1ZXQAAAAEZAAKX19zdHJ1Y3RfX2QAKkVsaXhpci5FbmdpbmUuSW5jZW50aXZlcy5QYXlsb2FkLlN0YWNrSXRlbWQADnN0YWNrX2dyb3VwX2lkYgAA--_ZAAEdHJ1ZXQAAAAEZAAKX19zdHJ1Y3RfX2QAKkVsaXhpci5FbmdpbmUuSW5j ...
# <button class="sds-button--medium" data-activity-rule-type="custom" data-linkname="email-lead-form-vdp" id="modal-trigger" phx-click="open_modal" phx-target="#lead-form-sticky-nav" type="button">Check availability</button>
# <div aria-modal="true" class="sds-modal aria-modal sds-modal-one lead-form-container" id="lead-form-sticky-nav" phx-hook="LeadForm" phx-target="#lead-form-sticky-nav">
# <div class="lead-modal sds-modal__content" phx-click="close" phx-target="#lead-form-sticky-nav" phx-value-close="false">
# <div class="lead-modal sds-modal__content-head">
# <div class="sds-icon--target btn-close" phx-click="reset" phx-target="#lead-form-sticky-nav" role="button">
# <span class="sds-icon">
# <svg height="16" width="16"><use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#close"></use></svg>
# </span>
# </div>
# </div>
# <div class="lead-modal sds-modal__content-body">
# <div class="dealer-section lead-form-top-anchor" id="dealer-section-sticky-sticky">
# <header>
# <h2 class="sds-heading--3 lead-form-heading">Contact seller</h2>
# </header>
# <div class="vehicle-dealer">
# <section class="dealer-phone-section">
# </section>
# </div>
# </div>
# <div class="lead-form" id="lead-form-container-sticky">
# <form action="#" data-index="sticky" data-reset-activity-limit-for="email-lead-error-vdp-inline" id="fields-lead-form-sticky-nav" method="post" phx-change="change" phx-hook="EmailLeadForm" phx-submit="save_lead" phx-target="#lead-form-sticky-nav"><input name="_csrf_token" type="hidden" value="NggXJQ8fLBBaChUfYnUsRzwXCRssA0UZaRgKW-FQ8rp-0MHqMFMw_r2_"/>
# <section data-activity-limit="1" data-activity-rule-type="custom" data-conversion-type="email-lead-error-vdp-inline" data-errorname="email-lead-error-vdp-inline" data-index="sticky">
# <div>
# <div class="sds-field-group">
# <div class="customer-form">
# <div class="first-name">
# <div class="sds-input-container">
# <input class="sds-text-field" data-fs="exclude" id="first_name-modal-sticky" name="lead[first_name]" phx-debounce="blur" placeholder=" " type="text"/>
# <label class="sds-label" for="first_name-modal-sticky">First name</label>
# </div>
# </div>
# <div class="last-name">
# <div class="sds-input-container">
# <input class="sds-text-field" data-fs="exclude" id="last_name-modal-sticky" name="lead[last_name]" phx-debounce="blur" placeholder=" " type="text"/>
# <label class="sds-label" for="last_name-modal-sticky">Last name</label>
# </div>
# </div>
# <div class="email">
# <div class="sds-input-container">
# <input class="sds-text-field" data-emailtype="transact" data-fs="exclude" id="email-modal-sticky" name="lead[email]" phx-debounce="blur" phx-hook="EmailInput" placeholder=" " type="text"/>
# <label class="sds-label" for="email-modal-sticky">Email</label>
# </div>
# </div>
# <div class="phone">
# <div class="sds-input-container">
# <input class="sds-text-field" data-fs="exclude" id="phone-modal-sticky" name="lead[phone]" phx-debounce="blur" phx-hook="PhoneNumber" placeholder=" " type="tel"/>
# <label class="sds-label" for="phone-modal-sticky">Phone (optional)</label>
# </div>
# </div>
# <div class="subject">
# <div class="sds-input-container sds-input-container--dropdown">
# <select class="sds-text-field" id="subject-modal-sticky" name="lead[subject]"><option selected="" value="Check availability">Check availability</option><option value="Check home delivery options">Check home delivery options</option><option value="Request virtual appointment">Request virtual appointment</option><option value="Get a price quote">Get a price quote</option><option value="Schedule a test drive">Schedule a test drive</option><option value="Discuss financing">Discuss financing</option><option value="Ask a question">Ask a question</option></select>
# <label class="sds-label" for="subject-modal-sticky">Subject</label>
# <svg class="sds-text-field__icon" height="16" width="16"><use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#chevron-down"></use></svg>
# </div>
# </div>
# <div class="comments">
# <div class="sds-input-container sds-input-container--textarea">
# <textarea class="sds-text-field comment-box" data-fs="exclude" id="comments-modal-sticky" name="lead[comments]" phx-debounce="blur" placeholder=" ">
# I'd like to know if the New 2022 Chrysler Pacifica Hybrid Touring L you have listed on Cars.com for $49,753 is still available.</textarea>
# <label class="sds-label" for="comments-modal-sticky">Comments</label>
# </div>
# </div>
# </div>
# <div class="sds-field trade-in">
# <div class="sds-field trade-in-checkbox">
# <div class="sds-checkbox trade-in" phx-click="show_trade_in" phx-target="#lead-form-sticky-nav">
# <input class="sds-input" id="trade-in-checkbox-lead-form-sticky-nav" type="checkbox"/>
# <label class="sds-label" for="trade-in-checkbox-lead-form-sticky-nav">I have a trade in</label>
# </div>
# </div>
# <div class="sds-field-group trade-in-form hidden">
# <div class="make">
# <div class="sds-input-container sds-input-container--dropdown">
# <select class="sds-text-field" id="fields-lead-form-sticky-nav_make_select-modal-sticky" name="lead[trade_in][make]"><optgroup label=""><option selected="" value="">Choose a make</option><option value="ac">AC</option><option value="acura">Acura</option><option value="alfa_romeo">Alfa Romeo</option><option value="american_motors">American Motors</option><option value="am_general">Am General</option><option value="aston_martin">Aston Martin</option><option value="auburn">Auburn</option><option value="audi">Audi</option><option value="austin">Austin</option><option value="austin_healey">Austin-Healey</option><option value="avanti_motors">Avanti Motors</option><option value="bentley">Bentley</option><option value="bmw">BMW</option><option value="bricklin">Bricklin</option><option value="bugatti">Bugatti</option><option value="buick">Buick</option><option value="cadillac">Cadillac</option><option value="checker">Checker</option><option value="chevrolet">Chevrolet</option><option value="chrysler">Chrysler</option><option value="citroen">Citroen</option><option value="daewoo">Daewoo</option><option value="daihatsu">Daihatsu</option><option value="datsun">Datsun</option><option value="delahaye">Delahaye</option><option value="delorean">Delorean</option><option value="desoto">Desoto</option><option value="detomaso">DeTomaso</option><option value="dodge">Dodge</option><option value="eagle">Eagle</option><option value="edsel">Edsel</option><option value="essex">Essex</option><option value="ferrari">Ferrari</option><option value="fiat">FIAT</option><option value="fisker">Fisker</option><option value="ford">Ford</option><option value="franklin">Franklin</option><option value="genesis">Genesis</option><option value="geo">Geo</option><option value="gmc">GMC</option><option value="honda">Honda</option><option value="hudson">Hudson</option><option value="hummer">Hummer</option><option value="hupmobile">Hupmobile</option><option value="hyundai">Hyundai</option><option value="infiniti">INFINITI</option><option value="international">International</option><option value="isuzu">Isuzu</option><option value="jaguar">Jaguar</option><option value="jeep">Jeep</option><option value="jensen">Jensen</option><option value="kaiser">Kaiser</option><option value="karma">Karma</option><option value="kia">Kia</option><option value="koenigsegg">Koenigsegg</option><option value="lamborghini">Lamborghini</option><option value="lancia">Lancia</option><option value="land_rover">Land Rover</option><option value="lasalle">LaSalle</option><option value="lexus">Lexus</option><option value="lincoln">Lincoln</option><option value="lotus">Lotus</option><option value="lucid">Lucid</option><option value="maserati">Maserati</option><option value="maybach">Maybach</option><option value="mazda">Mazda</option><option value="mclaren">McLaren</option><option value="mercedes_benz">Mercedes-Benz</option><option value="mercury">Mercury</option><option value="merkur">Merkur</option><option value="mg">MG</option><option value="mini">MINI</option><option value="mitsubishi">Mitsubishi</option><option value="morgan">Morgan</option><option value="morris">Morris</option><option value="nash">Nash</option><option value="nissan">Nissan</option><option value="oldsmobile">Oldsmobile</option><option value="opel">Opel</option><option value="packard">Packard</option><option value="pagani">Pagani</option><option value="panoz">Panoz</option><option value="peugeot">Peugeot</option><option value="plymouth">Plymouth</option><option value="polestar">Polestar</option><option value="pontiac">Pontiac</option><option value="porsche">Porsche</option><option value="qvale">Qvale</option><option value="ram">RAM</option><option value="renault">Renault</option><option value="rivian">Rivian</option><option value="rolls_royce">Rolls-Royce</option><option value="rover">Rover</option><option value="saab">Saab</option><option value="saleen">Saleen</option><option value="saturn">Saturn</option><option value="scion">Scion ...
# <label class="sds-label" for="make_select-modal-sticky">Make</label>
# <svg class="sds-text-field__icon" height="16" width="16"><use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#chevron-down"></use></svg>
# </div>
# </div>
# <div class="model">
# <div class="sds-input-container sds-input-container--dropdown">
# <select class="sds-text-field" disabled="" id="fields-lead-form-sticky-nav_model_select-modal-sticky" name="lead[trade_in][model]"><optgroup label=""><option selected="" value="">Choose a model</option></optgroup></select>
# <label class="sds-label" for="model_select-modal-sticky">Model</label>
# <svg class="sds-text-field__icon" height="16" width="16"><use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#chevron-down"></use></svg>
# </div>
# </div>
# <div class="year">
# <div class="sds-input-container sds-input-container--dropdown">
# <select class="sds-text-field" disabled="" id="fields-lead-form-sticky-nav_year_select-modal-sticky" name="lead[trade_in][year]"><optgroup label=""><option selected="" value="">Choose a year</option></optgroup></select>
# <label class="sds-label" for="year_select-modal-sticky">Year</label>
# <svg class="sds-text-field__icon" height="16" width="16"><use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#chevron-down"></use></svg>
# </div>
# </div>
# <div class="color">
# <div class="sds-input-container">
# <input class="sds-text-field" disabled="" id="color-modal-sticky" name="lead[trade_in][color]" phx-debounce="blur" placeholder=" " type="text" value=""/>
# <label class="sds-label" for="color-modal-sticky">Exterior color</label>
# </div>
# </div>
# <div class="mileage">
# <div class="sds-input-container">
# <input class="sds-text-field" disabled="" id="mileage_string-modal-sticky" name="lead[trade_in][mileage_string]" phx-debounce="blur" phx-hook="Mileage" placeholder=" " type="text" value=""/>
# <label class="sds-label" for="mileage_string-modal-sticky">Mileage</label>
# </div>
# </div>
# <div class="vin">
# <div class="sds-input-container">
# <input class="sds-text-field" disabled="" id="vin-modal-sticky" name="lead[trade_in][vin]" phx-debounce="blur" placeholder=" " type="text" value=""/>
# <label class="sds-label" for="vin-modal-sticky">VIN (optional)</label>
# </div>
# </div>
# </div>
# </div>
# <div class="sds-field section-content">
# <div aria-labelledby="employees-label" class="employees-collection" role="radiogroup">
# <p id="employees-label">Select a Salesperson (optional)</p>
# <div class="employee-wrapper">
# <label aria-hidden="false" class="sds-container employee-container">
# <input data-activity-rule-type="custom" data-linkname="select-employee" id="employee" phx-keyup="toggle_employee_selection" phx-target="#lead-form-sticky-nav" phx-value-id="433035" type="radio" value="433035"/>
# <div class="employee-info" phx-click="toggle_employee_selection" phx-target="#lead-form-sticky-nav" phx-value-id="433035">
# <figure class="sds-author__figure">
# <div class="sds-checkbox">
# <input class="sds-input" type="checkbox" value="433035"/>
# <label class="sds-label" data-activity-rule-type="custom" data-linkname="select-employee">
# </label>
# <img alt="Photo of Jon  Burfoot, Sales Consultant " class="sds-headshot employee-image" loading="lazy" src="https://cdn-user.dealerrater.com/images/dealer/23414/employees/da5e04997d3e.jpg"/>
# <figcaption class="sds-author__caption employee-caption">
# <div><strong>Jon  Burfoot</strong></div>
# <div>Sales Consultant </div>
# <div class="sds-rating">
# <span class="sds-rating__link sds-button-link">(45 reviews)</span>
# </div>
# <a aria-expanded="false" class="sds-reveal__expand sds-link--icon reviews-reveal" data-activity-rule-type="custom" data-linkname="show-employee-reviews" onclick="event.preventDefault()" phx-click="expand_employee_reviews" phx-keyup="expand_employee_reviews" phx-target="#lead-form-sticky-nav" phx-value-id="433035" role="button" tabindex="0">
# <div class="sds-reveal__label">Show reviews</div>
# <svg height="16" width="16"><use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#chevron-down"></use></svg>
# </a>
# </figcaption>
# </div>
# </figure>
# <div class="sds-reveal__hidden sds-container reviews-container">
# </div>
# </div>
# </label>
# </div>
# <div class="employee-wrapper">
# <label aria-hidden="false" class="sds-container employee-container">
# <input data-activity-rule-type="custom" data-linkname="select-employee" id="employee" phx-keyup="toggle_employee_selection" phx-target="#lead-form-sticky-nav" phx-value-id="120546" type="radio" value="120546"/>
# <div class="employee-info" phx-click="toggle_employee_selection" phx-target="#lead-form-sticky-nav" phx-value-id="120546">
# <figure class="sds-author__figure">
# <div class="sds-checkbox">
# <input class="sds-input" type="checkbox" value="120546"/>
# <label class="sds-label" data-activity-rule-type="custom" data-linkname="select-employee">
# </label>
# <img alt="Photo of Margaret Hall, Sales Consultant " class="sds-headshot employee-image" loading="lazy" src="https://cdn-user.dealerrater.com/images/dealer/23414/employees/23e466e57c8e.jpg"/>
# <figcaption class="sds-author__caption employee-caption">
# <div><strong>Margaret Hall</strong></div>
# <div>Sales Consultant </div>
# <div class="sds-rating">
# <span class="sds-rating__link sds-button-link">(45 reviews)</span>
# </div>
# <a aria-expanded="false" class="sds-reveal__expand sds-link--icon reviews-reveal" data-activity-rule-type="custom" data-linkname="show-employee-reviews" onclick="event.preventDefault()" phx-click="expand_employee_reviews" phx-keyup="expand_employee_reviews" phx-target="#lead-form-sticky-nav" phx-value-id="120546" role="button" tabindex="0">
# <div class="sds-reveal__label">Show reviews</div>
# <svg height="16" width="16"><use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#chevron-down"></use></svg>
# </a>
# </figcaption>
# </div>
# </figure>
# <div class="sds-reveal__hidden sds-container reviews-container">
# </div>
# </div>
# </label>
# </div>
# <label aria-hidden="true" class="sds-reveal__hidden sds-container employee-container">
# <input data-activity-rule-type="custom" data-linkname="select-employee" id="employee" phx-keyup="toggle_employee_selection" phx-target="#lead-form-sticky-nav" phx-value-id="433032" type="radio" value="433032"/>
# <div class="employee-info" phx-click="toggle_employee_selection" phx-target="#lead-form-sticky-nav" phx-value-id="433032">
# <figure class="sds-author__figure">
# <div class="sds-checkbox">
# <input class="sds-input" type="checkbox" value="433032"/>
# <label class="sds-label" data-activity-rule-type="custom" data-linkname="select-employee">
# </label>
# <img alt="Photo of Monty Baker, Sales Manager" class="sds-headshot employee-image" loading="lazy" src="https://cdn-user.dealerrater.com/images/dealer/23414/employees/8f2e8c37b9f9.jpg"/>
# <figcaption class="sds-author__caption employee-caption">
# <div><strong>Monty Baker</strong></div>
# <div>Sales Manager</div>
# <div class="sds-rating">
# <span class="sds-rating__link sds-button-link">(44 reviews)</span>
# </div>
# <a aria-expanded="false" class="sds-reveal__expand sds-link--icon reviews-reveal" data-activity-rule-type="custom" data-linkname="show-employee-reviews" onclick="event.preventDefault()" phx-click="expand_employee_reviews" phx-keyup="expand_employee_reviews" phx-target="#lead-form-sticky-nav" phx-value-id="433032" role="button" tabindex="0">
# <div class="sds-reveal__label">Show reviews</div>
# <svg height="16" width="16"><use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#chevron-down"></use></svg>
# </a>
# </figcaption>
# </div>
# </figure>
# <div class="sds-reveal__hidden sds-container reviews-container">
# </div>
# </div>
# </label>
# <label aria-hidden="true" class="sds-reveal__hidden sds-container employee-container">
# <input data-activity-rule-type="custom" data-linkname="select-employee" id="employee" phx-keyup="toggle_employee_selection" phx-target="#lead-form-sticky-nav" phx-value-id="117759" type="radio" value="117759"/>
# <div class="employee-info" phx-click="toggle_employee_selection" phx-target="#lead-form-sticky-nav" phx-value-id="117759">
# <figure class="sds-author__figure">
# <div class="sds-checkbox">
# <input class="sds-input" type="checkbox" value="117759"/>
# <label class="sds-label" data-activity-rule-type="custom" data-linkname="select-employee">
# </label>
# <img alt="Photo of Sheri Brandt, Sales Manager" class="sds-headshot employee-image" loading="lazy" src="https://cdn-user.dealerrater.com/images/dealer/23414/employees/7aca748f5fe4.jpg"/>
# <figcaption class="sds-author__caption employee-caption">
# <div><strong>Sheri Brandt</strong></div>
# <div>Sales Manager</div>
# <div class="sds-rating">
# <span class="sds-rating__link sds-button-link">(41 reviews)</span>
# </div>
# <a aria-expanded="false" class="sds-reveal__expand sds-link--icon reviews-reveal" data-activity-rule-type="custom" data-linkname="show-employee-reviews" onclick="event.preventDefault()" phx-click="expand_employee_reviews" phx-keyup="expand_employee_reviews" phx-target="#lead-form-sticky-nav" phx-value-id="117759" role="button" tabindex="0">
# <div class="sds-reveal__label">Show reviews</div>
# <svg height="16" width="16"><use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#chevron-down"></use></svg>
# </a>
# </figcaption>
# </div>
# </figure>
# <div class="sds-reveal__hidden sds-container reviews-container">
# </div>
# </div>
# </label>
# <label aria-hidden="true" class="sds-reveal__hidden sds-container employee-container">
# <input data-activity-rule-type="custom" data-linkname="select-employee" id="employee" phx-keyup="toggle_employee_selection" phx-target="#lead-form-sticky-nav" phx-value-id="433025" type="radio" value="433025"/>
# <div class="employee-info" phx-click="toggle_employee_selection" phx-target="#lead-form-sticky-nav" phx-value-id="433025">
# <figure class="sds-author__figure">
# <div class="sds-checkbox">
# <input class="sds-input" type="checkbox" value="433025"/>
# <label class="sds-label" data-activity-rule-type="custom" data-linkname="select-employee">
# </label>
# <img alt="Photo of Howard Hall, Sales Consultant " class="sds-headshot employee-image" loading="lazy" src="https://cdn-user.dealerrater.com/images/dealer/23414/employees/0bd245778d88.jpg"/>
# <figcaption class="sds-author__caption employee-caption">
# <div><strong>Howard Hall</strong></div>
# <div>Sales Consultant </div>
# <div class="sds-rating">
# <span class="sds-rating__link sds-button-link">(40 reviews)</span>
# </div>
# <a aria-expanded="false" class="sds-reveal__expand sds-link--icon reviews-reveal" data-activity-rule-type="custom" data-linkname="show-employee-reviews" onclick="event.preventDefault()" phx-click="expand_employee_reviews" phx-keyup="expand_employee_reviews" phx-target="#lead-form-sticky-nav" phx-value-id="433025" role="button" tabindex="0">
# <div class="sds-reveal__label">Show reviews</div>
# <svg height="16" width="16"><use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#chevron-down"></use></svg>
# </a>
# </figcaption>
# </div>
# </figure>
# <div class="sds-reveal__hidden sds-container reviews-container">
# </div>
# </div>
# </label>
# <label aria-hidden="true" class="sds-reveal__hidden sds-container employee-container">
# <input data-activity-rule-type="custom" data-linkname="select-employee" id="employee" phx-keyup="toggle_employee_selection" phx-target="#lead-form-sticky-nav" phx-value-id="120550" type="radio" value="120550"/>
# <div class="employee-info" phx-click="toggle_employee_selection" phx-target="#lead-form-sticky-nav" phx-value-id="120550">
# <figure class="sds-author__figure">
# <div class="sds-checkbox">
# <input class="sds-input" type="checkbox" value="120550"/>
# <label class="sds-label" data-activity-rule-type="custom" data-linkname="select-employee">
# </label>
# <img alt="Photo of Larry Cupp, Sales Consultant " class="sds-headshot employee-image" loading="lazy" src="https://cdn-user.dealerrater.com/images/dealer/23414/employees/f1b9f937-db7e-466e-8d58-5e7a54fa0202.jpg"/>
# <figcaption class="sds-author__caption employee-caption">
# <div><strong>Larry Cupp</strong></div>
# <div>Sales Consultant </div>
# <div class="sds-rating">
# <span class="sds-rating__link sds-button-link">(40 reviews)</span>
# </div>
# <a aria-expanded="false" class="sds-reveal__expand sds-link--icon reviews-reveal" data-activity-rule-type="custom" data-linkname="show-employee-reviews" onclick="event.preventDefault()" phx-click="expand_employee_reviews" phx-keyup="expand_employee_reviews" phx-target="#lead-form-sticky-nav" phx-value-id="120550" role="button" tabindex="0">
# <div class="sds-reveal__label">Show reviews</div>
# <svg height="16" width="16"><use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#chevron-down"></use></svg>
# </a>
# </figcaption>
# </div>
# </figure>
# <div class="sds-reveal__hidden sds-container reviews-container">
# </div>
# </div>
# </label>
# <label aria-hidden="true" class="sds-reveal__hidden sds-container employee-container">
# <input data-activity-rule-type="custom" data-linkname="select-employee" id="employee" phx-keyup="toggle_employee_selection" phx-target="#lead-form-sticky-nav" phx-value-id="575233" type="radio" value="575233"/>
# <div class="employee-info" phx-click="toggle_employee_selection" phx-target="#lead-form-sticky-nav" phx-value-id="575233">
# <figure class="sds-author__figure">
# <div class="sds-checkbox">
# <input class="sds-input" type="checkbox" value="575233"/>
# <label class="sds-label" data-activity-rule-type="custom" data-linkname="select-employee">
# </label>
# <img alt='Photo of Allen " Willie"  Stewart, Sales' class="sds-headshot employee-image" loading="lazy" src="https://cdn-user.dealerrater.com/images/dealer/23414/employees/9961dde89da3.jpg"/>
# <figcaption class="sds-author__caption employee-caption">
# <div><strong>Allen " Willie"  Stewart</strong></div>
# <div>Sales</div>
# <div class="sds-rating">
# <span class="sds-rating__link sds-button-link">(37 reviews)</span>
# </div>
# <a aria-expanded="false" class="sds-reveal__expand sds-link--icon reviews-reveal" data-activity-rule-type="custom" data-linkname="show-employee-reviews" onclick="event.preventDefault()" phx-click="expand_employee_reviews" phx-keyup="expand_employee_reviews" phx-target="#lead-form-sticky-nav" phx-value-id="575233" role="button" tabindex="0">
# <div class="sds-reveal__label">Show reviews</div>
# <svg height="16" width="16"><use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#chevron-down"></use></svg>
# </a>
# </figcaption>
# </div>
# </figure>
# <div class="sds-reveal__hidden sds-container reviews-container">
# </div>
# </div>
# </label>
# <label aria-hidden="true" class="sds-reveal__hidden sds-container employee-container">
# <input data-activity-rule-type="custom" data-linkname="select-employee" id="employee" phx-keyup="toggle_employee_selection" phx-target="#lead-form-sticky-nav" phx-value-id="433050" type="radio" value="433050"/>
# <div class="employee-info" phx-click="toggle_employee_selection" phx-target="#lead-form-sticky-nav" phx-value-id="433050">
# <figure class="sds-author__figure">
# <div class="sds-checkbox">
# <input class="sds-input" type="checkbox" value="433050"/>
# <label class="sds-label" data-activity-rule-type="custom" data-linkname="select-employee">
# </label>
# <img alt="Photo of Ryan Dixon, Internet Sales" class="sds-headshot employee-image" loading="lazy" src="https://cdn-user.dealerrater.com/images/dealer/23414/employees/6b5cf2832743.jpg"/>
# <figcaption class="sds-author__caption employee-caption">
# <div><strong>Ryan Dixon</strong></div>
# <div>Internet Sales</div>
# <div class="sds-rating">
# <span class="sds-rating__link sds-button-link">(37 reviews)</span>
# </div>
# <a aria-expanded="false" class="sds-reveal__expand sds-link--icon reviews-reveal" data-activity-rule-type="custom" data-linkname="show-employee-reviews" onclick="event.preventDefault()" phx-click="expand_employee_reviews" phx-keyup="expand_employee_reviews" phx-target="#lead-form-sticky-nav" phx-value-id="433050" role="button" tabindex="0">
# <div class="sds-reveal__label">Show reviews</div>
# <svg height="16" width="16"><use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#chevron-down"></use></svg>
# </a>
# </figcaption>
# </div>
# </figure>
# <div class="sds-reveal__hidden sds-container reviews-container">
# </div>
# </div>
# </label>
# <label aria-hidden="true" class="sds-reveal__hidden sds-container employee-container">
# ...
# <li><a data-activity-rule-type="page-over-page" data-component="footer-our-company" data-component-index="4" data-linkname="footer-careers" href="/careers/">Careers</a></li>
# <li><a aria-describedby="new-tab-link" aria-label="Licensing &amp; Reprints, External link" class="sds-link--ext" data-activity-rule-type="custom" data-component="footer-our-company" data-component-index="5" data-linkname="footer-licensing-reprints" href="https://info.wrightsmedia.com/cars-licensing-reprints" rel="noopener" target="_blank">Licensing &amp; Reprints<svg class="sds-text-field__icon" height="16" width="16"><use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#arrow-up-right"></use></svg></a></li>
# <li><a data-activity-rule-type="page-over-page" data-component="footer-our-company" data-component-index="6" data-linkname="footer-site-map" href="/sitemap/">Site Map</a></li>
# <li><a data-activity-rule-type="custom" data-component="footer-our-company" data-component-index="7" data-linkname="footer-feedback" data-target="#qualtrics-modal" data-toggle="modal" href="#">Feedback</a></li>
# </ul>
# </div>
# </div>
# <div class="global-footer-group global-footer-apps-and-social">
# <div class="global-footer-social-header">
# <span class="global-footer-heading">Our Mobile App</span>
# </div>
# <div class="global-footer-mobile-apps">
# <a data-activity-rule-type="page-over-page" data-linkname="footer-mobile-apps" href="/mobile/">Download the App Today</a>
# <div class="global-footer-mobile-buttons">
# <a data-activity-rule-type="custom" data-linkname="footer-app-store" href="https://apps.apple.com/us/app/cars-com-new-used-cars/id353263352">
# <img alt="App Store download" class="app-store-button js-lazy-load" data-src="https://beta.cstatic-images.com/medium/in/v2/static/mobile-apps/app-store-badge-us-black-1.png"/>
# </a>
# <a data-activity-rule-type="custom" data-linkname="footer-google-play" href="https://play.google.com/store/apps/details?id=com.cars.android&amp;hl=en_US">
# <img alt="Google Play download" class="google-play-button js-lazy-load" data-src="https://beta.cstatic-images.com/medium/in/v2/static/mobile-apps/google-play-badge-us-1.png"/>
# </a>
# </div>
# </div>
# <div class="global-footer-social-header">
# <span class="global-footer-heading">Connect With Us</span>
# </div>
# <div class="global-footer-social-buttons">
# <ul class="global-footer-list sds-list">
# <li class="social-link"><a aria-describedby="new-tab-link" aria-label="Twitter, External link" class="sds-link--ext sds-button--icon sds-icon--contain twitter" data-activity-rule-type="custom" data-component="footer-social" data-component-index="1" data-linkname="footer-twitter" href="https://twitter.com/carsdotcom" rel="noopener" target="_blank"><svg height="16" width="16"><use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#twitter"></use></svg></a></li>
# <li class="social-link"><a aria-describedby="new-tab-link" aria-label="Facebook, External link" class="sds-link--ext sds-button--icon sds-icon--contain facebook" data-activity-rule-type="custom" data-component="footer-social" data-component-index="2" data-linkname="footer-facebook" href="https://www.facebook.com/CarsDotCom/" rel="noopener" target="_blank"><svg height="16" width="16"><use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#facebook"></use></svg></a></li>
# <li class="social-link"><a aria-describedby="new-tab-link" aria-label="Youtube, External link" class="sds-link--ext sds-button--icon sds-icon--contain youtube" data-activity-rule-type="custom" data-component="footer-social" data-component-index="3" data-linkname="footer-youtube" href="https://www.youtube.com/user/Carscom/" rel="noopener" target="_blank"><svg height="16" width="16"><use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#youtube"></use></svg></a></li>
# <li class="social-link"><a aria-describedby="new-tab-link" aria-label="Instagram, External link" class="sds-link--ext sds-button--icon sds-icon--contain instagram" data-activity-rule-type="custom" data-component="footer-social" data-component-index="4" data-linkname="footer-instagram" href="https://www.instagram.com/carsdotcom/" rel="noopener" target="_blank"><svg height="16" width="16"><use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#instagram"></use></svg></a></li>
# <li class="social-link"><a aria-describedby="new-tab-link" aria-label="Linkedin, External link" class="sds-link--ext sds-button--icon sds-icon--contain linkedin" data-activity-rule-type="custom" data-component="footer-social" data-component-index="5" data-linkname="footer-linkedin" href="https://www.linkedin.com/company/cars-com" rel="noopener" target="_blank"><svg height="16" width="16"><use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#linkedin"></use></svg></a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="global-copyright">
# <div class="sds-container">
# <ul class="sds-list">
# <li><a data-activity-rule-type="page-over-page" data-component="footer-legal" data-component-index="1" data-linkname="footer-tos" href="/about/terms/">Terms of Service</a></li>
# <li><a data-activity-rule-type="page-over-page" data-component="footer-legal" data-component-index="2" data-linkname="footer-privacy-statement" href="/about/privacy/">Privacy Statement</a></li>
# <li><a data-activity-rule-type="page-over-page" data-component="footer-legal" data-component-index="3" data-linkname="footer-personal-information" href="/about/ccpa-privacy-notice/">Do Not Sell My Personal Information</a></li>
# <li><a data-activity-rule-type="page-over-page" data-component="footer-legal" data-component-index="4" data-linkname="footer-accessibility" href="/about/accessibility/">Accessibility Statement</a></li>
# <li><a data-activity-rule-type="page-over-page" data-component="footer-legal" data-component-index="5" data-linkname="footer-ad-choices" href="/about/ad-choices/">Ad Choices</a></li>
# </ul>
# <div class="global-copyright-copy">©
# 2022 Cars.com. All rights reserved.</div>
# </div>
# </div>
# <div aria-modal="true" class="sds-modal sds-modal-one" id="qualtrics-modal">
# <div class="sds-modal__content">
# <div class="sds-modal__content-head sds-modal__content-head">
# <div class="sds-icon--target btn-close js-close" role="button">
# <span class="sds-icon">
# <svg height="16" width="16"><use xlink:href="/svg/spritemap-45f421b6ebaae75d4813e9a2ac89dbe3.svg?vsn=d#close"></use></svg>
# </span>
# </div>
# </div>
# <iframe class="qualtrics-form" data-src="https://cars.qualtrics.com/jfe/form/SV_81Hx3Jkheo8zhmC " height="800px" width="600px"></iframe>
# </div>
# </div>
# </footer>
# <script src="https://prod.embed.conversations.dealerinspire.com/5ad4-da54-58f12"></script>
# <link data-href="/348126e679f08e6d6721/css/common.css?vsn=d" media="print" rel="stylesheet"/>
# <link data-href="/348126e679f08e6d6721/css/shop.css?vsn=d" media="print" rel="stylesheet"/>
# <link data-href="https://fonts.googleapis.com/css?family=Roboto" rel="stylesheet" type="text/css"/>
# <script>
#   window.CARS = window.CARS || {}
#   window.CARS["initialActivity"] = {"market_name":null,"utm_term":null,"sponsored":false,"fuel_type":"Hybrid","bodystyle":"Passenger Van","exterior_color":"Ceramic Gray Clearcoat","trip_id":"","page_detail":null,"listing_id":"540b3cb5-c4f0-4fa1-9c3e-272d1d9c4869","partner_name":"","msrp":"50503","canonical_mmty":"Chrysler:Pacifica Hybrid:Touring L:2022","utm_medium":null,"lat_long":"/","stock_sub":"","useragent":"","utm_campaign":null,"page_channel":"shopping","local_zone":null,"user_state":"anonymous","trim":"Touring L","loginStatus":false,"profileAccountType":null,"aff_code":"national","zip_ip2geo":null,"url_referer":"","mileage":null,"marketing_referral_source":"","facebook_event_id":"dHJpcF9pZD01ODQ5NTk5Zi02NjAyLTRhYzgtOGVhNi1mOWI2YzcxZmM5YzEmdHM9MTY2NTUzNTczNDE0OQ==","utm_content":null,"customer_id":"151464","platform_id":"cars_responsive","year":"2022","marketing_click_id":"","price_badge":null,"vertical_position":"","drivetrain":"Front-wheel Drive","seller_id":null,"model":"Pacifica Hybrid","cat":"hybrid_suv","private_seller":"","price":"49753","designated_market_area_key":null,"dealer_zip":"23235","canonical_mmt":"Chrysler:Pacifica Hybrid:Touring L","dealer_name":"Whitten Brothers of Richmond","badges":["virtual_appt","price_drop_in_cents","home_delivery"],"dealer_dma":"","vin":"2C4RC1L79NR206928","url_base":"","marketing_click_data":null,"utm_source":null,"stock_type":"New","page_key":"vehicle-details","seller_type":"dealership","page_features":["ph"],"interior_color":"Black","photo_count":27,"page_name":"shopping/vehicle-details","cpo_indicator":false,"page_type":"shopping/vehicle-details","search_instance_id":"","make":"Chrysler"}
# </script>
# <script>
#   window.CARS = window.CARS || {}
#   window.CARS["initialAls"] = {"utm_term":null,"als_private_data":"QTEyOEdDTQ.mOQA4eSGL4oP6EBWrIITd8ojg27m4mnx5zFeahcuhDSQPpdowzq2YGLNK68.8klMvDIWKwYN45Wb.48qLlt7it_sX4-0emnzi0aC4Uj_ZK7Mi7560nr0YEsgUjysENr71DkAK6Ut5nECYiamhEcw.t57uHpssom5ja3QZExvskA","bodystyle":"passenger_van","trip_id":"","pdid":null,"adobe_id":null,"roxanne_visitor_id":"","search_zipcode":null,"listing_id":"540b3cb5-c4f0-4fa1-9c3e-272d1d9c4869","msrp":"50503","utm_medium":null,"results_page_count":null,"device_id":null,"useragent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.121 Safari/537.36","utm_campaign":null,"trim":"touring_l","finance_application_id":null,"lead_event_id":null,"aff_code":"national","internet_connection":null,"carrier":null,"facebook_event_id":"dHJpcF9pZD01ODQ5NTk5Zi02NjAyLTRhYzgtOGVhNi1mOWI2YzcxZmM5YzEmdHM9MTY2NTUzNTczNDE0OQ==","utm_content":null,"referer_url":"","customer_id":"151464","platform_id":"cars_responsive","marketing_click_id":"","x_forwarded_for":null,"vertical_position":"","model_year":"2022","horizontal_position":"","external_uuids":null,"longitude":null,"latitude":null,"iframe_location":"","timestamp_utc":1665535734209,"web_page_type_to":"shopping/vehicle-details","facebook_event_intent_id":"capi_viv_event","seller_id":null,"model":"pacifica_hybrid","total_results":null,"app_version":null,"device_model":null,"page_instance_id":"Fx0r7P9mxntgD-wA-Z7i","price":49753,"is_bot":true,"bot_type":"Unknown Bot (B0B1CB20BEBCAE0F191F2D67CC6B7C5E):monitor:Behavior Anomaly;High-Velocity-BOT:100:aggressive","page_url":"https://www.cars.com/vehicledetail/540b3cb5-c4f0-4fa1-9c3e-272d1d9c4869/","results_page_number":null,"incentive_ids":"","device_os":null,"utm_source":null,"stock_type":"new","roxanne_visit_id":"","marketing_click_source":"","profile_user_id":null,"experiment_ids":[{"analytics":{"payload":{"pe":"tnt","tnta":"177914:1:0|0,177914:1:0|2,177914:1:0|1"}},"index":0,"name":"ab_test_2_srp_hp_prod","options":[{"responseTokens":{"activity.id":"177914","activity.name":"Prod | Cars Web | AB Test 5 | SRP, HP, SI, VDP | New Visitors / fourGroups: GroupB","experience.id":"1","experience.name":"Experience B","geo.city":"ashburn","geo.country":"united states","geo.state":"virginia","offer.id":"0","profile.activeActivities":"177914","profile.daysSinceLastVisit":"0","profile.firstDateTime":"1665535734141","profile.fourGroups":"GroupB","profile.isFirstSession":"true","profile.isNewSession":"true","profile.tntId":"dc64fab4-09cd-4581-9df1-6ed235329552","profile.twentyGroups":"Group5","profile.twoGroups":"GroupA","profile.visitNumber":"Place holder: requires new solution"},"sourceType":"target"}]},{"index":1,"name":"ab_test_6_vdp_prod"},{"index":2,"name":"ab_test_11_vdp_prod"}],"results_per_page":null,"cpo_indicator":false,"device_type":"desktop","search_instance_id":null,"upsells":["salesperson_connect","conversations","similar_vehicles","deep_linking_connections"],"web_page_type_from":"","ga_client_id":null,"make":"chrysler"}
# </script>
# <script async="" data-src="https://www.googletagservices.com/tag/js/gpt.js"></script>
# <script>
#   window.googletag = window.googletag || {cmd: []};
#   window.pbjs = window.pbjs || {que: []};
#   window.CARS = window.CARS || {};
#   window.CARS.disableAds = false;
#   window.CARS.disablePrebid = true;
#   window.CARS.isTest = false
# </script>
# <script async="" data-src="https://assets.adobedtm.com/306a737f2df1/a3d882c1ebd5/launch-3edaffcf6794.min.js" id="adobe-launch-script"></script>
# <script async="" data-src="https://d1n00d49gkbray.cloudfront.net/js/cars.js"></script>
# <script async="" data-src="https://accounts.google.com/gsi/client" defer=""></script>
# <script>
#   window.CARS["dispatcher"] = [];
#   window.CARS["dispatcher"].push({"CarsWeb": null})
#
#   window.CARS["dispatcher"].push({"CarsWeb.ListingController": null})
# window.CARS["dispatcher"].push({"CarsWeb.ListingController.show": {"callSourceDniMetadata":{"analytics":{"affCode":"national","ipAddress":"186.104.253.33","platform":"cars_responsive","source":"187bb31f-e7d6-5818-9925-645dc4d0f8c1","sourcePage":"shopping/vehicle-details","sourceUrl":"https://www.cars.com/vehicledetail/540b3cb5-c4f0-4fa1-9c3e-272d1d9c4869/"},"dimensions":{"bodyStyle":["Passenger Van"],"certified":false,"cylCntId":["6"],"drCntId":["4"],"drvTrnId":["Front-wheel Drive"],"extColor":["Ceramic Gray Clearcoat"],"fuelTypeId":["Hybrid"],"intColor":["Black"],"listingId":"540b3cb5-c4f0-4fa1-9c3e-272d1d9c4869","make":["Chrysler"],"mileage":null,"model":["Pacifica Hybrid"],"normFeatureId":["Third Row Seating","Alloy Wheels","Apple CarPlay/Android Auto","Brake Assist","Stability Control","Navigation System","Heated Seats","Heated Steering Wheel","Memory Seat","Backup Camera","Power Liftgate","USB Port"],"price":"49753","stockNumber":"22817","transTypeId":["Automatic CVT"],"trim":["Touring L"],"type":["New"],"vin":"2C4RC1L79NR206928","year":"2022"},"seller":{"id":"187bb31f-e7d6-5818-9925-645dc4d0f8c1","phoneNumber":"(877) 280-0203","zipcode":"23235"},"user":{"city":"Richmond","profileUserId":null,"state":"VA","tripId":""}},"chatWidgetMetadata":{"affId":"national","carsData":{"aff_code":"national","customer_id":151464,"data_version":"1","listing_id":"540b3cb5-c4f0-4fa1-9c3e-272d1d9c4869","make":"Chrysler","model":"Pacifica Hybrid","page_instance_id":"Fx0r7P9mxntgD-wA-Z7i","page_url":"https://www.cars.com/vehicledetail/540b3cb5-c4f0-4fa1-9c3e-272d1d9c4869/","pdid":null,"platform_id":"cars_responsive","price":49753,"search_instance_id":null,"stock_number":"22817","stock_type":"New","trip_id":"","utm_campaign":null,"utm_medium":null,"utm_source":null,"vin":"2C4RC1L79NR206928","web_page_type_from":"shopping/vehicle-details","year":2022}},"chatWidgetProvider":"dealer_inspire","shopperFinancingConfig":{"credit_iq_destination_org_id":"7e1d62f1-2601-e667-d3ab-5ff220bbc8f4","listing_id":"540b3cb5-c4f0-4fa1-9c3e-272d1d9c4869","model_year_id":"85ba0d71-d081-4e55-a5c7-88f25b97b6fe","sdk_url":"https://checkout.creditiq.com/ciq-sdk.js","source_org_id":"87f675b7-c000-414b-87f8-45c5a1555e8c","token_bundle":null,"trim_id":"dee019ed-92f1-474c-ac21-7f19e5f9e53d","trip_id":"","user":{},"vehicleInfo":{"isCertified":false,"make":"Chrysler","mileage":null,"model":"Pacifica Hybrid","salePrice":"49753","trim":"Touring L","type":"new","vin":"2C4RC1L79NR206928","year":"2022"}}}})
#
# </script>
# <div data-id="177914:1:0|0,177914:1:0|2,177914:1:0|1" hidden="" id="tnta-options"></div>
# <div hidden="" id="profile-data">days_since_last_visit: 0, is_first_session: true, is_new_session: true, visit_number: Place holder: requires new solution</div>
# <script id="graphql-config" type="application/json">
#     {
#
#       "apiKey": "5rrmnWVl1MDzPcEnDvEp3Pu101IGXEGo",
#       "url": "https://graph.cars.com/graphql/api"
#     }
#   </script>
# <noscript><img src="https://www.cars.com/akam/13/pixel_36c80cba?a=dD1hNTVlZWY3ODc2Y2MxYzZiODMxNDM0YWEyNWY1ODUxNDBmYTc0YzMzJmpzPW9mZg==" style="visibility: hidden; position: absolute; left: -999px; top: -999px;"/></noscript><script src="/eYlhd0z4z2AUvNOMnLRi/9zuEfzmVz9Yf/FEF2AQ/KSE-ZR/9LYi8B" type="text/javascript"></script></body>
# </html>

# %% [markdown]
# ### New_used

# %%
try:
    new_used = soup.find('p', {'class':'new-used'}).get_text()
except:
    new_used = 'n/a'
new_used
# Out:
# 'New'

# %% [markdown]
# ### Title

# %%
try:
    title = soup.find('h1', {'class':'listing-title'}).get_text()
except:
    title = 'n/a'
title
# Out:
# '2022 Chrysler Pacifica Hybrid Touring L'

# %% [markdown]
# ### Mileage

# %%
try:
    mileage = soup.find('div', {'class':'listing-mileage'}).get_text()
except:
    mileage = 'n/a'
mileage
# Out:
# ' '

# %% [markdown]
# ### Price

# %%
try:
    price = soup.find('span', {'class':'primary-price'}).get_text()
except:
    price = 'n/a'
price
# Out:
# '$49,753'

# %% [markdown]
# ### Exterior_color

# %%
try:
    ext_color = soup.findAll({'dd'})
except:
    ext_color = 'n/a'
a = ext_color[0].get_text()
a
# Out:
# ' Ceramic Gray Clearcoat '

# %% [markdown]
# ### Interior_color

# %%
try:
    int_color = soup.findAll({'dd'})
except:
    int_color = 'n/a'
b = int_color[1].get_text()
b
# Out:
# ' Black '

# %% [markdown]
# ### Drivetrain

# %%
try:
    drivetrain = soup.findAll({'dd'})
except:
    drivetrain = 'n/a'
c = drivetrain[2].get_text()
c
# Out:
# ' Front-wheel Drive '

# %% [markdown]
# ### Fuel_type

# %%
try:
    fuel_type = soup.findAll({'dd'})
except:
    fuel_type = 'n/a'
d = fuel_type[4].get_text()
d
# Out:
# 'Hybrid '

# %% [markdown]
# ### Transmission

# %%
try:
    transmission = soup.findAll({'dd'})
except:
    transmission = 'n/a'
e = transmission[5].get_text()
e
# Out:
# 'Automatic CVT'

# %% [markdown]
# ### Engine

# %%
try:
    engine = soup.findAll({'dd'})
except:
    engine = 'n/a'
f = engine[6].get_text()
f
# Out:
# '3.6L V6 24V MPFI DOHC Hybrid'

# %% [markdown]
# ### Comfort

# %%
try:
    comfort = soup.findAll('span', {'class':'sds-definition-list__value'})
except:
    comfort = 'n/a'
g = comfort[0].get_text()
g
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21820/2570802495.py in <module>
#       3 except:
#       4     comfort = 'n/a'
# ----> 5 g = comfort[0].get_text()
#       6 g
#
# IndexError: list index out of range

# %% [markdown]
# ### Interior_design

# %%
try:
    int_des = soup.findAll('span', {'class':'sds-definition-list__value'})
except:
    int_des = 'n/a'
h = int_des[1].get_text()
h
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21820/132412303.py in <module>
#       3 except:
#       4     int_des = 'n/a'
# ----> 5 h = int_des[1].get_text()
#       6 h
#
# IndexError: list index out of range

# %% [markdown]
# ### Performance

# %%
try:
    performance = soup.findAll('span', {'class':'sds-definition-list__value'})
except:
    performance = 'n/a'
i = performance[2].get_text()
i
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21820/1893154721.py in <module>
#       3 except:
#       4     performance = 'n/a'
# ----> 5 i = performance[2].get_text()
#       6 i
#
# IndexError: list index out of range

# %% [markdown]
# ### Value_for_money

# %%
try:
    vfm = soup.findAll('span', {'class':'sds-definition-list__value'})
except:
    vfm = 'n/a'
j = vfm[3].get_text()
j
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21820/4251305563.py in <module>
#       3 except:
#       4     vfm = 'n/a'
# ----> 5 j = vfm[3].get_text()
#       6 j
#
# IndexError: list index out of range

# %% [markdown]
# ### Exterior_styling

# %%
try:
    ext_sty = soup.findAll('span', {'class':'sds-definition-list__value'})
except:
    ext_sty = 'n/a'
k = ext_sty[4].get_text()
k
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21820/2302130775.py in <module>
#       3 except:
#       4     ext_sty = 'n/a'
# ----> 5 k = ext_sty[4].get_text()
#       6 k
#
# IndexError: list index out of range

# %% [markdown]
# ### Reliability

# %%
try:
    reliability = soup.findAll('span', {'class':'sds-definition-list__value'})
except:
    reliability = 'n/a'
l = reliability[5].get_text()
l
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21820/3393007583.py in <module>
#       3 except:
#       4     reliability = 'n/a'
# ----> 5 l = reliability[5].get_text()
#       6 l
#
# IndexError: list index out of range

# %% [markdown]
# ### Overall_score

# %%
try:
    os = soup.findAll('span', {'class':'sds-rating__count'})
except:
    os = 'n/a'
m = os[1].get_text()
m
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21820/2395896604.py in <module>
#       3 except:
#       4     os = 'n/a'
# ----> 5 m = os[1].get_text()
#       6 m
#
# IndexError: list index out of range

# %% [markdown]
# ### Seller_score

# %%
try:
    ss = soup.findAll('span', {'class':'sds-rating__count'})
except:
    ss = 'n/a'
n = ss[0].get_text()
n
# Out:
# '4.5'

# %% [markdown]
# ### URL

# %%
try:
    url = first_link
except:
    url = 'n/a'
url
# Out:
# 'https://www.cars.com/vehicledetail/540b3cb5-c4f0-4fa1-9c3e-272d1d9c4869/'
